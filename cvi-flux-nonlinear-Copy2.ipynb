# %%
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats, optimize, interpolate
from scipy.optimize import fsolve
from scipy.integrate import odeint
from scipy.integrate import solve_bvp
from scipy.linalg import solve_banded
plt.rcParams.update({'font.size': 18})

# %%
#
# Define function cvi_sim which computes resulting pore radius/gas concentration profiles as a function of CVI process parameters
#

def cvi_nonlinear(Tin,Pin, phi0in, rin, ain,plot_line_color,plot_line_label,dt,variable_plotted): # Temperature, pressure, initial pore diameter, aspect ratio, phase ratio, line color, line label, time stepper, variable to plot (between rp and C). 
    
    
    ###
    # CVI CONDITIONS
    ###
    
    phi0 = phi0in     # Pore diameter, m  
    L = rin*phi0      # Length, m
    nz = 28         # Number of grid points, dimensionless
    h = L/(nz+1)      # Distance between grid points, m
    hh = h**2
    dt = dt           # Time stepper, s

    phii = phi0*np.ones(nz)
    phi = phii
    
    Zrange = np.linspace(0,L/2,nz)           # Grid that represents length of specimen
    alpha = ain                            # Ratio between H2 and MTS concentrations at reactor entrance, dimensionless
    P = Pin                                # Pressure, Pa
    T = Tin                                # Temperature, K
    
    
    R = 8.314                              # Ideal gas constant, J/mol K
    
    CMTS0 = (1/(1+alpha))*(P / (R*T))      # MTS concentration at z=0 (BC), mol/m^3
    CH20 = (alpha/(1+alpha))*(P / (R*T))   # H2 concentration at z=0 (1-CMTS0), mol/m^3,  Fedou1993-2 Eqs. 9-10
    CHCl0 = 0                              # HCl concentration at z=0 (1-CMTS0), mol/m^3
    
    k0 = 3.89e9                            # Reaction rate coefficient, m/s
    Ea = 296e3                             # Activation energy, J/mol
    
    CMTS = CMTS0*np.ones(nz)
    CMTS[0] = CMTS0
    CH2 = CH20*np.ones(nz)                     # Gas phase composition at pore entrance, Fedou1993-2 Eqs. 9-10
    CH2[0] = CH20
    CHCl = CHCl0*np.ones(nz)
    CHCl[0] = CHCl0
    
    Ct0_before_penetration = [CMTS, CH2, CHCl]
    
    khet = k0*np.exp(-Ea/(R*T))
    print('khet_fedou=',khet)
    
    
    #### Walker DFT paper
    # R = 8.617333262e-5
    # T = 1273
    # Ea = 0.918 #mean
    # # Ea = 0.493 #lower bound
    # # Ea = 1.342 #upper bound
    # khet = np.exp(-Ea/(R*T))
    # print("khet_walker=",khet)
    ####
    
    nu = khet*CMTS         # Kinetic law, Fedou1993-2 Eq. 3
    
    dKMTS = 3.97 #m/sK^(1/2)               # Reduced Knudsen coefficient of MTS, m/s K^1/2
    dKH2 = 34.30 #m/sK^(1/2)               # Reduced Knudsen coefficient of H2, m/s K^1/2,  Fedou1993-2 Table I
    dKHCl = 8.03 #m/sK^(1/2)               # Reduced Knudsen coefficient of HCl, m/s K^1/2
    
    DKMTS=dKMTS*phi*(T**0.5)              # Knudsen diffusion coefficient of MTS, m^2/s 
    DKH2=dKH2*phi*(T**0.5)                # Knudsen diffusion coefficient of H2, m^2/s,  Fedou1993-2 Eq. 2
    DKHCl=dKHCl*phi*(T**0.5)              # Knudsen diffusion coefficient of HCl, m^2/s 
    
    # MSiC = 0.04011                       # Molar mass of SiC, kg/mol
    MMTS = 0.149                             # Molar mass of MTS, kg/mol
    MH2 = 2e-3                             # Molar mass of H2, kg/mol,  Fedou1993-2 Table I
    MHCl = 3.65e-2                         # Molar mass of HCl, kg/mol
    
    # rhoSiC = 3217                        # Density of SiC, kg/m^3
    # rhoMTS = 1270
    # rhoH2 = 0.08375
    # rhoHCl = 1048
    
    VSiC = 12.5e-6                         # Specific volume of SiC, m^3/mol,  Fedou1993-2 Section 2.2
    VMTS = 122.7e-6                          # Specific volume of MTS, m^3/mol
    VH2  = 14.3e-6                            # Specific volume of H2, m^3/mol,  Fedou1993-2 Table III
    VHCl = 25.3e-6                          # Specific volume of HCl, m^3/mol
    
    # VMTS = 122.7                          # Specific volume of MTS, cm^3/mol
    # VH2  = 14.3                            # Specific volume of H2, cm^3/mol,  Fedou1993-2 Table III
    # VHCl = 25.3                          # Specific volume of HCl, cm^3/mol
    
    sMTS = -1
    sH2 = 0                               # Stoichiometric coefficients of the chemical elements, Fedou1993-1 Eq. 1 and Fedou1993-2 Eq. 1
    sHCl = 3
    sSiC = 1
    deltas = sMTS + sH2 + sHCl + sSiC             # Sum of coefficients, Fedou1993-1 Eq. 11
    s = [sMTS, sH2, sHCl, sSiC]

    Dij_MTSH2 = 1.360e-3*((T**(3/2))/(P*(VH2**(1/3)+VMTS**(1/3))**2))*(1/MH2 + 1/MMTS)**0.5
    Dij_MTSHCl = 1.360e-3*((T**(3/2))/(P*(VHCl**(1/3)+VMTS**(1/3))**2))*(1/MHCl + 1/MMTS)**0.5   # Gilliland formula, Fedou1993-1 Appendix 1 Eq A4
    
    epsik = 59.7
    sigi = 0.2827e-9
    epsjk = 344.7
    sigj = 0.3339e-9
    sigij = (sigi+sigj)/2
    kepsij = (epsik * epsjk)**(-0.5)
    Tstar = kepsij*T
    Tstar = np.rint(Tstar)
    if Tstar ==7:
        omegaD = 0.79643333
    if Tstar == 8: 
        omegaD = 0.78003333                # Hirschfelder formula, Fedou1993-1 Appendix 1 Eqs. A1-A3; calculation of 
    if Tstar == 9:
        omegaD = 0.76611111
    if Tstar == 10:
        omegaD = 0.75401111
    V = 2.78125e4

    Dij_H2HCl = 5.876e-24  *((T**1.5)/(P*(sigij**2)*V*omegaD))*((1/MH2 + 1/MHCl)**0.5)
    Dij_H2HCl = 1.360e-3*((T**(3/2))/(P*(VHCl**(1/3)+VH2**(1/3))**2))*(1/MHCl + 1/MH2)**0.5 
    # print("dfomega=",Dij_H2HCl, "dfvhcl=",Dij_H2HCl_v2)
    
    N = deltas*nu
    
    xMTS  = CMTS/(CMTS+CH2+CHCl)
    xH2 = CH2/(CMTS+CH2+CHCl)                                     # Molar fractions, Fedou1993-1 Eq. 13                                    
    xHCl = CHCl/(CMTS+CH2+CHCl)
    
    dxMTSdz = dxH2dz = dxHCldz = np.zeros(nz)
    
    # DFMTS = ((1/(1-xMTS[0]))*(xHCl[0]/Dij_MTSHCl + xH2[0]/Dij_MTSH2))**(-1)
    # DFH2 = ((1/(1-xH2[0]))*(xHCl[0]/Dij_H2HCl + xMTS[0]/Dij_MTSH2))**(-1)      # Fick diffusion coefficients, Fedou1993-1 Eq. 16
    # DFHCl = ((1/(1-xHCl[0]))*(xH2[0]/Dij_H2HCl + xMTS[0]/Dij_MTSHCl))**(-1)
    
    DFMTS = ((1/(1-xMTS))*(xHCl/Dij_MTSHCl + xH2/Dij_MTSH2))**(-1)
    DFH2 = ((1/(1-xH2))*(xHCl/Dij_H2HCl + xMTS/Dij_MTSH2))**(-1)      # Fick diffusion coefficients, Fedou1993-1 Eq. 16
    DFHCl = ((1/(1-xHCl))*(xH2/Dij_H2HCl + xMTS/Dij_MTSHCl))**(-1)

    DMTS = (1/DFMTS + 1/DKMTS)**(-1)          
    DH2 = (1/DFH2 + 1/DKH2)**(-1)          # Overall diffusion coefficient, Fedou1993-1 Eq. 15
    DHCl = (1/DFHCl + 1/DKHCl)**(-1) 
    
    ###
    # INITIALIZE SOLUTION VECTORS
    ###
    
    Csol = []
    Dsol = []
    for k in range(nz):
        Dsol = np.append(Dsol,DMTS[k])
        Dsol = np.append(Dsol,DH2[k])  # D matrix
        Dsol = np.append(Dsol,DHCl[k])
        Csol = np.append(Csol,CMTS[k])
        Csol = np.append(Csol,CH2[k])  # C matrix
        Csol = np.append(Csol,CHCl[k])
    C0sol = Csol

    print('----------------------------------T=',T,'P=',P, 'CMTS0=',CMTS0,'CH20=',CH20,'CHCl0=',CHCl0)

    
    CMTSt = []                             
    CH2t = []                              # Array containing gas concentration profiles of MTS, H2, HCl
    CHClt = []
    
    phit = []
    rpt = []
    
    percent_closed = 0                     # Dimensionless rating of pore size relative to initial pore size
    counter =0                             # Time counter
    
    
    ###
    # NONLINEAR ITERATIVE SOLVER
    ###
    
    while any(phi<phi0/100) is not True:
        
        # Assemble D, C matrices so that (gas,gridpt)=(i,j) = Cm[3j+i]. Gases\in [0,2] = [MTS, H2, HCl]. Gridpts\in [0,n+1]
        # So C_{1,j} = C_{2,5} = C[3*5 + 2 = C[17].
        Csol = []
        Dsol = []
        
        for k in range(nz):
            Dsol = np.append(Dsol,DMTS[k])
            Dsol = np.append(Dsol,DH2[k])  # D matrix
            Dsol = np.append(Dsol,DHCl[k])
            Csol = np.append(Csol,CMTS[k])
            Csol = np.append(Csol,CH2[k])  # C matrix
            Csol = np.append(Csol,CHCl[k])
        # if counter==0:
        #     print('C=',Csol.size,'D=',Dsol.size)
        #     print(Csol,Dsol)
        
        def F(C, *data_args):
            D, h, hh, N, s, nu, phi = data_args
            exps = []
            n = nz-2
            for j in range(1,n+1): #1\leq j\leq n. #nz=7--> j=1,2,3,4,5     
                # print(C.size)
                # print(j)
                if j==1:
                    xi_jp1 = C[3]/(C[3]+C[4]+C[5])
                    xi_jm1 = CMTS0/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CMTS0 - 2*C[0] + C[3])/hh - (xi_jp1*N[2]-xi_jm1*N[0])/(2*D[0]*h) + (4*s[0]*nu[0])/(D[0]*phi[0]))
                    # print("exps1=",exps.size)
                    
                    xi_jp1 = C[4]/(C[4]+C[5]+C[3])
                    xi_jm1 = CH20/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CH20 - 2*C[1] + C[4])/hh - ((xi_jp1*N[2]-xi_jm1*N[0])/(2*D[1]*h)) + (4*s[1]*nu[0])/(D[1]*phi[0]))
                    # print("exps2=",exps.size)
                    
                    xi_jp1 = C[5]/(C[5]+C[4]+C[3])
                    xi_jm1 = CHCl0/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CHCl0 - 2*C[2] + C[5])/hh - ((xi_jp1*N[2]-xi_jm1*N[0])/(2*D[2]*h)) + (4*s[2]*nu[0])/(D[2]*phi[0]))
                    # print("exps3=",exps.size)
                    
                if not j==1 and not j==n: #j=2,3,4
                    for i in range(3): #i=0,1,2
                        if i==0: #defining molar fractions for each gas i. MTS
                            xi_jp1 = C[3*j]/(C[3*j]+C[3*j+1]+C[3*j+2])
                            xi_jm1 = C[3*(j-2)]/(C[3*(j-2)]+C[3*(j-2)+1]+C[3*(j-2)+2])
                        if i==1: #H2
                            xi_jp1 = C[3*j+1]/(C[3*j+1]+C[3*j+2]+C[3*j])
                            xi_jm1 = C[3*(j-2)+1]/(C[3*(j-2)+1]+C[3*(j-2)+2]+C[3*(j-2)])
                        if i==2: #HCl
                            xi_jp1 = C[3*j+2]/(C[3*j+2]+C[3*j+1]+C[3*j])
                            xi_jm1 = C[3*(j-2)+2]/(C[3*(j-2)+2]+C[3*(j-2)+1]+C[3*(j-2)])

                        expij = (C[3*(j-2)+i] - 2*C[3*(j-1)+i] + C[3*j+i])/hh - (xi_jp1*N[j+1]-xi_jm1*N[j-1])/(2*D[3*(j-1)+i]*h) + (4*s[i]*nu[j-1])/(D[3*(j-1)+i]*phi[j-1])
                        exps = np.append(exps, expij)
                        # print("exps4=",exps.size)
                        
                if j==n: #j=5,
                    for i in range(3):
                        if i==0: #defining molar fractions for each gas i. MTS
                            xi_jp1 = C[3*(n-1)]/(C[3*(n-1)]+C[3*(n-1)+1]+C[3*(n-1)+2])
                            xi_jm1 = C[3*(n-2)]/(C[3*(n-2)]+C[3*(n-2)+1]+C[3*(n-2)+2])
                        if i==1: #H2
                            xi_jp1 = C[3*(n-1)+1]/(C[3*(n-1)+1]+C[3*(n-1)+2]+C[3*(n-1)])
                            xi_jm1 = C[3*(n-2)+1]/(C[3*(n-2)+1]+C[3*(n-2)+2]+C[3*(n-2)])
                        if i==2: #HCl
                            xi_jp1 = C[3*(n-1)+2]/(C[3*(n-1)+2]+C[3*(n-1)+1]+C[3*(n-1)])
                            xi_jm1 = C[3*(n-2)+2]/(C[3*(n-2)+2]+C[3*(n-2)+1]+C[3*(n-2)])

                        expij = (C[3*(n-2)+i] - C[3*(n-1)+i])/hh - (xi_jp1*N[n+1]-xi_jm1*N[n-1])/(2*D[3*(n-1)+i]*h) + (4*s[i]*nu[n-1])/(D[3*(n-1)+i]*phi[n-1])
                        exps = np.append(exps, expij)
            return exps
        
        data_args = (Dsol[3:-3], h, hh, N, s, nu[1:-1], phi[1:-1])
        Csol = fsolve(F, C0sol[3:-3], args=data_args)
        Csol = np.insert(Csol, 0, CHCl0)
        Csol = np.insert(Csol, 0, CH20)           # left boundary condition
        Csol = np.insert(Csol, 0, CMTS0)
        for _ in range(3):
            Csol = np.append(Csol, Csol[-3])      # right boundary condition
            
        CMTS = Csol[0::3]
        CH2 = Csol[1::3]
        CHCl = Csol[2::3]
    
        # khet = k0*np.exp(-Ea/(R*T))
        # khet =
    
        nu = khet*CMTS                            # Kinetic law, Fedou1993-2 Eq. 3
        N = deltas*nu 
        phi = phi - (2*dt*nu*VSiC)                # Update pore diameter

        DFMTS = ((1/(1-xMTS))*(xHCl/Dij_MTSHCl + xH2/Dij_MTSH2))**(-1)
        DFH2 = ((1/(1-xH2))*(xHCl/Dij_H2HCl + xMTS/Dij_MTSH2))**(-1)     # Update Fick diffusion coefficients, Fedou1993-1 Eq. 16
        DFHCl = ((1/(1-xHCl))*(xH2/Dij_H2HCl + xMTS/Dij_MTSHCl))**(-1)
        
        DKMTS = dKMTS*phi*(T**0.5)
        DKH2 = dKH2*phi*(T**0.5)                                      # Update Knudsen diffusion coefficients, Fedou1993-2 Eq. 2
        DKHCl = dKHCl*phi*(T**0.5)

        DMTS = (1/DFMTS + 1/DKMTS)**(-1)          
        DH2 = (1/DFH2 + 1/DKH2)**(-1)                                    # Update overall diffusion coefficient, Fedou1993-1 Eq. 15
        DHCl = (1/DFHCl + 1/DKHCl)**(-1)              

        
        counter+=1
        rpt.append(phi[0]/2)
        if counter % 10 == 0:
            # print(rpt)
            CMTSt.append(CMTS)
            CH2t.append(CH2) # Collect pore diameter/gas concentration profiles at current time step
            CHClt.append(CHCl)
            # print("nu=",nu[0:3],"CMTS=",CMTS[0:3])
            phit.append(phi)
            percent_closed = 100*(1 -(phi[0]-phi0/100)/phi0)
            print('counter=',counter,': at t =',round(counter*dt*0.000277778,2),'hours, pore is', round(percent_closed,2),'% closed')
    print(counter) 
    t_f_hrs = counter*dt*0.000277778
    t_f_secs = counter*dt
    d = (phii-phi)/2
    # print('phi=',phi,'CMTS=', CMTS)
    
    counter_t = np.arange(0,counter,dt)
    # print('counter_t=',counter_t)
    # print(np.shape(counter_t), np.shape(rpt))
    
    
    ###
    # MOOSE DAMAGE INPUT
    ###
    
    rp = phi/2
    porosity = 0.95
    RpRVE = np.sqrt(1/porosity)*(phi0/2)

    # print('rp=',rp)
    xi = (rp**2)/(RpRVE**2)
    
    mesh_height = 7.5e-5
    num_elements = 28 #ideally =nz
    element_positions = np.linspace(0, mesh_height, num_elements)  
    
    moose_input_i = ''
    par_input = ''
    for q in range(num_elements-1):
        moose_input = str(moose_input_i)+'if(y>='+str(element_positions[num_elements-2-q])+', '+str(xi[q])+', '
        moose_input_i = moose_input
        par_input = str(par_input)+')'
    moose_input = str(moose_input_i)+' 0'+str(par_input)
    
    print('xi=',xi)
    print('moose input for damage is: ',moose_input)

    

    
    
    
    return [Zrange, CMTS,CH2,CHCl, phi, d, L, str(plot_line_label), rp, xi, khet, t_f_hrs, t_f_secs, rpt, counter_t, moose_input]

# %%
#
# Call the function cvi_sim
#

# Inputs: Temperature (K), pressure (Pa), pore diameter (m), aspect ratio, gas ratio,      ...
#         plot line color, plot line label, dt, variable to be plotted between "phi" or "C".

# %%
b = cvi_nonlinear(1273,20000,100e-6, 100, 1, '','',1,'')
c = cvi_nonlinear(1223,20000,100e-6, 100, 1, '','',1,'')
d = cvi_nonlinear(1173,20000,100e-6, 100, 1, '','',1,'')
f = cvi_nonlinear(1123,20000,100e-6, 100, 1, '','',1,'')
g = cvi_nonlinear(1073,20000,100e-6, 100, 1, '','',1,'')
# Out:
# khet_fedou= 0.0027786172881957174
# ----------------------------------T= 1273 P= 20000 CMTS0= 0.9448471908086777 CH20= 0.9448471908086777 CHCl0= 0
# counter= 10 : at t = 0.0 hours, pore is 1.66 % closed
# counter= 20 : at t = 0.01 hours, pore is 2.31 % closed
# counter= 30 : at t = 0.01 hours, pore is 2.97 % closed
# counter= 40 : at t = 0.01 hours, pore is 3.63 % closed
# counter= 50 : at t = 0.01 hours, pore is 4.28 % closed
# counter= 60 : at t = 0.02 hours, pore is 4.94 % closed
# counter= 70 : at t = 0.02 hours, pore is 5.59 % closed
# counter= 80 : at t = 0.02 hours, pore is 6.25 % closed
# counter= 90 : at t = 0.03 hours, pore is 6.91 % closed
# counter= 100 : at t = 0.03 hours, pore is 7.56 % closed
# counter= 110 : at t = 0.03 hours, pore is 8.22 % closed
# counter= 120 : at t = 0.03 hours, pore is 8.88 % closed
# counter= 130 : at t = 0.04 hours, pore is 9.53 % closed
# counter= 140 : at t = 0.04 hours, pore is 10.19 % closed
# counter= 150 : at t = 0.04 hours, pore is 10.85 % closed
# counter= 160 : at t = 0.04 hours, pore is 11.5 % closed
# counter= 170 : at t = 0.05 hours, pore is 12.16 % closed
# counter= 180 : at t = 0.05 hours, pore is 12.81 % closed
# counter= 190 : at t = 0.05 hours, pore is 13.47 % closed
# counter= 200 : at t = 0.06 hours, pore is 14.13 % closed
# counter= 210 : at t = 0.06 hours, pore is 14.78 % closed
# counter= 220 : at t = 0.06 hours, pore is 15.44 % closed
# counter= 230 : at t = 0.06 hours, pore is 16.1 % closed
# counter= 240 : at t = 0.07 hours, pore is 16.75 % closed
# counter= 250 : at t = 0.07 hours, pore is 17.41 % closed
# counter= 260 : at t = 0.07 hours, pore is 18.06 % closed
# counter= 270 : at t = 0.08 hours, pore is 18.72 % closed
# counter= 280 : at t = 0.08 hours, pore is 19.38 % closed
# counter= 290 : at t = 0.08 hours, pore is 20.03 % closed
# counter= 300 : at t = 0.08 hours, pore is 20.69 % closed
# counter= 310 : at t = 0.09 hours, pore is 21.35 % closed
# counter= 320 : at t = 0.09 hours, pore is 22.0 % closed
# counter= 330 : at t = 0.09 hours, pore is 22.66 % closed
# counter= 340 : at t = 0.09 hours, pore is 23.32 % closed
# counter= 350 : at t = 0.1 hours, pore is 23.97 % closed
# counter= 360 : at t = 0.1 hours, pore is 24.63 % closed
# counter= 370 : at t = 0.1 hours, pore is 25.28 % closed
# counter= 380 : at t = 0.11 hours, pore is 25.94 % closed
# counter= 390 : at t = 0.11 hours, pore is 26.6 % closed
# counter= 400 : at t = 0.11 hours, pore is 27.25 % closed
# counter= 410 : at t = 0.11 hours, pore is 27.91 % closed
# counter= 420 : at t = 0.12 hours, pore is 28.57 % closed
# counter= 430 : at t = 0.12 hours, pore is 29.22 % closed
# counter= 440 : at t = 0.12 hours, pore is 29.88 % closed
# counter= 450 : at t = 0.13 hours, pore is 30.54 % closed
# counter= 460 : at t = 0.13 hours, pore is 31.19 % closed
# counter= 470 : at t = 0.13 hours, pore is 31.85 % closed
# counter= 480 : at t = 0.13 hours, pore is 32.5 % closed
# counter= 490 : at t = 0.14 hours, pore is 33.16 % closed
# counter= 500 : at t = 0.14 hours, pore is 33.82 % closed
# counter= 510 : at t = 0.14 hours, pore is 34.47 % closed
# counter= 520 : at t = 0.14 hours, pore is 35.13 % closed
# counter= 530 : at t = 0.15 hours, pore is 35.79 % closed
# counter= 540 : at t = 0.15 hours, pore is 36.44 % closed
# counter= 550 : at t = 0.15 hours, pore is 37.1 % closed
# counter= 560 : at t = 0.16 hours, pore is 37.76 % closed
# counter= 570 : at t = 0.16 hours, pore is 38.41 % closed
# counter= 580 : at t = 0.16 hours, pore is 39.07 % closed
# counter= 590 : at t = 0.16 hours, pore is 39.72 % closed
# counter= 600 : at t = 0.17 hours, pore is 40.38 % closed
# counter= 610 : at t = 0.17 hours, pore is 41.04 % closed
# counter= 620 : at t = 0.17 hours, pore is 41.69 % closed
# counter= 630 : at t = 0.18 hours, pore is 42.35 % closed
# counter= 640 : at t = 0.18 hours, pore is 43.01 % closed
# counter= 650 : at t = 0.18 hours, pore is 43.66 % closed
# counter= 660 : at t = 0.18 hours, pore is 44.32 % closed
# counter= 670 : at t = 0.19 hours, pore is 44.97 % closed
# counter= 680 : at t = 0.19 hours, pore is 45.63 % closed
# counter= 690 : at t = 0.19 hours, pore is 46.29 % closed
# counter= 700 : at t = 0.19 hours, pore is 46.94 % closed
# counter= 710 : at t = 0.2 hours, pore is 47.6 % closed
# counter= 720 : at t = 0.2 hours, pore is 48.26 % closed
# counter= 730 : at t = 0.2 hours, pore is 48.91 % closed
# counter= 740 : at t = 0.21 hours, pore is 49.57 % closed
# counter= 750 : at t = 0.21 hours, pore is 50.23 % closed
# counter= 760 : at t = 0.21 hours, pore is 50.88 % closed
# counter= 770 : at t = 0.21 hours, pore is 51.54 % closed
# counter= 780 : at t = 0.22 hours, pore is 52.19 % closed
# counter= 790 : at t = 0.22 hours, pore is 52.85 % closed
# counter= 800 : at t = 0.22 hours, pore is 53.51 % closed
# counter= 810 : at t = 0.23 hours, pore is 54.16 % closed
# counter= 820 : at t = 0.23 hours, pore is 54.82 % closed
# counter= 830 : at t = 0.23 hours, pore is 55.48 % closed
# counter= 840 : at t = 0.23 hours, pore is 56.13 % closed
# counter= 850 : at t = 0.24 hours, pore is 56.79 % closed
# counter= 860 : at t = 0.24 hours, pore is 57.45 % closed
# counter= 870 : at t = 0.24 hours, pore is 58.1 % closed
# counter= 880 : at t = 0.24 hours, pore is 58.76 % closed
# counter= 890 : at t = 0.25 hours, pore is 59.41 % closed
# counter= 900 : at t = 0.25 hours, pore is 60.07 % closed
# counter= 910 : at t = 0.25 hours, pore is 60.73 % closed
# counter= 920 : at t = 0.26 hours, pore is 61.38 % closed
# counter= 930 : at t = 0.26 hours, pore is 62.04 % closed
# counter= 940 : at t = 0.26 hours, pore is 62.7 % closed
# counter= 950 : at t = 0.26 hours, pore is 63.35 % closed
# counter= 960 : at t = 0.27 hours, pore is 64.01 % closed
# counter= 970 : at t = 0.27 hours, pore is 64.67 % closed
# counter= 980 : at t = 0.27 hours, pore is 65.32 % closed
# counter= 990 : at t = 0.28 hours, pore is 65.98 % closed
# counter= 1000 : at t = 0.28 hours, pore is 66.63 % closed
# counter= 1010 : at t = 0.28 hours, pore is 67.29 % closed
# counter= 1020 : at t = 0.28 hours, pore is 67.95 % closed
# counter= 1030 : at t = 0.29 hours, pore is 68.6 % closed
# counter= 1040 : at t = 0.29 hours, pore is 69.26 % closed
# counter= 1050 : at t = 0.29 hours, pore is 69.92 % closed
# counter= 1060 : at t = 0.29 hours, pore is 70.57 % closed
# counter= 1070 : at t = 0.3 hours, pore is 71.23 % closed
# counter= 1080 : at t = 0.3 hours, pore is 71.88 % closed
# counter= 1090 : at t = 0.3 hours, pore is 72.54 % closed
# counter= 1100 : at t = 0.31 hours, pore is 73.2 % closed
# counter= 1110 : at t = 0.31 hours, pore is 73.85 % closed
# counter= 1120 : at t = 0.31 hours, pore is 74.51 % closed
# counter= 1130 : at t = 0.31 hours, pore is 75.17 % closed
# counter= 1140 : at t = 0.32 hours, pore is 75.82 % closed
# counter= 1150 : at t = 0.32 hours, pore is 76.48 % closed
# counter= 1160 : at t = 0.32 hours, pore is 77.14 % closed
# counter= 1170 : at t = 0.33 hours, pore is 77.79 % closed
# counter= 1180 : at t = 0.33 hours, pore is 78.45 % closed
# counter= 1190 : at t = 0.33 hours, pore is 79.1 % closed
# counter= 1200 : at t = 0.33 hours, pore is 79.76 % closed
# counter= 1210 : at t = 0.34 hours, pore is 80.42 % closed
# counter= 1220 : at t = 0.34 hours, pore is 81.07 % closed
# counter= 1230 : at t = 0.34 hours, pore is 81.73 % closed
# counter= 1240 : at t = 0.34 hours, pore is 82.39 % closed
# counter= 1250 : at t = 0.35 hours, pore is 83.04 % closed
# counter= 1260 : at t = 0.35 hours, pore is 83.7 % closed
# counter= 1270 : at t = 0.35 hours, pore is 84.36 % closed
# counter= 1280 : at t = 0.36 hours, pore is 85.01 % closed
# counter= 1290 : at t = 0.36 hours, pore is 85.67 % closed
# counter= 1300 : at t = 0.36 hours, pore is 86.32 % closed
# counter= 1310 : at t = 0.36 hours, pore is 86.98 % closed
# counter= 1320 : at t = 0.37 hours, pore is 87.64 % closed
# counter= 1330 : at t = 0.37 hours, pore is 88.29 % closed
# counter= 1340 : at t = 0.37 hours, pore is 88.95 % closed
# counter= 1350 : at t = 0.38 hours, pore is 89.61 % closed
# counter= 1360 : at t = 0.38 hours, pore is 90.26 % closed
# counter= 1370 : at t = 0.38 hours, pore is 90.92 % closed
# counter= 1380 : at t = 0.38 hours, pore is 91.58 % closed
# counter= 1390 : at t = 0.39 hours, pore is 92.23 % closed
# counter= 1400 : at t = 0.39 hours, pore is 92.89 % closed
# counter= 1410 : at t = 0.39 hours, pore is 93.54 % closed
# counter= 1420 : at t = 0.39 hours, pore is 94.2 % closed
# counter= 1430 : at t = 0.4 hours, pore is 94.86 % closed
# counter= 1440 : at t = 0.4 hours, pore is 95.51 % closed
# counter= 1450 : at t = 0.4 hours, pore is 96.17 % closed
# counter= 1460 : at t = 0.41 hours, pore is 96.83 % closed
# counter= 1470 : at t = 0.41 hours, pore is 97.48 % closed
# counter= 1480 : at t = 0.41 hours, pore is 98.14 % closed
# counter= 1490 : at t = 0.41 hours, pore is 98.79 % closed
# counter= 1500 : at t = 0.42 hours, pore is 99.45 % closed
# 1509
# xi= [8.71810853e-05 6.64329034e-03 2.04027293e-02 3.90681487e-02
#  6.12526420e-02 8.59408834e-02 1.12391193e-01 1.40009913e-01
#  1.68289040e-01 1.96804374e-01 2.25194934e-01 2.53150256e-01
#  2.80401316e-01 3.06713759e-01 3.31882720e-01 3.55728772e-01
#  3.78094720e-01 3.98843010e-01 4.17853620e-01 4.35022330e-01
#  4.50259271e-01 4.63487697e-01 4.74642919e-01 4.83671325e-01
#  4.90529422e-01 4.95182762e-01 4.97609130e-01 4.97609130e-01]
# moose input for damage is:  if(y>=7.222222222222222e-05, 8.718108529269773e-05, if(y>=6.944444444444443e-05, 0.0066432903441989155, if(y>=6.666666666666666e-05, 0.020402729346200944, if(y>=6.388888888888888e-05, 0.0390681487456089, if(y>=6.111111111111111e-05, 0.061252641951366565, if(y>=5.8333333333333326e-05, 0.08594088341261995, if(y>=5.555555555555555e-05, 0.11239119348149514, if(y>=5.277777777777777e-05, 0.14000991269640148, if(y>=4.9999999999999996e-05, 0.16828904045514925, if(y>=4.7222222222222214e-05, 0.1968043742469324, if(y>=4.444444444444444e-05, 0.2251949336976136, if(y>=4.1666666666666665e-05, 0.25315025593433693, if(y>=3.8888888888888884e-05, 0.28040131616503605, if(y>=3.611111111111111e-05, 0.30671375946482554, if(y>=3.333333333333333e-05, 0.3318827196238868, if(y>=3.0555555555555554e-05, 0.3557287720158366, if(y>=2.7777777777777776e-05, 0.3780947202249567, if(y>=2.4999999999999998e-05, 0.39884300952562146, if(y>=2.222222222222222e-05, 0.41785361991827624, if(y>=1.9444444444444442e-05, 0.43502233038497434, if(y>=1.6666666666666664e-05, 0.4502592713410828, if(y>=1.3888888888888888e-05, 0.4634876974044037, if(y>=1.111111111111111e-05, 0.4746429186667161, if(y>=8.333333333333332e-06, 0.4836713249224475, if(y>=5.555555555555555e-06, 0.4905294220214059, if(y>=2.7777777777777775e-06, 0.4951827620151176, if(y>=0.0, 0.4976091300522197,  0)))))))))))))))))))))))))))
# khet_fedou= 0.0008856415234400061
# ----------------------------------T= 1223 P= 20000 CMTS0= 0.9834754488139383 CH20= 0.9834754488139383 CHCl0= 0
# counter= 10 : at t = 0.0 hours, pore is 1.22 % closed
# counter= 20 : at t = 0.01 hours, pore is 1.44 % closed
# counter= 30 : at t = 0.01 hours, pore is 1.65 % closed
# counter= 40 : at t = 0.01 hours, pore is 1.87 % closed
# counter= 50 : at t = 0.01 hours, pore is 2.09 % closed
# counter= 60 : at t = 0.02 hours, pore is 2.31 % closed
# counter= 70 : at t = 0.02 hours, pore is 2.52 % closed
# counter= 80 : at t = 0.02 hours, pore is 2.74 % closed
# counter= 90 : at t = 0.03 hours, pore is 2.96 % closed
# counter= 100 : at t = 0.03 hours, pore is 3.18 % closed
# counter= 110 : at t = 0.03 hours, pore is 3.4 % closed
# counter= 120 : at t = 0.03 hours, pore is 3.61 % closed
# counter= 130 : at t = 0.04 hours, pore is 3.83 % closed
# counter= 140 : at t = 0.04 hours, pore is 4.05 % closed
# counter= 150 : at t = 0.04 hours, pore is 4.27 % closed
# counter= 160 : at t = 0.04 hours, pore is 4.48 % closed
# counter= 170 : at t = 0.05 hours, pore is 4.7 % closed
# counter= 180 : at t = 0.05 hours, pore is 4.92 % closed
# counter= 190 : at t = 0.05 hours, pore is 5.14 % closed
# counter= 200 : at t = 0.06 hours, pore is 5.36 % closed
# counter= 210 : at t = 0.06 hours, pore is 5.57 % closed
# counter= 220 : at t = 0.06 hours, pore is 5.79 % closed
# counter= 230 : at t = 0.06 hours, pore is 6.01 % closed
# counter= 240 : at t = 0.07 hours, pore is 6.23 % closed
# counter= 250 : at t = 0.07 hours, pore is 6.44 % closed
# counter= 260 : at t = 0.07 hours, pore is 6.66 % closed
# counter= 270 : at t = 0.08 hours, pore is 6.88 % closed
# counter= 280 : at t = 0.08 hours, pore is 7.1 % closed
# counter= 290 : at t = 0.08 hours, pore is 7.31 % closed
# counter= 300 : at t = 0.08 hours, pore is 7.53 % closed
# counter= 310 : at t = 0.09 hours, pore is 7.75 % closed
# counter= 320 : at t = 0.09 hours, pore is 7.97 % closed
# counter= 330 : at t = 0.09 hours, pore is 8.19 % closed
# counter= 340 : at t = 0.09 hours, pore is 8.4 % closed
# counter= 350 : at t = 0.1 hours, pore is 8.62 % closed
# counter= 360 : at t = 0.1 hours, pore is 8.84 % closed
# counter= 370 : at t = 0.1 hours, pore is 9.06 % closed
# counter= 380 : at t = 0.11 hours, pore is 9.27 % closed
# counter= 390 : at t = 0.11 hours, pore is 9.49 % closed
# counter= 400 : at t = 0.11 hours, pore is 9.71 % closed
# counter= 410 : at t = 0.11 hours, pore is 9.93 % closed
# counter= 420 : at t = 0.12 hours, pore is 10.15 % closed
# counter= 430 : at t = 0.12 hours, pore is 10.36 % closed
# counter= 440 : at t = 0.12 hours, pore is 10.58 % closed
# counter= 450 : at t = 0.13 hours, pore is 10.8 % closed
# counter= 460 : at t = 0.13 hours, pore is 11.02 % closed
# counter= 470 : at t = 0.13 hours, pore is 11.23 % closed
# counter= 480 : at t = 0.13 hours, pore is 11.45 % closed
# counter= 490 : at t = 0.14 hours, pore is 11.67 % closed
# counter= 500 : at t = 0.14 hours, pore is 11.89 % closed
# counter= 510 : at t = 0.14 hours, pore is 12.11 % closed
# counter= 520 : at t = 0.14 hours, pore is 12.32 % closed
# counter= 530 : at t = 0.15 hours, pore is 12.54 % closed
# counter= 540 : at t = 0.15 hours, pore is 12.76 % closed
# counter= 550 : at t = 0.15 hours, pore is 12.98 % closed
# counter= 560 : at t = 0.16 hours, pore is 13.19 % closed
# counter= 570 : at t = 0.16 hours, pore is 13.41 % closed
# counter= 580 : at t = 0.16 hours, pore is 13.63 % closed
# counter= 590 : at t = 0.16 hours, pore is 13.85 % closed
# counter= 600 : at t = 0.17 hours, pore is 14.07 % closed
# counter= 610 : at t = 0.17 hours, pore is 14.28 % closed
# counter= 620 : at t = 0.17 hours, pore is 14.5 % closed
# counter= 630 : at t = 0.18 hours, pore is 14.72 % closed
# counter= 640 : at t = 0.18 hours, pore is 14.94 % closed
# counter= 650 : at t = 0.18 hours, pore is 15.15 % closed
# counter= 660 : at t = 0.18 hours, pore is 15.37 % closed
# counter= 670 : at t = 0.19 hours, pore is 15.59 % closed
# counter= 680 : at t = 0.19 hours, pore is 15.81 % closed
# counter= 690 : at t = 0.19 hours, pore is 16.02 % closed
# counter= 700 : at t = 0.19 hours, pore is 16.24 % closed
# counter= 710 : at t = 0.2 hours, pore is 16.46 % closed
# counter= 720 : at t = 0.2 hours, pore is 16.68 % closed
# counter= 730 : at t = 0.2 hours, pore is 16.9 % closed
# counter= 740 : at t = 0.21 hours, pore is 17.11 % closed
# counter= 750 : at t = 0.21 hours, pore is 17.33 % closed
# counter= 760 : at t = 0.21 hours, pore is 17.55 % closed
# counter= 770 : at t = 0.21 hours, pore is 17.77 % closed
# counter= 780 : at t = 0.22 hours, pore is 17.98 % closed
# counter= 790 : at t = 0.22 hours, pore is 18.2 % closed
# counter= 800 : at t = 0.22 hours, pore is 18.42 % closed
# counter= 810 : at t = 0.23 hours, pore is 18.64 % closed
# counter= 820 : at t = 0.23 hours, pore is 18.86 % closed
# counter= 830 : at t = 0.23 hours, pore is 19.07 % closed
# counter= 840 : at t = 0.23 hours, pore is 19.29 % closed
# counter= 850 : at t = 0.24 hours, pore is 19.51 % closed
# counter= 860 : at t = 0.24 hours, pore is 19.73 % closed
# counter= 870 : at t = 0.24 hours, pore is 19.94 % closed
# counter= 880 : at t = 0.24 hours, pore is 20.16 % closed
# counter= 890 : at t = 0.25 hours, pore is 20.38 % closed
# counter= 900 : at t = 0.25 hours, pore is 20.6 % closed
# counter= 910 : at t = 0.25 hours, pore is 20.82 % closed
# counter= 920 : at t = 0.26 hours, pore is 21.03 % closed
# counter= 930 : at t = 0.26 hours, pore is 21.25 % closed
# counter= 940 : at t = 0.26 hours, pore is 21.47 % closed
# counter= 950 : at t = 0.26 hours, pore is 21.69 % closed
# counter= 960 : at t = 0.27 hours, pore is 21.9 % closed
# counter= 970 : at t = 0.27 hours, pore is 22.12 % closed
# counter= 980 : at t = 0.27 hours, pore is 22.34 % closed
# counter= 990 : at t = 0.28 hours, pore is 22.56 % closed
# counter= 1000 : at t = 0.28 hours, pore is 22.78 % closed
# counter= 1010 : at t = 0.28 hours, pore is 22.99 % closed
# counter= 1020 : at t = 0.28 hours, pore is 23.21 % closed
# counter= 1030 : at t = 0.29 hours, pore is 23.43 % closed
# counter= 1040 : at t = 0.29 hours, pore is 23.65 % closed
# counter= 1050 : at t = 0.29 hours, pore is 23.86 % closed
# counter= 1060 : at t = 0.29 hours, pore is 24.08 % closed
# counter= 1070 : at t = 0.3 hours, pore is 24.3 % closed
# counter= 1080 : at t = 0.3 hours, pore is 24.52 % closed
# counter= 1090 : at t = 0.3 hours, pore is 24.73 % closed
# counter= 1100 : at t = 0.31 hours, pore is 24.95 % closed
# counter= 1110 : at t = 0.31 hours, pore is 25.17 % closed
# counter= 1120 : at t = 0.31 hours, pore is 25.39 % closed
# counter= 1130 : at t = 0.31 hours, pore is 25.61 % closed
# counter= 1140 : at t = 0.32 hours, pore is 25.82 % closed
# counter= 1150 : at t = 0.32 hours, pore is 26.04 % closed
# counter= 1160 : at t = 0.32 hours, pore is 26.26 % closed
# counter= 1170 : at t = 0.33 hours, pore is 26.48 % closed
# counter= 1180 : at t = 0.33 hours, pore is 26.69 % closed
# counter= 1190 : at t = 0.33 hours, pore is 26.91 % closed
# counter= 1200 : at t = 0.33 hours, pore is 27.13 % closed
# counter= 1210 : at t = 0.34 hours, pore is 27.35 % closed
# counter= 1220 : at t = 0.34 hours, pore is 27.57 % closed
# counter= 1230 : at t = 0.34 hours, pore is 27.78 % closed
# counter= 1240 : at t = 0.34 hours, pore is 28.0 % closed
# counter= 1250 : at t = 0.35 hours, pore is 28.22 % closed
# counter= 1260 : at t = 0.35 hours, pore is 28.44 % closed
# counter= 1270 : at t = 0.35 hours, pore is 28.65 % closed
# counter= 1280 : at t = 0.36 hours, pore is 28.87 % closed
# counter= 1290 : at t = 0.36 hours, pore is 29.09 % closed
# counter= 1300 : at t = 0.36 hours, pore is 29.31 % closed
# counter= 1310 : at t = 0.36 hours, pore is 29.53 % closed
# counter= 1320 : at t = 0.37 hours, pore is 29.74 % closed
# counter= 1330 : at t = 0.37 hours, pore is 29.96 % closed
# counter= 1340 : at t = 0.37 hours, pore is 30.18 % closed
# counter= 1350 : at t = 0.38 hours, pore is 30.4 % closed
# counter= 1360 : at t = 0.38 hours, pore is 30.61 % closed
# counter= 1370 : at t = 0.38 hours, pore is 30.83 % closed
# counter= 1380 : at t = 0.38 hours, pore is 31.05 % closed
# counter= 1390 : at t = 0.39 hours, pore is 31.27 % closed
# counter= 1400 : at t = 0.39 hours, pore is 31.49 % closed
# counter= 1410 : at t = 0.39 hours, pore is 31.7 % closed
# counter= 1420 : at t = 0.39 hours, pore is 31.92 % closed
# counter= 1430 : at t = 0.4 hours, pore is 32.14 % closed
# counter= 1440 : at t = 0.4 hours, pore is 32.36 % closed
# counter= 1450 : at t = 0.4 hours, pore is 32.57 % closed
# counter= 1460 : at t = 0.41 hours, pore is 32.79 % closed
# counter= 1470 : at t = 0.41 hours, pore is 33.01 % closed
# counter= 1480 : at t = 0.41 hours, pore is 33.23 % closed
# counter= 1490 : at t = 0.41 hours, pore is 33.44 % closed
# counter= 1500 : at t = 0.42 hours, pore is 33.66 % closed
# counter= 1510 : at t = 0.42 hours, pore is 33.88 % closed
# counter= 1520 : at t = 0.42 hours, pore is 34.1 % closed
# counter= 1530 : at t = 0.43 hours, pore is 34.32 % closed
# counter= 1540 : at t = 0.43 hours, pore is 34.53 % closed
# counter= 1550 : at t = 0.43 hours, pore is 34.75 % closed
# counter= 1560 : at t = 0.43 hours, pore is 34.97 % closed
# counter= 1570 : at t = 0.44 hours, pore is 35.19 % closed
# counter= 1580 : at t = 0.44 hours, pore is 35.4 % closed
# counter= 1590 : at t = 0.44 hours, pore is 35.62 % closed
# counter= 1600 : at t = 0.44 hours, pore is 35.84 % closed
# counter= 1610 : at t = 0.45 hours, pore is 36.06 % closed
# counter= 1620 : at t = 0.45 hours, pore is 36.28 % closed
# counter= 1630 : at t = 0.45 hours, pore is 36.49 % closed
# counter= 1640 : at t = 0.46 hours, pore is 36.71 % closed
# counter= 1650 : at t = 0.46 hours, pore is 36.93 % closed
# counter= 1660 : at t = 0.46 hours, pore is 37.15 % closed
# counter= 1670 : at t = 0.46 hours, pore is 37.36 % closed
# counter= 1680 : at t = 0.47 hours, pore is 37.58 % closed
# counter= 1690 : at t = 0.47 hours, pore is 37.8 % closed
# counter= 1700 : at t = 0.47 hours, pore is 38.02 % closed
# counter= 1710 : at t = 0.48 hours, pore is 38.24 % closed
# counter= 1720 : at t = 0.48 hours, pore is 38.45 % closed
# counter= 1730 : at t = 0.48 hours, pore is 38.67 % closed
# counter= 1740 : at t = 0.48 hours, pore is 38.89 % closed
# counter= 1750 : at t = 0.49 hours, pore is 39.11 % closed
# counter= 1760 : at t = 0.49 hours, pore is 39.32 % closed
# counter= 1770 : at t = 0.49 hours, pore is 39.54 % closed
# counter= 1780 : at t = 0.49 hours, pore is 39.76 % closed
# counter= 1790 : at t = 0.5 hours, pore is 39.98 % closed
# counter= 1800 : at t = 0.5 hours, pore is 40.2 % closed
# counter= 1810 : at t = 0.5 hours, pore is 40.41 % closed
# counter= 1820 : at t = 0.51 hours, pore is 40.63 % closed
# counter= 1830 : at t = 0.51 hours, pore is 40.85 % closed
# counter= 1840 : at t = 0.51 hours, pore is 41.07 % closed
# counter= 1850 : at t = 0.51 hours, pore is 41.28 % closed
# counter= 1860 : at t = 0.52 hours, pore is 41.5 % closed
# counter= 1870 : at t = 0.52 hours, pore is 41.72 % closed
# counter= 1880 : at t = 0.52 hours, pore is 41.94 % closed
# counter= 1890 : at t = 0.53 hours, pore is 42.16 % closed
# counter= 1900 : at t = 0.53 hours, pore is 42.37 % closed
# counter= 1910 : at t = 0.53 hours, pore is 42.59 % closed
# counter= 1920 : at t = 0.53 hours, pore is 42.81 % closed
# counter= 1930 : at t = 0.54 hours, pore is 43.03 % closed
# counter= 1940 : at t = 0.54 hours, pore is 43.24 % closed
# counter= 1950 : at t = 0.54 hours, pore is 43.46 % closed
# counter= 1960 : at t = 0.54 hours, pore is 43.68 % closed
# counter= 1970 : at t = 0.55 hours, pore is 43.9 % closed
# counter= 1980 : at t = 0.55 hours, pore is 44.11 % closed
# counter= 1990 : at t = 0.55 hours, pore is 44.33 % closed
# counter= 2000 : at t = 0.56 hours, pore is 44.55 % closed
# counter= 2010 : at t = 0.56 hours, pore is 44.77 % closed
# counter= 2020 : at t = 0.56 hours, pore is 44.99 % closed
# counter= 2030 : at t = 0.56 hours, pore is 45.2 % closed
# counter= 2040 : at t = 0.57 hours, pore is 45.42 % closed
# counter= 2050 : at t = 0.57 hours, pore is 45.64 % closed
# counter= 2060 : at t = 0.57 hours, pore is 45.86 % closed
# counter= 2070 : at t = 0.58 hours, pore is 46.07 % closed
# counter= 2080 : at t = 0.58 hours, pore is 46.29 % closed
# counter= 2090 : at t = 0.58 hours, pore is 46.51 % closed
# counter= 2100 : at t = 0.58 hours, pore is 46.73 % closed
# counter= 2110 : at t = 0.59 hours, pore is 46.95 % closed
# counter= 2120 : at t = 0.59 hours, pore is 47.16 % closed
# counter= 2130 : at t = 0.59 hours, pore is 47.38 % closed
# counter= 2140 : at t = 0.59 hours, pore is 47.6 % closed
# counter= 2150 : at t = 0.6 hours, pore is 47.82 % closed
# counter= 2160 : at t = 0.6 hours, pore is 48.03 % closed
# counter= 2170 : at t = 0.6 hours, pore is 48.25 % closed
# counter= 2180 : at t = 0.61 hours, pore is 48.47 % closed
# counter= 2190 : at t = 0.61 hours, pore is 48.69 % closed
# counter= 2200 : at t = 0.61 hours, pore is 48.91 % closed
# counter= 2210 : at t = 0.61 hours, pore is 49.12 % closed
# counter= 2220 : at t = 0.62 hours, pore is 49.34 % closed
# counter= 2230 : at t = 0.62 hours, pore is 49.56 % closed
# counter= 2240 : at t = 0.62 hours, pore is 49.78 % closed
# counter= 2250 : at t = 0.63 hours, pore is 49.99 % closed
# counter= 2260 : at t = 0.63 hours, pore is 50.21 % closed
# counter= 2270 : at t = 0.63 hours, pore is 50.43 % closed
# counter= 2280 : at t = 0.63 hours, pore is 50.65 % closed
# counter= 2290 : at t = 0.64 hours, pore is 50.87 % closed
# counter= 2300 : at t = 0.64 hours, pore is 51.08 % closed
# counter= 2310 : at t = 0.64 hours, pore is 51.3 % closed
# counter= 2320 : at t = 0.64 hours, pore is 51.52 % closed
# counter= 2330 : at t = 0.65 hours, pore is 51.74 % closed
# counter= 2340 : at t = 0.65 hours, pore is 51.95 % closed
# counter= 2350 : at t = 0.65 hours, pore is 52.17 % closed
# counter= 2360 : at t = 0.66 hours, pore is 52.39 % closed
# counter= 2370 : at t = 0.66 hours, pore is 52.61 % closed
# counter= 2380 : at t = 0.66 hours, pore is 52.82 % closed
# counter= 2390 : at t = 0.66 hours, pore is 53.04 % closed
# counter= 2400 : at t = 0.67 hours, pore is 53.26 % closed
# counter= 2410 : at t = 0.67 hours, pore is 53.48 % closed
# counter= 2420 : at t = 0.67 hours, pore is 53.7 % closed
# counter= 2430 : at t = 0.68 hours, pore is 53.91 % closed
# counter= 2440 : at t = 0.68 hours, pore is 54.13 % closed
# counter= 2450 : at t = 0.68 hours, pore is 54.35 % closed
# counter= 2460 : at t = 0.68 hours, pore is 54.57 % closed
# counter= 2470 : at t = 0.69 hours, pore is 54.78 % closed
# counter= 2480 : at t = 0.69 hours, pore is 55.0 % closed
# counter= 2490 : at t = 0.69 hours, pore is 55.22 % closed
# counter= 2500 : at t = 0.69 hours, pore is 55.44 % closed
# counter= 2510 : at t = 0.7 hours, pore is 55.66 % closed
# counter= 2520 : at t = 0.7 hours, pore is 55.87 % closed
# counter= 2530 : at t = 0.7 hours, pore is 56.09 % closed
# counter= 2540 : at t = 0.71 hours, pore is 56.31 % closed
# counter= 2550 : at t = 0.71 hours, pore is 56.53 % closed
# counter= 2560 : at t = 0.71 hours, pore is 56.74 % closed
# counter= 2570 : at t = 0.71 hours, pore is 56.96 % closed
# counter= 2580 : at t = 0.72 hours, pore is 57.18 % closed
# counter= 2590 : at t = 0.72 hours, pore is 57.4 % closed
# counter= 2600 : at t = 0.72 hours, pore is 57.62 % closed
# counter= 2610 : at t = 0.73 hours, pore is 57.83 % closed
# counter= 2620 : at t = 0.73 hours, pore is 58.05 % closed
# counter= 2630 : at t = 0.73 hours, pore is 58.27 % closed
# counter= 2640 : at t = 0.73 hours, pore is 58.49 % closed
# counter= 2650 : at t = 0.74 hours, pore is 58.7 % closed
# counter= 2660 : at t = 0.74 hours, pore is 58.92 % closed
# counter= 2670 : at t = 0.74 hours, pore is 59.14 % closed
# counter= 2680 : at t = 0.74 hours, pore is 59.36 % closed
# counter= 2690 : at t = 0.75 hours, pore is 59.58 % closed
# counter= 2700 : at t = 0.75 hours, pore is 59.79 % closed
# counter= 2710 : at t = 0.75 hours, pore is 60.01 % closed
# counter= 2720 : at t = 0.76 hours, pore is 60.23 % closed
# counter= 2730 : at t = 0.76 hours, pore is 60.45 % closed
# counter= 2740 : at t = 0.76 hours, pore is 60.66 % closed
# counter= 2750 : at t = 0.76 hours, pore is 60.88 % closed
# counter= 2760 : at t = 0.77 hours, pore is 61.1 % closed
# counter= 2770 : at t = 0.77 hours, pore is 61.32 % closed
# counter= 2780 : at t = 0.77 hours, pore is 61.53 % closed
# counter= 2790 : at t = 0.78 hours, pore is 61.75 % closed
# counter= 2800 : at t = 0.78 hours, pore is 61.97 % closed
# counter= 2810 : at t = 0.78 hours, pore is 62.19 % closed
# counter= 2820 : at t = 0.78 hours, pore is 62.41 % closed
# counter= 2830 : at t = 0.79 hours, pore is 62.62 % closed
# counter= 2840 : at t = 0.79 hours, pore is 62.84 % closed
# counter= 2850 : at t = 0.79 hours, pore is 63.06 % closed
# counter= 2860 : at t = 0.79 hours, pore is 63.28 % closed
# counter= 2870 : at t = 0.8 hours, pore is 63.49 % closed
# counter= 2880 : at t = 0.8 hours, pore is 63.71 % closed
# counter= 2890 : at t = 0.8 hours, pore is 63.93 % closed
# counter= 2900 : at t = 0.81 hours, pore is 64.15 % closed
# counter= 2910 : at t = 0.81 hours, pore is 64.37 % closed
# counter= 2920 : at t = 0.81 hours, pore is 64.58 % closed
# counter= 2930 : at t = 0.81 hours, pore is 64.8 % closed
# counter= 2940 : at t = 0.82 hours, pore is 65.02 % closed
# counter= 2950 : at t = 0.82 hours, pore is 65.24 % closed
# counter= 2960 : at t = 0.82 hours, pore is 65.45 % closed
# counter= 2970 : at t = 0.83 hours, pore is 65.67 % closed
# counter= 2980 : at t = 0.83 hours, pore is 65.89 % closed
# counter= 2990 : at t = 0.83 hours, pore is 66.11 % closed
# counter= 3000 : at t = 0.83 hours, pore is 66.33 % closed
# counter= 3010 : at t = 0.84 hours, pore is 66.54 % closed
# counter= 3020 : at t = 0.84 hours, pore is 66.76 % closed
# counter= 3030 : at t = 0.84 hours, pore is 66.98 % closed
# counter= 3040 : at t = 0.84 hours, pore is 67.2 % closed
# counter= 3050 : at t = 0.85 hours, pore is 67.41 % closed
# counter= 3060 : at t = 0.85 hours, pore is 67.63 % closed
# counter= 3070 : at t = 0.85 hours, pore is 67.85 % closed
# counter= 3080 : at t = 0.86 hours, pore is 68.07 % closed
# counter= 3090 : at t = 0.86 hours, pore is 68.29 % closed
# counter= 3100 : at t = 0.86 hours, pore is 68.5 % closed
# counter= 3110 : at t = 0.86 hours, pore is 68.72 % closed
# counter= 3120 : at t = 0.87 hours, pore is 68.94 % closed
# counter= 3130 : at t = 0.87 hours, pore is 69.16 % closed
# counter= 3140 : at t = 0.87 hours, pore is 69.37 % closed
# counter= 3150 : at t = 0.88 hours, pore is 69.59 % closed
# counter= 3160 : at t = 0.88 hours, pore is 69.81 % closed
# counter= 3170 : at t = 0.88 hours, pore is 70.03 % closed
# counter= 3180 : at t = 0.88 hours, pore is 70.25 % closed
# counter= 3190 : at t = 0.89 hours, pore is 70.46 % closed
# counter= 3200 : at t = 0.89 hours, pore is 70.68 % closed
# counter= 3210 : at t = 0.89 hours, pore is 70.9 % closed
# counter= 3220 : at t = 0.89 hours, pore is 71.12 % closed
# counter= 3230 : at t = 0.9 hours, pore is 71.33 % closed
# counter= 3240 : at t = 0.9 hours, pore is 71.55 % closed
# counter= 3250 : at t = 0.9 hours, pore is 71.77 % closed
# counter= 3260 : at t = 0.91 hours, pore is 71.99 % closed
# counter= 3270 : at t = 0.91 hours, pore is 72.2 % closed
# counter= 3280 : at t = 0.91 hours, pore is 72.42 % closed
# counter= 3290 : at t = 0.91 hours, pore is 72.64 % closed
# counter= 3300 : at t = 0.92 hours, pore is 72.86 % closed
# counter= 3310 : at t = 0.92 hours, pore is 73.08 % closed
# counter= 3320 : at t = 0.92 hours, pore is 73.29 % closed
# counter= 3330 : at t = 0.93 hours, pore is 73.51 % closed
# counter= 3340 : at t = 0.93 hours, pore is 73.73 % closed
# counter= 3350 : at t = 0.93 hours, pore is 73.95 % closed
# counter= 3360 : at t = 0.93 hours, pore is 74.16 % closed
# counter= 3370 : at t = 0.94 hours, pore is 74.38 % closed
# counter= 3380 : at t = 0.94 hours, pore is 74.6 % closed
# counter= 3390 : at t = 0.94 hours, pore is 74.82 % closed
# counter= 3400 : at t = 0.94 hours, pore is 75.04 % closed
# counter= 3410 : at t = 0.95 hours, pore is 75.25 % closed
# counter= 3420 : at t = 0.95 hours, pore is 75.47 % closed
# counter= 3430 : at t = 0.95 hours, pore is 75.69 % closed
# counter= 3440 : at t = 0.96 hours, pore is 75.91 % closed
# counter= 3450 : at t = 0.96 hours, pore is 76.12 % closed
# counter= 3460 : at t = 0.96 hours, pore is 76.34 % closed
# counter= 3470 : at t = 0.96 hours, pore is 76.56 % closed
# counter= 3480 : at t = 0.97 hours, pore is 76.78 % closed
# counter= 3490 : at t = 0.97 hours, pore is 77.0 % closed
# counter= 3500 : at t = 0.97 hours, pore is 77.21 % closed
# counter= 3510 : at t = 0.98 hours, pore is 77.43 % closed
# counter= 3520 : at t = 0.98 hours, pore is 77.65 % closed
# counter= 3530 : at t = 0.98 hours, pore is 77.87 % closed
# counter= 3540 : at t = 0.98 hours, pore is 78.08 % closed
# counter= 3550 : at t = 0.99 hours, pore is 78.3 % closed
# counter= 3560 : at t = 0.99 hours, pore is 78.52 % closed
# counter= 3570 : at t = 0.99 hours, pore is 78.74 % closed
# counter= 3580 : at t = 0.99 hours, pore is 78.96 % closed
# counter= 3590 : at t = 1.0 hours, pore is 79.17 % closed
# counter= 3600 : at t = 1.0 hours, pore is 79.39 % closed
# counter= 3610 : at t = 1.0 hours, pore is 79.61 % closed
# counter= 3620 : at t = 1.01 hours, pore is 79.83 % closed
# counter= 3630 : at t = 1.01 hours, pore is 80.04 % closed
# counter= 3640 : at t = 1.01 hours, pore is 80.26 % closed
# counter= 3650 : at t = 1.01 hours, pore is 80.48 % closed
# counter= 3660 : at t = 1.02 hours, pore is 80.7 % closed
# counter= 3670 : at t = 1.02 hours, pore is 80.91 % closed
# counter= 3680 : at t = 1.02 hours, pore is 81.13 % closed
# counter= 3690 : at t = 1.03 hours, pore is 81.35 % closed
# counter= 3700 : at t = 1.03 hours, pore is 81.57 % closed
# counter= 3710 : at t = 1.03 hours, pore is 81.79 % closed
# counter= 3720 : at t = 1.03 hours, pore is 82.0 % closed
# counter= 3730 : at t = 1.04 hours, pore is 82.22 % closed
# counter= 3740 : at t = 1.04 hours, pore is 82.44 % closed
# counter= 3750 : at t = 1.04 hours, pore is 82.66 % closed
# counter= 3760 : at t = 1.04 hours, pore is 82.87 % closed
# counter= 3770 : at t = 1.05 hours, pore is 83.09 % closed
# counter= 3780 : at t = 1.05 hours, pore is 83.31 % closed
# counter= 3790 : at t = 1.05 hours, pore is 83.53 % closed
# counter= 3800 : at t = 1.06 hours, pore is 83.75 % closed
# counter= 3810 : at t = 1.06 hours, pore is 83.96 % closed
# counter= 3820 : at t = 1.06 hours, pore is 84.18 % closed
# counter= 3830 : at t = 1.06 hours, pore is 84.4 % closed
# counter= 3840 : at t = 1.07 hours, pore is 84.62 % closed
# counter= 3850 : at t = 1.07 hours, pore is 84.83 % closed
# counter= 3860 : at t = 1.07 hours, pore is 85.05 % closed
# counter= 3870 : at t = 1.08 hours, pore is 85.27 % closed
# counter= 3880 : at t = 1.08 hours, pore is 85.49 % closed
# counter= 3890 : at t = 1.08 hours, pore is 85.71 % closed
# counter= 3900 : at t = 1.08 hours, pore is 85.92 % closed
# counter= 3910 : at t = 1.09 hours, pore is 86.14 % closed
# counter= 3920 : at t = 1.09 hours, pore is 86.36 % closed
# counter= 3930 : at t = 1.09 hours, pore is 86.58 % closed
# counter= 3940 : at t = 1.09 hours, pore is 86.79 % closed
# counter= 3950 : at t = 1.1 hours, pore is 87.01 % closed
# counter= 3960 : at t = 1.1 hours, pore is 87.23 % closed
# counter= 3970 : at t = 1.1 hours, pore is 87.45 % closed
# counter= 3980 : at t = 1.11 hours, pore is 87.67 % closed
# counter= 3990 : at t = 1.11 hours, pore is 87.88 % closed
# counter= 4000 : at t = 1.11 hours, pore is 88.1 % closed
# counter= 4010 : at t = 1.11 hours, pore is 88.32 % closed
# counter= 4020 : at t = 1.12 hours, pore is 88.54 % closed
# counter= 4030 : at t = 1.12 hours, pore is 88.75 % closed
# counter= 4040 : at t = 1.12 hours, pore is 88.97 % closed
# counter= 4050 : at t = 1.13 hours, pore is 89.19 % closed
# counter= 4060 : at t = 1.13 hours, pore is 89.41 % closed
# counter= 4070 : at t = 1.13 hours, pore is 89.62 % closed
# counter= 4080 : at t = 1.13 hours, pore is 89.84 % closed
# counter= 4090 : at t = 1.14 hours, pore is 90.06 % closed
# counter= 4100 : at t = 1.14 hours, pore is 90.28 % closed
# counter= 4110 : at t = 1.14 hours, pore is 90.5 % closed
# counter= 4120 : at t = 1.14 hours, pore is 90.71 % closed
# counter= 4130 : at t = 1.15 hours, pore is 90.93 % closed
# counter= 4140 : at t = 1.15 hours, pore is 91.15 % closed
# counter= 4150 : at t = 1.15 hours, pore is 91.37 % closed
# counter= 4160 : at t = 1.16 hours, pore is 91.58 % closed
# counter= 4170 : at t = 1.16 hours, pore is 91.8 % closed
# counter= 4180 : at t = 1.16 hours, pore is 92.02 % closed
# counter= 4190 : at t = 1.16 hours, pore is 92.24 % closed
# counter= 4200 : at t = 1.17 hours, pore is 92.46 % closed
# counter= 4210 : at t = 1.17 hours, pore is 92.67 % closed
# counter= 4220 : at t = 1.17 hours, pore is 92.89 % closed
# counter= 4230 : at t = 1.18 hours, pore is 93.11 % closed
# counter= 4240 : at t = 1.18 hours, pore is 93.33 % closed
# counter= 4250 : at t = 1.18 hours, pore is 93.54 % closed
# counter= 4260 : at t = 1.18 hours, pore is 93.76 % closed
# counter= 4270 : at t = 1.19 hours, pore is 93.98 % closed
# counter= 4280 : at t = 1.19 hours, pore is 94.2 % closed
# counter= 4290 : at t = 1.19 hours, pore is 94.42 % closed
# counter= 4300 : at t = 1.19 hours, pore is 94.63 % closed
# counter= 4310 : at t = 1.2 hours, pore is 94.85 % closed
# counter= 4320 : at t = 1.2 hours, pore is 95.07 % closed
# counter= 4330 : at t = 1.2 hours, pore is 95.29 % closed
# counter= 4340 : at t = 1.21 hours, pore is 95.5 % closed
# counter= 4350 : at t = 1.21 hours, pore is 95.72 % closed
# counter= 4360 : at t = 1.21 hours, pore is 95.94 % closed
# counter= 4370 : at t = 1.21 hours, pore is 96.16 % closed
# counter= 4380 : at t = 1.22 hours, pore is 96.38 % closed
# counter= 4390 : at t = 1.22 hours, pore is 96.59 % closed
# counter= 4400 : at t = 1.22 hours, pore is 96.81 % closed
# counter= 4410 : at t = 1.23 hours, pore is 97.03 % closed
# counter= 4420 : at t = 1.23 hours, pore is 97.25 % closed
# counter= 4430 : at t = 1.23 hours, pore is 97.46 % closed
# counter= 4440 : at t = 1.23 hours, pore is 97.68 % closed
# counter= 4450 : at t = 1.24 hours, pore is 97.9 % closed
# counter= 4460 : at t = 1.24 hours, pore is 98.12 % closed
# counter= 4470 : at t = 1.24 hours, pore is 98.33 % closed
# counter= 4480 : at t = 1.24 hours, pore is 98.55 % closed
# counter= 4490 : at t = 1.25 hours, pore is 98.77 % closed
# counter= 4500 : at t = 1.25 hours, pore is 98.99 % closed
# counter= 4510 : at t = 1.25 hours, pore is 99.21 % closed
# counter= 4520 : at t = 1.26 hours, pore is 99.42 % closed
# counter= 4530 : at t = 1.26 hours, pore is 99.64 % closed
# counter= 4540 : at t = 1.26 hours, pore is 99.86 % closed
# 4547
# xi= [9.27926285e-05 1.95150663e-03 5.25821538e-03 9.44434163e-03
#  1.42053452e-02 1.93409599e-02 2.47066597e-02 3.01923704e-02
#  3.57112515e-02 4.11930783e-02 4.65800252e-02 5.18238252e-02
#  5.68837706e-02 6.17252612e-02 6.63187191e-02 7.06387615e-02
#  7.46635580e-02 7.83743256e-02 8.17549261e-02 8.47915440e-02
#  8.74724265e-02 8.97876742e-02 9.17290721e-02 9.32899558e-02
#  9.44651052e-02 9.52506647e-02 9.56440848e-02 9.56440848e-02]
# moose input for damage is:  if(y>=7.222222222222222e-05, 9.27926285478188e-05, if(y>=6.944444444444443e-05, 0.0019515066262424865, if(y>=6.666666666666666e-05, 0.005258215384410921, if(y>=6.388888888888888e-05, 0.009444341629725591, if(y>=6.111111111111111e-05, 0.014205345182478107, if(y>=5.8333333333333326e-05, 0.019340959908290503, if(y>=5.555555555555555e-05, 0.02470665970371345, if(y>=5.277777777777777e-05, 0.030192370431995103, if(y>=4.9999999999999996e-05, 0.035711251535379414, if(y>=4.7222222222222214e-05, 0.041193078260470126, if(y>=4.444444444444444e-05, 0.04658002524808095, if(y>=4.1666666666666665e-05, 0.05182382515898756, if(y>=3.8888888888888884e-05, 0.056883770558538944, if(y>=3.611111111111111e-05, 0.06172526115964593, if(y>=3.333333333333333e-05, 0.06631871910229221, if(y>=3.0555555555555554e-05, 0.0706387614686003, if(y>=2.7777777777777776e-05, 0.07466355799374295, if(y>=2.4999999999999998e-05, 0.07837432556508395, if(y>=2.222222222222222e-05, 0.08175492607136861, if(y>=1.9444444444444442e-05, 0.08479154396369873, if(y>=1.6666666666666664e-05, 0.08747242649382443, if(y>=1.3888888888888888e-05, 0.08978767416248862, if(y>=1.111111111111111e-05, 0.09172907214673588, if(y>=8.333333333333332e-06, 0.09328995582150526, if(y>=5.555555555555555e-06, 0.0944651052332875, if(y>=2.7777777777777775e-06, 0.09525066471016484, if(y>=0.0, 0.09564408483260248,  0)))))))))))))))))))))))))))
# khet_fedou= 0.00025606711513304325
# ----------------------------------T= 1173 P= 20000 CMTS0= 1.0253968234436885 CH20= 1.0253968234436885 CHCl0= 0
# counter= 10 : at t = 0.0 hours, pore is 1.07 % closed
# counter= 20 : at t = 0.01 hours, pore is 1.13 % closed
# counter= 30 : at t = 0.01 hours, pore is 1.2 % closed
# counter= 40 : at t = 0.01 hours, pore is 1.26 % closed
# counter= 50 : at t = 0.01 hours, pore is 1.33 % closed
# counter= 60 : at t = 0.02 hours, pore is 1.39 % closed
# counter= 70 : at t = 0.02 hours, pore is 1.46 % closed
# counter= 80 : at t = 0.02 hours, pore is 1.53 % closed
# counter= 90 : at t = 0.03 hours, pore is 1.59 % closed
# counter= 100 : at t = 0.03 hours, pore is 1.66 % closed
# counter= 110 : at t = 0.03 hours, pore is 1.72 % closed
# counter= 120 : at t = 0.03 hours, pore is 1.79 % closed
# counter= 130 : at t = 0.04 hours, pore is 1.85 % closed
# counter= 140 : at t = 0.04 hours, pore is 1.92 % closed
# counter= 150 : at t = 0.04 hours, pore is 1.98 % closed
# counter= 160 : at t = 0.04 hours, pore is 2.05 % closed
# counter= 170 : at t = 0.05 hours, pore is 2.12 % closed
# counter= 180 : at t = 0.05 hours, pore is 2.18 % closed
# counter= 190 : at t = 0.05 hours, pore is 2.25 % closed
# counter= 200 : at t = 0.06 hours, pore is 2.31 % closed
# counter= 210 : at t = 0.06 hours, pore is 2.38 % closed
# counter= 220 : at t = 0.06 hours, pore is 2.44 % closed
# counter= 230 : at t = 0.06 hours, pore is 2.51 % closed
# counter= 240 : at t = 0.07 hours, pore is 2.58 % closed
# counter= 250 : at t = 0.07 hours, pore is 2.64 % closed
# counter= 260 : at t = 0.07 hours, pore is 2.71 % closed
# counter= 270 : at t = 0.08 hours, pore is 2.77 % closed
# counter= 280 : at t = 0.08 hours, pore is 2.84 % closed
# counter= 290 : at t = 0.08 hours, pore is 2.9 % closed
# counter= 300 : at t = 0.08 hours, pore is 2.97 % closed
# counter= 310 : at t = 0.09 hours, pore is 3.03 % closed
# counter= 320 : at t = 0.09 hours, pore is 3.1 % closed
# counter= 330 : at t = 0.09 hours, pore is 3.17 % closed
# counter= 340 : at t = 0.09 hours, pore is 3.23 % closed
# counter= 350 : at t = 0.1 hours, pore is 3.3 % closed
# counter= 360 : at t = 0.1 hours, pore is 3.36 % closed
# counter= 370 : at t = 0.1 hours, pore is 3.43 % closed
# counter= 380 : at t = 0.11 hours, pore is 3.49 % closed
# counter= 390 : at t = 0.11 hours, pore is 3.56 % closed
# counter= 400 : at t = 0.11 hours, pore is 3.63 % closed
# counter= 410 : at t = 0.11 hours, pore is 3.69 % closed
# counter= 420 : at t = 0.12 hours, pore is 3.76 % closed
# counter= 430 : at t = 0.12 hours, pore is 3.82 % closed
# counter= 440 : at t = 0.12 hours, pore is 3.89 % closed
# counter= 450 : at t = 0.13 hours, pore is 3.95 % closed
# counter= 460 : at t = 0.13 hours, pore is 4.02 % closed
# counter= 470 : at t = 0.13 hours, pore is 4.09 % closed
# counter= 480 : at t = 0.13 hours, pore is 4.15 % closed
# counter= 490 : at t = 0.14 hours, pore is 4.22 % closed
# counter= 500 : at t = 0.14 hours, pore is 4.28 % closed
# counter= 510 : at t = 0.14 hours, pore is 4.35 % closed
# counter= 520 : at t = 0.14 hours, pore is 4.41 % closed
# counter= 530 : at t = 0.15 hours, pore is 4.48 % closed
# counter= 540 : at t = 0.15 hours, pore is 4.54 % closed
# counter= 550 : at t = 0.15 hours, pore is 4.61 % closed
# counter= 560 : at t = 0.16 hours, pore is 4.68 % closed
# counter= 570 : at t = 0.16 hours, pore is 4.74 % closed
# counter= 580 : at t = 0.16 hours, pore is 4.81 % closed
# counter= 590 : at t = 0.16 hours, pore is 4.87 % closed
# counter= 600 : at t = 0.17 hours, pore is 4.94 % closed
# counter= 610 : at t = 0.17 hours, pore is 5.0 % closed
# counter= 620 : at t = 0.17 hours, pore is 5.07 % closed
# counter= 630 : at t = 0.18 hours, pore is 5.14 % closed
# counter= 640 : at t = 0.18 hours, pore is 5.2 % closed
# counter= 650 : at t = 0.18 hours, pore is 5.27 % closed
# counter= 660 : at t = 0.18 hours, pore is 5.33 % closed
# counter= 670 : at t = 0.19 hours, pore is 5.4 % closed
# counter= 680 : at t = 0.19 hours, pore is 5.46 % closed
# counter= 690 : at t = 0.19 hours, pore is 5.53 % closed
# counter= 700 : at t = 0.19 hours, pore is 5.59 % closed
# counter= 710 : at t = 0.2 hours, pore is 5.66 % closed
# counter= 720 : at t = 0.2 hours, pore is 5.73 % closed
# counter= 730 : at t = 0.2 hours, pore is 5.79 % closed
# counter= 740 : at t = 0.21 hours, pore is 5.86 % closed
# counter= 750 : at t = 0.21 hours, pore is 5.92 % closed
# counter= 760 : at t = 0.21 hours, pore is 5.99 % closed
# counter= 770 : at t = 0.21 hours, pore is 6.05 % closed
# counter= 780 : at t = 0.22 hours, pore is 6.12 % closed
# counter= 790 : at t = 0.22 hours, pore is 6.19 % closed
# counter= 800 : at t = 0.22 hours, pore is 6.25 % closed
# counter= 810 : at t = 0.23 hours, pore is 6.32 % closed
# counter= 820 : at t = 0.23 hours, pore is 6.38 % closed
# counter= 830 : at t = 0.23 hours, pore is 6.45 % closed
# counter= 840 : at t = 0.23 hours, pore is 6.51 % closed
# counter= 850 : at t = 0.24 hours, pore is 6.58 % closed
# counter= 860 : at t = 0.24 hours, pore is 6.65 % closed
# counter= 870 : at t = 0.24 hours, pore is 6.71 % closed
# counter= 880 : at t = 0.24 hours, pore is 6.78 % closed
# counter= 890 : at t = 0.25 hours, pore is 6.84 % closed
# counter= 900 : at t = 0.25 hours, pore is 6.91 % closed
# counter= 910 : at t = 0.25 hours, pore is 6.97 % closed
# counter= 920 : at t = 0.26 hours, pore is 7.04 % closed
# counter= 930 : at t = 0.26 hours, pore is 7.1 % closed
# counter= 940 : at t = 0.26 hours, pore is 7.17 % closed
# counter= 950 : at t = 0.26 hours, pore is 7.24 % closed
# counter= 960 : at t = 0.27 hours, pore is 7.3 % closed
# counter= 970 : at t = 0.27 hours, pore is 7.37 % closed
# counter= 980 : at t = 0.27 hours, pore is 7.43 % closed
# counter= 990 : at t = 0.28 hours, pore is 7.5 % closed
# counter= 1000 : at t = 0.28 hours, pore is 7.56 % closed
# counter= 1010 : at t = 0.28 hours, pore is 7.63 % closed
# counter= 1020 : at t = 0.28 hours, pore is 7.7 % closed
# counter= 1030 : at t = 0.29 hours, pore is 7.76 % closed
# counter= 1040 : at t = 0.29 hours, pore is 7.83 % closed
# counter= 1050 : at t = 0.29 hours, pore is 7.89 % closed
# counter= 1060 : at t = 0.29 hours, pore is 7.96 % closed
# counter= 1070 : at t = 0.3 hours, pore is 8.02 % closed
# counter= 1080 : at t = 0.3 hours, pore is 8.09 % closed
# counter= 1090 : at t = 0.3 hours, pore is 8.16 % closed
# counter= 1100 : at t = 0.31 hours, pore is 8.22 % closed
# counter= 1110 : at t = 0.31 hours, pore is 8.29 % closed
# counter= 1120 : at t = 0.31 hours, pore is 8.35 % closed
# counter= 1130 : at t = 0.31 hours, pore is 8.42 % closed
# counter= 1140 : at t = 0.32 hours, pore is 8.48 % closed
# counter= 1150 : at t = 0.32 hours, pore is 8.55 % closed
# counter= 1160 : at t = 0.32 hours, pore is 8.61 % closed
# counter= 1170 : at t = 0.33 hours, pore is 8.68 % closed
# counter= 1180 : at t = 0.33 hours, pore is 8.75 % closed
# counter= 1190 : at t = 0.33 hours, pore is 8.81 % closed
# counter= 1200 : at t = 0.33 hours, pore is 8.88 % closed
# counter= 1210 : at t = 0.34 hours, pore is 8.94 % closed
# counter= 1220 : at t = 0.34 hours, pore is 9.01 % closed
# counter= 1230 : at t = 0.34 hours, pore is 9.07 % closed
# counter= 1240 : at t = 0.34 hours, pore is 9.14 % closed
# counter= 1250 : at t = 0.35 hours, pore is 9.21 % closed
# counter= 1260 : at t = 0.35 hours, pore is 9.27 % closed
# counter= 1270 : at t = 0.35 hours, pore is 9.34 % closed
# counter= 1280 : at t = 0.36 hours, pore is 9.4 % closed
# counter= 1290 : at t = 0.36 hours, pore is 9.47 % closed
# counter= 1300 : at t = 0.36 hours, pore is 9.53 % closed
# counter= 1310 : at t = 0.36 hours, pore is 9.6 % closed
# counter= 1320 : at t = 0.37 hours, pore is 9.66 % closed
# counter= 1330 : at t = 0.37 hours, pore is 9.73 % closed
# counter= 1340 : at t = 0.37 hours, pore is 9.8 % closed
# counter= 1350 : at t = 0.38 hours, pore is 9.86 % closed
# counter= 1360 : at t = 0.38 hours, pore is 9.93 % closed
# counter= 1370 : at t = 0.38 hours, pore is 9.99 % closed
# counter= 1380 : at t = 0.38 hours, pore is 10.06 % closed
# counter= 1390 : at t = 0.39 hours, pore is 10.12 % closed
# counter= 1400 : at t = 0.39 hours, pore is 10.19 % closed
# counter= 1410 : at t = 0.39 hours, pore is 10.26 % closed
# counter= 1420 : at t = 0.39 hours, pore is 10.32 % closed
# counter= 1430 : at t = 0.4 hours, pore is 10.39 % closed
# counter= 1440 : at t = 0.4 hours, pore is 10.45 % closed
# counter= 1450 : at t = 0.4 hours, pore is 10.52 % closed
# counter= 1460 : at t = 0.41 hours, pore is 10.58 % closed
# counter= 1470 : at t = 0.41 hours, pore is 10.65 % closed
# counter= 1480 : at t = 0.41 hours, pore is 10.72 % closed
# counter= 1490 : at t = 0.41 hours, pore is 10.78 % closed
# counter= 1500 : at t = 0.42 hours, pore is 10.85 % closed
# counter= 1510 : at t = 0.42 hours, pore is 10.91 % closed
# counter= 1520 : at t = 0.42 hours, pore is 10.98 % closed
# counter= 1530 : at t = 0.43 hours, pore is 11.04 % closed
# counter= 1540 : at t = 0.43 hours, pore is 11.11 % closed
# counter= 1550 : at t = 0.43 hours, pore is 11.17 % closed
# counter= 1560 : at t = 0.43 hours, pore is 11.24 % closed
# counter= 1570 : at t = 0.44 hours, pore is 11.31 % closed
# counter= 1580 : at t = 0.44 hours, pore is 11.37 % closed
# counter= 1590 : at t = 0.44 hours, pore is 11.44 % closed
# counter= 1600 : at t = 0.44 hours, pore is 11.5 % closed
# counter= 1610 : at t = 0.45 hours, pore is 11.57 % closed
# counter= 1620 : at t = 0.45 hours, pore is 11.63 % closed
# counter= 1630 : at t = 0.45 hours, pore is 11.7 % closed
# ...
# counter= 231170 : at t = 64.21 hours, pore is 99.02 % closed
# counter= 231180 : at t = 64.22 hours, pore is 99.03 % closed
# counter= 231190 : at t = 64.22 hours, pore is 99.03 % closed
# counter= 231200 : at t = 64.22 hours, pore is 99.04 % closed
# counter= 231210 : at t = 64.23 hours, pore is 99.04 % closed
# counter= 231220 : at t = 64.23 hours, pore is 99.05 % closed
# counter= 231230 : at t = 64.23 hours, pore is 99.05 % closed
# counter= 231240 : at t = 64.23 hours, pore is 99.05 % closed
# counter= 231250 : at t = 64.24 hours, pore is 99.06 % closed
# counter= 231260 : at t = 64.24 hours, pore is 99.06 % closed
# counter= 231270 : at t = 64.24 hours, pore is 99.07 % closed
# counter= 231280 : at t = 64.24 hours, pore is 99.07 % closed
# counter= 231290 : at t = 64.25 hours, pore is 99.08 % closed
# counter= 231300 : at t = 64.25 hours, pore is 99.08 % closed
# counter= 231310 : at t = 64.25 hours, pore is 99.08 % closed
# counter= 231320 : at t = 64.26 hours, pore is 99.09 % closed
# counter= 231330 : at t = 64.26 hours, pore is 99.09 % closed
# counter= 231340 : at t = 64.26 hours, pore is 99.1 % closed
# counter= 231350 : at t = 64.26 hours, pore is 99.1 % closed
# counter= 231360 : at t = 64.27 hours, pore is 99.11 % closed
# counter= 231370 : at t = 64.27 hours, pore is 99.11 % closed
# counter= 231380 : at t = 64.27 hours, pore is 99.11 % closed
# counter= 231390 : at t = 64.28 hours, pore is 99.12 % closed
# counter= 231400 : at t = 64.28 hours, pore is 99.12 % closed
# counter= 231410 : at t = 64.28 hours, pore is 99.13 % closed
# counter= 231420 : at t = 64.28 hours, pore is 99.13 % closed
# counter= 231430 : at t = 64.29 hours, pore is 99.13 % closed
# counter= 231440 : at t = 64.29 hours, pore is 99.14 % closed
# counter= 231450 : at t = 64.29 hours, pore is 99.14 % closed
# counter= 231460 : at t = 64.29 hours, pore is 99.15 % closed
# counter= 231470 : at t = 64.3 hours, pore is 99.15 % closed
# counter= 231480 : at t = 64.3 hours, pore is 99.16 % closed
# counter= 231490 : at t = 64.3 hours, pore is 99.16 % closed
# counter= 231500 : at t = 64.31 hours, pore is 99.16 % closed
# counter= 231510 : at t = 64.31 hours, pore is 99.17 % closed
# counter= 231520 : at t = 64.31 hours, pore is 99.17 % closed
# counter= 231530 : at t = 64.31 hours, pore is 99.18 % closed
# counter= 231540 : at t = 64.32 hours, pore is 99.18 % closed
# counter= 231550 : at t = 64.32 hours, pore is 99.19 % closed
# counter= 231560 : at t = 64.32 hours, pore is 99.19 % closed
# counter= 231570 : at t = 64.33 hours, pore is 99.19 % closed
# counter= 231580 : at t = 64.33 hours, pore is 99.2 % closed
# counter= 231590 : at t = 64.33 hours, pore is 99.2 % closed
# counter= 231600 : at t = 64.33 hours, pore is 99.21 % closed
# counter= 231610 : at t = 64.34 hours, pore is 99.21 % closed
# counter= 231620 : at t = 64.34 hours, pore is 99.22 % closed
# counter= 231630 : at t = 64.34 hours, pore is 99.22 % closed
# counter= 231640 : at t = 64.34 hours, pore is 99.22 % closed
# counter= 231650 : at t = 64.35 hours, pore is 99.23 % closed
# counter= 231660 : at t = 64.35 hours, pore is 99.23 % closed
# counter= 231670 : at t = 64.35 hours, pore is 99.24 % closed
# counter= 231680 : at t = 64.36 hours, pore is 99.24 % closed
# counter= 231690 : at t = 64.36 hours, pore is 99.25 % closed
# counter= 231700 : at t = 64.36 hours, pore is 99.25 % closed
# counter= 231710 : at t = 64.36 hours, pore is 99.25 % closed
# counter= 231720 : at t = 64.37 hours, pore is 99.26 % closed
# counter= 231730 : at t = 64.37 hours, pore is 99.26 % closed
# counter= 231740 : at t = 64.37 hours, pore is 99.27 % closed
# counter= 231750 : at t = 64.38 hours, pore is 99.27 % closed
# counter= 231760 : at t = 64.38 hours, pore is 99.27 % closed
# counter= 231770 : at t = 64.38 hours, pore is 99.28 % closed
# counter= 231780 : at t = 64.38 hours, pore is 99.28 % closed
# counter= 231790 : at t = 64.39 hours, pore is 99.29 % closed
# counter= 231800 : at t = 64.39 hours, pore is 99.29 % closed
# counter= 231810 : at t = 64.39 hours, pore is 99.3 % closed
# counter= 231820 : at t = 64.39 hours, pore is 99.3 % closed
# counter= 231830 : at t = 64.4 hours, pore is 99.3 % closed
# counter= 231840 : at t = 64.4 hours, pore is 99.31 % closed
# counter= 231850 : at t = 64.4 hours, pore is 99.31 % closed
# counter= 231860 : at t = 64.41 hours, pore is 99.32 % closed
# counter= 231870 : at t = 64.41 hours, pore is 99.32 % closed
# counter= 231880 : at t = 64.41 hours, pore is 99.33 % closed
# counter= 231890 : at t = 64.41 hours, pore is 99.33 % closed
# counter= 231900 : at t = 64.42 hours, pore is 99.33 % closed
# counter= 231910 : at t = 64.42 hours, pore is 99.34 % closed
# counter= 231920 : at t = 64.42 hours, pore is 99.34 % closed
# counter= 231930 : at t = 64.43 hours, pore is 99.35 % closed
# counter= 231940 : at t = 64.43 hours, pore is 99.35 % closed
# counter= 231950 : at t = 64.43 hours, pore is 99.36 % closed
# counter= 231960 : at t = 64.43 hours, pore is 99.36 % closed
# counter= 231970 : at t = 64.44 hours, pore is 99.36 % closed
# counter= 231980 : at t = 64.44 hours, pore is 99.37 % closed
# counter= 231990 : at t = 64.44 hours, pore is 99.37 % closed
# counter= 232000 : at t = 64.44 hours, pore is 99.38 % closed
# counter= 232010 : at t = 64.45 hours, pore is 99.38 % closed
# counter= 232020 : at t = 64.45 hours, pore is 99.39 % closed
# counter= 232030 : at t = 64.45 hours, pore is 99.39 % closed
# counter= 232040 : at t = 64.46 hours, pore is 99.39 % closed
# counter= 232050 : at t = 64.46 hours, pore is 99.4 % closed
# counter= 232060 : at t = 64.46 hours, pore is 99.4 % closed
# counter= 232070 : at t = 64.46 hours, pore is 99.41 % closed
# counter= 232080 : at t = 64.47 hours, pore is 99.41 % closed
# counter= 232090 : at t = 64.47 hours, pore is 99.41 % closed
# counter= 232100 : at t = 64.47 hours, pore is 99.42 % closed
# counter= 232110 : at t = 64.48 hours, pore is 99.42 % closed
# counter= 232120 : at t = 64.48 hours, pore is 99.43 % closed
# counter= 232130 : at t = 64.48 hours, pore is 99.43 % closed
# counter= 232140 : at t = 64.48 hours, pore is 99.44 % closed
# counter= 232150 : at t = 64.49 hours, pore is 99.44 % closed
# counter= 232160 : at t = 64.49 hours, pore is 99.44 % closed
# counter= 232170 : at t = 64.49 hours, pore is 99.45 % closed
# counter= 232180 : at t = 64.49 hours, pore is 99.45 % closed
# counter= 232190 : at t = 64.5 hours, pore is 99.46 % closed
# counter= 232200 : at t = 64.5 hours, pore is 99.46 % closed
# counter= 232210 : at t = 64.5 hours, pore is 99.47 % closed
# counter= 232220 : at t = 64.51 hours, pore is 99.47 % closed
# counter= 232230 : at t = 64.51 hours, pore is 99.47 % closed
# counter= 232240 : at t = 64.51 hours, pore is 99.48 % closed
# counter= 232250 : at t = 64.51 hours, pore is 99.48 % closed
# counter= 232260 : at t = 64.52 hours, pore is 99.49 % closed
# counter= 232270 : at t = 64.52 hours, pore is 99.49 % closed
# counter= 232280 : at t = 64.52 hours, pore is 99.5 % closed
# counter= 232290 : at t = 64.53 hours, pore is 99.5 % closed
# counter= 232300 : at t = 64.53 hours, pore is 99.5 % closed
# counter= 232310 : at t = 64.53 hours, pore is 99.51 % closed
# counter= 232320 : at t = 64.53 hours, pore is 99.51 % closed
# counter= 232330 : at t = 64.54 hours, pore is 99.52 % closed
# counter= 232340 : at t = 64.54 hours, pore is 99.52 % closed
# counter= 232350 : at t = 64.54 hours, pore is 99.52 % closed
# counter= 232360 : at t = 64.54 hours, pore is 99.53 % closed
# counter= 232370 : at t = 64.55 hours, pore is 99.53 % closed
# counter= 232380 : at t = 64.55 hours, pore is 99.54 % closed
# counter= 232390 : at t = 64.55 hours, pore is 99.54 % closed
# counter= 232400 : at t = 64.56 hours, pore is 99.55 % closed
# counter= 232410 : at t = 64.56 hours, pore is 99.55 % closed
# counter= 232420 : at t = 64.56 hours, pore is 99.55 % closed
# counter= 232430 : at t = 64.56 hours, pore is 99.56 % closed
# counter= 232440 : at t = 64.57 hours, pore is 99.56 % closed
# counter= 232450 : at t = 64.57 hours, pore is 99.57 % closed
# counter= 232460 : at t = 64.57 hours, pore is 99.57 % closed
# counter= 232470 : at t = 64.58 hours, pore is 99.58 % closed
# counter= 232480 : at t = 64.58 hours, pore is 99.58 % closed
# counter= 232490 : at t = 64.58 hours, pore is 99.58 % closed
# counter= 232500 : at t = 64.58 hours, pore is 99.59 % closed
# counter= 232510 : at t = 64.59 hours, pore is 99.59 % closed
# counter= 232520 : at t = 64.59 hours, pore is 99.6 % closed
# counter= 232530 : at t = 64.59 hours, pore is 99.6 % closed
# counter= 232540 : at t = 64.59 hours, pore is 99.61 % closed
# counter= 232550 : at t = 64.6 hours, pore is 99.61 % closed
# counter= 232560 : at t = 64.6 hours, pore is 99.61 % closed
# counter= 232570 : at t = 64.6 hours, pore is 99.62 % closed
# counter= 232580 : at t = 64.61 hours, pore is 99.62 % closed
# counter= 232590 : at t = 64.61 hours, pore is 99.63 % closed
# counter= 232600 : at t = 64.61 hours, pore is 99.63 % closed
# counter= 232610 : at t = 64.61 hours, pore is 99.64 % closed
# counter= 232620 : at t = 64.62 hours, pore is 99.64 % closed
# counter= 232630 : at t = 64.62 hours, pore is 99.64 % closed
# counter= 232640 : at t = 64.62 hours, pore is 99.65 % closed
# counter= 232650 : at t = 64.63 hours, pore is 99.65 % closed
# counter= 232660 : at t = 64.63 hours, pore is 99.66 % closed
# counter= 232670 : at t = 64.63 hours, pore is 99.66 % closed
# counter= 232680 : at t = 64.63 hours, pore is 99.66 % closed
# counter= 232690 : at t = 64.64 hours, pore is 99.67 % closed
# counter= 232700 : at t = 64.64 hours, pore is 99.67 % closed
# counter= 232710 : at t = 64.64 hours, pore is 99.68 % closed
# counter= 232720 : at t = 64.64 hours, pore is 99.68 % closed
# counter= 232730 : at t = 64.65 hours, pore is 99.69 % closed
# counter= 232740 : at t = 64.65 hours, pore is 99.69 % closed
# counter= 232750 : at t = 64.65 hours, pore is 99.69 % closed
# counter= 232760 : at t = 64.66 hours, pore is 99.7 % closed
# counter= 232770 : at t = 64.66 hours, pore is 99.7 % closed
# counter= 232780 : at t = 64.66 hours, pore is 99.71 % closed
# counter= 232790 : at t = 64.66 hours, pore is 99.71 % closed
# counter= 232800 : at t = 64.67 hours, pore is 99.72 % closed
# counter= 232810 : at t = 64.67 hours, pore is 99.72 % closed
# counter= 232820 : at t = 64.67 hours, pore is 99.72 % closed
# counter= 232830 : at t = 64.68 hours, pore is 99.73 % closed
# counter= 232840 : at t = 64.68 hours, pore is 99.73 % closed
# counter= 232850 : at t = 64.68 hours, pore is 99.74 % closed
# counter= 232860 : at t = 64.68 hours, pore is 99.74 % closed
# counter= 232870 : at t = 64.69 hours, pore is 99.75 % closed
# counter= 232880 : at t = 64.69 hours, pore is 99.75 % closed
# counter= 232890 : at t = 64.69 hours, pore is 99.75 % closed
# counter= 232900 : at t = 64.69 hours, pore is 99.76 % closed
# counter= 232910 : at t = 64.7 hours, pore is 99.76 % closed
# counter= 232920 : at t = 64.7 hours, pore is 99.77 % closed
# counter= 232930 : at t = 64.7 hours, pore is 99.77 % closed
# counter= 232940 : at t = 64.71 hours, pore is 99.78 % closed
# counter= 232950 : at t = 64.71 hours, pore is 99.78 % closed
# counter= 232960 : at t = 64.71 hours, pore is 99.78 % closed
# counter= 232970 : at t = 64.71 hours, pore is 99.79 % closed
# counter= 232980 : at t = 64.72 hours, pore is 99.79 % closed
# counter= 232990 : at t = 64.72 hours, pore is 99.8 % closed
# counter= 233000 : at t = 64.72 hours, pore is 99.8 % closed
# counter= 233010 : at t = 64.73 hours, pore is 99.8 % closed
# counter= 233020 : at t = 64.73 hours, pore is 99.81 % closed
# counter= 233030 : at t = 64.73 hours, pore is 99.81 % closed
# counter= 233040 : at t = 64.73 hours, pore is 99.82 % closed
# counter= 233050 : at t = 64.74 hours, pore is 99.82 % closed
# counter= 233060 : at t = 64.74 hours, pore is 99.83 % closed
# counter= 233070 : at t = 64.74 hours, pore is 99.83 % closed
# counter= 233080 : at t = 64.74 hours, pore is 99.83 % closed
# counter= 233090 : at t = 64.75 hours, pore is 99.84 % closed
# counter= 233100 : at t = 64.75 hours, pore is 99.84 % closed
# counter= 233110 : at t = 64.75 hours, pore is 99.85 % closed
# counter= 233120 : at t = 64.76 hours, pore is 99.85 % closed
# counter= 233130 : at t = 64.76 hours, pore is 99.86 % closed
# counter= 233140 : at t = 64.76 hours, pore is 99.86 % closed
# counter= 233150 : at t = 64.76 hours, pore is 99.86 % closed
# counter= 233160 : at t = 64.77 hours, pore is 99.87 % closed
# counter= 233170 : at t = 64.77 hours, pore is 99.87 % closed
# counter= 233180 : at t = 64.77 hours, pore is 99.88 % closed
# counter= 233190 : at t = 64.78 hours, pore is 99.88 % closed
# counter= 233200 : at t = 64.78 hours, pore is 99.89 % closed
# counter= 233210 : at t = 64.78 hours, pore is 99.89 % closed
# counter= 233220 : at t = 64.78 hours, pore is 99.89 % closed
# counter= 233230 : at t = 64.79 hours, pore is 99.9 % closed
# counter= 233240 : at t = 64.79 hours, pore is 99.9 % closed
# counter= 233250 : at t = 64.79 hours, pore is 99.91 % closed
# counter= 233260 : at t = 64.79 hours, pore is 99.91 % closed
# counter= 233270 : at t = 64.8 hours, pore is 99.92 % closed
# counter= 233280 : at t = 64.8 hours, pore is 99.92 % closed
# counter= 233290 : at t = 64.8 hours, pore is 99.92 % closed
# counter= 233300 : at t = 64.81 hours, pore is 99.93 % closed
# counter= 233310 : at t = 64.81 hours, pore is 99.93 % closed
# counter= 233320 : at t = 64.81 hours, pore is 99.94 % closed
# counter= 233330 : at t = 64.81 hours, pore is 99.94 % closed
# counter= 233340 : at t = 64.82 hours, pore is 99.94 % closed
# counter= 233350 : at t = 64.82 hours, pore is 99.95 % closed
# counter= 233360 : at t = 64.82 hours, pore is 99.95 % closed
# counter= 233370 : at t = 64.83 hours, pore is 99.96 % closed
# counter= 233380 : at t = 64.83 hours, pore is 99.96 % closed
# counter= 233390 : at t = 64.83 hours, pore is 99.97 % closed
# counter= 233400 : at t = 64.83 hours, pore is 99.97 % closed
# counter= 233410 : at t = 64.84 hours, pore is 99.97 % closed
# counter= 233420 : at t = 64.84 hours, pore is 99.98 % closed
# counter= 233430 : at t = 64.84 hours, pore is 99.98 % closed
# counter= 233440 : at t = 64.84 hours, pore is 99.99 % closed
# counter= 233450 : at t = 64.85 hours, pore is 99.99 % closed
# counter= 233460 : at t = 64.85 hours, pore is 100.0 % closed
# counter= 233470 : at t = 64.85 hours, pore is 100.0 % closed
# 233471
# xi= [9.49427696e-05 1.85310548e-04 2.92451811e-04 4.11587132e-04
#  5.39182490e-04 6.72469390e-04 8.09198203e-04 9.47494531e-04
#  1.08576826e-03 1.22265239e-03 1.35696001e-03 1.48765293e-03
#  1.61381810e-03 1.73464962e-03 1.84943457e-03 1.95754185e-03
#  2.05841316e-03 2.15155571e-03 2.23653623e-03 2.31297610e-03
#  2.38054733e-03 2.43896922e-03 2.48800568e-03 2.52746304e-03
#  2.55718830e-03 2.57706782e-03 2.58702634e-03 2.58702634e-03]
# moose input for damage is:  if(y>=7.222222222222222e-05, 9.494276955874269e-05, if(y>=6.944444444444443e-05, 0.0001853105483650713, if(y>=6.666666666666666e-05, 0.0002924518106639339, if(y>=6.388888888888888e-05, 0.00041158713163677184, if(y>=6.111111111111111e-05, 0.0005391824904057366, if(y>=5.8333333333333326e-05, 0.0006724693901520869, if(y>=5.555555555555555e-05, 0.0008091982031581124, if(y>=5.277777777777777e-05, 0.000947494531272611, if(y>=4.9999999999999996e-05, 0.0010857682579710401, if(y>=4.7222222222222214e-05, 0.0012226523891018342, if(y>=4.444444444444444e-05, 0.0013569600142332803, if(y>=4.1666666666666665e-05, 0.001487652928336063, if(y>=3.8888888888888884e-05, 0.001613818099883416, if(y>=3.611111111111111e-05, 0.0017346496156532868, if(y>=3.333333333333333e-05, 0.0018494345672069202, if(y>=3.0555555555555554e-05, 0.00195754184966835, if(y>=2.7777777777777776e-05, 0.0020584131622068008, if(y>=2.4999999999999998e-05, 0.002151555707425617, if(y>=2.222222222222222e-05, 0.0022365362263992755, if(y>=1.9444444444444442e-05, 0.002312976102273095, if(y>=1.6666666666666664e-05, 0.0023805473332068065, if(y>=1.3888888888888888e-05, 0.0024389692243326536, if(y>=1.111111111111111e-05, 0.002488005684417025, if(y>=8.333333333333332e-06, 0.0025274630399594157, if(y>=5.555555555555555e-06, 0.0025571883002365246, if(y>=2.7777777777777775e-06, 0.0025770678230256556, if(y>=0.0, 0.0025870263440755945,  0)))))))))))))))))))))))))))

# %%
fig, ax = plt.subplots(figsize = (5,2.7), layout='constrained')

ax.plot(b[0]*1e3,b[5]*1e6,label='1273K',color='red',linewidth=3)
ax.plot(c[0]*1e3,c[5]*1e6,label='1223K',color='orange',linewidth=3)
ax.plot(d[0]*1e3,d[5]*1e6,label='1173K',color='green',linewidth=3)
ax.plot(f[0]*1e3,f[5]*1e6,label='1123K',color='blue',linewidth=3)
ax.plot(g[0]*1e3,g[5]*1e6,label='1073K',color='black',linewidth=3)


plt.ylim([0,50])
# plt.xlim([0,5])
plt.yticks(np.arange(0, 60, step=10))
plt.xticks(np.arange(0, 6, step=1))
ax.set_xlabel('z mm')
ax.set_ylabel(r'$d \ \mu m$')
ax.set_title(r'$\xi_0 = 0.30, \ \alpha=1$') 
ax.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.savefig('sample.svg', dpi=220,bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 ax.plot(c[0]*1e3,c[5]*1e6,label='1223K',color='orange',linewidth=3)
#       5 ax.plot(d[0]*1e3,d[5]*1e6,label='1173K',color='green',linewidth=3)
# ----> 6 ax.plot(f[0]*1e3,f[5]*1e6,label='1123K',color='blue',linewidth=3)
#       7 ax.plot(g[0]*1e3,g[5]*1e6,label='1073K',color='black',linewidth=3)
#      10 plt.ylim([0,50])
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
from datetime import date
today = date.today()

f = open(r'/Users/jjmarzia/Desktop/cvisim/moose_inputs/1273_95__'+str(today)+r'.txt', "w")
f.write("\n========="+str(today)+"===\n")
f.write(str(b[-1]))
f.write("\n======================\n")
f.close()

f = open(r'/Users/jjmarzia/Desktop/cvisim/moose_inputs/1223_95__'+str(today)+r'.txt', "w")
f.write("\n========="+str(today)+"===\n")
f.write(str(c[-1]))
f.write("\n======================\n")
f.close()

f = open(r'/Users/jjmarzia/Desktop/cvisim/moose_inputs/1173_95__'+str(today)+r'.txt', "w")
f.write("\n========="+str(today)+"===\n")
f.write(str(d[-1]))
f.write("\n======================\n")
f.close()

f = open(r'/Users/jjmarzia/Desktop/cvisim/moose_inputs/1123_95__'+str(today)+r'.txt', "w")
f.write("\n========="+str(today)+"===\n")
f.write(str(f[-1]))
f.write("\n======================\n")
f.close()

f = open(r'/Users/jjmarzia/Desktop/cvisim/moose_inputs/1073_95__'+str(today)+r'.txt', "w")
f.write("\n========="+str(today)+"===\n")
f.write(str(g[-1]))
f.write("\n======================\n")
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 24
#      22 f = open(r'/Users/jjmarzia/Desktop/cvisim/moose_inputs/1123_95__'+str(today)+r'.txt', "w")
#      23 f.write("\n========="+str(today)+"===\n")
# ---> 24 f.write(str(f[-1]))
#      25 f.write("\n======================\n")
#      26 f.close()
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(a[-1],a[-2],label='K='+str(round(a[-5],6)))
# # ax.plot(b[-1],b[-2],label='9.85')

# ax.set_xlabel('t s')
# ax.set_ylabel('$r_p$ $\mu$m')
# # plt.xlim([0,1000])
# # plt.xticks(np.arange(0, 6, step=1))
# # plt.ylim([0,50])
# # plt.yticks(np.arange(0, (50 + 50/5), step=50/5))
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('dP.svg', dpi=220,bbox_inches='tight')

# %%
# c = cvi_nonlinear(1223,2000,34e-6, 10e-3/34e-6, 5, "blue",r"$1273$K, $dt = 1$s",100,"phi")
# b = cvi_nonlinear(1223,10000,34e-6, 10e-3/34e-6, 5, "blue",r"$1273$K, $dt = 1$s",10,"phi")
# a = cvi_nonlinear(1223,20000,34e-6, 10e-3/34e-6, 5, "blue",r"$1273$K, $dt = 1$s",10,"phi")

# %%
#P comparison

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# arr_10kpa_x = np.array([0.89,1.48,1.89,2.89,3.08,5.68])
# arr_10kpa_y = np.array([0.92,6.98,9.98,13.01,13.49,15.76])

# arr_2kpa_x = np.array([0.41, 2.38, 3.28, 4.39, 4.99])
# arr_2kpa_y = np.array([0.76, 14.68, 16, 16.7,16.92])

# arr_10kpa_x = arr_10kpa_x - arr_10kpa_x[0]
# arr_2kpa_x = arr_2kpa_x - arr_2kpa_x[0]
# arr_10kpa_y = 17 - (arr_10kpa_y - arr_10kpa_y[0])
# arr_2kpa_y = 17 - (arr_2kpa_y - arr_2kpa_y[0])

# # ax.plot(b[0]*1000,a[5]*1e6,label=r'20kPa',color='blue')
# ax.plot(b[0]*1000,b[5]*1e6,label=r'10kPa, calc',color='green')
# ax.scatter(arr_10kpa_x, arr_10kpa_y,color='green',label='10kPa, exp',marker=matplotlib.markers.CARETUPBASE)
# ax.plot(c[0]*1000,c[5]*1e6,label=r'2kPa, calc',color='red')
# ax.scatter(arr_2kpa_x, arr_2kpa_y,color='red',label='2kPa, exp',marker=matplotlib.markers.CARETDOWNBASE)

# ax.set_xlabel('z mm')
# ax.set_ylabel('$d$ $\mu$m')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([0,17])
# plt.yticks(np.arange(0, (17 + 17/5), step=17/5))
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('dP.svg', dpi=220,bbox_inches='tight')

# %%
# llp = cvi_nonlinear(1173,5000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# lp = cvi_nonlinear(1173,10000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# n = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",500,"phi")

# %%
# hp = cvi_nonlinear(1173,35000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# %%
# hhp = cvi_nonlinear(1173,50000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",200,"phi")

# %%
# b = cvi_nonlinear(1123,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# c = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",500,"phi")

# %%
# d = cvi_nonlinear(1223,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# %%
# e = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",50,"phi")

# %%
# f = cvi_nonlinear(1283,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",40,"phi")

# %%
# g= cvi_nonlinear(1293,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",30,"phi")

# %%
# h= cvi_nonlinear(1303,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",25,"phi")

# %%
# fig, ax = plt.subplots(figsize = (7,3), layout='constrained')

# tp_t = np.array([1073, 1173, 1173, 1173, 1173, 1173, 1273])
# tp_p = np.array([20, 5, 10, 20, 35, 50, 20])
# tp_tf = np.array([358.33, 92.22, 46.11, str(23.06)+' hrs', 13.67, 9.22, 2.31])

# ax.scatter(tp_t, tp_p,color='red')
# for i, txt in enumerate(tp_tf):
#     ax.annotate(txt, (tp_t[i],tp_p[i]),fontsize=13)

# ax.set_xlabel('$T$ K')
# ax.set_ylabel('$P$ kPa')
# plt.xlim([1073-27,1300])
# plt.xticks(np.arange(1073, 1373, step=100))
# plt.ylim([0,60])
# plt.yticks(np.arange(0, 60, step=10))
# plt.title(r'$t_f$ vs. {$T,P$}')
# # plt.legend(bbox_to_anchor=(1.05, 1.1), loc="upper left")
# ax.grid(True)

# plt.savefig('pt.svg', dpi=220,bbox_inches='tight')

# %%
# i= cvi_nonlinear(1313,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",5,"phi")

# %%
# #T comparison

# c = cvi_nonlinear(1073,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",10000,"phi")
# b = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")
# a = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1,"phi")

# %%
# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# arr_10kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_10kpa_y = np.array([2.62, 3.38, 3.88, 4.05, 4.22, 4.31])

# arr_11kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_11kpa_y = np.array([2.62, 7.43, 11.06, 13.26, 14.19, 14.70])

# arr_12kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_12kpa_y = np.array([2.62, 18.66, 28.88, 33.78, 36.57, 37.33])

# arr_10kpa_x = arr_10kpa_x - arr_10kpa_x[0]
# arr_11kpa_x = arr_11kpa_x - arr_11kpa_x[0]
# arr_12kpa_x = arr_12kpa_x - arr_12kpa_x[0]

# arr_10kpa_y = 50 - (arr_10kpa_y - arr_10kpa_y[0])
# arr_11kpa_y = 50 - (arr_11kpa_y - arr_11kpa_y[0])
# arr_12kpa_y = 50 - (arr_12kpa_y - arr_12kpa_y[0])
# ax.plot(b[0]*1000,c[5]*1e6,label=r'1073K',color='blue')
# ax.scatter(arr_10kpa_x, arr_10kpa_y,color='blue',label='1073K, exp',marker=matplotlib.markers.CARETDOWNBASE)
# ax.plot(b[0]*1000,b[5]*1e6,label=r'1173K',color='green')
# ax.scatter(arr_11kpa_x, arr_11kpa_y,color='green',label='1173K, exp',marker='X')
# ax.plot(b[0]*1000,a[5]*1e6,label=r'1273K',color='red')
# ax.scatter(arr_12kpa_x, arr_12kpa_y,color='red',label='1273K, exp',marker=matplotlib.markers.CARETUPBASE)




# ax.set_xlabel('z mm')
# ax.set_ylabel('$d$ $\mu$m')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([0,50])
# plt.yticks(np.arange(0, 60, step=10))
# plt.legend(bbox_to_anchor=(1.05, 1.1), loc="upper left")
# ax.grid(True)

# plt.savefig('dT.svg', dpi=220,bbox_inches='tight')

# %%
#alpha comparison

# c = cvi_nonlinear(1273,20000,100e-6, 100, 100, "blue",r"$1273$K, $dt = 1$s",1000,"phi")
# b = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# a = cvi_nonlinear(1273,20000,100e-6, 100, 1, "blue",r"$1273$K, $dt = 1$s",10,"phi")

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(a[0]*1000,a[1],label=r'MTS',color='red')
# ax.plot(a[0]*1000,a[2],label=r'H2',color='blue')
# ax.plot(a[0]*1000,a[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.title(r'$\alpha=1$')
# plt.ylim([0,1.5])
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha1.svg', dpi=220,bbox_inches='tight')


# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(b[0]*1000,b[1],label=r'MTS',color='red')
# ax.plot(b[0]*1000,b[2],label=r'H2',color='blue')
# ax.plot(b[0]*1000,b[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.title(r'$\alpha=10$')
# plt.ylim([-0.2,2])
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha10.svg', dpi=220,bbox_inches='tight')

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(c[0]*1000,c[1],label=r'MTS',color='red')
# ax.plot(c[0]*1000,c[2],label=r'H2',color='blue')
# ax.plot(c[0]*1000,c[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([-0.2,2])
# plt.title(r'$\alpha=100$')
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha100.svg', dpi=220,bbox_inches='tight')
