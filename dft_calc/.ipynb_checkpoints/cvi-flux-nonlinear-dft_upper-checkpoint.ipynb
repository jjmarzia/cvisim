# %%
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats, optimize, interpolate
from scipy.optimize import fsolve
from scipy.integrate import odeint
from scipy.integrate import solve_bvp
from scipy.linalg import solve_banded
plt.rcParams.update({'font.size': 18})

# %%
#
# Define function cvi_sim which computes resulting pore radius/gas concentration profiles as a function of CVI process parameters
#

def cvi_nonlinear(Tin,Pin, phi0in, rin, ain,plot_line_color,plot_line_label,dt,variable_plotted): # Temperature, pressure, initial pore diameter, aspect ratio, phase ratio, line color, line label, time stepper, variable to plot (between rp and C). 
    
    
    ###
    # CVI CONDITIONS
    ###
    
    phi0 = phi0in     # Pore diameter, m  
    L = rin*phi0      # Length, m
    nz = 28         # Number of grid points, dimensionless
    h = L/(nz+1)      # Distance between grid points, m
    hh = h**2
    dt = dt           # Time stepper, s

    phii = phi0*np.ones(nz)
    phi = phii
    
    Zrange = np.linspace(0,L/2,nz)           # Grid that represents length of specimen
    alpha = ain                            # Ratio between H2 and MTS concentrations at reactor entrance, dimensionless
    P = Pin                                # Pressure, Pa
    T = Tin                                # Temperature, K
    
    
    R = 8.314                              # Ideal gas constant, J/mol K
    
    CMTS0 = (1/(1+alpha))*(P / (R*T))      # MTS concentration at z=0 (BC), mol/m^3
    CH20 = (alpha/(1+alpha))*(P / (R*T))   # H2 concentration at z=0 (1-CMTS0), mol/m^3,  Fedou1993-2 Eqs. 9-10
    CHCl0 = 0                              # HCl concentration at z=0 (1-CMTS0), mol/m^3
    
    k0 = 3.89e9                            # Reaction rate coefficient, m/s
    Ea = 296e3                             # Activation energy, J/mol
    
    CMTS = CMTS0*np.ones(nz)
    CMTS[0] = CMTS0
    CH2 = CH20*np.ones(nz)                     # Gas phase composition at pore entrance, Fedou1993-2 Eqs. 9-10
    CH2[0] = CH20
    CHCl = CHCl0*np.ones(nz)
    CHCl[0] = CHCl0
    
    Ct0_before_penetration = [CMTS, CH2, CHCl]
    
    khet = k0*np.exp(-Ea/(R*T))
    print('khet_fedou=',khet)
    
    
    #### Walker DFT paper
    R = 8.617333262e-5
    T = 1273
    # Ea = 0.918 #mean
    # Ea = 0.493 #lower bound
    Ea = 1.342 #upper bound
    khet = np.exp(-Ea/(R*T))
    print("khet_walker=",khet)
    ####
    
    nu = khet*CMTS         # Kinetic law, Fedou1993-2 Eq. 3
    
    dKMTS = 3.97 #m/sK^(1/2)               # Reduced Knudsen coefficient of MTS, m/s K^1/2
    dKH2 = 34.30 #m/sK^(1/2)               # Reduced Knudsen coefficient of H2, m/s K^1/2,  Fedou1993-2 Table I
    dKHCl = 8.03 #m/sK^(1/2)               # Reduced Knudsen coefficient of HCl, m/s K^1/2
    
    DKMTS=dKMTS*phi*(T**0.5)              # Knudsen diffusion coefficient of MTS, m^2/s 
    DKH2=dKH2*phi*(T**0.5)                # Knudsen diffusion coefficient of H2, m^2/s,  Fedou1993-2 Eq. 2
    DKHCl=dKHCl*phi*(T**0.5)              # Knudsen diffusion coefficient of HCl, m^2/s 
    
    # MSiC = 0.04011                       # Molar mass of SiC, kg/mol
    MMTS = 0.149                             # Molar mass of MTS, kg/mol
    MH2 = 2e-3                             # Molar mass of H2, kg/mol,  Fedou1993-2 Table I
    MHCl = 3.65e-2                         # Molar mass of HCl, kg/mol
    
    # rhoSiC = 3217                        # Density of SiC, kg/m^3
    # rhoMTS = 1270
    # rhoH2 = 0.08375
    # rhoHCl = 1048
    
    VSiC = 12.5e-6                         # Specific volume of SiC, m^3/mol,  Fedou1993-2 Section 2.2
    VMTS = 122.7e-6                          # Specific volume of MTS, m^3/mol
    VH2  = 14.3e-6                            # Specific volume of H2, m^3/mol,  Fedou1993-2 Table III
    VHCl = 25.3e-6                          # Specific volume of HCl, m^3/mol
    
    # VMTS = 122.7                          # Specific volume of MTS, cm^3/mol
    # VH2  = 14.3                            # Specific volume of H2, cm^3/mol,  Fedou1993-2 Table III
    # VHCl = 25.3                          # Specific volume of HCl, cm^3/mol
    
    sMTS = -1
    sH2 = 0                               # Stoichiometric coefficients of the chemical elements, Fedou1993-1 Eq. 1 and Fedou1993-2 Eq. 1
    sHCl = 3
    sSiC = 1
    deltas = sMTS + sH2 + sHCl + sSiC             # Sum of coefficients, Fedou1993-1 Eq. 11
    s = [sMTS, sH2, sHCl, sSiC]

    Dij_MTSH2 = 1.360e-3*((T**(3/2))/(P*(VH2**(1/3)+VMTS**(1/3))**2))*(1/MH2 + 1/MMTS)**0.5
    Dij_MTSHCl = 1.360e-3*((T**(3/2))/(P*(VHCl**(1/3)+VMTS**(1/3))**2))*(1/MHCl + 1/MMTS)**0.5   # Gilliland formula, Fedou1993-1 Appendix 1 Eq A4
    
    epsik = 59.7
    sigi = 0.2827e-9
    epsjk = 344.7
    sigj = 0.3339e-9
    sigij = (sigi+sigj)/2
    kepsij = (epsik * epsjk)**(-0.5)
    Tstar = kepsij*T
    Tstar = np.rint(Tstar)
    if Tstar ==7:
        omegaD = 0.79643333
    if Tstar == 8: 
        omegaD = 0.78003333                # Hirschfelder formula, Fedou1993-1 Appendix 1 Eqs. A1-A3; calculation of 
    if Tstar == 9:
        omegaD = 0.76611111
    if Tstar == 10:
        omegaD = 0.75401111
    V = 2.78125e4

    Dij_H2HCl = 5.876e-24  *((T**1.5)/(P*(sigij**2)*V*omegaD))*((1/MH2 + 1/MHCl)**0.5)
    Dij_H2HCl = 1.360e-3*((T**(3/2))/(P*(VHCl**(1/3)+VH2**(1/3))**2))*(1/MHCl + 1/MH2)**0.5 
    # print("dfomega=",Dij_H2HCl, "dfvhcl=",Dij_H2HCl_v2)
    
    N = deltas*nu
    
    xMTS  = CMTS/(CMTS+CH2+CHCl)
    xH2 = CH2/(CMTS+CH2+CHCl)                                     # Molar fractions, Fedou1993-1 Eq. 13                                    
    xHCl = CHCl/(CMTS+CH2+CHCl)
    
    dxMTSdz = dxH2dz = dxHCldz = np.zeros(nz)
    
    # DFMTS = ((1/(1-xMTS[0]))*(xHCl[0]/Dij_MTSHCl + xH2[0]/Dij_MTSH2))**(-1)
    # DFH2 = ((1/(1-xH2[0]))*(xHCl[0]/Dij_H2HCl + xMTS[0]/Dij_MTSH2))**(-1)      # Fick diffusion coefficients, Fedou1993-1 Eq. 16
    # DFHCl = ((1/(1-xHCl[0]))*(xH2[0]/Dij_H2HCl + xMTS[0]/Dij_MTSHCl))**(-1)
    
    DFMTS = ((1/(1-xMTS))*(xHCl/Dij_MTSHCl + xH2/Dij_MTSH2))**(-1)
    DFH2 = ((1/(1-xH2))*(xHCl/Dij_H2HCl + xMTS/Dij_MTSH2))**(-1)      # Fick diffusion coefficients, Fedou1993-1 Eq. 16
    DFHCl = ((1/(1-xHCl))*(xH2/Dij_H2HCl + xMTS/Dij_MTSHCl))**(-1)

    DMTS = (1/DFMTS + 1/DKMTS)**(-1)          
    DH2 = (1/DFH2 + 1/DKH2)**(-1)          # Overall diffusion coefficient, Fedou1993-1 Eq. 15
    DHCl = (1/DFHCl + 1/DKHCl)**(-1) 
    
    ###
    # INITIALIZE SOLUTION VECTORS
    ###
    
    Csol = []
    Dsol = []
    for k in range(nz):
        Dsol = np.append(Dsol,DMTS[k])
        Dsol = np.append(Dsol,DH2[k])  # D matrix
        Dsol = np.append(Dsol,DHCl[k])
        Csol = np.append(Csol,CMTS[k])
        Csol = np.append(Csol,CH2[k])  # C matrix
        Csol = np.append(Csol,CHCl[k])
    C0sol = Csol

    print('----------------------------------T=',T,'P=',P, 'CMTS0=',CMTS0,'CH20=',CH20,'CHCl0=',CHCl0)

    
    CMTSt = []                             
    CH2t = []                              # Array containing gas concentration profiles of MTS, H2, HCl
    CHClt = []
    
    phit = []
    rpt = []
    
    percent_closed = 0                     # Dimensionless rating of pore size relative to initial pore size
    counter =0                             # Time counter
    
    
    ###
    # NONLINEAR ITERATIVE SOLVER
    ###
    
    while any(phi<phi0/100) is not True:
        
        # Assemble D, C matrices so that (gas,gridpt)=(i,j) = Cm[3j+i]. Gases\in [0,2] = [MTS, H2, HCl]. Gridpts\in [0,n+1]
        # So C_{1,j} = C_{2,5} = C[3*5 + 2 = C[17].
        Csol = []
        Dsol = []
        
        for k in range(nz):
            Dsol = np.append(Dsol,DMTS[k])
            Dsol = np.append(Dsol,DH2[k])  # D matrix
            Dsol = np.append(Dsol,DHCl[k])
            Csol = np.append(Csol,CMTS[k])
            Csol = np.append(Csol,CH2[k])  # C matrix
            Csol = np.append(Csol,CHCl[k])
        # if counter==0:
        #     print('C=',Csol.size,'D=',Dsol.size)
        #     print(Csol,Dsol)
        
        def F(C, *data_args):
            D, h, hh, N, s, nu, phi = data_args
            exps = []
            n = nz-2
            for j in range(1,n+1): #1\leq j\leq n. #nz=7--> j=1,2,3,4,5     
                # print(C.size)
                # print(j)
                if j==1:
                    xi_jp1 = C[3]/(C[3]+C[4]+C[5])
                    xi_jm1 = CMTS0/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CMTS0 - 2*C[0] + C[3])/hh - (xi_jp1*N[2]-xi_jm1*N[0])/(2*D[0]*h) + (4*s[0]*nu[0])/(D[0]*phi[0]))
                    # print("exps1=",exps.size)
                    
                    xi_jp1 = C[4]/(C[4]+C[5]+C[3])
                    xi_jm1 = CH20/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CH20 - 2*C[1] + C[4])/hh - ((xi_jp1*N[2]-xi_jm1*N[0])/(2*D[1]*h)) + (4*s[1]*nu[0])/(D[1]*phi[0]))
                    # print("exps2=",exps.size)
                    
                    xi_jp1 = C[5]/(C[5]+C[4]+C[3])
                    xi_jm1 = CHCl0/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CHCl0 - 2*C[2] + C[5])/hh - ((xi_jp1*N[2]-xi_jm1*N[0])/(2*D[2]*h)) + (4*s[2]*nu[0])/(D[2]*phi[0]))
                    # print("exps3=",exps.size)
                    
                if not j==1 and not j==n: #j=2,3,4
                    for i in range(3): #i=0,1,2
                        if i==0: #defining molar fractions for each gas i. MTS
                            xi_jp1 = C[3*j]/(C[3*j]+C[3*j+1]+C[3*j+2])
                            xi_jm1 = C[3*(j-2)]/(C[3*(j-2)]+C[3*(j-2)+1]+C[3*(j-2)+2])
                        if i==1: #H2
                            xi_jp1 = C[3*j+1]/(C[3*j+1]+C[3*j+2]+C[3*j])
                            xi_jm1 = C[3*(j-2)+1]/(C[3*(j-2)+1]+C[3*(j-2)+2]+C[3*(j-2)])
                        if i==2: #HCl
                            xi_jp1 = C[3*j+2]/(C[3*j+2]+C[3*j+1]+C[3*j])
                            xi_jm1 = C[3*(j-2)+2]/(C[3*(j-2)+2]+C[3*(j-2)+1]+C[3*(j-2)])

                        expij = (C[3*(j-2)+i] - 2*C[3*(j-1)+i] + C[3*j+i])/hh - (xi_jp1*N[j+1]-xi_jm1*N[j-1])/(2*D[3*(j-1)+i]*h) + (4*s[i]*nu[j-1])/(D[3*(j-1)+i]*phi[j-1])
                        exps = np.append(exps, expij)
                        # print("exps4=",exps.size)
                        
                if j==n: #j=5,
                    for i in range(3):
                        if i==0: #defining molar fractions for each gas i. MTS
                            xi_jp1 = C[3*(n-1)]/(C[3*(n-1)]+C[3*(n-1)+1]+C[3*(n-1)+2])
                            xi_jm1 = C[3*(n-2)]/(C[3*(n-2)]+C[3*(n-2)+1]+C[3*(n-2)+2])
                        if i==1: #H2
                            xi_jp1 = C[3*(n-1)+1]/(C[3*(n-1)+1]+C[3*(n-1)+2]+C[3*(n-1)])
                            xi_jm1 = C[3*(n-2)+1]/(C[3*(n-2)+1]+C[3*(n-2)+2]+C[3*(n-2)])
                        if i==2: #HCl
                            xi_jp1 = C[3*(n-1)+2]/(C[3*(n-1)+2]+C[3*(n-1)+1]+C[3*(n-1)])
                            xi_jm1 = C[3*(n-2)+2]/(C[3*(n-2)+2]+C[3*(n-2)+1]+C[3*(n-2)])

                        expij = (C[3*(n-2)+i] - C[3*(n-1)+i])/hh - (xi_jp1*N[n+1]-xi_jm1*N[n-1])/(2*D[3*(n-1)+i]*h) + (4*s[i]*nu[n-1])/(D[3*(n-1)+i]*phi[n-1])
                        exps = np.append(exps, expij)
            return exps
        
        data_args = (Dsol[3:-3], h, hh, N, s, nu[1:-1], phi[1:-1])
        Csol = fsolve(F, C0sol[3:-3], args=data_args)
        Csol = np.insert(Csol, 0, CHCl0)
        Csol = np.insert(Csol, 0, CH20)           # left boundary condition
        Csol = np.insert(Csol, 0, CMTS0)
        for _ in range(3):
            Csol = np.append(Csol, Csol[-3])      # right boundary condition
            
        CMTS = Csol[0::3]
        CH2 = Csol[1::3]
        CHCl = Csol[2::3]
    
        # khet = k0*np.exp(-Ea/(R*T))
        # khet =
    
        nu = khet*CMTS                            # Kinetic law, Fedou1993-2 Eq. 3
        N = deltas*nu 
        phi = phi - (2*dt*nu*VSiC)                # Update pore diameter

        DFMTS = ((1/(1-xMTS))*(xHCl/Dij_MTSHCl + xH2/Dij_MTSH2))**(-1)
        DFH2 = ((1/(1-xH2))*(xHCl/Dij_H2HCl + xMTS/Dij_MTSH2))**(-1)     # Update Fick diffusion coefficients, Fedou1993-1 Eq. 16
        DFHCl = ((1/(1-xHCl))*(xH2/Dij_H2HCl + xMTS/Dij_MTSHCl))**(-1)
        
        DKMTS = dKMTS*phi*(T**0.5)
        DKH2 = dKH2*phi*(T**0.5)                                      # Update Knudsen diffusion coefficients, Fedou1993-2 Eq. 2
        DKHCl = dKHCl*phi*(T**0.5)

        DMTS = (1/DFMTS + 1/DKMTS)**(-1)          
        DH2 = (1/DFH2 + 1/DKH2)**(-1)                                    # Update overall diffusion coefficient, Fedou1993-1 Eq. 15
        DHCl = (1/DFHCl + 1/DKHCl)**(-1)              

        
        counter+=1
        rpt.append(phi[0]/2)
        if counter % 10 == 0:
            # print(rpt)
            CMTSt.append(CMTS)
            CH2t.append(CH2) # Collect pore diameter/gas concentration profiles at current time step
            CHClt.append(CHCl)
            # print("nu=",nu[0:3],"CMTS=",CMTS[0:3])
            phit.append(phi)
            percent_closed = 100*(1 -(phi[0]-phi0/100)/phi0)
            print('counter=',counter,': at t =',round(counter*dt*0.000277778,2),'hours, pore is', round(percent_closed,2),'% closed')
    print(counter) 
    t_f_hrs = counter*dt*0.000277778
    t_f_secs = counter*dt
    d = (phii-phi)/2
    # print('phi=',phi,'CMTS=', CMTS)
    
    counter_t = np.arange(0,counter,dt)
    # print('counter_t=',counter_t)
    # print(np.shape(counter_t), np.shape(rpt))
    
    
    ###
    # MOOSE DAMAGE INPUT
    ###
    
    rp = phi/2
    porosity = 0.30
    RpRVE = np.sqrt(1/porosity)*(phi0/2)

    # print('rp=',rp)
    xi = (rp**2)/(RpRVE**2)
    
    mesh_height = 7.5e-5
    num_elements = 28 #ideally =nz
    element_positions = np.linspace(0, mesh_height, num_elements)  
    
    moose_input_i = ''
    par_input = ''
    for q in range(num_elements-1):
        moose_input = str(moose_input_i)+'if(y>='+str(element_positions[num_elements-2-q])+', '+str(xi[q])+', '
        moose_input_i = moose_input
        par_input = str(par_input)+')'
    moose_input = str(moose_input_i)+' 0'+str(par_input)
    
    print('xi=',xi)
    print('moose input for damage is: ',moose_input)
    
    
    return [Zrange, CMTS,CH2,CHCl, phi, d, L, str(plot_line_label), rp, xi, khet, t_f_hrs, t_f_secs, rpt, counter_t]

# %%
#
# Call the function cvi_sim
#

# Inputs: Temperature (K), pressure (Pa), pore diameter (m), aspect ratio, gas ratio,      ...
#         plot line color, plot line label, dt, variable to be plotted between "phi" or "C".

# %%
a = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',100,'')
# b = cvi_nonlinear(1073,20000,100e-6, 100, 10, '','',1000,'')
# c = cvi_nonlinear(1303,20000,100e-6, 100, 10, '','',1,'')
# Out:
# khet_fedou= 0.0027786172881957174
# khet_walker= 4.864658704892461e-06
# ----------------------------------T= 1273 P= 20000 CMTS0= 0.1717903983288505 CH20= 1.717903983288505 CHCl0= 0
# counter= 10 : at t = 0.28 hours, pore is 1.02 % closed
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# counter= 20 : at t = 0.56 hours, pore is 1.04 % closed
# counter= 30 : at t = 0.83 hours, pore is 1.06 % closed
# counter= 40 : at t = 1.11 hours, pore is 1.08 % closed
# counter= 50 : at t = 1.39 hours, pore is 1.1 % closed
# counter= 60 : at t = 1.67 hours, pore is 1.13 % closed
# counter= 70 : at t = 1.94 hours, pore is 1.15 % closed
# counter= 80 : at t = 2.22 hours, pore is 1.17 % closed
# counter= 90 : at t = 2.5 hours, pore is 1.19 % closed
# counter= 100 : at t = 2.78 hours, pore is 1.21 % closed
# counter= 110 : at t = 3.06 hours, pore is 1.23 % closed
# counter= 120 : at t = 3.33 hours, pore is 1.25 % closed
# counter= 130 : at t = 3.61 hours, pore is 1.27 % closed
# counter= 140 : at t = 3.89 hours, pore is 1.29 % closed
# counter= 150 : at t = 4.17 hours, pore is 1.31 % closed
# counter= 160 : at t = 4.44 hours, pore is 1.33 % closed
# counter= 170 : at t = 4.72 hours, pore is 1.36 % closed
# counter= 180 : at t = 5.0 hours, pore is 1.38 % closed
# counter= 190 : at t = 5.28 hours, pore is 1.4 % closed
# counter= 200 : at t = 5.56 hours, pore is 1.42 % closed
# counter= 210 : at t = 5.83 hours, pore is 1.44 % closed
# counter= 220 : at t = 6.11 hours, pore is 1.46 % closed
# counter= 230 : at t = 6.39 hours, pore is 1.48 % closed
# counter= 240 : at t = 6.67 hours, pore is 1.5 % closed
# counter= 250 : at t = 6.94 hours, pore is 1.52 % closed
# counter= 260 : at t = 7.22 hours, pore is 1.54 % closed
# counter= 270 : at t = 7.5 hours, pore is 1.56 % closed
# counter= 280 : at t = 7.78 hours, pore is 1.58 % closed
# counter= 290 : at t = 8.06 hours, pore is 1.61 % closed
# counter= 300 : at t = 8.33 hours, pore is 1.63 % closed
# counter= 310 : at t = 8.61 hours, pore is 1.65 % closed
# counter= 320 : at t = 8.89 hours, pore is 1.67 % closed
# counter= 330 : at t = 9.17 hours, pore is 1.69 % closed
# counter= 340 : at t = 9.44 hours, pore is 1.71 % closed
# counter= 350 : at t = 9.72 hours, pore is 1.73 % closed
# counter= 360 : at t = 10.0 hours, pore is 1.75 % closed
# counter= 370 : at t = 10.28 hours, pore is 1.77 % closed
# counter= 380 : at t = 10.56 hours, pore is 1.79 % closed
# counter= 390 : at t = 10.83 hours, pore is 1.81 % closed
# counter= 400 : at t = 11.11 hours, pore is 1.84 % closed
# counter= 410 : at t = 11.39 hours, pore is 1.86 % closed
# counter= 420 : at t = 11.67 hours, pore is 1.88 % closed
# counter= 430 : at t = 11.94 hours, pore is 1.9 % closed
# counter= 440 : at t = 12.22 hours, pore is 1.92 % closed
# counter= 450 : at t = 12.5 hours, pore is 1.94 % closed
# counter= 460 : at t = 12.78 hours, pore is 1.96 % closed
# counter= 470 : at t = 13.06 hours, pore is 1.98 % closed
# counter= 480 : at t = 13.33 hours, pore is 2.0 % closed
# counter= 490 : at t = 13.61 hours, pore is 2.02 % closed
# counter= 500 : at t = 13.89 hours, pore is 2.04 % closed
# counter= 510 : at t = 14.17 hours, pore is 2.07 % closed
# counter= 520 : at t = 14.44 hours, pore is 2.09 % closed
# counter= 530 : at t = 14.72 hours, pore is 2.11 % closed
# counter= 540 : at t = 15.0 hours, pore is 2.13 % closed
# counter= 550 : at t = 15.28 hours, pore is 2.15 % closed
# counter= 560 : at t = 15.56 hours, pore is 2.17 % closed
# counter= 570 : at t = 15.83 hours, pore is 2.19 % closed
# counter= 580 : at t = 16.11 hours, pore is 2.21 % closed
# counter= 590 : at t = 16.39 hours, pore is 2.23 % closed
# counter= 600 : at t = 16.67 hours, pore is 2.25 % closed
# counter= 610 : at t = 16.94 hours, pore is 2.27 % closed
# counter= 620 : at t = 17.22 hours, pore is 2.3 % closed
# counter= 630 : at t = 17.5 hours, pore is 2.32 % closed
# counter= 640 : at t = 17.78 hours, pore is 2.34 % closed
# counter= 650 : at t = 18.06 hours, pore is 2.36 % closed
# counter= 660 : at t = 18.33 hours, pore is 2.38 % closed
# counter= 670 : at t = 18.61 hours, pore is 2.4 % closed
# counter= 680 : at t = 18.89 hours, pore is 2.42 % closed
# counter= 690 : at t = 19.17 hours, pore is 2.44 % closed
# counter= 700 : at t = 19.44 hours, pore is 2.46 % closed
# counter= 710 : at t = 19.72 hours, pore is 2.48 % closed
# counter= 720 : at t = 20.0 hours, pore is 2.5 % closed
# counter= 730 : at t = 20.28 hours, pore is 2.53 % closed
# counter= 740 : at t = 20.56 hours, pore is 2.55 % closed
# counter= 750 : at t = 20.83 hours, pore is 2.57 % closed
# counter= 760 : at t = 21.11 hours, pore is 2.59 % closed
# counter= 770 : at t = 21.39 hours, pore is 2.61 % closed
# counter= 780 : at t = 21.67 hours, pore is 2.63 % closed
# counter= 790 : at t = 21.94 hours, pore is 2.65 % closed
# counter= 800 : at t = 22.22 hours, pore is 2.67 % closed
# counter= 810 : at t = 22.5 hours, pore is 2.69 % closed
# counter= 820 : at t = 22.78 hours, pore is 2.71 % closed
# counter= 830 : at t = 23.06 hours, pore is 2.73 % closed
# counter= 840 : at t = 23.33 hours, pore is 2.75 % closed
# counter= 850 : at t = 23.61 hours, pore is 2.78 % closed
# counter= 860 : at t = 23.89 hours, pore is 2.8 % closed
# counter= 870 : at t = 24.17 hours, pore is 2.82 % closed
# counter= 880 : at t = 24.44 hours, pore is 2.84 % closed
# counter= 890 : at t = 24.72 hours, pore is 2.86 % closed
# counter= 900 : at t = 25.0 hours, pore is 2.88 % closed
# counter= 910 : at t = 25.28 hours, pore is 2.9 % closed
# counter= 920 : at t = 25.56 hours, pore is 2.92 % closed
# counter= 930 : at t = 25.83 hours, pore is 2.94 % closed
# counter= 940 : at t = 26.11 hours, pore is 2.96 % closed
# counter= 950 : at t = 26.39 hours, pore is 2.98 % closed
# counter= 960 : at t = 26.67 hours, pore is 3.01 % closed
# counter= 970 : at t = 26.94 hours, pore is 3.03 % closed
# counter= 980 : at t = 27.22 hours, pore is 3.05 % closed
# counter= 990 : at t = 27.5 hours, pore is 3.07 % closed
# counter= 1000 : at t = 27.78 hours, pore is 3.09 % closed
# counter= 1010 : at t = 28.06 hours, pore is 3.11 % closed
# counter= 1020 : at t = 28.33 hours, pore is 3.13 % closed
# counter= 1030 : at t = 28.61 hours, pore is 3.15 % closed
# counter= 1040 : at t = 28.89 hours, pore is 3.17 % closed
# counter= 1050 : at t = 29.17 hours, pore is 3.19 % closed
# counter= 1060 : at t = 29.44 hours, pore is 3.21 % closed
# counter= 1070 : at t = 29.72 hours, pore is 3.24 % closed
# counter= 1080 : at t = 30.0 hours, pore is 3.26 % closed
# counter= 1090 : at t = 30.28 hours, pore is 3.28 % closed
# counter= 1100 : at t = 30.56 hours, pore is 3.3 % closed
# counter= 1110 : at t = 30.83 hours, pore is 3.32 % closed
# counter= 1120 : at t = 31.11 hours, pore is 3.34 % closed
# counter= 1130 : at t = 31.39 hours, pore is 3.36 % closed
# counter= 1140 : at t = 31.67 hours, pore is 3.38 % closed
# counter= 1150 : at t = 31.94 hours, pore is 3.4 % closed
# counter= 1160 : at t = 32.22 hours, pore is 3.42 % closed
# counter= 1170 : at t = 32.5 hours, pore is 3.44 % closed
# counter= 1180 : at t = 32.78 hours, pore is 3.47 % closed
# counter= 1190 : at t = 33.06 hours, pore is 3.49 % closed
# counter= 1200 : at t = 33.33 hours, pore is 3.51 % closed
# counter= 1210 : at t = 33.61 hours, pore is 3.53 % closed
# counter= 1220 : at t = 33.89 hours, pore is 3.55 % closed
# counter= 1230 : at t = 34.17 hours, pore is 3.57 % closed
# counter= 1240 : at t = 34.44 hours, pore is 3.59 % closed
# counter= 1250 : at t = 34.72 hours, pore is 3.61 % closed
# counter= 1260 : at t = 35.0 hours, pore is 3.63 % closed
# counter= 1270 : at t = 35.28 hours, pore is 3.65 % closed
# counter= 1280 : at t = 35.56 hours, pore is 3.67 % closed
# counter= 1290 : at t = 35.83 hours, pore is 3.7 % closed
# counter= 1300 : at t = 36.11 hours, pore is 3.72 % closed
# counter= 1310 : at t = 36.39 hours, pore is 3.74 % closed
# counter= 1320 : at t = 36.67 hours, pore is 3.76 % closed
# counter= 1330 : at t = 36.94 hours, pore is 3.78 % closed
# counter= 1340 : at t = 37.22 hours, pore is 3.8 % closed
# counter= 1350 : at t = 37.5 hours, pore is 3.82 % closed
# counter= 1360 : at t = 37.78 hours, pore is 3.84 % closed
# counter= 1370 : at t = 38.06 hours, pore is 3.86 % closed
# counter= 1380 : at t = 38.33 hours, pore is 3.88 % closed
# counter= 1390 : at t = 38.61 hours, pore is 3.9 % closed
# counter= 1400 : at t = 38.89 hours, pore is 3.92 % closed
# counter= 1410 : at t = 39.17 hours, pore is 3.95 % closed
# counter= 1420 : at t = 39.44 hours, pore is 3.97 % closed
# counter= 1430 : at t = 39.72 hours, pore is 3.99 % closed
# counter= 1440 : at t = 40.0 hours, pore is 4.01 % closed
# counter= 1450 : at t = 40.28 hours, pore is 4.03 % closed
# counter= 1460 : at t = 40.56 hours, pore is 4.05 % closed
# counter= 1470 : at t = 40.83 hours, pore is 4.07 % closed
# counter= 1480 : at t = 41.11 hours, pore is 4.09 % closed
# counter= 1490 : at t = 41.39 hours, pore is 4.11 % closed
# counter= 1500 : at t = 41.67 hours, pore is 4.13 % closed
# counter= 1510 : at t = 41.94 hours, pore is 4.15 % closed
# counter= 1520 : at t = 42.22 hours, pore is 4.18 % closed
# counter= 1530 : at t = 42.5 hours, pore is 4.2 % closed
# counter= 1540 : at t = 42.78 hours, pore is 4.22 % closed
# counter= 1550 : at t = 43.06 hours, pore is 4.24 % closed
# counter= 1560 : at t = 43.33 hours, pore is 4.26 % closed
# counter= 1570 : at t = 43.61 hours, pore is 4.28 % closed
# counter= 1580 : at t = 43.89 hours, pore is 4.3 % closed
# counter= 1590 : at t = 44.17 hours, pore is 4.32 % closed
# counter= 1600 : at t = 44.44 hours, pore is 4.34 % closed
# counter= 1610 : at t = 44.72 hours, pore is 4.36 % closed
# counter= 1620 : at t = 45.0 hours, pore is 4.38 % closed
# counter= 1630 : at t = 45.28 hours, pore is 4.41 % closed
# counter= 1640 : at t = 45.56 hours, pore is 4.43 % closed
# counter= 1650 : at t = 45.83 hours, pore is 4.45 % closed
# counter= 1660 : at t = 46.11 hours, pore is 4.47 % closed
# counter= 1670 : at t = 46.39 hours, pore is 4.49 % closed
# counter= 1680 : at t = 46.67 hours, pore is 4.51 % closed
# counter= 1690 : at t = 46.94 hours, pore is 4.53 % closed
# counter= 1700 : at t = 47.22 hours, pore is 4.55 % closed
# counter= 1710 : at t = 47.5 hours, pore is 4.57 % closed
# counter= 1720 : at t = 47.78 hours, pore is 4.59 % closed
# counter= 1730 : at t = 48.06 hours, pore is 4.61 % closed
# counter= 1740 : at t = 48.33 hours, pore is 4.64 % closed
# counter= 1750 : at t = 48.61 hours, pore is 4.66 % closed
# counter= 1760 : at t = 48.89 hours, pore is 4.68 % closed
# counter= 1770 : at t = 49.17 hours, pore is 4.7 % closed
# counter= 1780 : at t = 49.44 hours, pore is 4.72 % closed
# counter= 1790 : at t = 49.72 hours, pore is 4.74 % closed
# counter= 1800 : at t = 50.0 hours, pore is 4.76 % closed
# counter= 1810 : at t = 50.28 hours, pore is 4.78 % closed
# counter= 1820 : at t = 50.56 hours, pore is 4.8 % closed
# counter= 1830 : at t = 50.83 hours, pore is 4.82 % closed
# counter= 1840 : at t = 51.11 hours, pore is 4.84 % closed
# counter= 1850 : at t = 51.39 hours, pore is 4.87 % closed
# counter= 1860 : at t = 51.67 hours, pore is 4.89 % closed
# counter= 1870 : at t = 51.94 hours, pore is 4.91 % closed
# counter= 1880 : at t = 52.22 hours, pore is 4.93 % closed
# counter= 1890 : at t = 52.5 hours, pore is 4.95 % closed
# counter= 1900 : at t = 52.78 hours, pore is 4.97 % closed
# counter= 1910 : at t = 53.06 hours, pore is 4.99 % closed
# counter= 1920 : at t = 53.33 hours, pore is 5.01 % closed
# counter= 1930 : at t = 53.61 hours, pore is 5.03 % closed
# counter= 1940 : at t = 53.89 hours, pore is 5.05 % closed
# counter= 1950 : at t = 54.17 hours, pore is 5.07 % closed
# counter= 1960 : at t = 54.44 hours, pore is 5.09 % closed
# counter= 1970 : at t = 54.72 hours, pore is 5.12 % closed
# counter= 1980 : at t = 55.0 hours, pore is 5.14 % closed
# counter= 1990 : at t = 55.28 hours, pore is 5.16 % closed
# counter= 2000 : at t = 55.56 hours, pore is 5.18 % closed
# counter= 2010 : at t = 55.83 hours, pore is 5.2 % closed
# counter= 2020 : at t = 56.11 hours, pore is 5.22 % closed
# counter= 2030 : at t = 56.39 hours, pore is 5.24 % closed
# counter= 2040 : at t = 56.67 hours, pore is 5.26 % closed
# counter= 2050 : at t = 56.94 hours, pore is 5.28 % closed
# counter= 2060 : at t = 57.22 hours, pore is 5.3 % closed
# counter= 2070 : at t = 57.5 hours, pore is 5.32 % closed
# counter= 2080 : at t = 57.78 hours, pore is 5.35 % closed
# counter= 2090 : at t = 58.06 hours, pore is 5.37 % closed
# counter= 2100 : at t = 58.33 hours, pore is 5.39 % closed
# counter= 2110 : at t = 58.61 hours, pore is 5.41 % closed
# counter= 2120 : at t = 58.89 hours, pore is 5.43 % closed
# counter= 2130 : at t = 59.17 hours, pore is 5.45 % closed
# counter= 2140 : at t = 59.44 hours, pore is 5.47 % closed
# counter= 2150 : at t = 59.72 hours, pore is 5.49 % closed
# counter= 2160 : at t = 60.0 hours, pore is 5.51 % closed
# counter= 2170 : at t = 60.28 hours, pore is 5.53 % closed
# counter= 2180 : at t = 60.56 hours, pore is 5.55 % closed
# counter= 2190 : at t = 60.83 hours, pore is 5.58 % closed
# counter= 2200 : at t = 61.11 hours, pore is 5.6 % closed
# counter= 2210 : at t = 61.39 hours, pore is 5.62 % closed
# counter= 2220 : at t = 61.67 hours, pore is 5.64 % closed
# counter= 2230 : at t = 61.94 hours, pore is 5.66 % closed
# counter= 2240 : at t = 62.22 hours, pore is 5.68 % closed
# counter= 2250 : at t = 62.5 hours, pore is 5.7 % closed
# counter= 2260 : at t = 62.78 hours, pore is 5.72 % closed
# counter= 2270 : at t = 63.06 hours, pore is 5.74 % closed
# counter= 2280 : at t = 63.33 hours, pore is 5.76 % closed
# counter= 2290 : at t = 63.61 hours, pore is 5.78 % closed
# counter= 2300 : at t = 63.89 hours, pore is 5.81 % closed
# counter= 2310 : at t = 64.17 hours, pore is 5.83 % closed
# counter= 2320 : at t = 64.44 hours, pore is 5.85 % closed
# counter= 2330 : at t = 64.72 hours, pore is 5.87 % closed
# counter= 2340 : at t = 65.0 hours, pore is 5.89 % closed
# counter= 2350 : at t = 65.28 hours, pore is 5.91 % closed
# counter= 2360 : at t = 65.56 hours, pore is 5.93 % closed
# counter= 2370 : at t = 65.83 hours, pore is 5.95 % closed
# counter= 2380 : at t = 66.11 hours, pore is 5.97 % closed
# counter= 2390 : at t = 66.39 hours, pore is 5.99 % closed
# counter= 2400 : at t = 66.67 hours, pore is 6.01 % closed
# counter= 2410 : at t = 66.94 hours, pore is 6.04 % closed
# counter= 2420 : at t = 67.22 hours, pore is 6.06 % closed
# counter= 2430 : at t = 67.5 hours, pore is 6.08 % closed
# counter= 2440 : at t = 67.78 hours, pore is 6.1 % closed
# counter= 2450 : at t = 68.06 hours, pore is 6.12 % closed
# counter= 2460 : at t = 68.33 hours, pore is 6.14 % closed
# counter= 2470 : at t = 68.61 hours, pore is 6.16 % closed
# counter= 2480 : at t = 68.89 hours, pore is 6.18 % closed
# counter= 2490 : at t = 69.17 hours, pore is 6.2 % closed
# counter= 2500 : at t = 69.44 hours, pore is 6.22 % closed
# counter= 2510 : at t = 69.72 hours, pore is 6.24 % closed
# counter= 2520 : at t = 70.0 hours, pore is 6.26 % closed
# counter= 2530 : at t = 70.28 hours, pore is 6.29 % closed
# counter= 2540 : at t = 70.56 hours, pore is 6.31 % closed
# counter= 2550 : at t = 70.83 hours, pore is 6.33 % closed
# counter= 2560 : at t = 71.11 hours, pore is 6.35 % closed
# counter= 2570 : at t = 71.39 hours, pore is 6.37 % closed
# counter= 2580 : at t = 71.67 hours, pore is 6.39 % closed
# counter= 2590 : at t = 71.94 hours, pore is 6.41 % closed
# counter= 2600 : at t = 72.22 hours, pore is 6.43 % closed
# counter= 2610 : at t = 72.5 hours, pore is 6.45 % closed
# counter= 2620 : at t = 72.78 hours, pore is 6.47 % closed
# counter= 2630 : at t = 73.06 hours, pore is 6.49 % closed
# counter= 2640 : at t = 73.33 hours, pore is 6.52 % closed
# counter= 2650 : at t = 73.61 hours, pore is 6.54 % closed
# counter= 2660 : at t = 73.89 hours, pore is 6.56 % closed
# counter= 2670 : at t = 74.17 hours, pore is 6.58 % closed
# counter= 2680 : at t = 74.44 hours, pore is 6.6 % closed
# counter= 2690 : at t = 74.72 hours, pore is 6.62 % closed
# counter= 2700 : at t = 75.0 hours, pore is 6.64 % closed
# counter= 2710 : at t = 75.28 hours, pore is 6.66 % closed
# counter= 2720 : at t = 75.56 hours, pore is 6.68 % closed
# counter= 2730 : at t = 75.83 hours, pore is 6.7 % closed
# counter= 2740 : at t = 76.11 hours, pore is 6.72 % closed
# counter= 2750 : at t = 76.39 hours, pore is 6.75 % closed
# counter= 2760 : at t = 76.67 hours, pore is 6.77 % closed
# counter= 2770 : at t = 76.94 hours, pore is 6.79 % closed
# counter= 2780 : at t = 77.22 hours, pore is 6.81 % closed
# counter= 2790 : at t = 77.5 hours, pore is 6.83 % closed
# counter= 2800 : at t = 77.78 hours, pore is 6.85 % closed
# counter= 2810 : at t = 78.06 hours, pore is 6.87 % closed
# counter= 2820 : at t = 78.33 hours, pore is 6.89 % closed
# counter= 2830 : at t = 78.61 hours, pore is 6.91 % closed
# counter= 2840 : at t = 78.89 hours, pore is 6.93 % closed
# counter= 2850 : at t = 79.17 hours, pore is 6.95 % closed
# counter= 2860 : at t = 79.44 hours, pore is 6.98 % closed
# counter= 2870 : at t = 79.72 hours, pore is 7.0 % closed
# counter= 2880 : at t = 80.0 hours, pore is 7.02 % closed
# counter= 2890 : at t = 80.28 hours, pore is 7.04 % closed
# counter= 2900 : at t = 80.56 hours, pore is 7.06 % closed
# counter= 2910 : at t = 80.83 hours, pore is 7.08 % closed
# counter= 2920 : at t = 81.11 hours, pore is 7.1 % closed
# counter= 2930 : at t = 81.39 hours, pore is 7.12 % closed
# counter= 2940 : at t = 81.67 hours, pore is 7.14 % closed
# counter= 2950 : at t = 81.94 hours, pore is 7.16 % closed
# counter= 2960 : at t = 82.22 hours, pore is 7.18 % closed
# counter= 2970 : at t = 82.5 hours, pore is 7.21 % closed
# counter= 2980 : at t = 82.78 hours, pore is 7.23 % closed
# counter= 2990 : at t = 83.06 hours, pore is 7.25 % closed
# counter= 3000 : at t = 83.33 hours, pore is 7.27 % closed
# counter= 3010 : at t = 83.61 hours, pore is 7.29 % closed
# counter= 3020 : at t = 83.89 hours, pore is 7.31 % closed
# counter= 3030 : at t = 84.17 hours, pore is 7.33 % closed
# counter= 3040 : at t = 84.44 hours, pore is 7.35 % closed
# counter= 3050 : at t = 84.72 hours, pore is 7.37 % closed
# counter= 3060 : at t = 85.0 hours, pore is 7.39 % closed
# counter= 3070 : at t = 85.28 hours, pore is 7.41 % closed
# counter= 3080 : at t = 85.56 hours, pore is 7.43 % closed
# counter= 3090 : at t = 85.83 hours, pore is 7.46 % closed
# counter= 3100 : at t = 86.11 hours, pore is 7.48 % closed
# counter= 3110 : at t = 86.39 hours, pore is 7.5 % closed
# counter= 3120 : at t = 86.67 hours, pore is 7.52 % closed
# counter= 3130 : at t = 86.94 hours, pore is 7.54 % closed
# counter= 3140 : at t = 87.22 hours, pore is 7.56 % closed
# counter= 3150 : at t = 87.5 hours, pore is 7.58 % closed
# counter= 3160 : at t = 87.78 hours, pore is 7.6 % closed
# counter= 3170 : at t = 88.06 hours, pore is 7.62 % closed
# counter= 3180 : at t = 88.33 hours, pore is 7.64 % closed
# counter= 3190 : at t = 88.61 hours, pore is 7.66 % closed
# counter= 3200 : at t = 88.89 hours, pore is 7.69 % closed
# counter= 3210 : at t = 89.17 hours, pore is 7.71 % closed
# counter= 3220 : at t = 89.44 hours, pore is 7.73 % closed
# counter= 3230 : at t = 89.72 hours, pore is 7.75 % closed
# counter= 3240 : at t = 90.0 hours, pore is 7.77 % closed
# counter= 3250 : at t = 90.28 hours, pore is 7.79 % closed
# counter= 3260 : at t = 90.56 hours, pore is 7.81 % closed
# counter= 3270 : at t = 90.83 hours, pore is 7.83 % closed
# counter= 3280 : at t = 91.11 hours, pore is 7.85 % closed
# counter= 3290 : at t = 91.39 hours, pore is 7.87 % closed
# counter= 3300 : at t = 91.67 hours, pore is 7.89 % closed
# counter= 3310 : at t = 91.94 hours, pore is 7.92 % closed
# counter= 3320 : at t = 92.22 hours, pore is 7.94 % closed
# counter= 3330 : at t = 92.5 hours, pore is 7.96 % closed
# counter= 3340 : at t = 92.78 hours, pore is 7.98 % closed
# counter= 3350 : at t = 93.06 hours, pore is 8.0 % closed
# counter= 3360 : at t = 93.33 hours, pore is 8.02 % closed
# counter= 3370 : at t = 93.61 hours, pore is 8.04 % closed
# counter= 3380 : at t = 93.89 hours, pore is 8.06 % closed
# counter= 3390 : at t = 94.17 hours, pore is 8.08 % closed
# counter= 3400 : at t = 94.44 hours, pore is 8.1 % closed
# counter= 3410 : at t = 94.72 hours, pore is 8.12 % closed
# counter= 3420 : at t = 95.0 hours, pore is 8.15 % closed
# counter= 3430 : at t = 95.28 hours, pore is 8.17 % closed
# counter= 3440 : at t = 95.56 hours, pore is 8.19 % closed
# counter= 3450 : at t = 95.83 hours, pore is 8.21 % closed
# counter= 3460 : at t = 96.11 hours, pore is 8.23 % closed
# counter= 3470 : at t = 96.39 hours, pore is 8.25 % closed
# counter= 3480 : at t = 96.67 hours, pore is 8.27 % closed
# counter= 3490 : at t = 96.94 hours, pore is 8.29 % closed
# counter= 3500 : at t = 97.22 hours, pore is 8.31 % closed
# counter= 3510 : at t = 97.5 hours, pore is 8.33 % closed
# counter= 3520 : at t = 97.78 hours, pore is 8.35 % closed
# counter= 3530 : at t = 98.06 hours, pore is 8.38 % closed
# counter= 3540 : at t = 98.33 hours, pore is 8.4 % closed
# counter= 3550 : at t = 98.61 hours, pore is 8.42 % closed
# counter= 3560 : at t = 98.89 hours, pore is 8.44 % closed
# counter= 3570 : at t = 99.17 hours, pore is 8.46 % closed
# counter= 3580 : at t = 99.44 hours, pore is 8.48 % closed
# counter= 3590 : at t = 99.72 hours, pore is 8.5 % closed
# counter= 3600 : at t = 100.0 hours, pore is 8.52 % closed
# counter= 3610 : at t = 100.28 hours, pore is 8.54 % closed
# counter= 3620 : at t = 100.56 hours, pore is 8.56 % closed
# counter= 3630 : at t = 100.83 hours, pore is 8.58 % closed
# counter= 3640 : at t = 101.11 hours, pore is 8.6 % closed
# counter= 3650 : at t = 101.39 hours, pore is 8.63 % closed
# counter= 3660 : at t = 101.67 hours, pore is 8.65 % closed
# counter= 3670 : at t = 101.94 hours, pore is 8.67 % closed
# counter= 3680 : at t = 102.22 hours, pore is 8.69 % closed
# counter= 3690 : at t = 102.5 hours, pore is 8.71 % closed
# counter= 3700 : at t = 102.78 hours, pore is 8.73 % closed
# counter= 3710 : at t = 103.06 hours, pore is 8.75 % closed
# counter= 3720 : at t = 103.33 hours, pore is 8.77 % closed
# counter= 3730 : at t = 103.61 hours, pore is 8.79 % closed
# counter= 3740 : at t = 103.89 hours, pore is 8.81 % closed
# counter= 3750 : at t = 104.17 hours, pore is 8.83 % closed
# counter= 3760 : at t = 104.44 hours, pore is 8.86 % closed
# counter= 3770 : at t = 104.72 hours, pore is 8.88 % closed
# counter= 3780 : at t = 105.0 hours, pore is 8.9 % closed
# counter= 3790 : at t = 105.28 hours, pore is 8.92 % closed
# counter= 3800 : at t = 105.56 hours, pore is 8.94 % closed
# counter= 3810 : at t = 105.83 hours, pore is 8.96 % closed
# counter= 3820 : at t = 106.11 hours, pore is 8.98 % closed
# counter= 3830 : at t = 106.39 hours, pore is 9.0 % closed
# counter= 3840 : at t = 106.67 hours, pore is 9.02 % closed
# counter= 3850 : at t = 106.94 hours, pore is 9.04 % closed
# counter= 3860 : at t = 107.22 hours, pore is 9.06 % closed
# counter= 3870 : at t = 107.5 hours, pore is 9.09 % closed
# counter= 3880 : at t = 107.78 hours, pore is 9.11 % closed
# counter= 3890 : at t = 108.06 hours, pore is 9.13 % closed
# counter= 3900 : at t = 108.33 hours, pore is 9.15 % closed
# counter= 3910 : at t = 108.61 hours, pore is 9.17 % closed
# counter= 3920 : at t = 108.89 hours, pore is 9.19 % closed
# counter= 3930 : at t = 109.17 hours, pore is 9.21 % closed
# counter= 3940 : at t = 109.44 hours, pore is 9.23 % closed
# counter= 3950 : at t = 109.72 hours, pore is 9.25 % closed
# counter= 3960 : at t = 110.0 hours, pore is 9.27 % closed
# counter= 3970 : at t = 110.28 hours, pore is 9.29 % closed
# counter= 3980 : at t = 110.56 hours, pore is 9.32 % closed
# counter= 3990 : at t = 110.83 hours, pore is 9.34 % closed
# counter= 4000 : at t = 111.11 hours, pore is 9.36 % closed
# counter= 4010 : at t = 111.39 hours, pore is 9.38 % closed
# counter= 4020 : at t = 111.67 hours, pore is 9.4 % closed
# counter= 4030 : at t = 111.94 hours, pore is 9.42 % closed
# counter= 4040 : at t = 112.22 hours, pore is 9.44 % closed
# counter= 4050 : at t = 112.5 hours, pore is 9.46 % closed
# counter= 4060 : at t = 112.78 hours, pore is 9.48 % closed
# counter= 4070 : at t = 113.06 hours, pore is 9.5 % closed
# counter= 4080 : at t = 113.33 hours, pore is 9.52 % closed
# counter= 4090 : at t = 113.61 hours, pore is 9.55 % closed
# counter= 4100 : at t = 113.89 hours, pore is 9.57 % closed
# counter= 4110 : at t = 114.17 hours, pore is 9.59 % closed
# counter= 4120 : at t = 114.44 hours, pore is 9.61 % closed
# counter= 4130 : at t = 114.72 hours, pore is 9.63 % closed
# counter= 4140 : at t = 115.0 hours, pore is 9.65 % closed
# counter= 4150 : at t = 115.28 hours, pore is 9.67 % closed
# counter= 4160 : at t = 115.56 hours, pore is 9.69 % closed
# counter= 4170 : at t = 115.83 hours, pore is 9.71 % closed
# counter= 4180 : at t = 116.11 hours, pore is 9.73 % closed
# counter= 4190 : at t = 116.39 hours, pore is 9.75 % closed
# counter= 4200 : at t = 116.67 hours, pore is 9.77 % closed
# counter= 4210 : at t = 116.94 hours, pore is 9.8 % closed
# counter= 4220 : at t = 117.22 hours, pore is 9.82 % closed
# counter= 4230 : at t = 117.5 hours, pore is 9.84 % closed
# counter= 4240 : at t = 117.78 hours, pore is 9.86 % closed
# counter= 4250 : at t = 118.06 hours, pore is 9.88 % closed
# counter= 4260 : at t = 118.33 hours, pore is 9.9 % closed
# counter= 4270 : at t = 118.61 hours, pore is 9.92 % closed
# counter= 4280 : at t = 118.89 hours, pore is 9.94 % closed
# counter= 4290 : at t = 119.17 hours, pore is 9.96 % closed
# counter= 4300 : at t = 119.44 hours, pore is 9.98 % closed
# counter= 4310 : at t = 119.72 hours, pore is 10.0 % closed
# counter= 4320 : at t = 120.0 hours, pore is 10.03 % closed
# counter= 4330 : at t = 120.28 hours, pore is 10.05 % closed
# counter= 4340 : at t = 120.56 hours, pore is 10.07 % closed
# counter= 4350 : at t = 120.83 hours, pore is 10.09 % closed
# counter= 4360 : at t = 121.11 hours, pore is 10.11 % closed
# counter= 4370 : at t = 121.39 hours, pore is 10.13 % closed
# counter= 4380 : at t = 121.67 hours, pore is 10.15 % closed
# counter= 4390 : at t = 121.94 hours, pore is 10.17 % closed
# counter= 4400 : at t = 122.22 hours, pore is 10.19 % closed
# counter= 4410 : at t = 122.5 hours, pore is 10.21 % closed
# counter= 4420 : at t = 122.78 hours, pore is 10.23 % closed
# counter= 4430 : at t = 123.06 hours, pore is 10.26 % closed
# counter= 4440 : at t = 123.33 hours, pore is 10.28 % closed
# counter= 4450 : at t = 123.61 hours, pore is 10.3 % closed
# counter= 4460 : at t = 123.89 hours, pore is 10.32 % closed
# counter= 4470 : at t = 124.17 hours, pore is 10.34 % closed
# counter= 4480 : at t = 124.44 hours, pore is 10.36 % closed
# counter= 4490 : at t = 124.72 hours, pore is 10.38 % closed
# counter= 4500 : at t = 125.0 hours, pore is 10.4 % closed
# counter= 4510 : at t = 125.28 hours, pore is 10.42 % closed
# counter= 4520 : at t = 125.56 hours, pore is 10.44 % closed
# counter= 4530 : at t = 125.83 hours, pore is 10.46 % closed
# counter= 4540 : at t = 126.11 hours, pore is 10.49 % closed
# counter= 4550 : at t = 126.39 hours, pore is 10.51 % closed
# counter= 4560 : at t = 126.67 hours, pore is 10.53 % closed
# counter= 4570 : at t = 126.94 hours, pore is 10.55 % closed
# counter= 4580 : at t = 127.22 hours, pore is 10.57 % closed
# counter= 4590 : at t = 127.5 hours, pore is 10.59 % closed
# counter= 4600 : at t = 127.78 hours, pore is 10.61 % closed
# counter= 4610 : at t = 128.06 hours, pore is 10.63 % closed
# counter= 4620 : at t = 128.33 hours, pore is 10.65 % closed
# counter= 4630 : at t = 128.61 hours, pore is 10.67 % closed
# counter= 4640 : at t = 128.89 hours, pore is 10.69 % closed
# counter= 4650 : at t = 129.17 hours, pore is 10.72 % closed
# counter= 4660 : at t = 129.44 hours, pore is 10.74 % closed
# counter= 4670 : at t = 129.72 hours, pore is 10.76 % closed
# counter= 4680 : at t = 130.0 hours, pore is 10.78 % closed
# counter= 4690 : at t = 130.28 hours, pore is 10.8 % closed
# counter= 4700 : at t = 130.56 hours, pore is 10.82 % closed
# counter= 4710 : at t = 130.83 hours, pore is 10.84 % closed
# counter= 4720 : at t = 131.11 hours, pore is 10.86 % closed
# counter= 4730 : at t = 131.39 hours, pore is 10.88 % closed
# counter= 4740 : at t = 131.67 hours, pore is 10.9 % closed
# counter= 4750 : at t = 131.94 hours, pore is 10.92 % closed
# counter= 4760 : at t = 132.22 hours, pore is 10.94 % closed
# counter= 4770 : at t = 132.5 hours, pore is 10.97 % closed
# counter= 4780 : at t = 132.78 hours, pore is 10.99 % closed
# counter= 4790 : at t = 133.06 hours, pore is 11.01 % closed
# counter= 4800 : at t = 133.33 hours, pore is 11.03 % closed
# counter= 4810 : at t = 133.61 hours, pore is 11.05 % closed
# counter= 4820 : at t = 133.89 hours, pore is 11.07 % closed
# counter= 4830 : at t = 134.17 hours, pore is 11.09 % closed
# counter= 4840 : at t = 134.44 hours, pore is 11.11 % closed
# counter= 4850 : at t = 134.72 hours, pore is 11.13 % closed
# counter= 4860 : at t = 135.0 hours, pore is 11.15 % closed
# counter= 4870 : at t = 135.28 hours, pore is 11.17 % closed
# counter= 4880 : at t = 135.56 hours, pore is 11.2 % closed
# counter= 4890 : at t = 135.83 hours, pore is 11.22 % closed
# counter= 4900 : at t = 136.11 hours, pore is 11.24 % closed
# counter= 4910 : at t = 136.39 hours, pore is 11.26 % closed
# counter= 4920 : at t = 136.67 hours, pore is 11.28 % closed
# counter= 4930 : at t = 136.94 hours, pore is 11.3 % closed
# counter= 4940 : at t = 137.22 hours, pore is 11.32 % closed
# counter= 4950 : at t = 137.5 hours, pore is 11.34 % closed
# counter= 4960 : at t = 137.78 hours, pore is 11.36 % closed
# counter= 4970 : at t = 138.06 hours, pore is 11.38 % closed
# counter= 4980 : at t = 138.33 hours, pore is 11.4 % closed
# counter= 4990 : at t = 138.61 hours, pore is 11.43 % closed
# counter= 5000 : at t = 138.89 hours, pore is 11.45 % closed
# counter= 5020 : at t = 139.44 hours, pore is 11.49 % closed
# counter= 5030 : at t = 139.72 hours, pore is 11.51 % closed
# counter= 5040 : at t = 140.0 hours, pore is 11.53 % closed
# counter= 5050 : at t = 140.28 hours, pore is 11.55 % closed
# counter= 5060 : at t = 140.56 hours, pore is 11.57 % closed
# counter= 5070 : at t = 140.83 hours, pore is 11.59 % closed
# counter= 5080 : at t = 141.11 hours, pore is 11.61 % closed
# counter= 5090 : at t = 141.39 hours, pore is 11.63 % closed
# counter= 5100 : at t = 141.67 hours, pore is 11.66 % closed
# counter= 5110 : at t = 141.94 hours, pore is 11.68 % closed
# counter= 5120 : at t = 142.22 hours, pore is 11.7 % closed
# counter= 5130 : at t = 142.5 hours, pore is 11.72 % closed
# counter= 5140 : at t = 142.78 hours, pore is 11.74 % closed
# counter= 5150 : at t = 143.06 hours, pore is 11.76 % closed
# counter= 5160 : at t = 143.33 hours, pore is 11.78 % closed
# counter= 5170 : at t = 143.61 hours, pore is 11.8 % closed
# counter= 5180 : at t = 143.89 hours, pore is 11.82 % closed
# counter= 5190 : at t = 144.17 hours, pore is 11.84 % closed
# counter= 5200 : at t = 144.44 hours, pore is 11.86 % closed
# counter= 5210 : at t = 144.72 hours, pore is 11.89 % closed
# counter= 5220 : at t = 145.0 hours, pore is 11.91 % closed
# counter= 5230 : at t = 145.28 hours, pore is 11.93 % closed
# counter= 5240 : at t = 145.56 hours, pore is 11.95 % closed
# counter= 5250 : at t = 145.83 hours, pore is 11.97 % closed
# counter= 5260 : at t = 146.11 hours, pore is 11.99 % closed
# counter= 5270 : at t = 146.39 hours, pore is 12.01 % closed
# counter= 5280 : at t = 146.67 hours, pore is 12.03 % closed
# counter= 5290 : at t = 146.94 hours, pore is 12.05 % closed
# counter= 5300 : at t = 147.22 hours, pore is 12.07 % closed
# counter= 5310 : at t = 147.5 hours, pore is 12.09 % closed
# counter= 5320 : at t = 147.78 hours, pore is 12.11 % closed
# counter= 5330 : at t = 148.06 hours, pore is 12.14 % closed
# counter= 5340 : at t = 148.33 hours, pore is 12.16 % closed
# counter= 5350 : at t = 148.61 hours, pore is 12.18 % closed
# counter= 5360 : at t = 148.89 hours, pore is 12.2 % closed
# counter= 5370 : at t = 149.17 hours, pore is 12.22 % closed
# counter= 5380 : at t = 149.44 hours, pore is 12.24 % closed
# counter= 5390 : at t = 149.72 hours, pore is 12.26 % closed
# counter= 5400 : at t = 150.0 hours, pore is 12.28 % closed
# counter= 5410 : at t = 150.28 hours, pore is 12.3 % closed
# counter= 5420 : at t = 150.56 hours, pore is 12.32 % closed
# counter= 5430 : at t = 150.83 hours, pore is 12.34 % closed
# counter= 5440 : at t = 151.11 hours, pore is 12.37 % closed
# counter= 5450 : at t = 151.39 hours, pore is 12.39 % closed
# counter= 5460 : at t = 151.67 hours, pore is 12.41 % closed
# counter= 5470 : at t = 151.94 hours, pore is 12.43 % closed
# counter= 5480 : at t = 152.22 hours, pore is 12.45 % closed
# counter= 5490 : at t = 152.5 hours, pore is 12.47 % closed
# counter= 5500 : at t = 152.78 hours, pore is 12.49 % closed
# counter= 5510 : at t = 153.06 hours, pore is 12.51 % closed
# counter= 5520 : at t = 153.33 hours, pore is 12.53 % closed
# counter= 5530 : at t = 153.61 hours, pore is 12.55 % closed
# counter= 5540 : at t = 153.89 hours, pore is 12.57 % closed
# counter= 5550 : at t = 154.17 hours, pore is 12.6 % closed
# counter= 5560 : at t = 154.44 hours, pore is 12.62 % closed
# counter= 5570 : at t = 154.72 hours, pore is 12.64 % closed
# counter= 5580 : at t = 155.0 hours, pore is 12.66 % closed
# counter= 5590 : at t = 155.28 hours, pore is 12.68 % closed
# counter= 5600 : at t = 155.56 hours, pore is 12.7 % closed
# counter= 5610 : at t = 155.83 hours, pore is 12.72 % closed
# counter= 5620 : at t = 156.11 hours, pore is 12.74 % closed
# counter= 5630 : at t = 156.39 hours, pore is 12.76 % closed
# counter= 5640 : at t = 156.67 hours, pore is 12.78 % closed
# counter= 5650 : at t = 156.94 hours, pore is 12.8 % closed
# counter= 5660 : at t = 157.22 hours, pore is 12.83 % closed
# counter= 5670 : at t = 157.5 hours, pore is 12.85 % closed
# counter= 5680 : at t = 157.78 hours, pore is 12.87 % closed
# counter= 5690 : at t = 158.06 hours, pore is 12.89 % closed
# counter= 5700 : at t = 158.33 hours, pore is 12.91 % closed
# counter= 5710 : at t = 158.61 hours, pore is 12.93 % closed
# counter= 5720 : at t = 158.89 hours, pore is 12.95 % closed
# counter= 5730 : at t = 159.17 hours, pore is 12.97 % closed
# counter= 5740 : at t = 159.44 hours, pore is 12.99 % closed
# counter= 5750 : at t = 159.72 hours, pore is 13.01 % closed
# counter= 5760 : at t = 160.0 hours, pore is 13.03 % closed
# counter= 5770 : at t = 160.28 hours, pore is 13.05 % closed
# counter= 5780 : at t = 160.56 hours, pore is 13.08 % closed
# counter= 5790 : at t = 160.83 hours, pore is 13.1 % closed
# counter= 5800 : at t = 161.11 hours, pore is 13.12 % closed
# counter= 5810 : at t = 161.39 hours, pore is 13.14 % closed
# counter= 5820 : at t = 161.67 hours, pore is 13.16 % closed
# counter= 5830 : at t = 161.94 hours, pore is 13.18 % closed
# counter= 5840 : at t = 162.22 hours, pore is 13.2 % closed
# counter= 5850 : at t = 162.5 hours, pore is 13.22 % closed
# counter= 5860 : at t = 162.78 hours, pore is 13.24 % closed
# counter= 5870 : at t = 163.06 hours, pore is 13.26 % closed
# counter= 5880 : at t = 163.33 hours, pore is 13.28 % closed
# counter= 5890 : at t = 163.61 hours, pore is 13.31 % closed
# counter= 5900 : at t = 163.89 hours, pore is 13.33 % closed
# counter= 5910 : at t = 164.17 hours, pore is 13.35 % closed
# counter= 5920 : at t = 164.44 hours, pore is 13.37 % closed
# counter= 5930 : at t = 164.72 hours, pore is 13.39 % closed
# counter= 5940 : at t = 165.0 hours, pore is 13.41 % closed
# counter= 5950 : at t = 165.28 hours, pore is 13.43 % closed
# counter= 5960 : at t = 165.56 hours, pore is 13.45 % closed
# counter= 5970 : at t = 165.83 hours, pore is 13.47 % closed
# counter= 5980 : at t = 166.11 hours, pore is 13.49 % closed
# counter= 5990 : at t = 166.39 hours, pore is 13.51 % closed
# counter= 6000 : at t = 166.67 hours, pore is 13.54 % closed
# counter= 6010 : at t = 166.94 hours, pore is 13.56 % closed
# counter= 6020 : at t = 167.22 hours, pore is 13.58 % closed
# counter= 6030 : at t = 167.5 hours, pore is 13.6 % closed
# counter= 6040 : at t = 167.78 hours, pore is 13.62 % closed
# counter= 6050 : at t = 168.06 hours, pore is 13.64 % closed
# counter= 6060 : at t = 168.33 hours, pore is 13.66 % closed
# counter= 6070 : at t = 168.61 hours, pore is 13.68 % closed
# counter= 6080 : at t = 168.89 hours, pore is 13.7 % closed
# counter= 6090 : at t = 169.17 hours, pore is 13.72 % closed
# counter= 6100 : at t = 169.44 hours, pore is 13.74 % closed
# counter= 6110 : at t = 169.72 hours, pore is 13.77 % closed
# counter= 6120 : at t = 170.0 hours, pore is 13.79 % closed
# counter= 6130 : at t = 170.28 hours, pore is 13.81 % closed
# counter= 6140 : at t = 170.56 hours, pore is 13.83 % closed
# counter= 6150 : at t = 170.83 hours, pore is 13.85 % closed
# counter= 6160 : at t = 171.11 hours, pore is 13.87 % closed
# counter= 6170 : at t = 171.39 hours, pore is 13.89 % closed
# counter= 6180 : at t = 171.67 hours, pore is 13.91 % closed
# counter= 6190 : at t = 171.94 hours, pore is 13.93 % closed
# counter= 6200 : at t = 172.22 hours, pore is 13.95 % closed
# counter= 6210 : at t = 172.5 hours, pore is 13.97 % closed
# counter= 6220 : at t = 172.78 hours, pore is 14.0 % closed
# counter= 6230 : at t = 173.06 hours, pore is 14.02 % closed
# counter= 6240 : at t = 173.33 hours, pore is 14.04 % closed
# counter= 6250 : at t = 173.61 hours, pore is 14.06 % closed
# counter= 6260 : at t = 173.89 hours, pore is 14.08 % closed
# counter= 6270 : at t = 174.17 hours, pore is 14.1 % closed
# counter= 6280 : at t = 174.44 hours, pore is 14.12 % closed
# counter= 6290 : at t = 174.72 hours, pore is 14.14 % closed
# counter= 6300 : at t = 175.0 hours, pore is 14.16 % closed
# counter= 6310 : at t = 175.28 hours, pore is 14.18 % closed
# counter= 6320 : at t = 175.56 hours, pore is 14.2 % closed
# counter= 6330 : at t = 175.83 hours, pore is 14.22 % closed
# counter= 6340 : at t = 176.11 hours, pore is 14.25 % closed
# counter= 6350 : at t = 176.39 hours, pore is 14.27 % closed
# counter= 6360 : at t = 176.67 hours, pore is 14.29 % closed
# counter= 6370 : at t = 176.94 hours, pore is 14.31 % closed
# counter= 6380 : at t = 177.22 hours, pore is 14.33 % closed
# counter= 6390 : at t = 177.5 hours, pore is 14.35 % closed
# counter= 6400 : at t = 177.78 hours, pore is 14.37 % closed
# counter= 6410 : at t = 178.06 hours, pore is 14.39 % closed
# counter= 6420 : at t = 178.33 hours, pore is 14.41 % closed
# counter= 6430 : at t = 178.61 hours, pore is 14.43 % closed
# counter= 6440 : at t = 178.89 hours, pore is 14.45 % closed
# counter= 6450 : at t = 179.17 hours, pore is 14.48 % closed
# counter= 6460 : at t = 179.44 hours, pore is 14.5 % closed
# counter= 6470 : at t = 179.72 hours, pore is 14.52 % closed
# counter= 6480 : at t = 180.0 hours, pore is 14.54 % closed
# counter= 6490 : at t = 180.28 hours, pore is 14.56 % closed
# counter= 6500 : at t = 180.56 hours, pore is 14.58 % closed
# counter= 6510 : at t = 180.83 hours, pore is 14.6 % closed
# counter= 6520 : at t = 181.11 hours, pore is 14.62 % closed
# counter= 6530 : at t = 181.39 hours, pore is 14.64 % closed
# counter= 6540 : at t = 181.67 hours, pore is 14.66 % closed
# counter= 6550 : at t = 181.94 hours, pore is 14.68 % closed
# counter= 6560 : at t = 182.22 hours, pore is 14.71 % closed
# counter= 6570 : at t = 182.5 hours, pore is 14.73 % closed
# counter= 6580 : at t = 182.78 hours, pore is 14.75 % closed
# counter= 6590 : at t = 183.06 hours, pore is 14.77 % closed
# counter= 6600 : at t = 183.33 hours, pore is 14.79 % closed
# counter= 6610 : at t = 183.61 hours, pore is 14.81 % closed
# counter= 6620 : at t = 183.89 hours, pore is 14.83 % closed
# counter= 6630 : at t = 184.17 hours, pore is 14.85 % closed
# counter= 6640 : at t = 184.44 hours, pore is 14.87 % closed
# counter= 6650 : at t = 184.72 hours, pore is 14.89 % closed
# counter= 6660 : at t = 185.0 hours, pore is 14.91 % closed
# counter= 6670 : at t = 185.28 hours, pore is 14.94 % closed
# counter= 6680 : at t = 185.56 hours, pore is 14.96 % closed
# counter= 6690 : at t = 185.83 hours, pore is 14.98 % closed
# counter= 6700 : at t = 186.11 hours, pore is 15.0 % closed
# counter= 6710 : at t = 186.39 hours, pore is 15.02 % closed
# counter= 6720 : at t = 186.67 hours, pore is 15.04 % closed
# counter= 6730 : at t = 186.94 hours, pore is 15.06 % closed
# counter= 6740 : at t = 187.22 hours, pore is 15.08 % closed
# counter= 6750 : at t = 187.5 hours, pore is 15.1 % closed
# counter= 6760 : at t = 187.78 hours, pore is 15.12 % closed
# counter= 6770 : at t = 188.06 hours, pore is 15.14 % closed
# counter= 6780 : at t = 188.33 hours, pore is 15.17 % closed
# counter= 6790 : at t = 188.61 hours, pore is 15.19 % closed
# counter= 6800 : at t = 188.89 hours, pore is 15.21 % closed
# counter= 6810 : at t = 189.17 hours, pore is 15.23 % closed
# counter= 6820 : at t = 189.44 hours, pore is 15.25 % closed
# counter= 6830 : at t = 189.72 hours, pore is 15.27 % closed
# counter= 6840 : at t = 190.0 hours, pore is 15.29 % closed
# counter= 6850 : at t = 190.28 hours, pore is 15.31 % closed
# counter= 6860 : at t = 190.56 hours, pore is 15.33 % closed
# counter= 6870 : at t = 190.83 hours, pore is 15.35 % closed
# counter= 6880 : at t = 191.11 hours, pore is 15.37 % closed
# counter= 6890 : at t = 191.39 hours, pore is 15.39 % closed
# counter= 6900 : at t = 191.67 hours, pore is 15.42 % closed
# counter= 6910 : at t = 191.94 hours, pore is 15.44 % closed
# counter= 6920 : at t = 192.22 hours, pore is 15.46 % closed
# counter= 6930 : at t = 192.5 hours, pore is 15.48 % closed
# counter= 6940 : at t = 192.78 hours, pore is 15.5 % closed
# counter= 6950 : at t = 193.06 hours, pore is 15.52 % closed
# counter= 6960 : at t = 193.33 hours, pore is 15.54 % closed
# counter= 6970 : at t = 193.61 hours, pore is 15.56 % closed
# counter= 6980 : at t = 193.89 hours, pore is 15.58 % closed
# counter= 6990 : at t = 194.17 hours, pore is 15.6 % closed
# counter= 7000 : at t = 194.44 hours, pore is 15.62 % closed
# counter= 7010 : at t = 194.72 hours, pore is 15.65 % closed
# counter= 7020 : at t = 195.0 hours, pore is 15.67 % closed
# counter= 7030 : at t = 195.28 hours, pore is 15.69 % closed
# counter= 7040 : at t = 195.56 hours, pore is 15.71 % closed
# counter= 7050 : at t = 195.83 hours, pore is 15.73 % closed
# counter= 7060 : at t = 196.11 hours, pore is 15.75 % closed
# counter= 7070 : at t = 196.39 hours, pore is 15.77 % closed
# counter= 7080 : at t = 196.67 hours, pore is 15.79 % closed
# counter= 7090 : at t = 196.94 hours, pore is 15.81 % closed
# counter= 7100 : at t = 197.22 hours, pore is 15.83 % closed
# counter= 7110 : at t = 197.5 hours, pore is 15.85 % closed
# counter= 7120 : at t = 197.78 hours, pore is 15.88 % closed
# counter= 7130 : at t = 198.06 hours, pore is 15.9 % closed
# counter= 7140 : at t = 198.33 hours, pore is 15.92 % closed
# counter= 7150 : at t = 198.61 hours, pore is 15.94 % closed
# counter= 7160 : at t = 198.89 hours, pore is 15.96 % closed
# counter= 7170 : at t = 199.17 hours, pore is 15.98 % closed
# counter= 7180 : at t = 199.44 hours, pore is 16.0 % closed
# counter= 7190 : at t = 199.72 hours, pore is 16.02 % closed
# counter= 7200 : at t = 200.0 hours, pore is 16.04 % closed
# counter= 7210 : at t = 200.28 hours, pore is 16.06 % closed
# counter= 7220 : at t = 200.56 hours, pore is 16.08 % closed
# counter= 7230 : at t = 200.83 hours, pore is 16.11 % closed
# counter= 7240 : at t = 201.11 hours, pore is 16.13 % closed
# counter= 7250 : at t = 201.39 hours, pore is 16.15 % closed
# counter= 7260 : at t = 201.67 hours, pore is 16.17 % closed
# counter= 7270 : at t = 201.94 hours, pore is 16.19 % closed
# counter= 7280 : at t = 202.22 hours, pore is 16.21 % closed
# counter= 7290 : at t = 202.5 hours, pore is 16.23 % closed
# counter= 7300 : at t = 202.78 hours, pore is 16.25 % closed
# counter= 7310 : at t = 203.06 hours, pore is 16.27 % closed
# counter= 7320 : at t = 203.33 hours, pore is 16.29 % closed
# counter= 7330 : at t = 203.61 hours, pore is 16.31 % closed
# counter= 7340 : at t = 203.89 hours, pore is 16.34 % closed
# counter= 7350 : at t = 204.17 hours, pore is 16.36 % closed
# counter= 7360 : at t = 204.44 hours, pore is 16.38 % closed
# counter= 7370 : at t = 204.72 hours, pore is 16.4 % closed
# counter= 7380 : at t = 205.0 hours, pore is 16.42 % closed
# counter= 7390 : at t = 205.28 hours, pore is 16.44 % closed
# counter= 7400 : at t = 205.56 hours, pore is 16.46 % closed
# counter= 7410 : at t = 205.83 hours, pore is 16.48 % closed
# counter= 7420 : at t = 206.11 hours, pore is 16.5 % closed
# counter= 7430 : at t = 206.39 hours, pore is 16.52 % closed
# counter= 7440 : at t = 206.67 hours, pore is 16.54 % closed
# counter= 7450 : at t = 206.94 hours, pore is 16.56 % closed
# counter= 7460 : at t = 207.22 hours, pore is 16.59 % closed
# counter= 7470 : at t = 207.5 hours, pore is 16.61 % closed
# counter= 7480 : at t = 207.78 hours, pore is 16.63 % closed
# counter= 7490 : at t = 208.06 hours, pore is 16.65 % closed
# counter= 7500 : at t = 208.33 hours, pore is 16.67 % closed
# counter= 7510 : at t = 208.61 hours, pore is 16.69 % closed
# counter= 7520 : at t = 208.89 hours, pore is 16.71 % closed
# counter= 7530 : at t = 209.17 hours, pore is 16.73 % closed
# counter= 7540 : at t = 209.44 hours, pore is 16.75 % closed
# counter= 7550 : at t = 209.72 hours, pore is 16.77 % closed
# counter= 7560 : at t = 210.0 hours, pore is 16.79 % closed
# counter= 7570 : at t = 210.28 hours, pore is 16.82 % closed
# counter= 7580 : at t = 210.56 hours, pore is 16.84 % closed
# counter= 7590 : at t = 210.83 hours, pore is 16.86 % closed
# counter= 7600 : at t = 211.11 hours, pore is 16.88 % closed
# counter= 7610 : at t = 211.39 hours, pore is 16.9 % closed
# counter= 7620 : at t = 211.67 hours, pore is 16.92 % closed
# counter= 7630 : at t = 211.94 hours, pore is 16.94 % closed
# counter= 7640 : at t = 212.22 hours, pore is 16.96 % closed
# counter= 7650 : at t = 212.5 hours, pore is 16.98 % closed
# counter= 7660 : at t = 212.78 hours, pore is 17.0 % closed
# counter= 7670 : at t = 213.06 hours, pore is 17.02 % closed
# counter= 7680 : at t = 213.33 hours, pore is 17.05 % closed
# counter= 7690 : at t = 213.61 hours, pore is 17.07 % closed
# counter= 7700 : at t = 213.89 hours, pore is 17.09 % closed
# counter= 7710 : at t = 214.17 hours, pore is 17.11 % closed
# counter= 7720 : at t = 214.44 hours, pore is 17.13 % closed
# counter= 7730 : at t = 214.72 hours, pore is 17.15 % closed
# counter= 7740 : at t = 215.0 hours, pore is 17.17 % closed
# counter= 7750 : at t = 215.28 hours, pore is 17.19 % closed
# counter= 7760 : at t = 215.56 hours, pore is 17.21 % closed
# counter= 7770 : at t = 215.83 hours, pore is 17.23 % closed
# counter= 7780 : at t = 216.11 hours, pore is 17.25 % closed
# counter= 7790 : at t = 216.39 hours, pore is 17.28 % closed
# counter= 7800 : at t = 216.67 hours, pore is 17.3 % closed
# counter= 7810 : at t = 216.94 hours, pore is 17.32 % closed
# counter= 7820 : at t = 217.22 hours, pore is 17.34 % closed
# counter= 7830 : at t = 217.5 hours, pore is 17.36 % closed
# counter= 7840 : at t = 217.78 hours, pore is 17.38 % closed
# counter= 7850 : at t = 218.06 hours, pore is 17.4 % closed
# counter= 7860 : at t = 218.33 hours, pore is 17.42 % closed
# counter= 7870 : at t = 218.61 hours, pore is 17.44 % closed
# counter= 7880 : at t = 218.89 hours, pore is 17.46 % closed
# counter= 7890 : at t = 219.17 hours, pore is 17.48 % closed
# counter= 7900 : at t = 219.44 hours, pore is 17.51 % closed
# counter= 7910 : at t = 219.72 hours, pore is 17.53 % closed
# counter= 7920 : at t = 220.0 hours, pore is 17.55 % closed
# counter= 7930 : at t = 220.28 hours, pore is 17.57 % closed
# counter= 7940 : at t = 220.56 hours, pore is 17.59 % closed
# counter= 7950 : at t = 220.83 hours, pore is 17.61 % closed
# counter= 7960 : at t = 221.11 hours, pore is 17.63 % closed
# counter= 7970 : at t = 221.39 hours, pore is 17.65 % closed
# counter= 7980 : at t = 221.67 hours, pore is 17.67 % closed
# counter= 7990 : at t = 221.94 hours, pore is 17.69 % closed
# counter= 8000 : at t = 222.22 hours, pore is 17.71 % closed
# counter= 8010 : at t = 222.5 hours, pore is 17.73 % closed
# counter= 8020 : at t = 222.78 hours, pore is 17.76 % closed
# counter= 8030 : at t = 223.06 hours, pore is 17.78 % closed
# counter= 8040 : at t = 223.33 hours, pore is 17.8 % closed
# counter= 8050 : at t = 223.61 hours, pore is 17.82 % closed
# counter= 8060 : at t = 223.89 hours, pore is 17.84 % closed
# counter= 8070 : at t = 224.17 hours, pore is 17.86 % closed
# counter= 8080 : at t = 224.44 hours, pore is 17.88 % closed
# counter= 8090 : at t = 224.72 hours, pore is 17.9 % closed
# counter= 8100 : at t = 225.0 hours, pore is 17.92 % closed
# counter= 8110 : at t = 225.28 hours, pore is 17.94 % closed
# ...
# counter= 45110 : at t = 1253.06 hours, pore is 95.25 % closed
# counter= 45120 : at t = 1253.33 hours, pore is 95.27 % closed
# counter= 45130 : at t = 1253.61 hours, pore is 95.29 % closed
# counter= 45140 : at t = 1253.89 hours, pore is 95.31 % closed
# counter= 45150 : at t = 1254.17 hours, pore is 95.33 % closed
# counter= 45160 : at t = 1254.45 hours, pore is 95.35 % closed
# counter= 45170 : at t = 1254.72 hours, pore is 95.37 % closed
# counter= 45180 : at t = 1255.0 hours, pore is 95.39 % closed
# counter= 45190 : at t = 1255.28 hours, pore is 95.41 % closed
# counter= 45200 : at t = 1255.56 hours, pore is 95.43 % closed
# counter= 45210 : at t = 1255.83 hours, pore is 95.46 % closed
# counter= 45220 : at t = 1256.11 hours, pore is 95.48 % closed
# counter= 45230 : at t = 1256.39 hours, pore is 95.5 % closed
# counter= 45240 : at t = 1256.67 hours, pore is 95.52 % closed
# counter= 45250 : at t = 1256.95 hours, pore is 95.54 % closed
# counter= 45260 : at t = 1257.22 hours, pore is 95.56 % closed
# counter= 45270 : at t = 1257.5 hours, pore is 95.58 % closed
# counter= 45280 : at t = 1257.78 hours, pore is 95.6 % closed
# counter= 45290 : at t = 1258.06 hours, pore is 95.62 % closed
# counter= 45300 : at t = 1258.33 hours, pore is 95.64 % closed
# counter= 45310 : at t = 1258.61 hours, pore is 95.66 % closed
# counter= 45320 : at t = 1258.89 hours, pore is 95.68 % closed
# counter= 45330 : at t = 1259.17 hours, pore is 95.71 % closed
# counter= 45340 : at t = 1259.45 hours, pore is 95.73 % closed
# counter= 45350 : at t = 1259.72 hours, pore is 95.75 % closed
# counter= 45360 : at t = 1260.0 hours, pore is 95.77 % closed
# counter= 45370 : at t = 1260.28 hours, pore is 95.79 % closed
# counter= 45380 : at t = 1260.56 hours, pore is 95.81 % closed
# counter= 45390 : at t = 1260.83 hours, pore is 95.83 % closed
# counter= 45400 : at t = 1261.11 hours, pore is 95.85 % closed
# counter= 45410 : at t = 1261.39 hours, pore is 95.87 % closed
# counter= 45420 : at t = 1261.67 hours, pore is 95.89 % closed
# counter= 45430 : at t = 1261.95 hours, pore is 95.91 % closed
# counter= 45440 : at t = 1262.22 hours, pore is 95.94 % closed
# counter= 45450 : at t = 1262.5 hours, pore is 95.96 % closed
# counter= 45460 : at t = 1262.78 hours, pore is 95.98 % closed
# counter= 45470 : at t = 1263.06 hours, pore is 96.0 % closed
# counter= 45480 : at t = 1263.33 hours, pore is 96.02 % closed
# counter= 45490 : at t = 1263.61 hours, pore is 96.04 % closed
# counter= 45500 : at t = 1263.89 hours, pore is 96.06 % closed
# counter= 45510 : at t = 1264.17 hours, pore is 96.08 % closed
# counter= 45520 : at t = 1264.45 hours, pore is 96.1 % closed
# counter= 45530 : at t = 1264.72 hours, pore is 96.12 % closed
# counter= 45540 : at t = 1265.0 hours, pore is 96.14 % closed
# counter= 45550 : at t = 1265.28 hours, pore is 96.17 % closed
# counter= 45560 : at t = 1265.56 hours, pore is 96.19 % closed
# counter= 45570 : at t = 1265.83 hours, pore is 96.21 % closed
# counter= 45580 : at t = 1266.11 hours, pore is 96.23 % closed
# counter= 45590 : at t = 1266.39 hours, pore is 96.25 % closed
# counter= 45600 : at t = 1266.67 hours, pore is 96.27 % closed
# counter= 45610 : at t = 1266.95 hours, pore is 96.29 % closed
# counter= 45620 : at t = 1267.22 hours, pore is 96.31 % closed
# counter= 45630 : at t = 1267.5 hours, pore is 96.33 % closed
# counter= 45640 : at t = 1267.78 hours, pore is 96.35 % closed
# counter= 45650 : at t = 1268.06 hours, pore is 96.37 % closed
# counter= 45660 : at t = 1268.33 hours, pore is 96.4 % closed
# counter= 45670 : at t = 1268.61 hours, pore is 96.42 % closed
# counter= 45680 : at t = 1268.89 hours, pore is 96.44 % closed
# counter= 45690 : at t = 1269.17 hours, pore is 96.46 % closed
# counter= 45700 : at t = 1269.45 hours, pore is 96.48 % closed
# counter= 45710 : at t = 1269.72 hours, pore is 96.5 % closed
# counter= 45720 : at t = 1270.0 hours, pore is 96.52 % closed
# counter= 45730 : at t = 1270.28 hours, pore is 96.54 % closed
# counter= 45740 : at t = 1270.56 hours, pore is 96.56 % closed
# counter= 45750 : at t = 1270.83 hours, pore is 96.58 % closed
# counter= 45760 : at t = 1271.11 hours, pore is 96.6 % closed
# counter= 45770 : at t = 1271.39 hours, pore is 96.63 % closed
# counter= 45780 : at t = 1271.67 hours, pore is 96.65 % closed
# counter= 45790 : at t = 1271.95 hours, pore is 96.67 % closed
# counter= 45800 : at t = 1272.22 hours, pore is 96.69 % closed
# counter= 45810 : at t = 1272.5 hours, pore is 96.71 % closed
# counter= 45820 : at t = 1272.78 hours, pore is 96.73 % closed
# counter= 45830 : at t = 1273.06 hours, pore is 96.75 % closed
# counter= 45840 : at t = 1273.33 hours, pore is 96.77 % closed
# counter= 45850 : at t = 1273.61 hours, pore is 96.79 % closed
# counter= 45860 : at t = 1273.89 hours, pore is 96.81 % closed
# counter= 45870 : at t = 1274.17 hours, pore is 96.83 % closed
# counter= 45880 : at t = 1274.45 hours, pore is 96.85 % closed
# counter= 45890 : at t = 1274.72 hours, pore is 96.88 % closed
# counter= 45900 : at t = 1275.0 hours, pore is 96.9 % closed
# counter= 45910 : at t = 1275.28 hours, pore is 96.92 % closed
# counter= 45920 : at t = 1275.56 hours, pore is 96.94 % closed
# counter= 45930 : at t = 1275.83 hours, pore is 96.96 % closed
# counter= 45940 : at t = 1276.11 hours, pore is 96.98 % closed
# counter= 45950 : at t = 1276.39 hours, pore is 97.0 % closed
# counter= 45960 : at t = 1276.67 hours, pore is 97.02 % closed
# counter= 45970 : at t = 1276.95 hours, pore is 97.04 % closed
# counter= 45980 : at t = 1277.22 hours, pore is 97.06 % closed
# counter= 45990 : at t = 1277.5 hours, pore is 97.08 % closed
# counter= 46000 : at t = 1277.78 hours, pore is 97.11 % closed
# counter= 46010 : at t = 1278.06 hours, pore is 97.13 % closed
# counter= 46020 : at t = 1278.33 hours, pore is 97.15 % closed
# counter= 46030 : at t = 1278.61 hours, pore is 97.17 % closed
# counter= 46040 : at t = 1278.89 hours, pore is 97.19 % closed
# counter= 46050 : at t = 1279.17 hours, pore is 97.21 % closed
# counter= 46060 : at t = 1279.45 hours, pore is 97.23 % closed
# counter= 46070 : at t = 1279.72 hours, pore is 97.25 % closed
# counter= 46080 : at t = 1280.0 hours, pore is 97.27 % closed
# counter= 46090 : at t = 1280.28 hours, pore is 97.29 % closed
# counter= 46100 : at t = 1280.56 hours, pore is 97.31 % closed
# counter= 46110 : at t = 1280.83 hours, pore is 97.34 % closed
# counter= 46120 : at t = 1281.11 hours, pore is 97.36 % closed
# counter= 46130 : at t = 1281.39 hours, pore is 97.38 % closed
# counter= 46140 : at t = 1281.67 hours, pore is 97.4 % closed
# counter= 46150 : at t = 1281.95 hours, pore is 97.42 % closed
# counter= 46160 : at t = 1282.22 hours, pore is 97.44 % closed
# counter= 46170 : at t = 1282.5 hours, pore is 97.46 % closed
# counter= 46180 : at t = 1282.78 hours, pore is 97.48 % closed
# counter= 46190 : at t = 1283.06 hours, pore is 97.5 % closed
# counter= 46200 : at t = 1283.33 hours, pore is 97.52 % closed
# counter= 46210 : at t = 1283.61 hours, pore is 97.54 % closed
# counter= 46220 : at t = 1283.89 hours, pore is 97.57 % closed
# counter= 46230 : at t = 1284.17 hours, pore is 97.59 % closed
# counter= 46240 : at t = 1284.45 hours, pore is 97.61 % closed
# counter= 46250 : at t = 1284.72 hours, pore is 97.63 % closed
# counter= 46260 : at t = 1285.0 hours, pore is 97.65 % closed
# counter= 46270 : at t = 1285.28 hours, pore is 97.67 % closed
# counter= 46280 : at t = 1285.56 hours, pore is 97.69 % closed
# counter= 46290 : at t = 1285.83 hours, pore is 97.71 % closed
# counter= 46300 : at t = 1286.11 hours, pore is 97.73 % closed
# counter= 46310 : at t = 1286.39 hours, pore is 97.75 % closed
# counter= 46320 : at t = 1286.67 hours, pore is 97.77 % closed
# counter= 46330 : at t = 1286.95 hours, pore is 97.8 % closed
# counter= 46340 : at t = 1287.22 hours, pore is 97.82 % closed
# counter= 46350 : at t = 1287.5 hours, pore is 97.84 % closed
# counter= 46360 : at t = 1287.78 hours, pore is 97.86 % closed
# counter= 46370 : at t = 1288.06 hours, pore is 97.88 % closed
# counter= 46380 : at t = 1288.33 hours, pore is 97.9 % closed
# counter= 46390 : at t = 1288.61 hours, pore is 97.92 % closed
# counter= 46400 : at t = 1288.89 hours, pore is 97.94 % closed
# counter= 46410 : at t = 1289.17 hours, pore is 97.96 % closed
# counter= 46420 : at t = 1289.45 hours, pore is 97.98 % closed
# counter= 46430 : at t = 1289.72 hours, pore is 98.0 % closed
# counter= 46440 : at t = 1290.0 hours, pore is 98.02 % closed
# counter= 46450 : at t = 1290.28 hours, pore is 98.05 % closed
# counter= 46460 : at t = 1290.56 hours, pore is 98.07 % closed
# counter= 46470 : at t = 1290.83 hours, pore is 98.09 % closed
# counter= 46480 : at t = 1291.11 hours, pore is 98.11 % closed
# counter= 46490 : at t = 1291.39 hours, pore is 98.13 % closed
# counter= 46500 : at t = 1291.67 hours, pore is 98.15 % closed
# counter= 46510 : at t = 1291.95 hours, pore is 98.17 % closed
# counter= 46520 : at t = 1292.22 hours, pore is 98.19 % closed
# counter= 46530 : at t = 1292.5 hours, pore is 98.21 % closed
# counter= 46540 : at t = 1292.78 hours, pore is 98.23 % closed
# counter= 46550 : at t = 1293.06 hours, pore is 98.25 % closed
# counter= 46560 : at t = 1293.33 hours, pore is 98.28 % closed
# counter= 46570 : at t = 1293.61 hours, pore is 98.3 % closed
# counter= 46580 : at t = 1293.89 hours, pore is 98.32 % closed
# counter= 46590 : at t = 1294.17 hours, pore is 98.34 % closed
# counter= 46600 : at t = 1294.45 hours, pore is 98.36 % closed
# counter= 46610 : at t = 1294.72 hours, pore is 98.38 % closed
# counter= 46620 : at t = 1295.0 hours, pore is 98.4 % closed
# counter= 46630 : at t = 1295.28 hours, pore is 98.42 % closed
# counter= 46640 : at t = 1295.56 hours, pore is 98.44 % closed
# counter= 46650 : at t = 1295.83 hours, pore is 98.46 % closed
# counter= 46660 : at t = 1296.11 hours, pore is 98.48 % closed
# counter= 46670 : at t = 1296.39 hours, pore is 98.51 % closed
# counter= 46680 : at t = 1296.67 hours, pore is 98.53 % closed
# counter= 46690 : at t = 1296.95 hours, pore is 98.55 % closed
# counter= 46700 : at t = 1297.22 hours, pore is 98.57 % closed
# counter= 46710 : at t = 1297.5 hours, pore is 98.59 % closed
# counter= 46720 : at t = 1297.78 hours, pore is 98.61 % closed
# counter= 46730 : at t = 1298.06 hours, pore is 98.63 % closed
# counter= 46740 : at t = 1298.33 hours, pore is 98.65 % closed
# counter= 46750 : at t = 1298.61 hours, pore is 98.67 % closed
# counter= 46760 : at t = 1298.89 hours, pore is 98.69 % closed
# counter= 46770 : at t = 1299.17 hours, pore is 98.71 % closed
# counter= 46780 : at t = 1299.45 hours, pore is 98.74 % closed
# counter= 46790 : at t = 1299.72 hours, pore is 98.76 % closed
# counter= 46800 : at t = 1300.0 hours, pore is 98.78 % closed
# counter= 46810 : at t = 1300.28 hours, pore is 98.8 % closed
# counter= 46820 : at t = 1300.56 hours, pore is 98.82 % closed
# counter= 46830 : at t = 1300.83 hours, pore is 98.84 % closed
# counter= 46840 : at t = 1301.11 hours, pore is 98.86 % closed
# counter= 46850 : at t = 1301.39 hours, pore is 98.88 % closed
# counter= 46860 : at t = 1301.67 hours, pore is 98.9 % closed
# counter= 46870 : at t = 1301.95 hours, pore is 98.92 % closed
# counter= 46880 : at t = 1302.22 hours, pore is 98.94 % closed
# counter= 46890 : at t = 1302.5 hours, pore is 98.97 % closed
# counter= 46900 : at t = 1302.78 hours, pore is 98.99 % closed
# counter= 46910 : at t = 1303.06 hours, pore is 99.01 % closed
# counter= 46920 : at t = 1303.33 hours, pore is 99.03 % closed
# counter= 46930 : at t = 1303.61 hours, pore is 99.05 % closed
# counter= 46940 : at t = 1303.89 hours, pore is 99.07 % closed
# counter= 46950 : at t = 1304.17 hours, pore is 99.09 % closed
# counter= 46960 : at t = 1304.45 hours, pore is 99.11 % closed
# counter= 46970 : at t = 1304.72 hours, pore is 99.13 % closed
# counter= 46980 : at t = 1305.0 hours, pore is 99.15 % closed
# counter= 46990 : at t = 1305.28 hours, pore is 99.17 % closed
# counter= 47000 : at t = 1305.56 hours, pore is 99.19 % closed
# counter= 47010 : at t = 1305.83 hours, pore is 99.22 % closed
# counter= 47020 : at t = 1306.11 hours, pore is 99.24 % closed
# counter= 47030 : at t = 1306.39 hours, pore is 99.26 % closed
# counter= 47040 : at t = 1306.67 hours, pore is 99.28 % closed
# counter= 47050 : at t = 1306.95 hours, pore is 99.3 % closed
# counter= 47060 : at t = 1307.22 hours, pore is 99.32 % closed
# counter= 47070 : at t = 1307.5 hours, pore is 99.34 % closed
# counter= 47080 : at t = 1307.78 hours, pore is 99.36 % closed
# counter= 47090 : at t = 1308.06 hours, pore is 99.38 % closed
# counter= 47100 : at t = 1308.33 hours, pore is 99.4 % closed
# counter= 47110 : at t = 1308.61 hours, pore is 99.42 % closed
# counter= 47120 : at t = 1308.89 hours, pore is 99.45 % closed
# counter= 47130 : at t = 1309.17 hours, pore is 99.47 % closed
# counter= 47140 : at t = 1309.45 hours, pore is 99.49 % closed
# counter= 47150 : at t = 1309.72 hours, pore is 99.51 % closed
# counter= 47160 : at t = 1310.0 hours, pore is 99.53 % closed
# counter= 47170 : at t = 1310.28 hours, pore is 99.55 % closed
# counter= 47180 : at t = 1310.56 hours, pore is 99.57 % closed
# counter= 47190 : at t = 1310.83 hours, pore is 99.59 % closed
# counter= 47200 : at t = 1311.11 hours, pore is 99.61 % closed
# counter= 47210 : at t = 1311.39 hours, pore is 99.63 % closed
# counter= 47220 : at t = 1311.67 hours, pore is 99.65 % closed
# counter= 47230 : at t = 1311.95 hours, pore is 99.68 % closed
# counter= 47240 : at t = 1312.22 hours, pore is 99.7 % closed
# counter= 47250 : at t = 1312.5 hours, pore is 99.72 % closed
# counter= 47260 : at t = 1312.78 hours, pore is 99.74 % closed
# counter= 47270 : at t = 1313.06 hours, pore is 99.76 % closed
# counter= 47280 : at t = 1313.33 hours, pore is 99.78 % closed
# counter= 47290 : at t = 1313.61 hours, pore is 99.8 % closed
# counter= 47300 : at t = 1313.89 hours, pore is 99.82 % closed
# counter= 47310 : at t = 1314.17 hours, pore is 99.84 % closed
# counter= 47320 : at t = 1314.45 hours, pore is 99.86 % closed
# counter= 47330 : at t = 1314.72 hours, pore is 99.88 % closed
# counter= 47340 : at t = 1315.0 hours, pore is 99.91 % closed
# counter= 47350 : at t = 1315.28 hours, pore is 99.93 % closed
# counter= 47360 : at t = 1315.56 hours, pore is 99.95 % closed
# counter= 47370 : at t = 1315.83 hours, pore is 99.97 % closed
# counter= 47380 : at t = 1316.11 hours, pore is 99.99 % closed
# 47386
# xi= [2.99162533e-05 4.18223406e-05 5.46068035e-05 6.80111012e-05
#  8.18234137e-05 9.58659687e-05 1.09986940e-04 1.24054956e-04
#  1.37955216e-04 1.51586635e-04 1.64859702e-04 1.77694820e-04
#  1.90021008e-04 2.01774863e-04 2.12899724e-04 2.23344986e-04
#  2.33065539e-04 2.42021298e-04 2.50176820e-04 2.57500976e-04
#  2.63966685e-04 2.69550686e-04 2.74233355e-04 2.77998556e-04
#  2.80833514e-04 2.82728731e-04 2.83677908e-04 2.83677908e-04]
# moose input for damage is:  if(y>=7.222222222222222e-05, 2.9916253251108547e-05, if(y>=6.944444444444443e-05, 4.182234059805335e-05, if(y>=6.666666666666666e-05, 5.460680349445072e-05, if(y>=6.388888888888888e-05, 6.801110124451015e-05, if(y>=6.111111111111111e-05, 8.182341370668346e-05, if(y>=5.8333333333333326e-05, 9.586596871105097e-05, if(y>=5.555555555555555e-05, 0.00010998693979386868, if(y>=5.277777777777777e-05, 0.00012405495631666774, if(y>=4.9999999999999996e-05, 0.00013795521600636242, if(y>=4.7222222222222214e-05, 0.00015158663537359528, if(y>=4.444444444444444e-05, 0.00016485970216951212, if(y>=4.1666666666666665e-05, 0.00017769481989607906, if(y>=3.8888888888888884e-05, 0.00019002100761635, if(y>=3.611111111111111e-05, 0.00020177486291384603, if(y>=3.333333333333333e-05, 0.00021289972412517818, if(y>=3.0555555555555554e-05, 0.00022334498643380624, if(y>=2.7777777777777776e-05, 0.00023306553889714936, if(y>=2.4999999999999998e-05, 0.00024202129806154577, if(y>=2.222222222222222e-05, 0.00025017681991236273, if(y>=1.9444444444444442e-05, 0.0002575009762827443, if(y>=1.6666666666666664e-05, 0.0002639666850612525, if(y>=1.3888888888888888e-05, 0.00026955068596487254, if(y>=1.111111111111111e-05, 0.00027423335545290775, if(y>=8.333333333333332e-06, 0.0002779985558013603, if(y>=5.555555555555555e-06, 0.00028083351447135227, if(y>=2.7777777777777775e-06, 0.00028272873081231815, if(y>=0.0, 0.0002836779078928454,  0)))))))))))))))))))))))))))

# %%
fig, ax = plt.subplots(figsize = (10,2.7), layout='constrained')
# a[-1]=a[-1]*100
# ax.plot(np.linspace(0,5,5),np.ones(5)*0.3,color='black',linestyle='--',label='Initial')
# ax.plot(c[0],c[5],label='1303K',color='blue',linewidth=3)
ax.plot(np.linspace(0,a[-1][-1],len(a[-2])),a[-2],label='1.342 eV upper bound',color='black',linewidth=3)
# ax.plot(b[0],b[5],label='1073K',color='red',linewidth=3)
plt.ylim([0,5e-5])
plt.xlim([0,50])
# plt.yticks(np.arange(0, 60, step=10))
ax.set_xlabel('t hr')
ax.set_ylabel(r'$r_p$ m')
# ax.set_title(r'$\xi_0 = 0.30$')
ax.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.savefig('walker_rp_t_1342.svg', dpi=220,bbox_inches='tight')

# %%
# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(a[-1],a[-2],label='K='+str(round(a[-5],6)))
# # ax.plot(b[-1],b[-2],label='9.85')

# ax.set_xlabel('t s')
# ax.set_ylabel('$r_p$ $\mu$m')
# # plt.xlim([0,1000])
# # plt.xticks(np.arange(0, 6, step=1))
# # plt.ylim([0,50])
# # plt.yticks(np.arange(0, (50 + 50/5), step=50/5))
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('dP.svg', dpi=220,bbox_inches='tight')

# %%
# c = cvi_nonlinear(1223,2000,34e-6, 10e-3/34e-6, 5, "blue",r"$1273$K, $dt = 1$s",100,"phi")
# b = cvi_nonlinear(1223,10000,34e-6, 10e-3/34e-6, 5, "blue",r"$1273$K, $dt = 1$s",10,"phi")
# a = cvi_nonlinear(1223,20000,34e-6, 10e-3/34e-6, 5, "blue",r"$1273$K, $dt = 1$s",10,"phi")

# %%
# #P comparison

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# arr_10kpa_x = np.array([0.89,1.48,1.89,2.89,3.08,5.68])
# arr_10kpa_y = np.array([0.92,6.98,9.98,13.01,13.49,15.76])

# arr_2kpa_x = np.array([0.41, 2.38, 3.28, 4.39, 4.99])
# arr_2kpa_y = np.array([0.76, 14.68, 16, 16.7,16.92])

# arr_10kpa_x = arr_10kpa_x - arr_10kpa_x[0]
# arr_2kpa_x = arr_2kpa_x - arr_2kpa_x[0]
# arr_10kpa_y = 17 - (arr_10kpa_y - arr_10kpa_y[0])
# arr_2kpa_y = 17 - (arr_2kpa_y - arr_2kpa_y[0])

# # ax.plot(b[0]*1000,a[5]*1e6,label=r'20kPa',color='blue')
# ax.plot(b[0]*1000,b[5]*1e6,label=r'10kPa, calc',color='green')
# ax.scatter(arr_10kpa_x, arr_10kpa_y,color='green',label='10kPa, exp',marker=matplotlib.markers.CARETUPBASE)
# ax.plot(c[0]*1000,c[5]*1e6,label=r'2kPa, calc',color='red')
# ax.scatter(arr_2kpa_x, arr_2kpa_y,color='red',label='2kPa, exp',marker=matplotlib.markers.CARETDOWNBASE)

# ax.set_xlabel('z mm')
# ax.set_ylabel('$d$ $\mu$m')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([0,17])
# plt.yticks(np.arange(0, (17 + 17/5), step=17/5))
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('dP.svg', dpi=220,bbox_inches='tight')

# %%
# llp = cvi_nonlinear(1173,5000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# lp = cvi_nonlinear(1173,10000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# n = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",500,"phi")

# %%
# hp = cvi_nonlinear(1173,35000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# %%
# hhp = cvi_nonlinear(1173,50000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",200,"phi")

# %%
# b = cvi_nonlinear(1123,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# c = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",500,"phi")

# %%
# d = cvi_nonlinear(1223,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# %%
# e = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",50,"phi")

# %%
# f = cvi_nonlinear(1283,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",40,"phi")

# %%
# g= cvi_nonlinear(1293,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",30,"phi")

# %%
# h= cvi_nonlinear(1303,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",25,"phi")

# %%
# fig, ax = plt.subplots(figsize = (7,3), layout='constrained')

# tp_t = np.array([1073, 1173, 1173, 1173, 1173, 1173, 1273])
# tp_p = np.array([20, 5, 10, 20, 35, 50, 20])
# tp_tf = np.array([358.33, 92.22, 46.11, str(23.06)+' hrs', 13.67, 9.22, 2.31])

# ax.scatter(tp_t, tp_p,color='red')
# for i, txt in enumerate(tp_tf):
#     ax.annotate(txt, (tp_t[i],tp_p[i]),fontsize=13)

# ax.set_xlabel('$T$ K')
# ax.set_ylabel('$P$ kPa')
# plt.xlim([1073-27,1300])
# plt.xticks(np.arange(1073, 1373, step=100))
# plt.ylim([0,60])
# plt.yticks(np.arange(0, 60, step=10))
# plt.title(r'$t_f$ vs. {$T,P$}')
# # plt.legend(bbox_to_anchor=(1.05, 1.1), loc="upper left")
# ax.grid(True)

# plt.savefig('pt.svg', dpi=220,bbox_inches='tight')

# %%
# i= cvi_nonlinear(1313,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",5,"phi")

# %%
# #T comparison

# c = cvi_nonlinear(1073,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",10000,"phi")
# b = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")
# a = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1,"phi")

# %%
# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# arr_10kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_10kpa_y = np.array([2.62, 3.38, 3.88, 4.05, 4.22, 4.31])

# arr_11kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_11kpa_y = np.array([2.62, 7.43, 11.06, 13.26, 14.19, 14.70])

# arr_12kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_12kpa_y = np.array([2.62, 18.66, 28.88, 33.78, 36.57, 37.33])

# arr_10kpa_x = arr_10kpa_x - arr_10kpa_x[0]
# arr_11kpa_x = arr_11kpa_x - arr_11kpa_x[0]
# arr_12kpa_x = arr_12kpa_x - arr_12kpa_x[0]

# arr_10kpa_y = 50 - (arr_10kpa_y - arr_10kpa_y[0])
# arr_11kpa_y = 50 - (arr_11kpa_y - arr_11kpa_y[0])
# arr_12kpa_y = 50 - (arr_12kpa_y - arr_12kpa_y[0])
# ax.plot(b[0]*1000,c[5]*1e6,label=r'1073K',color='blue')
# ax.scatter(arr_10kpa_x, arr_10kpa_y,color='blue',label='1073K, exp',marker=matplotlib.markers.CARETDOWNBASE)
# ax.plot(b[0]*1000,b[5]*1e6,label=r'1173K',color='green')
# ax.scatter(arr_11kpa_x, arr_11kpa_y,color='green',label='1173K, exp',marker='X')
# ax.plot(b[0]*1000,a[5]*1e6,label=r'1273K',color='red')
# ax.scatter(arr_12kpa_x, arr_12kpa_y,color='red',label='1273K, exp',marker=matplotlib.markers.CARETUPBASE)




# ax.set_xlabel('z mm')
# ax.set_ylabel('$d$ $\mu$m')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([0,50])
# plt.yticks(np.arange(0, 60, step=10))
# plt.legend(bbox_to_anchor=(1.05, 1.1), loc="upper left")
# ax.grid(True)

# plt.savefig('dT.svg', dpi=220,bbox_inches='tight')

# %%
# #alpha comparison

# c = cvi_nonlinear(1273,20000,100e-6, 100, 100, "blue",r"$1273$K, $dt = 1$s",1000,"phi")
# b = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")
# a = cvi_nonlinear(1273,20000,100e-6, 100, 1, "blue",r"$1273$K, $dt = 1$s",10,"phi")

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(a[0]*1000,a[1],label=r'MTS, $\alpha=1$',color='red')
# ax.plot(a[0]*1000,a[2],label=r'H2, $\alpha=1$',color='blue')
# ax.plot(a[0]*1000,a[3],label=r'HCl, $\alpha=1$',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.title(r'$\alpha=1$')
# plt.ylim([0,1.5])
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha1.svg', dpi=220,bbox_inches='tight')


# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(b[0]*1000,b[1],label=r'MTS',color='red')
# ax.plot(b[0]*1000,b[2],label=r'H2',color='blue')
# ax.plot(b[0]*1000,b[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.title(r'$\alpha=10$')
# plt.ylim([-0.2,2])
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha10.svg', dpi=220,bbox_inches='tight')

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(c[0]*1000,c[1],label=r'MTS',color='red')
# ax.plot(c[0]*1000,c[2],label=r'H2',color='blue')
# ax.plot(c[0]*1000,c[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([-0.2,2])
# plt.title(r'$\alpha=100$')
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha100.svg', dpi=220,bbox_inches='tight')
