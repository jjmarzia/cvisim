# %%
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats, optimize, interpolate
from scipy.optimize import fsolve
from scipy.integrate import odeint
from scipy.integrate import solve_bvp
from scipy.linalg import solve_banded
plt.rcParams.update({'font.size': 18})

# %%
#
# Define function cvi_nonlinear which computes resulting pore radius/gas concentration profiles as a function of CVI process parameters
#

def cvi_nonlinear(Tin,Pin, phi0in, rin, ain,plot_line_color,plot_line_label,dt,variable_plotted,nzin): # Temperature, pressure, initial pore diameter, aspect ratio, phase ratio, line color, line label, time stepper, variable to plot (between rp and C). 
    
    
    ###
    # CVI CONDITIONS
    ###
    
    phi0 = phi0in     # Pore diameter, m  
    L = rin*phi0      # Length, m
    nz = nzin         # Number of grid points, dimensionless
    h = L/(nz+1)      # Distance between grid points, m
    hh = h**2
    dt = dt           # Time stepper, s

    phii = phi0*np.ones(nz)
    phi = phii
    
    Zrange = np.linspace(0,L/2,nz)           # Grid that represents length of specimen
    alpha = ain                            # Ratio between H2 and MTS concentrations at reactor entrance, dimensionless
    P = Pin                                # Pressure, Pa
    T = Tin                                # Temperature, K
    
    
    R = 8.314                              # Ideal gas constant, J/mol K
    
    CMTS0 = (1/(1+alpha))*(P / (R*T))      # MTS concentration at z=0 (BC), mol/m^3
    CH20 = (alpha/(1+alpha))*(P / (R*T))   # H2 concentration at z=0 (1-CMTS0), mol/m^3,  Fedou1993-2 Eqs. 9-10
    CHCl0 = 0                              # HCl concentration at z=0 (1-CMTS0), mol/m^3
    
    k0 = 3.89e9                            # Reaction rate coefficient, m/s
    Ea = 296e3                             # Activation energy, J/mol
    
    CMTS = CMTS0*np.ones(nz)
    CMTS[0] = CMTS0
    CH2 = CH20*np.ones(nz)                     # Gas phase composition at pore entrance, Fedou1993-2 Eqs. 9-10
    CH2[0] = CH20
    CHCl = CHCl0*np.ones(nz)
    CHCl[0] = CHCl0
    
    Ct0_before_penetration = [CMTS, CH2, CHCl]
    
    khet = k0*np.exp(-Ea/(R*T))
    print('khet_fedou=',khet)
    
    
    #### Walker DFT paper
    # R = 8.617333262e-5
    # T = 1273
    # Ea = 0.918 #mean
    # # Ea = 0.493 #lower bound
    # # Ea = 1.342 #upper bound
    # khet = np.exp(-Ea/(R*T))
    # print("khet_walker=",khet)
    ####
    
    nu = khet*CMTS         # Kinetic law, Fedou1993-2 Eq. 3
    
    dKMTS = 3.97 #m/sK^(1/2)               # Reduced Knudsen coefficient of MTS, m/s K^1/2
    dKH2 = 34.30 #m/sK^(1/2)               # Reduced Knudsen coefficient of H2, m/s K^1/2,  Fedou1993-2 Table I
    dKHCl = 8.03 #m/sK^(1/2)               # Reduced Knudsen coefficient of HCl, m/s K^1/2
    
    DKMTS=dKMTS*phi*(T**0.5)              # Knudsen diffusion coefficient of MTS, m^2/s 
    DKH2=dKH2*phi*(T**0.5)                # Knudsen diffusion coefficient of H2, m^2/s,  Fedou1993-2 Eq. 2
    DKHCl=dKHCl*phi*(T**0.5)              # Knudsen diffusion coefficient of HCl, m^2/s 
    
    # MSiC = 0.04011                       # Molar mass of SiC, kg/mol
    MMTS = 0.149                             # Molar mass of MTS, kg/mol
    MH2 = 2e-3                             # Molar mass of H2, kg/mol,  Fedou1993-2 Table I
    MHCl = 3.65e-2                         # Molar mass of HCl, kg/mol
    
    # rhoSiC = 3217                        # Density of SiC, kg/m^3
    # rhoMTS = 1270
    # rhoH2 = 0.08375
    # rhoHCl = 1048
    
    VSiC = 12.5e-6                         # Specific volume of SiC, m^3/mol,  Fedou1993-2 Section 2.2
    VMTS = 122.7e-6                          # Specific volume of MTS, m^3/mol
    VH2  = 14.3e-6                            # Specific volume of H2, m^3/mol,  Fedou1993-2 Table III
    VHCl = 25.3e-6                          # Specific volume of HCl, m^3/mol
    
    # VMTS = 122.7                          # Specific volume of MTS, cm^3/mol
    # VH2  = 14.3                            # Specific volume of H2, cm^3/mol,  Fedou1993-2 Table III
    # VHCl = 25.3                          # Specific volume of HCl, cm^3/mol
    
    sMTS = -1
    sH2 = 0                               # Stoichiometric coefficients of the chemical elements, Fedou1993-1 Eq. 1 and Fedou1993-2 Eq. 1
    sHCl = 3
    sSiC = 1
    deltas = sMTS + sH2 + sHCl + sSiC             # Sum of coefficients, Fedou1993-1 Eq. 11
    s = [sMTS, sH2, sHCl, sSiC]

    Dij_MTSH2 = 1.360e-3*((T**(3/2))/(P*(VH2**(1/3)+VMTS**(1/3))**2))*(1/MH2 + 1/MMTS)**0.5
    Dij_MTSHCl = 1.360e-3*((T**(3/2))/(P*(VHCl**(1/3)+VMTS**(1/3))**2))*(1/MHCl + 1/MMTS)**0.5   # Gilliland formula, Fedou1993-1 Appendix 1 Eq A4
    
    epsik = 59.7
    sigi = 0.2827e-9
    epsjk = 344.7
    sigj = 0.3339e-9
    sigij = (sigi+sigj)/2
    kepsij = (epsik * epsjk)**(-0.5)
    Tstar = kepsij*T
    Tstar = np.rint(Tstar)
    if Tstar ==7:
        omegaD = 0.79643333
    if Tstar == 8: 
        omegaD = 0.78003333                # Hirschfelder formula, Fedou1993-1 Appendix 1 Eqs. A1-A3; calculation of 
    if Tstar == 9:
        omegaD = 0.76611111
    if Tstar == 10:
        omegaD = 0.75401111
    V = 2.78125e4

    Dij_H2HCl = 5.876e-24  *((T**1.5)/(P*(sigij**2)*V*omegaD))*((1/MH2 + 1/MHCl)**0.5)
    Dij_H2HCl = 1.360e-3*((T**(3/2))/(P*(VHCl**(1/3)+VH2**(1/3))**2))*(1/MHCl + 1/MH2)**0.5 
    # print("dfomega=",Dij_H2HCl, "dfvhcl=",Dij_H2HCl_v2)
    
    N = deltas*nu
    
    xMTS  = CMTS/(CMTS+CH2+CHCl)
    xH2 = CH2/(CMTS+CH2+CHCl)                                     # Molar fractions, Fedou1993-1 Eq. 13                                    
    xHCl = CHCl/(CMTS+CH2+CHCl)
    
    dxMTSdz = dxH2dz = dxHCldz = np.zeros(nz)
    
    # DFMTS = ((1/(1-xMTS[0]))*(xHCl[0]/Dij_MTSHCl + xH2[0]/Dij_MTSH2))**(-1)
    # DFH2 = ((1/(1-xH2[0]))*(xHCl[0]/Dij_H2HCl + xMTS[0]/Dij_MTSH2))**(-1)      # Fick diffusion coefficients, Fedou1993-1 Eq. 16
    # DFHCl = ((1/(1-xHCl[0]))*(xH2[0]/Dij_H2HCl + xMTS[0]/Dij_MTSHCl))**(-1)
    
    DFMTS = ((1/(1-xMTS))*(xHCl/Dij_MTSHCl + xH2/Dij_MTSH2))**(-1)
    DFH2 = ((1/(1-xH2))*(xHCl/Dij_H2HCl + xMTS/Dij_MTSH2))**(-1)      # Fick diffusion coefficients, Fedou1993-1 Eq. 16
    DFHCl = ((1/(1-xHCl))*(xH2/Dij_H2HCl + xMTS/Dij_MTSHCl))**(-1)

    DMTS = (1/DFMTS + 1/DKMTS)**(-1)          
    DH2 = (1/DFH2 + 1/DKH2)**(-1)          # Overall diffusion coefficient, Fedou1993-1 Eq. 15
    DHCl = (1/DFHCl + 1/DKHCl)**(-1) 
    
    ###
    # INITIALIZE SOLUTION VECTORS
    ###
    
    Csol = []
    Dsol = []
    for k in range(nz):
        Dsol = np.append(Dsol,DMTS[k])
        Dsol = np.append(Dsol,DH2[k])  # D matrix
        Dsol = np.append(Dsol,DHCl[k])
        Csol = np.append(Csol,CMTS[k])
        Csol = np.append(Csol,CH2[k])  # C matrix
        Csol = np.append(Csol,CHCl[k])
    C0sol = Csol

    print('----------------------------------T=',T,'P=',P, 'CMTS0=',CMTS0,'CH20=',CH20,'CHCl0=',CHCl0)

    
    CMTSt = []                             
    CH2t = []                              # Array containing gas concentration profiles of MTS, H2, HCl
    CHClt = []
    
    phit = []
    rpt = []
    
    percent_closed = 0                     # Dimensionless rating of pore size relative to initial pore size
    counter =0                             # Time counter
    
    
    ###
    # NONLINEAR ITERATIVE SOLVER
    ###
    
    while any(phi<phi0/100) is not True:
        
        # Assemble D, C matrices so that (gas,gridpt)=(i,j) = Cm[3j+i]. Gases\in [0,2] = [MTS, H2, HCl]. Gridpts\in [0,n+1]
        # So C_{1,j} = C_{2,5} = C[3*5 + 2 = C[17].
        Csol = []
        Dsol = []
        
        for k in range(nz):
            Dsol = np.append(Dsol,DMTS[k])
            Dsol = np.append(Dsol,DH2[k])  # D matrix
            Dsol = np.append(Dsol,DHCl[k])
            Csol = np.append(Csol,CMTS[k])
            Csol = np.append(Csol,CH2[k])  # C matrix
            Csol = np.append(Csol,CHCl[k])
        # if counter==0:
        #     print('C=',Csol.size,'D=',Dsol.size)
        #     print(Csol,Dsol)
        
        def F(C, *data_args):
            D, h, hh, N, s, nu, phi = data_args
            exps = []
            n = nz-2
            for j in range(1,n+1): #1\leq j\leq n. #nz=7--> j=1,2,3,4,5     
                # print(C.size)
                # print(j)
                if j==1:
                    xi_jp1 = C[3]/(C[3]+C[4]+C[5])
                    xi_jm1 = CMTS0/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CMTS0 - 2*C[0] + C[3])/hh - (xi_jp1*N[2]-xi_jm1*N[0])/(2*D[0]*h) + (4*s[0]*nu[0])/(D[0]*phi[0]))
                    # print("exps1=",exps.size)
                    
                    xi_jp1 = C[4]/(C[4]+C[5]+C[3])
                    xi_jm1 = CH20/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CH20 - 2*C[1] + C[4])/hh - ((xi_jp1*N[2]-xi_jm1*N[0])/(2*D[1]*h)) + (4*s[1]*nu[0])/(D[1]*phi[0]))
                    # print("exps2=",exps.size)
                    
                    xi_jp1 = C[5]/(C[5]+C[4]+C[3])
                    xi_jm1 = CHCl0/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CHCl0 - 2*C[2] + C[5])/hh - ((xi_jp1*N[2]-xi_jm1*N[0])/(2*D[2]*h)) + (4*s[2]*nu[0])/(D[2]*phi[0]))
                    # print("exps3=",exps.size)
                    
                if not j==1 and not j==n: #j=2,3,4
                    for i in range(3): #i=0,1,2
                        if i==0: #defining molar fractions for each gas i. MTS
                            xi_jp1 = C[3*j]/(C[3*j]+C[3*j+1]+C[3*j+2])
                            xi_jm1 = C[3*(j-2)]/(C[3*(j-2)]+C[3*(j-2)+1]+C[3*(j-2)+2])
                        if i==1: #H2
                            xi_jp1 = C[3*j+1]/(C[3*j+1]+C[3*j+2]+C[3*j])
                            xi_jm1 = C[3*(j-2)+1]/(C[3*(j-2)+1]+C[3*(j-2)+2]+C[3*(j-2)])
                        if i==2: #HCl
                            xi_jp1 = C[3*j+2]/(C[3*j+2]+C[3*j+1]+C[3*j])
                            xi_jm1 = C[3*(j-2)+2]/(C[3*(j-2)+2]+C[3*(j-2)+1]+C[3*(j-2)])

                        expij = (C[3*(j-2)+i] - 2*C[3*(j-1)+i] + C[3*j+i])/hh - (xi_jp1*N[j+1]-xi_jm1*N[j-1])/(2*D[3*(j-1)+i]*h) + (4*s[i]*nu[j-1])/(D[3*(j-1)+i]*phi[j-1])
                        exps = np.append(exps, expij)
                        # print("exps4=",exps.size)
                        
                if j==n: #j=5,
                    for i in range(3):
                        if i==0: #defining molar fractions for each gas i. MTS
                            xi_jp1 = C[3*(n-1)]/(C[3*(n-1)]+C[3*(n-1)+1]+C[3*(n-1)+2])
                            xi_jm1 = C[3*(n-2)]/(C[3*(n-2)]+C[3*(n-2)+1]+C[3*(n-2)+2])
                        if i==1: #H2
                            xi_jp1 = C[3*(n-1)+1]/(C[3*(n-1)+1]+C[3*(n-1)+2]+C[3*(n-1)])
                            xi_jm1 = C[3*(n-2)+1]/(C[3*(n-2)+1]+C[3*(n-2)+2]+C[3*(n-2)])
                        if i==2: #HCl
                            xi_jp1 = C[3*(n-1)+2]/(C[3*(n-1)+2]+C[3*(n-1)+1]+C[3*(n-1)])
                            xi_jm1 = C[3*(n-2)+2]/(C[3*(n-2)+2]+C[3*(n-2)+1]+C[3*(n-2)])

                        expij = (C[3*(n-2)+i] - C[3*(n-1)+i])/hh - (xi_jp1*N[n+1]-xi_jm1*N[n-1])/(2*D[3*(n-1)+i]*h) + (4*s[i]*nu[n-1])/(D[3*(n-1)+i]*phi[n-1])
                        exps = np.append(exps, expij)
            return exps
        
        data_args = (Dsol[3:-3], h, hh, N, s, nu[1:-1], phi[1:-1])
        Csol = fsolve(F, C0sol[3:-3], args=data_args)
        Csol = np.insert(Csol, 0, CHCl0)
        Csol = np.insert(Csol, 0, CH20)           # left boundary condition
        Csol = np.insert(Csol, 0, CMTS0)
        for _ in range(3):
            Csol = np.append(Csol, Csol[-3])      # right boundary condition
            
        CMTS = Csol[0::3]
        CH2 = Csol[1::3]
        CHCl = Csol[2::3]
    
        # khet = k0*np.exp(-Ea/(R*T))
        # khet =
    
        nu = khet*CMTS                            # Kinetic law, Fedou1993-2 Eq. 3
        N = deltas*nu 
        phi = phi - (2*dt*nu*VSiC)                # Update pore diameter

        DFMTS = ((1/(1-xMTS))*(xHCl/Dij_MTSHCl + xH2/Dij_MTSH2))**(-1)
        DFH2 = ((1/(1-xH2))*(xHCl/Dij_H2HCl + xMTS/Dij_MTSH2))**(-1)     # Update Fick diffusion coefficients, Fedou1993-1 Eq. 16
        DFHCl = ((1/(1-xHCl))*(xH2/Dij_H2HCl + xMTS/Dij_MTSHCl))**(-1)
        
        DKMTS = dKMTS*phi*(T**0.5)
        DKH2 = dKH2*phi*(T**0.5)                                      # Update Knudsen diffusion coefficients, Fedou1993-2 Eq. 2
        DKHCl = dKHCl*phi*(T**0.5)

        DMTS = (1/DFMTS + 1/DKMTS)**(-1)          
        DH2 = (1/DFH2 + 1/DKH2)**(-1)                                    # Update overall diffusion coefficient, Fedou1993-1 Eq. 15
        DHCl = (1/DFHCl + 1/DKHCl)**(-1)              

        
        counter+=1
        rpt.append(phi[0]/2)
        if counter % 10 == 0:
            # print(rpt)
            CMTSt.append(CMTS)
            CH2t.append(CH2) # Collect pore diameter/gas concentration profiles at current time step
            CHClt.append(CHCl)
            # print("nu=",nu[0:3],"CMTS=",CMTS[0:3])
            phit.append(phi)
            percent_closed = 100*(1 -(phi[0]-phi0/100)/phi0)
            print('counter=',counter,': at t =',round(counter*dt*0.000277778,2),'hours, pore is', round(percent_closed,2),'% closed')
    print(counter) 
    t_f_hrs = counter*dt*0.000277778
    t_f_secs = counter*dt
    d = (phii-phi)/2
    # print('phi=',phi,'CMTS=', CMTS)
    
    counter_t = np.arange(0,counter,dt)
    # print('counter_t=',counter_t)
    # print(np.shape(counter_t), np.shape(rpt))
    
    
    ###
    # MOOSE DAMAGE INPUT
    ###
    
    rp = phi/2
    porosity = 0.3
    RpRVE = np.sqrt(1/porosity)*(phi0/2)

    # print('rp=',rp)
    xi = (rp**2)/(RpRVE**2)
    print('xi=',xi)
    
    mesh_height = 7.5e-5
    num_elements = 28 #ideally =nz
    
    Zrange_fem = np.linspace(0,L/2,num_elements)
    
    counter_xi=0
    xi_condensed = []
    for q in range(num_elements):
        counter_xi = round(q*(nz/num_elements))
        xi_condensed.append(xi[counter_xi])
    # print('xi_condensed=',xi_condensed)
    xi = xi_condensed
    
    element_positions = np.linspace(0, mesh_height, num_elements)  
    
    moose_input_i = ''
    par_input = ''
    for q in range(num_elements-1):
        moose_input = str(moose_input_i)+'if(y>='+str(element_positions[num_elements-2-q])+', '+str(xi[q])+', '
        moose_input_i = moose_input
        par_input = str(par_input)+')'
    moose_input = str(moose_input_i)+' 0'+str(par_input)
    
    print('xi=',xi)
    print('moose input for damage is: ',moose_input)
    
    
    return [Zrange, Zrange_fem, CMTS,CH2,CHCl, phi, d, L, str(plot_line_label), rp, xi, khet, t_f_hrs, t_f_secs, rpt, counter_t]

# %%
#
# Call the function cvi_sim
#

# Inputs: Temperature (K), pressure (Pa), pore diameter (m), aspect ratio, gas ratio,      ...
#         plot line color, plot line label, dt, variable to be plotted between "phi" or "C".

# %%
asol = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',1,'',28)
bsol = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',1,'',100)
csol = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',1,'',200)
dsol = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',1,'',400)
fsol = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',1,'',800)
# Out:
# khet_fedou= 0.0027786172881957174
# ----------------------------------T= 1273 P= 20000 CMTS0= 0.1717903983288505 CH20= 1.717903983288505 CHCl0= 0
# counter= 10 : at t = 0.0 hours, pore is 1.12 % closed
# counter= 20 : at t = 0.01 hours, pore is 1.24 % closed
# counter= 30 : at t = 0.01 hours, pore is 1.36 % closed
# counter= 40 : at t = 0.01 hours, pore is 1.48 % closed
# counter= 50 : at t = 0.01 hours, pore is 1.6 % closed
# counter= 60 : at t = 0.02 hours, pore is 1.72 % closed
# counter= 70 : at t = 0.02 hours, pore is 1.84 % closed
# counter= 80 : at t = 0.02 hours, pore is 1.95 % closed
# counter= 90 : at t = 0.03 hours, pore is 2.07 % closed
# counter= 100 : at t = 0.03 hours, pore is 2.19 % closed
# counter= 110 : at t = 0.03 hours, pore is 2.31 % closed
# counter= 120 : at t = 0.03 hours, pore is 2.43 % closed
# counter= 130 : at t = 0.04 hours, pore is 2.55 % closed
# counter= 140 : at t = 0.04 hours, pore is 2.67 % closed
# counter= 150 : at t = 0.04 hours, pore is 2.79 % closed
# counter= 160 : at t = 0.04 hours, pore is 2.91 % closed
# counter= 170 : at t = 0.05 hours, pore is 3.03 % closed
# counter= 180 : at t = 0.05 hours, pore is 3.15 % closed
# counter= 190 : at t = 0.05 hours, pore is 3.27 % closed
# counter= 200 : at t = 0.06 hours, pore is 3.39 % closed
# counter= 210 : at t = 0.06 hours, pore is 3.51 % closed
# counter= 220 : at t = 0.06 hours, pore is 3.63 % closed
# counter= 230 : at t = 0.06 hours, pore is 3.74 % closed
# counter= 240 : at t = 0.07 hours, pore is 3.86 % closed
# counter= 250 : at t = 0.07 hours, pore is 3.98 % closed
# counter= 260 : at t = 0.07 hours, pore is 4.1 % closed
# counter= 270 : at t = 0.08 hours, pore is 4.22 % closed
# counter= 280 : at t = 0.08 hours, pore is 4.34 % closed
# counter= 290 : at t = 0.08 hours, pore is 4.46 % closed
# counter= 300 : at t = 0.08 hours, pore is 4.58 % closed
# counter= 310 : at t = 0.09 hours, pore is 4.7 % closed
# counter= 320 : at t = 0.09 hours, pore is 4.82 % closed
# counter= 330 : at t = 0.09 hours, pore is 4.94 % closed
# counter= 340 : at t = 0.09 hours, pore is 5.06 % closed
# counter= 350 : at t = 0.1 hours, pore is 5.18 % closed
# counter= 360 : at t = 0.1 hours, pore is 5.3 % closed
# counter= 370 : at t = 0.1 hours, pore is 5.42 % closed
# counter= 380 : at t = 0.11 hours, pore is 5.53 % closed
# counter= 390 : at t = 0.11 hours, pore is 5.65 % closed
# counter= 400 : at t = 0.11 hours, pore is 5.77 % closed
# counter= 410 : at t = 0.11 hours, pore is 5.89 % closed
# counter= 420 : at t = 0.12 hours, pore is 6.01 % closed
# counter= 430 : at t = 0.12 hours, pore is 6.13 % closed
# counter= 440 : at t = 0.12 hours, pore is 6.25 % closed
# counter= 450 : at t = 0.13 hours, pore is 6.37 % closed
# counter= 460 : at t = 0.13 hours, pore is 6.49 % closed
# counter= 470 : at t = 0.13 hours, pore is 6.61 % closed
# counter= 480 : at t = 0.13 hours, pore is 6.73 % closed
# counter= 490 : at t = 0.14 hours, pore is 6.85 % closed
# counter= 500 : at t = 0.14 hours, pore is 6.97 % closed
# counter= 510 : at t = 0.14 hours, pore is 7.09 % closed
# counter= 520 : at t = 0.14 hours, pore is 7.21 % closed
# counter= 530 : at t = 0.15 hours, pore is 7.32 % closed
# counter= 540 : at t = 0.15 hours, pore is 7.44 % closed
# counter= 550 : at t = 0.15 hours, pore is 7.56 % closed
# counter= 560 : at t = 0.16 hours, pore is 7.68 % closed
# counter= 570 : at t = 0.16 hours, pore is 7.8 % closed
# counter= 580 : at t = 0.16 hours, pore is 7.92 % closed
# counter= 590 : at t = 0.16 hours, pore is 8.04 % closed
# counter= 600 : at t = 0.17 hours, pore is 8.16 % closed
# counter= 610 : at t = 0.17 hours, pore is 8.28 % closed
# counter= 620 : at t = 0.17 hours, pore is 8.4 % closed
# counter= 630 : at t = 0.18 hours, pore is 8.52 % closed
# counter= 640 : at t = 0.18 hours, pore is 8.64 % closed
# counter= 650 : at t = 0.18 hours, pore is 8.76 % closed
# counter= 660 : at t = 0.18 hours, pore is 8.88 % closed
# counter= 670 : at t = 0.19 hours, pore is 9.0 % closed
# counter= 680 : at t = 0.19 hours, pore is 9.11 % closed
# counter= 690 : at t = 0.19 hours, pore is 9.23 % closed
# counter= 700 : at t = 0.19 hours, pore is 9.35 % closed
# counter= 710 : at t = 0.2 hours, pore is 9.47 % closed
# counter= 720 : at t = 0.2 hours, pore is 9.59 % closed
# counter= 730 : at t = 0.2 hours, pore is 9.71 % closed
# counter= 740 : at t = 0.21 hours, pore is 9.83 % closed
# counter= 750 : at t = 0.21 hours, pore is 9.95 % closed
# counter= 760 : at t = 0.21 hours, pore is 10.07 % closed
# counter= 770 : at t = 0.21 hours, pore is 10.19 % closed
# counter= 780 : at t = 0.22 hours, pore is 10.31 % closed
# counter= 790 : at t = 0.22 hours, pore is 10.43 % closed
# counter= 800 : at t = 0.22 hours, pore is 10.55 % closed
# counter= 810 : at t = 0.23 hours, pore is 10.67 % closed
# counter= 820 : at t = 0.23 hours, pore is 10.79 % closed
# counter= 830 : at t = 0.23 hours, pore is 10.9 % closed
# counter= 840 : at t = 0.23 hours, pore is 11.02 % closed
# counter= 850 : at t = 0.24 hours, pore is 11.14 % closed
# counter= 860 : at t = 0.24 hours, pore is 11.26 % closed
# counter= 870 : at t = 0.24 hours, pore is 11.38 % closed
# counter= 880 : at t = 0.24 hours, pore is 11.5 % closed
# counter= 890 : at t = 0.25 hours, pore is 11.62 % closed
# counter= 900 : at t = 0.25 hours, pore is 11.74 % closed
# counter= 910 : at t = 0.25 hours, pore is 11.86 % closed
# counter= 920 : at t = 0.26 hours, pore is 11.98 % closed
# counter= 930 : at t = 0.26 hours, pore is 12.1 % closed
# counter= 940 : at t = 0.26 hours, pore is 12.22 % closed
# counter= 950 : at t = 0.26 hours, pore is 12.34 % closed
# counter= 960 : at t = 0.27 hours, pore is 12.46 % closed
# counter= 970 : at t = 0.27 hours, pore is 12.58 % closed
# counter= 980 : at t = 0.27 hours, pore is 12.69 % closed
# counter= 990 : at t = 0.28 hours, pore is 12.81 % closed
# counter= 1000 : at t = 0.28 hours, pore is 12.93 % closed
# counter= 1010 : at t = 0.28 hours, pore is 13.05 % closed
# counter= 1020 : at t = 0.28 hours, pore is 13.17 % closed
# counter= 1030 : at t = 0.29 hours, pore is 13.29 % closed
# counter= 1040 : at t = 0.29 hours, pore is 13.41 % closed
# counter= 1050 : at t = 0.29 hours, pore is 13.53 % closed
# counter= 1060 : at t = 0.29 hours, pore is 13.65 % closed
# counter= 1070 : at t = 0.3 hours, pore is 13.77 % closed
# counter= 1080 : at t = 0.3 hours, pore is 13.89 % closed
# counter= 1090 : at t = 0.3 hours, pore is 14.01 % closed
# counter= 1100 : at t = 0.31 hours, pore is 14.13 % closed
# counter= 1110 : at t = 0.31 hours, pore is 14.25 % closed
# counter= 1120 : at t = 0.31 hours, pore is 14.37 % closed
# counter= 1130 : at t = 0.31 hours, pore is 14.48 % closed
# counter= 1140 : at t = 0.32 hours, pore is 14.6 % closed
# counter= 1150 : at t = 0.32 hours, pore is 14.72 % closed
# counter= 1160 : at t = 0.32 hours, pore is 14.84 % closed
# counter= 1170 : at t = 0.33 hours, pore is 14.96 % closed
# counter= 1180 : at t = 0.33 hours, pore is 15.08 % closed
# counter= 1190 : at t = 0.33 hours, pore is 15.2 % closed
# counter= 1200 : at t = 0.33 hours, pore is 15.32 % closed
# counter= 1210 : at t = 0.34 hours, pore is 15.44 % closed
# counter= 1220 : at t = 0.34 hours, pore is 15.56 % closed
# counter= 1230 : at t = 0.34 hours, pore is 15.68 % closed
# counter= 1240 : at t = 0.34 hours, pore is 15.8 % closed
# counter= 1250 : at t = 0.35 hours, pore is 15.92 % closed
# counter= 1260 : at t = 0.35 hours, pore is 16.04 % closed
# counter= 1270 : at t = 0.35 hours, pore is 16.16 % closed
# counter= 1280 : at t = 0.36 hours, pore is 16.27 % closed
# counter= 1290 : at t = 0.36 hours, pore is 16.39 % closed
# counter= 1300 : at t = 0.36 hours, pore is 16.51 % closed
# counter= 1310 : at t = 0.36 hours, pore is 16.63 % closed
# counter= 1320 : at t = 0.37 hours, pore is 16.75 % closed
# counter= 1330 : at t = 0.37 hours, pore is 16.87 % closed
# counter= 1340 : at t = 0.37 hours, pore is 16.99 % closed
# counter= 1350 : at t = 0.38 hours, pore is 17.11 % closed
# counter= 1360 : at t = 0.38 hours, pore is 17.23 % closed
# counter= 1370 : at t = 0.38 hours, pore is 17.35 % closed
# counter= 1380 : at t = 0.38 hours, pore is 17.47 % closed
# counter= 1390 : at t = 0.39 hours, pore is 17.59 % closed
# counter= 1400 : at t = 0.39 hours, pore is 17.71 % closed
# counter= 1410 : at t = 0.39 hours, pore is 17.83 % closed
# counter= 1420 : at t = 0.39 hours, pore is 17.95 % closed
# counter= 1430 : at t = 0.4 hours, pore is 18.06 % closed
# counter= 1440 : at t = 0.4 hours, pore is 18.18 % closed
# counter= 1450 : at t = 0.4 hours, pore is 18.3 % closed
# counter= 1460 : at t = 0.41 hours, pore is 18.42 % closed
# counter= 1470 : at t = 0.41 hours, pore is 18.54 % closed
# counter= 1480 : at t = 0.41 hours, pore is 18.66 % closed
# counter= 1490 : at t = 0.41 hours, pore is 18.78 % closed
# counter= 1500 : at t = 0.42 hours, pore is 18.9 % closed
# counter= 1510 : at t = 0.42 hours, pore is 19.02 % closed
# counter= 1520 : at t = 0.42 hours, pore is 19.14 % closed
# counter= 1530 : at t = 0.43 hours, pore is 19.26 % closed
# counter= 1540 : at t = 0.43 hours, pore is 19.38 % closed
# counter= 1550 : at t = 0.43 hours, pore is 19.5 % closed
# counter= 1560 : at t = 0.43 hours, pore is 19.62 % closed
# counter= 1570 : at t = 0.44 hours, pore is 19.74 % closed
# counter= 1580 : at t = 0.44 hours, pore is 19.85 % closed
# counter= 1590 : at t = 0.44 hours, pore is 19.97 % closed
# counter= 1600 : at t = 0.44 hours, pore is 20.09 % closed
# counter= 1610 : at t = 0.45 hours, pore is 20.21 % closed
# counter= 1620 : at t = 0.45 hours, pore is 20.33 % closed
# counter= 1630 : at t = 0.45 hours, pore is 20.45 % closed
# counter= 1640 : at t = 0.46 hours, pore is 20.57 % closed
# counter= 1650 : at t = 0.46 hours, pore is 20.69 % closed
# counter= 1660 : at t = 0.46 hours, pore is 20.81 % closed
# counter= 1670 : at t = 0.46 hours, pore is 20.93 % closed
# counter= 1680 : at t = 0.47 hours, pore is 21.05 % closed
# counter= 1690 : at t = 0.47 hours, pore is 21.17 % closed
# counter= 1700 : at t = 0.47 hours, pore is 21.29 % closed
# counter= 1710 : at t = 0.48 hours, pore is 21.41 % closed
# counter= 1720 : at t = 0.48 hours, pore is 21.53 % closed
# counter= 1730 : at t = 0.48 hours, pore is 21.64 % closed
# counter= 1740 : at t = 0.48 hours, pore is 21.76 % closed
# counter= 1750 : at t = 0.49 hours, pore is 21.88 % closed
# counter= 1760 : at t = 0.49 hours, pore is 22.0 % closed
# counter= 1770 : at t = 0.49 hours, pore is 22.12 % closed
# counter= 1780 : at t = 0.49 hours, pore is 22.24 % closed
# counter= 1790 : at t = 0.5 hours, pore is 22.36 % closed
# counter= 1800 : at t = 0.5 hours, pore is 22.48 % closed
# counter= 1810 : at t = 0.5 hours, pore is 22.6 % closed
# counter= 1820 : at t = 0.51 hours, pore is 22.72 % closed
# counter= 1830 : at t = 0.51 hours, pore is 22.84 % closed
# counter= 1840 : at t = 0.51 hours, pore is 22.96 % closed
# counter= 1850 : at t = 0.51 hours, pore is 23.08 % closed
# counter= 1860 : at t = 0.52 hours, pore is 23.2 % closed
# counter= 1870 : at t = 0.52 hours, pore is 23.32 % closed
# counter= 1880 : at t = 0.52 hours, pore is 23.43 % closed
# counter= 1890 : at t = 0.53 hours, pore is 23.55 % closed
# counter= 1900 : at t = 0.53 hours, pore is 23.67 % closed
# counter= 1910 : at t = 0.53 hours, pore is 23.79 % closed
# counter= 1920 : at t = 0.53 hours, pore is 23.91 % closed
# counter= 1930 : at t = 0.54 hours, pore is 24.03 % closed
# counter= 1940 : at t = 0.54 hours, pore is 24.15 % closed
# counter= 1950 : at t = 0.54 hours, pore is 24.27 % closed
# counter= 1960 : at t = 0.54 hours, pore is 24.39 % closed
# counter= 1970 : at t = 0.55 hours, pore is 24.51 % closed
# counter= 1980 : at t = 0.55 hours, pore is 24.63 % closed
# counter= 1990 : at t = 0.55 hours, pore is 24.75 % closed
# counter= 2000 : at t = 0.56 hours, pore is 24.87 % closed
# counter= 2010 : at t = 0.56 hours, pore is 24.99 % closed
# counter= 2020 : at t = 0.56 hours, pore is 25.11 % closed
# counter= 2030 : at t = 0.56 hours, pore is 25.22 % closed
# counter= 2040 : at t = 0.57 hours, pore is 25.34 % closed
# counter= 2050 : at t = 0.57 hours, pore is 25.46 % closed
# counter= 2060 : at t = 0.57 hours, pore is 25.58 % closed
# counter= 2070 : at t = 0.58 hours, pore is 25.7 % closed
# counter= 2080 : at t = 0.58 hours, pore is 25.82 % closed
# counter= 2090 : at t = 0.58 hours, pore is 25.94 % closed
# counter= 2100 : at t = 0.58 hours, pore is 26.06 % closed
# counter= 2110 : at t = 0.59 hours, pore is 26.18 % closed
# counter= 2120 : at t = 0.59 hours, pore is 26.3 % closed
# counter= 2130 : at t = 0.59 hours, pore is 26.42 % closed
# counter= 2140 : at t = 0.59 hours, pore is 26.54 % closed
# counter= 2150 : at t = 0.6 hours, pore is 26.66 % closed
# counter= 2160 : at t = 0.6 hours, pore is 26.78 % closed
# counter= 2170 : at t = 0.6 hours, pore is 26.9 % closed
# counter= 2180 : at t = 0.61 hours, pore is 27.02 % closed
# counter= 2190 : at t = 0.61 hours, pore is 27.13 % closed
# counter= 2200 : at t = 0.61 hours, pore is 27.25 % closed
# counter= 2210 : at t = 0.61 hours, pore is 27.37 % closed
# counter= 2220 : at t = 0.62 hours, pore is 27.49 % closed
# counter= 2230 : at t = 0.62 hours, pore is 27.61 % closed
# counter= 2240 : at t = 0.62 hours, pore is 27.73 % closed
# counter= 2250 : at t = 0.63 hours, pore is 27.85 % closed
# counter= 2260 : at t = 0.63 hours, pore is 27.97 % closed
# counter= 2270 : at t = 0.63 hours, pore is 28.09 % closed
# counter= 2280 : at t = 0.63 hours, pore is 28.21 % closed
# counter= 2290 : at t = 0.64 hours, pore is 28.33 % closed
# counter= 2300 : at t = 0.64 hours, pore is 28.45 % closed
# counter= 2310 : at t = 0.64 hours, pore is 28.57 % closed
# counter= 2320 : at t = 0.64 hours, pore is 28.69 % closed
# counter= 2330 : at t = 0.65 hours, pore is 28.81 % closed
# counter= 2340 : at t = 0.65 hours, pore is 28.92 % closed
# counter= 2350 : at t = 0.65 hours, pore is 29.04 % closed
# counter= 2360 : at t = 0.66 hours, pore is 29.16 % closed
# counter= 2370 : at t = 0.66 hours, pore is 29.28 % closed
# counter= 2380 : at t = 0.66 hours, pore is 29.4 % closed
# counter= 2390 : at t = 0.66 hours, pore is 29.52 % closed
# counter= 2400 : at t = 0.67 hours, pore is 29.64 % closed
# counter= 2410 : at t = 0.67 hours, pore is 29.76 % closed
# counter= 2420 : at t = 0.67 hours, pore is 29.88 % closed
# counter= 2430 : at t = 0.68 hours, pore is 30.0 % closed
# counter= 2440 : at t = 0.68 hours, pore is 30.12 % closed
# counter= 2450 : at t = 0.68 hours, pore is 30.24 % closed
# counter= 2460 : at t = 0.68 hours, pore is 30.36 % closed
# counter= 2470 : at t = 0.69 hours, pore is 30.48 % closed
# counter= 2480 : at t = 0.69 hours, pore is 30.6 % closed
# counter= 2490 : at t = 0.69 hours, pore is 30.71 % closed
# counter= 2500 : at t = 0.69 hours, pore is 30.83 % closed
# counter= 2510 : at t = 0.7 hours, pore is 30.95 % closed
# counter= 2520 : at t = 0.7 hours, pore is 31.07 % closed
# counter= 2530 : at t = 0.7 hours, pore is 31.19 % closed
# counter= 2540 : at t = 0.71 hours, pore is 31.31 % closed
# counter= 2550 : at t = 0.71 hours, pore is 31.43 % closed
# counter= 2560 : at t = 0.71 hours, pore is 31.55 % closed
# counter= 2570 : at t = 0.71 hours, pore is 31.67 % closed
# counter= 2580 : at t = 0.72 hours, pore is 31.79 % closed
# counter= 2590 : at t = 0.72 hours, pore is 31.91 % closed
# counter= 2600 : at t = 0.72 hours, pore is 32.03 % closed
# counter= 2610 : at t = 0.73 hours, pore is 32.15 % closed
# counter= 2620 : at t = 0.73 hours, pore is 32.27 % closed
# counter= 2630 : at t = 0.73 hours, pore is 32.39 % closed
# counter= 2640 : at t = 0.73 hours, pore is 32.5 % closed
# counter= 2650 : at t = 0.74 hours, pore is 32.62 % closed
# counter= 2660 : at t = 0.74 hours, pore is 32.74 % closed
# counter= 2670 : at t = 0.74 hours, pore is 32.86 % closed
# counter= 2680 : at t = 0.74 hours, pore is 32.98 % closed
# counter= 2690 : at t = 0.75 hours, pore is 33.1 % closed
# counter= 2700 : at t = 0.75 hours, pore is 33.22 % closed
# counter= 2710 : at t = 0.75 hours, pore is 33.34 % closed
# counter= 2720 : at t = 0.76 hours, pore is 33.46 % closed
# counter= 2730 : at t = 0.76 hours, pore is 33.58 % closed
# counter= 2740 : at t = 0.76 hours, pore is 33.7 % closed
# counter= 2750 : at t = 0.76 hours, pore is 33.82 % closed
# counter= 2760 : at t = 0.77 hours, pore is 33.94 % closed
# counter= 2770 : at t = 0.77 hours, pore is 34.06 % closed
# counter= 2780 : at t = 0.77 hours, pore is 34.18 % closed
# counter= 2790 : at t = 0.78 hours, pore is 34.29 % closed
# counter= 2800 : at t = 0.78 hours, pore is 34.41 % closed
# counter= 2810 : at t = 0.78 hours, pore is 34.53 % closed
# counter= 2820 : at t = 0.78 hours, pore is 34.65 % closed
# counter= 2830 : at t = 0.79 hours, pore is 34.77 % closed
# counter= 2840 : at t = 0.79 hours, pore is 34.89 % closed
# counter= 2850 : at t = 0.79 hours, pore is 35.01 % closed
# counter= 2860 : at t = 0.79 hours, pore is 35.13 % closed
# counter= 2870 : at t = 0.8 hours, pore is 35.25 % closed
# counter= 2880 : at t = 0.8 hours, pore is 35.37 % closed
# counter= 2890 : at t = 0.8 hours, pore is 35.49 % closed
# counter= 2900 : at t = 0.81 hours, pore is 35.61 % closed
# counter= 2910 : at t = 0.81 hours, pore is 35.73 % closed
# counter= 2920 : at t = 0.81 hours, pore is 35.85 % closed
# counter= 2930 : at t = 0.81 hours, pore is 35.97 % closed
# counter= 2940 : at t = 0.82 hours, pore is 36.08 % closed
# counter= 2950 : at t = 0.82 hours, pore is 36.2 % closed
# counter= 2960 : at t = 0.82 hours, pore is 36.32 % closed
# counter= 2970 : at t = 0.83 hours, pore is 36.44 % closed
# counter= 2980 : at t = 0.83 hours, pore is 36.56 % closed
# counter= 2990 : at t = 0.83 hours, pore is 36.68 % closed
# counter= 3000 : at t = 0.83 hours, pore is 36.8 % closed
# counter= 3010 : at t = 0.84 hours, pore is 36.92 % closed
# counter= 3020 : at t = 0.84 hours, pore is 37.04 % closed
# counter= 3030 : at t = 0.84 hours, pore is 37.16 % closed
# counter= 3040 : at t = 0.84 hours, pore is 37.28 % closed
# counter= 3050 : at t = 0.85 hours, pore is 37.4 % closed
# counter= 3060 : at t = 0.85 hours, pore is 37.52 % closed
# counter= 3070 : at t = 0.85 hours, pore is 37.64 % closed
# counter= 3080 : at t = 0.86 hours, pore is 37.76 % closed
# counter= 3090 : at t = 0.86 hours, pore is 37.87 % closed
# counter= 3100 : at t = 0.86 hours, pore is 37.99 % closed
# counter= 3110 : at t = 0.86 hours, pore is 38.11 % closed
# counter= 3120 : at t = 0.87 hours, pore is 38.23 % closed
# counter= 3130 : at t = 0.87 hours, pore is 38.35 % closed
# counter= 3140 : at t = 0.87 hours, pore is 38.47 % closed
# counter= 3150 : at t = 0.88 hours, pore is 38.59 % closed
# counter= 3160 : at t = 0.88 hours, pore is 38.71 % closed
# counter= 3170 : at t = 0.88 hours, pore is 38.83 % closed
# counter= 3180 : at t = 0.88 hours, pore is 38.95 % closed
# counter= 3190 : at t = 0.89 hours, pore is 39.07 % closed
# counter= 3200 : at t = 0.89 hours, pore is 39.19 % closed
# counter= 3210 : at t = 0.89 hours, pore is 39.31 % closed
# counter= 3220 : at t = 0.89 hours, pore is 39.43 % closed
# counter= 3230 : at t = 0.9 hours, pore is 39.55 % closed
# counter= 3240 : at t = 0.9 hours, pore is 39.66 % closed
# counter= 3250 : at t = 0.9 hours, pore is 39.78 % closed
# counter= 3260 : at t = 0.91 hours, pore is 39.9 % closed
# counter= 3270 : at t = 0.91 hours, pore is 40.02 % closed
# counter= 3280 : at t = 0.91 hours, pore is 40.14 % closed
# counter= 3290 : at t = 0.91 hours, pore is 40.26 % closed
# counter= 3300 : at t = 0.92 hours, pore is 40.38 % closed
# counter= 3310 : at t = 0.92 hours, pore is 40.5 % closed
# counter= 3320 : at t = 0.92 hours, pore is 40.62 % closed
# counter= 3330 : at t = 0.93 hours, pore is 40.74 % closed
# counter= 3340 : at t = 0.93 hours, pore is 40.86 % closed
# counter= 3350 : at t = 0.93 hours, pore is 40.98 % closed
# counter= 3360 : at t = 0.93 hours, pore is 41.1 % closed
# counter= 3370 : at t = 0.94 hours, pore is 41.22 % closed
# counter= 3380 : at t = 0.94 hours, pore is 41.34 % closed
# counter= 3390 : at t = 0.94 hours, pore is 41.45 % closed
# counter= 3400 : at t = 0.94 hours, pore is 41.57 % closed
# counter= 3410 : at t = 0.95 hours, pore is 41.69 % closed
# counter= 3420 : at t = 0.95 hours, pore is 41.81 % closed
# counter= 3430 : at t = 0.95 hours, pore is 41.93 % closed
# counter= 3440 : at t = 0.96 hours, pore is 42.05 % closed
# counter= 3450 : at t = 0.96 hours, pore is 42.17 % closed
# counter= 3460 : at t = 0.96 hours, pore is 42.29 % closed
# counter= 3470 : at t = 0.96 hours, pore is 42.41 % closed
# counter= 3480 : at t = 0.97 hours, pore is 42.53 % closed
# counter= 3490 : at t = 0.97 hours, pore is 42.65 % closed
# counter= 3500 : at t = 0.97 hours, pore is 42.77 % closed
# counter= 3510 : at t = 0.98 hours, pore is 42.89 % closed
# counter= 3520 : at t = 0.98 hours, pore is 43.01 % closed
# counter= 3530 : at t = 0.98 hours, pore is 43.13 % closed
# counter= 3540 : at t = 0.98 hours, pore is 43.24 % closed
# counter= 3550 : at t = 0.99 hours, pore is 43.36 % closed
# counter= 3560 : at t = 0.99 hours, pore is 43.48 % closed
# counter= 3570 : at t = 0.99 hours, pore is 43.6 % closed
# counter= 3580 : at t = 0.99 hours, pore is 43.72 % closed
# counter= 3590 : at t = 1.0 hours, pore is 43.84 % closed
# counter= 3600 : at t = 1.0 hours, pore is 43.96 % closed
# counter= 3610 : at t = 1.0 hours, pore is 44.08 % closed
# counter= 3620 : at t = 1.01 hours, pore is 44.2 % closed
# counter= 3630 : at t = 1.01 hours, pore is 44.32 % closed
# counter= 3640 : at t = 1.01 hours, pore is 44.44 % closed
# counter= 3650 : at t = 1.01 hours, pore is 44.56 % closed
# counter= 3660 : at t = 1.02 hours, pore is 44.68 % closed
# counter= 3670 : at t = 1.02 hours, pore is 44.8 % closed
# counter= 3680 : at t = 1.02 hours, pore is 44.92 % closed
# counter= 3690 : at t = 1.03 hours, pore is 45.03 % closed
# counter= 3700 : at t = 1.03 hours, pore is 45.15 % closed
# counter= 3710 : at t = 1.03 hours, pore is 45.27 % closed
# counter= 3720 : at t = 1.03 hours, pore is 45.39 % closed
# counter= 3730 : at t = 1.04 hours, pore is 45.51 % closed
# counter= 3740 : at t = 1.04 hours, pore is 45.63 % closed
# counter= 3750 : at t = 1.04 hours, pore is 45.75 % closed
# counter= 3760 : at t = 1.04 hours, pore is 45.87 % closed
# counter= 3770 : at t = 1.05 hours, pore is 45.99 % closed
# counter= 3780 : at t = 1.05 hours, pore is 46.11 % closed
# counter= 3790 : at t = 1.05 hours, pore is 46.23 % closed
# counter= 3800 : at t = 1.06 hours, pore is 46.35 % closed
# counter= 3810 : at t = 1.06 hours, pore is 46.47 % closed
# counter= 3820 : at t = 1.06 hours, pore is 46.59 % closed
# counter= 3830 : at t = 1.06 hours, pore is 46.71 % closed
# counter= 3840 : at t = 1.07 hours, pore is 46.82 % closed
# counter= 3850 : at t = 1.07 hours, pore is 46.94 % closed
# counter= 3860 : at t = 1.07 hours, pore is 47.06 % closed
# counter= 3870 : at t = 1.08 hours, pore is 47.18 % closed
# counter= 3880 : at t = 1.08 hours, pore is 47.3 % closed
# counter= 3890 : at t = 1.08 hours, pore is 47.42 % closed
# counter= 3900 : at t = 1.08 hours, pore is 47.54 % closed
# counter= 3910 : at t = 1.09 hours, pore is 47.66 % closed
# counter= 3920 : at t = 1.09 hours, pore is 47.78 % closed
# counter= 3930 : at t = 1.09 hours, pore is 47.9 % closed
# counter= 3940 : at t = 1.09 hours, pore is 48.02 % closed
# counter= 3950 : at t = 1.1 hours, pore is 48.14 % closed
# counter= 3960 : at t = 1.1 hours, pore is 48.26 % closed
# counter= 3970 : at t = 1.1 hours, pore is 48.38 % closed
# counter= 3980 : at t = 1.11 hours, pore is 48.5 % closed
# counter= 3990 : at t = 1.11 hours, pore is 48.61 % closed
# counter= 4000 : at t = 1.11 hours, pore is 48.73 % closed
# counter= 4010 : at t = 1.11 hours, pore is 48.85 % closed
# counter= 4020 : at t = 1.12 hours, pore is 48.97 % closed
# counter= 4030 : at t = 1.12 hours, pore is 49.09 % closed
# counter= 4040 : at t = 1.12 hours, pore is 49.21 % closed
# counter= 4050 : at t = 1.13 hours, pore is 49.33 % closed
# counter= 4060 : at t = 1.13 hours, pore is 49.45 % closed
# counter= 4070 : at t = 1.13 hours, pore is 49.57 % closed
# counter= 4080 : at t = 1.13 hours, pore is 49.69 % closed
# counter= 4090 : at t = 1.14 hours, pore is 49.81 % closed
# counter= 4100 : at t = 1.14 hours, pore is 49.93 % closed
# counter= 4110 : at t = 1.14 hours, pore is 50.05 % closed
# counter= 4120 : at t = 1.14 hours, pore is 50.17 % closed
# counter= 4130 : at t = 1.15 hours, pore is 50.29 % closed
# counter= 4140 : at t = 1.15 hours, pore is 50.4 % closed
# counter= 4150 : at t = 1.15 hours, pore is 50.52 % closed
# counter= 4160 : at t = 1.16 hours, pore is 50.64 % closed
# counter= 4170 : at t = 1.16 hours, pore is 50.76 % closed
# counter= 4180 : at t = 1.16 hours, pore is 50.88 % closed
# counter= 4190 : at t = 1.16 hours, pore is 51.0 % closed
# counter= 4200 : at t = 1.17 hours, pore is 51.12 % closed
# counter= 4210 : at t = 1.17 hours, pore is 51.24 % closed
# counter= 4220 : at t = 1.17 hours, pore is 51.36 % closed
# counter= 4230 : at t = 1.18 hours, pore is 51.48 % closed
# counter= 4240 : at t = 1.18 hours, pore is 51.6 % closed
# counter= 4250 : at t = 1.18 hours, pore is 51.72 % closed
# counter= 4260 : at t = 1.18 hours, pore is 51.84 % closed
# counter= 4270 : at t = 1.19 hours, pore is 51.96 % closed
# counter= 4280 : at t = 1.19 hours, pore is 52.08 % closed
# counter= 4290 : at t = 1.19 hours, pore is 52.19 % closed
# counter= 4300 : at t = 1.19 hours, pore is 52.31 % closed
# counter= 4310 : at t = 1.2 hours, pore is 52.43 % closed
# counter= 4320 : at t = 1.2 hours, pore is 52.55 % closed
# counter= 4330 : at t = 1.2 hours, pore is 52.67 % closed
# counter= 4340 : at t = 1.21 hours, pore is 52.79 % closed
# counter= 4350 : at t = 1.21 hours, pore is 52.91 % closed
# counter= 4360 : at t = 1.21 hours, pore is 53.03 % closed
# counter= 4370 : at t = 1.21 hours, pore is 53.15 % closed
# counter= 4380 : at t = 1.22 hours, pore is 53.27 % closed
# counter= 4390 : at t = 1.22 hours, pore is 53.39 % closed
# counter= 4400 : at t = 1.22 hours, pore is 53.51 % closed
# counter= 4410 : at t = 1.23 hours, pore is 53.63 % closed
# counter= 4420 : at t = 1.23 hours, pore is 53.75 % closed
# counter= 4430 : at t = 1.23 hours, pore is 53.87 % closed
# counter= 4440 : at t = 1.23 hours, pore is 53.98 % closed
# counter= 4450 : at t = 1.24 hours, pore is 54.1 % closed
# counter= 4460 : at t = 1.24 hours, pore is 54.22 % closed
# counter= 4470 : at t = 1.24 hours, pore is 54.34 % closed
# counter= 4480 : at t = 1.24 hours, pore is 54.46 % closed
# counter= 4490 : at t = 1.25 hours, pore is 54.58 % closed
# counter= 4500 : at t = 1.25 hours, pore is 54.7 % closed
# counter= 4510 : at t = 1.25 hours, pore is 54.82 % closed
# counter= 4520 : at t = 1.26 hours, pore is 54.94 % closed
# counter= 4530 : at t = 1.26 hours, pore is 55.06 % closed
# counter= 4540 : at t = 1.26 hours, pore is 55.18 % closed
# counter= 4550 : at t = 1.26 hours, pore is 55.3 % closed
# counter= 4560 : at t = 1.27 hours, pore is 55.42 % closed
# counter= 4570 : at t = 1.27 hours, pore is 55.54 % closed
# counter= 4580 : at t = 1.27 hours, pore is 55.66 % closed
# counter= 4590 : at t = 1.28 hours, pore is 55.77 % closed
# counter= 4600 : at t = 1.28 hours, pore is 55.89 % closed
# counter= 4610 : at t = 1.28 hours, pore is 56.01 % closed
# counter= 4620 : at t = 1.28 hours, pore is 56.13 % closed
# counter= 4630 : at t = 1.29 hours, pore is 56.25 % closed
# counter= 4640 : at t = 1.29 hours, pore is 56.37 % closed
# counter= 4650 : at t = 1.29 hours, pore is 56.49 % closed
# counter= 4660 : at t = 1.29 hours, pore is 56.61 % closed
# counter= 4670 : at t = 1.3 hours, pore is 56.73 % closed
# counter= 4680 : at t = 1.3 hours, pore is 56.85 % closed
# counter= 4690 : at t = 1.3 hours, pore is 56.97 % closed
# counter= 4700 : at t = 1.31 hours, pore is 57.09 % closed
# counter= 4710 : at t = 1.31 hours, pore is 57.21 % closed
# counter= 4720 : at t = 1.31 hours, pore is 57.33 % closed
# counter= 4730 : at t = 1.31 hours, pore is 57.45 % closed
# counter= 4740 : at t = 1.32 hours, pore is 57.56 % closed
# counter= 4750 : at t = 1.32 hours, pore is 57.68 % closed
# counter= 4760 : at t = 1.32 hours, pore is 57.8 % closed
# counter= 4770 : at t = 1.33 hours, pore is 57.92 % closed
# counter= 4780 : at t = 1.33 hours, pore is 58.04 % closed
# counter= 4790 : at t = 1.33 hours, pore is 58.16 % closed
# counter= 4800 : at t = 1.33 hours, pore is 58.28 % closed
# counter= 4810 : at t = 1.34 hours, pore is 58.4 % closed
# counter= 4820 : at t = 1.34 hours, pore is 58.52 % closed
# counter= 4830 : at t = 1.34 hours, pore is 58.64 % closed
# counter= 4840 : at t = 1.34 hours, pore is 58.76 % closed
# counter= 4850 : at t = 1.35 hours, pore is 58.88 % closed
# counter= 4860 : at t = 1.35 hours, pore is 59.0 % closed
# counter= 4870 : at t = 1.35 hours, pore is 59.12 % closed
# counter= 4880 : at t = 1.36 hours, pore is 59.24 % closed
# counter= 4890 : at t = 1.36 hours, pore is 59.35 % closed
# counter= 4900 : at t = 1.36 hours, pore is 59.47 % closed
# counter= 4910 : at t = 1.36 hours, pore is 59.59 % closed
# counter= 4920 : at t = 1.37 hours, pore is 59.71 % closed
# counter= 4930 : at t = 1.37 hours, pore is 59.83 % closed
# counter= 4940 : at t = 1.37 hours, pore is 59.95 % closed
# counter= 4950 : at t = 1.38 hours, pore is 60.07 % closed
# counter= 4960 : at t = 1.38 hours, pore is 60.19 % closed
# counter= 4970 : at t = 1.38 hours, pore is 60.31 % closed
# counter= 4980 : at t = 1.38 hours, pore is 60.43 % closed
# counter= 4990 : at t = 1.39 hours, pore is 60.55 % closed
# counter= 5000 : at t = 1.39 hours, pore is 60.67 % closed
# counter= 5010 : at t = 1.39 hours, pore is 60.79 % closed
# counter= 5020 : at t = 1.39 hours, pore is 60.91 % closed
# counter= 5030 : at t = 1.4 hours, pore is 61.03 % closed
# counter= 5040 : at t = 1.4 hours, pore is 61.14 % closed
# counter= 5050 : at t = 1.4 hours, pore is 61.26 % closed
# counter= 5060 : at t = 1.41 hours, pore is 61.38 % closed
# counter= 5070 : at t = 1.41 hours, pore is 61.5 % closed
# counter= 5080 : at t = 1.41 hours, pore is 61.62 % closed
# counter= 5090 : at t = 1.41 hours, pore is 61.74 % closed
# counter= 5100 : at t = 1.42 hours, pore is 61.86 % closed
# counter= 5110 : at t = 1.42 hours, pore is 61.98 % closed
# counter= 5120 : at t = 1.42 hours, pore is 62.1 % closed
# counter= 5130 : at t = 1.43 hours, pore is 62.22 % closed
# counter= 5140 : at t = 1.43 hours, pore is 62.34 % closed
# counter= 5150 : at t = 1.43 hours, pore is 62.46 % closed
# counter= 5160 : at t = 1.43 hours, pore is 62.58 % closed
# counter= 5170 : at t = 1.44 hours, pore is 62.7 % closed
# counter= 5180 : at t = 1.44 hours, pore is 62.82 % closed
# counter= 5190 : at t = 1.44 hours, pore is 62.93 % closed
# counter= 5200 : at t = 1.44 hours, pore is 63.05 % closed
# counter= 5210 : at t = 1.45 hours, pore is 63.17 % closed
# counter= 5220 : at t = 1.45 hours, pore is 63.29 % closed
# counter= 5230 : at t = 1.45 hours, pore is 63.41 % closed
# counter= 5240 : at t = 1.46 hours, pore is 63.53 % closed
# counter= 5250 : at t = 1.46 hours, pore is 63.65 % closed
# counter= 5260 : at t = 1.46 hours, pore is 63.77 % closed
# counter= 5270 : at t = 1.46 hours, pore is 63.89 % closed
# counter= 5280 : at t = 1.47 hours, pore is 64.01 % closed
# counter= 5290 : at t = 1.47 hours, pore is 64.13 % closed
# counter= 5300 : at t = 1.47 hours, pore is 64.25 % closed
# counter= 5310 : at t = 1.48 hours, pore is 64.37 % closed
# counter= 5320 : at t = 1.48 hours, pore is 64.49 % closed
# counter= 5330 : at t = 1.48 hours, pore is 64.61 % closed
# counter= 5340 : at t = 1.48 hours, pore is 64.72 % closed
# counter= 5350 : at t = 1.49 hours, pore is 64.84 % closed
# counter= 5360 : at t = 1.49 hours, pore is 64.96 % closed
# counter= 5370 : at t = 1.49 hours, pore is 65.08 % closed
# counter= 5380 : at t = 1.49 hours, pore is 65.2 % closed
# counter= 5390 : at t = 1.5 hours, pore is 65.32 % closed
# counter= 5400 : at t = 1.5 hours, pore is 65.44 % closed
# counter= 5410 : at t = 1.5 hours, pore is 65.56 % closed
# counter= 5420 : at t = 1.51 hours, pore is 65.68 % closed
# counter= 5430 : at t = 1.51 hours, pore is 65.8 % closed
# counter= 5440 : at t = 1.51 hours, pore is 65.92 % closed
# counter= 5450 : at t = 1.51 hours, pore is 66.04 % closed
# counter= 5460 : at t = 1.52 hours, pore is 66.16 % closed
# counter= 5470 : at t = 1.52 hours, pore is 66.28 % closed
# counter= 5480 : at t = 1.52 hours, pore is 66.4 % closed
# counter= 5490 : at t = 1.53 hours, pore is 66.51 % closed
# counter= 5500 : at t = 1.53 hours, pore is 66.63 % closed
# counter= 5510 : at t = 1.53 hours, pore is 66.75 % closed
# counter= 5520 : at t = 1.53 hours, pore is 66.87 % closed
# counter= 5530 : at t = 1.54 hours, pore is 66.99 % closed
# counter= 5540 : at t = 1.54 hours, pore is 67.11 % closed
# counter= 5550 : at t = 1.54 hours, pore is 67.23 % closed
# counter= 5560 : at t = 1.54 hours, pore is 67.35 % closed
# counter= 5570 : at t = 1.55 hours, pore is 67.47 % closed
# counter= 5580 : at t = 1.55 hours, pore is 67.59 % closed
# counter= 5590 : at t = 1.55 hours, pore is 67.71 % closed
# counter= 5600 : at t = 1.56 hours, pore is 67.83 % closed
# counter= 5610 : at t = 1.56 hours, pore is 67.95 % closed
# counter= 5620 : at t = 1.56 hours, pore is 68.07 % closed
# counter= 5630 : at t = 1.56 hours, pore is 68.19 % closed
# counter= 5640 : at t = 1.57 hours, pore is 68.3 % closed
# counter= 5650 : at t = 1.57 hours, pore is 68.42 % closed
# counter= 5660 : at t = 1.57 hours, pore is 68.54 % closed
# counter= 5670 : at t = 1.58 hours, pore is 68.66 % closed
# counter= 5680 : at t = 1.58 hours, pore is 68.78 % closed
# counter= 5690 : at t = 1.58 hours, pore is 68.9 % closed
# counter= 5700 : at t = 1.58 hours, pore is 69.02 % closed
# counter= 5710 : at t = 1.59 hours, pore is 69.14 % closed
# counter= 5720 : at t = 1.59 hours, pore is 69.26 % closed
# counter= 5730 : at t = 1.59 hours, pore is 69.38 % closed
# counter= 5740 : at t = 1.59 hours, pore is 69.5 % closed
# counter= 5750 : at t = 1.6 hours, pore is 69.62 % closed
# counter= 5760 : at t = 1.6 hours, pore is 69.74 % closed
# counter= 5770 : at t = 1.6 hours, pore is 69.86 % closed
# counter= 5780 : at t = 1.61 hours, pore is 69.98 % closed
# counter= 5790 : at t = 1.61 hours, pore is 70.09 % closed
# counter= 5800 : at t = 1.61 hours, pore is 70.21 % closed
# counter= 5810 : at t = 1.61 hours, pore is 70.33 % closed
# counter= 5820 : at t = 1.62 hours, pore is 70.45 % closed
# counter= 5830 : at t = 1.62 hours, pore is 70.57 % closed
# counter= 5840 : at t = 1.62 hours, pore is 70.69 % closed
# counter= 5850 : at t = 1.63 hours, pore is 70.81 % closed
# counter= 5860 : at t = 1.63 hours, pore is 70.93 % closed
# counter= 5870 : at t = 1.63 hours, pore is 71.05 % closed
# counter= 5880 : at t = 1.63 hours, pore is 71.17 % closed
# counter= 5890 : at t = 1.64 hours, pore is 71.29 % closed
# counter= 5900 : at t = 1.64 hours, pore is 71.41 % closed
# counter= 5910 : at t = 1.64 hours, pore is 71.53 % closed
# counter= 5920 : at t = 1.64 hours, pore is 71.65 % closed
# counter= 5930 : at t = 1.65 hours, pore is 71.77 % closed
# counter= 5940 : at t = 1.65 hours, pore is 71.88 % closed
# counter= 5950 : at t = 1.65 hours, pore is 72.0 % closed
# counter= 5960 : at t = 1.66 hours, pore is 72.12 % closed
# counter= 5970 : at t = 1.66 hours, pore is 72.24 % closed
# counter= 5980 : at t = 1.66 hours, pore is 72.36 % closed
# counter= 5990 : at t = 1.66 hours, pore is 72.48 % closed
# counter= 6000 : at t = 1.67 hours, pore is 72.6 % closed
# counter= 6010 : at t = 1.67 hours, pore is 72.72 % closed
# counter= 6020 : at t = 1.67 hours, pore is 72.84 % closed
# counter= 6030 : at t = 1.68 hours, pore is 72.96 % closed
# counter= 6040 : at t = 1.68 hours, pore is 73.08 % closed
# counter= 6050 : at t = 1.68 hours, pore is 73.2 % closed
# counter= 6060 : at t = 1.68 hours, pore is 73.32 % closed
# counter= 6070 : at t = 1.69 hours, pore is 73.44 % closed
# counter= 6080 : at t = 1.69 hours, pore is 73.56 % closed
# counter= 6090 : at t = 1.69 hours, pore is 73.67 % closed
# counter= 6100 : at t = 1.69 hours, pore is 73.79 % closed
# counter= 6110 : at t = 1.7 hours, pore is 73.91 % closed
# counter= 6120 : at t = 1.7 hours, pore is 74.03 % closed
# counter= 6130 : at t = 1.7 hours, pore is 74.15 % closed
# counter= 6140 : at t = 1.71 hours, pore is 74.27 % closed
# counter= 6150 : at t = 1.71 hours, pore is 74.39 % closed
# counter= 6160 : at t = 1.71 hours, pore is 74.51 % closed
# counter= 6170 : at t = 1.71 hours, pore is 74.63 % closed
# counter= 6180 : at t = 1.72 hours, pore is 74.75 % closed
# counter= 6190 : at t = 1.72 hours, pore is 74.87 % closed
# counter= 6200 : at t = 1.72 hours, pore is 74.99 % closed
# counter= 6210 : at t = 1.73 hours, pore is 75.11 % closed
# counter= 6220 : at t = 1.73 hours, pore is 75.23 % closed
# counter= 6230 : at t = 1.73 hours, pore is 75.35 % closed
# counter= 6240 : at t = 1.73 hours, pore is 75.47 % closed
# counter= 6250 : at t = 1.74 hours, pore is 75.58 % closed
# counter= 6260 : at t = 1.74 hours, pore is 75.7 % closed
# counter= 6270 : at t = 1.74 hours, pore is 75.82 % closed
# counter= 6280 : at t = 1.74 hours, pore is 75.94 % closed
# counter= 6290 : at t = 1.75 hours, pore is 76.06 % closed
# counter= 6300 : at t = 1.75 hours, pore is 76.18 % closed
# counter= 6310 : at t = 1.75 hours, pore is 76.3 % closed
# counter= 6320 : at t = 1.76 hours, pore is 76.42 % closed
# counter= 6330 : at t = 1.76 hours, pore is 76.54 % closed
# counter= 6340 : at t = 1.76 hours, pore is 76.66 % closed
# counter= 6350 : at t = 1.76 hours, pore is 76.78 % closed
# counter= 6360 : at t = 1.77 hours, pore is 76.9 % closed
# counter= 6370 : at t = 1.77 hours, pore is 77.02 % closed
# counter= 6380 : at t = 1.77 hours, pore is 77.14 % closed
# counter= 6390 : at t = 1.78 hours, pore is 77.26 % closed
# counter= 6400 : at t = 1.78 hours, pore is 77.37 % closed
# counter= 6410 : at t = 1.78 hours, pore is 77.49 % closed
# counter= 6420 : at t = 1.78 hours, pore is 77.61 % closed
# counter= 6430 : at t = 1.79 hours, pore is 77.73 % closed
# counter= 6440 : at t = 1.79 hours, pore is 77.85 % closed
# counter= 6450 : at t = 1.79 hours, pore is 77.97 % closed
# counter= 6460 : at t = 1.79 hours, pore is 78.09 % closed
# counter= 6470 : at t = 1.8 hours, pore is 78.21 % closed
# counter= 6480 : at t = 1.8 hours, pore is 78.33 % closed
# counter= 6490 : at t = 1.8 hours, pore is 78.45 % closed
# counter= 6500 : at t = 1.81 hours, pore is 78.57 % closed
# counter= 6510 : at t = 1.81 hours, pore is 78.69 % closed
# counter= 6520 : at t = 1.81 hours, pore is 78.81 % closed
# counter= 6530 : at t = 1.81 hours, pore is 78.93 % closed
# counter= 6540 : at t = 1.82 hours, pore is 79.05 % closed
# counter= 6550 : at t = 1.82 hours, pore is 79.16 % closed
# counter= 6560 : at t = 1.82 hours, pore is 79.28 % closed
# counter= 6570 : at t = 1.83 hours, pore is 79.4 % closed
# counter= 6580 : at t = 1.83 hours, pore is 79.52 % closed
# counter= 6590 : at t = 1.83 hours, pore is 79.64 % closed
# counter= 6600 : at t = 1.83 hours, pore is 79.76 % closed
# counter= 6610 : at t = 1.84 hours, pore is 79.88 % closed
# counter= 6620 : at t = 1.84 hours, pore is 80.0 % closed
# counter= 6630 : at t = 1.84 hours, pore is 80.12 % closed
# counter= 6640 : at t = 1.84 hours, pore is 80.24 % closed
# counter= 6650 : at t = 1.85 hours, pore is 80.36 % closed
# counter= 6660 : at t = 1.85 hours, pore is 80.48 % closed
# counter= 6670 : at t = 1.85 hours, pore is 80.6 % closed
# counter= 6680 : at t = 1.86 hours, pore is 80.72 % closed
# counter= 6690 : at t = 1.86 hours, pore is 80.84 % closed
# counter= 6700 : at t = 1.86 hours, pore is 80.95 % closed
# counter= 6710 : at t = 1.86 hours, pore is 81.07 % closed
# counter= 6720 : at t = 1.87 hours, pore is 81.19 % closed
# counter= 6730 : at t = 1.87 hours, pore is 81.31 % closed
# counter= 6740 : at t = 1.87 hours, pore is 81.43 % closed
# counter= 6750 : at t = 1.88 hours, pore is 81.55 % closed
# counter= 6760 : at t = 1.88 hours, pore is 81.67 % closed
# counter= 6770 : at t = 1.88 hours, pore is 81.79 % closed
# counter= 6780 : at t = 1.88 hours, pore is 81.91 % closed
# counter= 6790 : at t = 1.89 hours, pore is 82.03 % closed
# counter= 6800 : at t = 1.89 hours, pore is 82.15 % closed
# counter= 6810 : at t = 1.89 hours, pore is 82.27 % closed
# counter= 6820 : at t = 1.89 hours, pore is 82.39 % closed
# counter= 6830 : at t = 1.9 hours, pore is 82.51 % closed
# counter= 6840 : at t = 1.9 hours, pore is 82.63 % closed
# counter= 6850 : at t = 1.9 hours, pore is 82.74 % closed
# counter= 6860 : at t = 1.91 hours, pore is 82.86 % closed
# counter= 6870 : at t = 1.91 hours, pore is 82.98 % closed
# counter= 6880 : at t = 1.91 hours, pore is 83.1 % closed
# counter= 6890 : at t = 1.91 hours, pore is 83.22 % closed
# counter= 6900 : at t = 1.92 hours, pore is 83.34 % closed
# counter= 6910 : at t = 1.92 hours, pore is 83.46 % closed
# counter= 6920 : at t = 1.92 hours, pore is 83.58 % closed
# counter= 6930 : at t = 1.93 hours, pore is 83.7 % closed
# counter= 6940 : at t = 1.93 hours, pore is 83.82 % closed
# counter= 6950 : at t = 1.93 hours, pore is 83.94 % closed
# counter= 6960 : at t = 1.93 hours, pore is 84.06 % closed
# counter= 6970 : at t = 1.94 hours, pore is 84.18 % closed
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# counter= 6980 : at t = 1.94 hours, pore is 84.3 % closed
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# counter= 6990 : at t = 1.94 hours, pore is 84.42 % closed
# counter= 7000 : at t = 1.94 hours, pore is 84.53 % closed
# counter= 7010 : at t = 1.95 hours, pore is 84.65 % closed
# counter= 7020 : at t = 1.95 hours, pore is 84.77 % closed
# counter= 7030 : at t = 1.95 hours, pore is 84.89 % closed
# counter= 7040 : at t = 1.96 hours, pore is 85.01 % closed
# counter= 7050 : at t = 1.96 hours, pore is 85.13 % closed
# counter= 7060 : at t = 1.96 hours, pore is 85.25 % closed
# counter= 7070 : at t = 1.96 hours, pore is 85.37 % closed
# counter= 7080 : at t = 1.97 hours, pore is 85.49 % closed
# counter= 7090 : at t = 1.97 hours, pore is 85.61 % closed
# counter= 7100 : at t = 1.97 hours, pore is 85.73 % closed
# counter= 7110 : at t = 1.98 hours, pore is 85.85 % closed
# counter= 7120 : at t = 1.98 hours, pore is 85.97 % closed
# counter= 7130 : at t = 1.98 hours, pore is 86.09 % closed
# counter= 7140 : at t = 1.98 hours, pore is 86.21 % closed
# counter= 7150 : at t = 1.99 hours, pore is 86.32 % closed
# counter= 7160 : at t = 1.99 hours, pore is 86.44 % closed
# counter= 7170 : at t = 1.99 hours, pore is 86.56 % closed
# counter= 7180 : at t = 1.99 hours, pore is 86.68 % closed
# counter= 7190 : at t = 2.0 hours, pore is 86.8 % closed
# counter= 7200 : at t = 2.0 hours, pore is 86.92 % closed
# counter= 7210 : at t = 2.0 hours, pore is 87.04 % closed
# counter= 7220 : at t = 2.01 hours, pore is 87.16 % closed
# counter= 7230 : at t = 2.01 hours, pore is 87.28 % closed
# counter= 7240 : at t = 2.01 hours, pore is 87.4 % closed
# counter= 7250 : at t = 2.01 hours, pore is 87.52 % closed
# counter= 7260 : at t = 2.02 hours, pore is 87.64 % closed
# counter= 7270 : at t = 2.02 hours, pore is 87.76 % closed
# counter= 7280 : at t = 2.02 hours, pore is 87.88 % closed
# counter= 7290 : at t = 2.03 hours, pore is 88.0 % closed
# counter= 7300 : at t = 2.03 hours, pore is 88.11 % closed
# counter= 7310 : at t = 2.03 hours, pore is 88.23 % closed
# counter= 7320 : at t = 2.03 hours, pore is 88.35 % closed
# counter= 7330 : at t = 2.04 hours, pore is 88.47 % closed
# counter= 7340 : at t = 2.04 hours, pore is 88.59 % closed
# counter= 7350 : at t = 2.04 hours, pore is 88.71 % closed
# counter= 7360 : at t = 2.04 hours, pore is 88.83 % closed
# counter= 7370 : at t = 2.05 hours, pore is 88.95 % closed
# counter= 7380 : at t = 2.05 hours, pore is 89.07 % closed
# counter= 7390 : at t = 2.05 hours, pore is 89.19 % closed
# counter= 7400 : at t = 2.06 hours, pore is 89.31 % closed
# counter= 7410 : at t = 2.06 hours, pore is 89.43 % closed
# counter= 7420 : at t = 2.06 hours, pore is 89.55 % closed
# counter= 7430 : at t = 2.06 hours, pore is 89.67 % closed
# counter= 7440 : at t = 2.07 hours, pore is 89.79 % closed
# counter= 7450 : at t = 2.07 hours, pore is 89.9 % closed
# counter= 7460 : at t = 2.07 hours, pore is 90.02 % closed
# counter= 7470 : at t = 2.08 hours, pore is 90.14 % closed
# counter= 7480 : at t = 2.08 hours, pore is 90.26 % closed
# counter= 7490 : at t = 2.08 hours, pore is 90.38 % closed
# counter= 7500 : at t = 2.08 hours, pore is 90.5 % closed
# counter= 7510 : at t = 2.09 hours, pore is 90.62 % closed
# counter= 7520 : at t = 2.09 hours, pore is 90.74 % closed
# counter= 7530 : at t = 2.09 hours, pore is 90.86 % closed
# counter= 7540 : at t = 2.09 hours, pore is 90.98 % closed
# counter= 7550 : at t = 2.1 hours, pore is 91.1 % closed
# counter= 7560 : at t = 2.1 hours, pore is 91.22 % closed
# counter= 7570 : at t = 2.1 hours, pore is 91.34 % closed
# counter= 7580 : at t = 2.11 hours, pore is 91.46 % closed
# counter= 7590 : at t = 2.11 hours, pore is 91.58 % closed
# counter= 7600 : at t = 2.11 hours, pore is 91.69 % closed
# counter= 7610 : at t = 2.11 hours, pore is 91.81 % closed
# counter= 7620 : at t = 2.12 hours, pore is 91.93 % closed
# counter= 7630 : at t = 2.12 hours, pore is 92.05 % closed
# counter= 7640 : at t = 2.12 hours, pore is 92.17 % closed
# counter= 7650 : at t = 2.13 hours, pore is 92.29 % closed
# counter= 7660 : at t = 2.13 hours, pore is 92.41 % closed
# counter= 7670 : at t = 2.13 hours, pore is 92.53 % closed
# counter= 7680 : at t = 2.13 hours, pore is 92.65 % closed
# counter= 7690 : at t = 2.14 hours, pore is 92.77 % closed
# counter= 7700 : at t = 2.14 hours, pore is 92.89 % closed
# counter= 7710 : at t = 2.14 hours, pore is 93.01 % closed
# counter= 7720 : at t = 2.14 hours, pore is 93.13 % closed
# counter= 7730 : at t = 2.15 hours, pore is 93.25 % closed
# counter= 7740 : at t = 2.15 hours, pore is 93.37 % closed
# counter= 7750 : at t = 2.15 hours, pore is 93.48 % closed
# counter= 7760 : at t = 2.16 hours, pore is 93.6 % closed
# counter= 7770 : at t = 2.16 hours, pore is 93.72 % closed
# counter= 7780 : at t = 2.16 hours, pore is 93.84 % closed
# counter= 7790 : at t = 2.16 hours, pore is 93.96 % closed
# counter= 7800 : at t = 2.17 hours, pore is 94.08 % closed
# counter= 7810 : at t = 2.17 hours, pore is 94.2 % closed
# counter= 7820 : at t = 2.17 hours, pore is 94.32 % closed
# counter= 7830 : at t = 2.18 hours, pore is 94.44 % closed
# counter= 7840 : at t = 2.18 hours, pore is 94.56 % closed
# counter= 7850 : at t = 2.18 hours, pore is 94.68 % closed
# counter= 7860 : at t = 2.18 hours, pore is 94.8 % closed
# counter= 7870 : at t = 2.19 hours, pore is 94.92 % closed
# counter= 7880 : at t = 2.19 hours, pore is 95.04 % closed
# counter= 7890 : at t = 2.19 hours, pore is 95.16 % closed
# counter= 7900 : at t = 2.19 hours, pore is 95.27 % closed
# counter= 7910 : at t = 2.2 hours, pore is 95.39 % closed
# counter= 7920 : at t = 2.2 hours, pore is 95.51 % closed
# counter= 7930 : at t = 2.2 hours, pore is 95.63 % closed
# counter= 7940 : at t = 2.21 hours, pore is 95.75 % closed
# counter= 7950 : at t = 2.21 hours, pore is 95.87 % closed
# counter= 7960 : at t = 2.21 hours, pore is 95.99 % closed
# counter= 7970 : at t = 2.21 hours, pore is 96.11 % closed
# counter= 7980 : at t = 2.22 hours, pore is 96.23 % closed
# counter= 7990 : at t = 2.22 hours, pore is 96.35 % closed
# counter= 8000 : at t = 2.22 hours, pore is 96.47 % closed
# counter= 8010 : at t = 2.23 hours, pore is 96.59 % closed
# counter= 8020 : at t = 2.23 hours, pore is 96.71 % closed
# counter= 8030 : at t = 2.23 hours, pore is 96.83 % closed
# counter= 8040 : at t = 2.23 hours, pore is 96.95 % closed
# counter= 8050 : at t = 2.24 hours, pore is 97.06 % closed
# counter= 8060 : at t = 2.24 hours, pore is 97.18 % closed
# counter= 8070 : at t = 2.24 hours, pore is 97.3 % closed
# counter= 8080 : at t = 2.24 hours, pore is 97.42 % closed
# counter= 8090 : at t = 2.25 hours, pore is 97.54 % closed
# counter= 8100 : at t = 2.25 hours, pore is 97.66 % closed
# counter= 8110 : at t = 2.25 hours, pore is 97.78 % closed
# counter= 8120 : at t = 2.26 hours, pore is 97.9 % closed
# counter= 8130 : at t = 2.26 hours, pore is 98.02 % closed
# counter= 8140 : at t = 2.26 hours, pore is 98.14 % closed
# counter= 8150 : at t = 2.26 hours, pore is 98.26 % closed
# counter= 8160 : at t = 2.27 hours, pore is 98.38 % closed
# counter= 8170 : at t = 2.27 hours, pore is 98.5 % closed
# counter= 8180 : at t = 2.27 hours, pore is 98.62 % closed
# counter= 8190 : at t = 2.28 hours, pore is 98.74 % closed
# counter= 8200 : at t = 2.28 hours, pore is 98.85 % closed
# counter= 8210 : at t = 2.28 hours, pore is 98.97 % closed
# ...
# counter= 7120 : at t = 1.98 hours, pore is 85.97 % closed
# counter= 7130 : at t = 1.98 hours, pore is 86.09 % closed
# counter= 7140 : at t = 1.98 hours, pore is 86.21 % closed
# counter= 7150 : at t = 1.99 hours, pore is 86.32 % closed
# counter= 7160 : at t = 1.99 hours, pore is 86.44 % closed
# counter= 7170 : at t = 1.99 hours, pore is 86.56 % closed
# counter= 7180 : at t = 1.99 hours, pore is 86.68 % closed
# counter= 7190 : at t = 2.0 hours, pore is 86.8 % closed
# counter= 7200 : at t = 2.0 hours, pore is 86.92 % closed
# counter= 7210 : at t = 2.0 hours, pore is 87.04 % closed
# counter= 7220 : at t = 2.01 hours, pore is 87.16 % closed
# counter= 7230 : at t = 2.01 hours, pore is 87.28 % closed
# counter= 7240 : at t = 2.01 hours, pore is 87.4 % closed
# counter= 7250 : at t = 2.01 hours, pore is 87.52 % closed
# counter= 7260 : at t = 2.02 hours, pore is 87.64 % closed
# counter= 7270 : at t = 2.02 hours, pore is 87.76 % closed
# counter= 7280 : at t = 2.02 hours, pore is 87.88 % closed
# counter= 7290 : at t = 2.03 hours, pore is 88.0 % closed
# counter= 7300 : at t = 2.03 hours, pore is 88.11 % closed
# counter= 7310 : at t = 2.03 hours, pore is 88.23 % closed
# counter= 7320 : at t = 2.03 hours, pore is 88.35 % closed
# counter= 7330 : at t = 2.04 hours, pore is 88.47 % closed
# counter= 7340 : at t = 2.04 hours, pore is 88.59 % closed
# counter= 7350 : at t = 2.04 hours, pore is 88.71 % closed
# counter= 7360 : at t = 2.04 hours, pore is 88.83 % closed
# counter= 7370 : at t = 2.05 hours, pore is 88.95 % closed
# counter= 7380 : at t = 2.05 hours, pore is 89.07 % closed
# counter= 7390 : at t = 2.05 hours, pore is 89.19 % closed
# counter= 7400 : at t = 2.06 hours, pore is 89.31 % closed
# counter= 7410 : at t = 2.06 hours, pore is 89.43 % closed
# counter= 7420 : at t = 2.06 hours, pore is 89.55 % closed
# counter= 7430 : at t = 2.06 hours, pore is 89.67 % closed
# counter= 7440 : at t = 2.07 hours, pore is 89.79 % closed
# counter= 7450 : at t = 2.07 hours, pore is 89.9 % closed
# counter= 7460 : at t = 2.07 hours, pore is 90.02 % closed
# counter= 7470 : at t = 2.08 hours, pore is 90.14 % closed
# counter= 7480 : at t = 2.08 hours, pore is 90.26 % closed
# counter= 7490 : at t = 2.08 hours, pore is 90.38 % closed
# counter= 7500 : at t = 2.08 hours, pore is 90.5 % closed
# counter= 7510 : at t = 2.09 hours, pore is 90.62 % closed
# counter= 7520 : at t = 2.09 hours, pore is 90.74 % closed
# counter= 7530 : at t = 2.09 hours, pore is 90.86 % closed
# counter= 7540 : at t = 2.09 hours, pore is 90.98 % closed
# counter= 7550 : at t = 2.1 hours, pore is 91.1 % closed
# counter= 7560 : at t = 2.1 hours, pore is 91.22 % closed
# counter= 7570 : at t = 2.1 hours, pore is 91.34 % closed
# counter= 7580 : at t = 2.11 hours, pore is 91.46 % closed
# counter= 7590 : at t = 2.11 hours, pore is 91.58 % closed
# counter= 7600 : at t = 2.11 hours, pore is 91.69 % closed
# counter= 7610 : at t = 2.11 hours, pore is 91.81 % closed
# counter= 7620 : at t = 2.12 hours, pore is 91.93 % closed
# counter= 7630 : at t = 2.12 hours, pore is 92.05 % closed
# counter= 7640 : at t = 2.12 hours, pore is 92.17 % closed
# counter= 7650 : at t = 2.13 hours, pore is 92.29 % closed
# counter= 7660 : at t = 2.13 hours, pore is 92.41 % closed
# counter= 7670 : at t = 2.13 hours, pore is 92.53 % closed
# counter= 7680 : at t = 2.13 hours, pore is 92.65 % closed
# counter= 7690 : at t = 2.14 hours, pore is 92.77 % closed
# counter= 7700 : at t = 2.14 hours, pore is 92.89 % closed
# counter= 7710 : at t = 2.14 hours, pore is 93.01 % closed
# counter= 7720 : at t = 2.14 hours, pore is 93.13 % closed
# counter= 7730 : at t = 2.15 hours, pore is 93.25 % closed
# counter= 7740 : at t = 2.15 hours, pore is 93.37 % closed
# counter= 7750 : at t = 2.15 hours, pore is 93.48 % closed
# counter= 7760 : at t = 2.16 hours, pore is 93.6 % closed
# counter= 7770 : at t = 2.16 hours, pore is 93.72 % closed
# counter= 7780 : at t = 2.16 hours, pore is 93.84 % closed
# counter= 7790 : at t = 2.16 hours, pore is 93.96 % closed
# counter= 7800 : at t = 2.17 hours, pore is 94.08 % closed
# counter= 7810 : at t = 2.17 hours, pore is 94.2 % closed
# counter= 7820 : at t = 2.17 hours, pore is 94.32 % closed
# counter= 7830 : at t = 2.18 hours, pore is 94.44 % closed
# counter= 7840 : at t = 2.18 hours, pore is 94.56 % closed
# counter= 7850 : at t = 2.18 hours, pore is 94.68 % closed
# counter= 7860 : at t = 2.18 hours, pore is 94.8 % closed
# counter= 7870 : at t = 2.19 hours, pore is 94.92 % closed
# counter= 7880 : at t = 2.19 hours, pore is 95.04 % closed
# counter= 7890 : at t = 2.19 hours, pore is 95.16 % closed
# counter= 7900 : at t = 2.19 hours, pore is 95.27 % closed
# counter= 7910 : at t = 2.2 hours, pore is 95.39 % closed
# counter= 7920 : at t = 2.2 hours, pore is 95.51 % closed
# counter= 7930 : at t = 2.2 hours, pore is 95.63 % closed
# counter= 7940 : at t = 2.21 hours, pore is 95.75 % closed
# counter= 7950 : at t = 2.21 hours, pore is 95.87 % closed
# counter= 7960 : at t = 2.21 hours, pore is 95.99 % closed
# counter= 7970 : at t = 2.21 hours, pore is 96.11 % closed
# counter= 7980 : at t = 2.22 hours, pore is 96.23 % closed
# counter= 7990 : at t = 2.22 hours, pore is 96.35 % closed
# counter= 8000 : at t = 2.22 hours, pore is 96.47 % closed
# counter= 8010 : at t = 2.23 hours, pore is 96.59 % closed
# counter= 8020 : at t = 2.23 hours, pore is 96.71 % closed
# counter= 8030 : at t = 2.23 hours, pore is 96.83 % closed
# counter= 8040 : at t = 2.23 hours, pore is 96.95 % closed
# counter= 8050 : at t = 2.24 hours, pore is 97.06 % closed
# counter= 8060 : at t = 2.24 hours, pore is 97.18 % closed
# counter= 8070 : at t = 2.24 hours, pore is 97.3 % closed
# counter= 8080 : at t = 2.24 hours, pore is 97.42 % closed
# counter= 8090 : at t = 2.25 hours, pore is 97.54 % closed
# counter= 8100 : at t = 2.25 hours, pore is 97.66 % closed
# counter= 8110 : at t = 2.25 hours, pore is 97.78 % closed
# counter= 8120 : at t = 2.26 hours, pore is 97.9 % closed
# counter= 8130 : at t = 2.26 hours, pore is 98.02 % closed
# counter= 8140 : at t = 2.26 hours, pore is 98.14 % closed
# counter= 8150 : at t = 2.26 hours, pore is 98.26 % closed
# counter= 8160 : at t = 2.27 hours, pore is 98.38 % closed
# counter= 8170 : at t = 2.27 hours, pore is 98.5 % closed
# counter= 8180 : at t = 2.27 hours, pore is 98.62 % closed
# counter= 8190 : at t = 2.28 hours, pore is 98.74 % closed
# counter= 8200 : at t = 2.28 hours, pore is 98.85 % closed
# counter= 8210 : at t = 2.28 hours, pore is 98.97 % closed
# counter= 8220 : at t = 2.28 hours, pore is 99.09 % closed
# counter= 8230 : at t = 2.29 hours, pore is 99.21 % closed
# counter= 8240 : at t = 2.29 hours, pore is 99.33 % closed
# counter= 8250 : at t = 2.29 hours, pore is 99.45 % closed
# counter= 8260 : at t = 2.29 hours, pore is 99.57 % closed
# counter= 8270 : at t = 2.3 hours, pore is 99.69 % closed
# counter= 8280 : at t = 2.3 hours, pore is 99.81 % closed
# counter= 8290 : at t = 2.3 hours, pore is 99.93 % closed
# 8296
# xi= [2.99838950e-05 8.03958948e-05 1.51181169e-04 2.40422265e-04
#  3.46701869e-04 4.68889849e-04 6.06045107e-04 7.57359630e-04
#  9.22125411e-04 1.09971142e-03 1.28954845e-03 1.49111780e-03
#  1.70394299e-03 1.92758328e-03 2.16162871e-03 2.40569607e-03
#  2.65942561e-03 2.92247840e-03 3.19453409e-03 3.47528902e-03
#  3.76445462e-03 4.06175605e-03 4.36693099e-03 4.67972864e-03
#  4.99990878e-03 5.32724101e-03 5.66150402e-03 6.00248495e-03
#  6.34997884e-03 6.70378814e-03 7.06372222e-03 7.42959697e-03
#  7.80123442e-03 8.17846239e-03 8.56111419e-03 8.94902837e-03
#  9.34204840e-03 9.74002247e-03 1.01428032e-02 1.05502474e-02
#  1.09622162e-02 1.13785742e-02 1.17991905e-02 1.22239364e-02
#  1.26526805e-02 1.30853060e-02 1.35217026e-02 1.39617514e-02
#  1.44053385e-02 1.48523546e-02 1.53026929e-02 1.57562491e-02
#  1.62129217e-02 1.66726112e-02 1.71352208e-02 1.76006559e-02
#  1.80688237e-02 1.85396341e-02 1.90129986e-02 1.94888308e-02
#  1.99670458e-02 2.04475625e-02 2.09302978e-02 2.14151719e-02
#  2.19021066e-02 2.23910296e-02 2.28818698e-02 2.33745525e-02
#  2.38690057e-02 2.43651578e-02 2.48629424e-02 2.53622921e-02
#  2.58631417e-02 2.63654271e-02 2.68690855e-02 2.73740554e-02
#  2.78802769e-02 2.83876901e-02 2.88962396e-02 2.94058559e-02
#  2.99165550e-02 3.04285256e-02 3.09413898e-02 3.14547950e-02
#  3.19689602e-02 3.24839014e-02 3.29995499e-02 3.35158589e-02
#  3.40327787e-02 3.45502622e-02 3.50682633e-02 3.55867364e-02
#  3.61056369e-02 3.66249211e-02 3.71445460e-02 3.76644695e-02
#  3.81846501e-02 3.87050472e-02 3.92256208e-02 3.97463318e-02
#  4.02671416e-02 4.07880124e-02 4.13089070e-02 4.18297888e-02
#  4.23506221e-02 4.28713716e-02 4.33920026e-02 4.39124811e-02
#  4.44327737e-02 4.49528476e-02 4.54726704e-02 4.59922104e-02
#  4.65114365e-02 4.70303179e-02 4.75488246e-02 4.80669270e-02
#  4.85845960e-02 4.91018029e-02 4.96185198e-02 5.01347187e-02
#  5.06503732e-02 5.11654562e-02 5.16799407e-02 5.21937999e-02
#  5.27070089e-02 5.32195442e-02 5.37313815e-02 5.42424965e-02
#  5.47528648e-02 5.52624634e-02 5.57712691e-02 5.62792595e-02
#  5.67864124e-02 5.72927060e-02 5.77981189e-02 5.83026297e-02
#  5.88062181e-02 5.93088637e-02 5.98105468e-02 6.03112474e-02
#  6.08109455e-02 6.13096213e-02 6.18072560e-02 6.23038315e-02
#  6.27993294e-02 6.32937312e-02 6.37870181e-02 6.42791602e-02
#  6.47701253e-02 6.52599843e-02 6.57487269e-02 6.62362501e-02
#  6.67225468e-02 6.72076118e-02 6.76914321e-02 6.81739949e-02
#  6.86552877e-02 6.91352971e-02 6.96140067e-02 7.00914027e-02
#  7.05674703e-02 7.10421969e-02 7.15155690e-02 7.19875736e-02
#  7.24581979e-02 7.29274293e-02 7.33952554e-02 7.38616640e-02
#  7.43266431e-02 7.47901811e-02 7.52522663e-02 7.57128874e-02
#  7.61720333e-02 7.66296929e-02 7.70858556e-02 7.75405108e-02
#  7.79936480e-02 7.84452571e-02 7.88953281e-02 7.93438512e-02
#  7.97908166e-02 8.02362149e-02 8.06800369e-02 8.11222733e-02
#  8.15629153e-02 8.20019540e-02 8.24393808e-02 8.28751872e-02
#  8.33093649e-02 8.37419058e-02 8.41728019e-02 8.46020452e-02
#  8.50296282e-02 8.54555433e-02 8.58797831e-02 8.63023404e-02
#  8.67232080e-02 8.71423789e-02 8.75598464e-02 8.79756038e-02
#  8.83896445e-02 8.88019621e-02 8.92125503e-02 8.96214030e-02
#  9.00285141e-02 9.04338777e-02 9.08374881e-02 9.12393396e-02
#  9.16394267e-02 9.20377440e-02 9.24342862e-02 9.28290482e-02
#  9.32220248e-02 9.36132111e-02 9.40026024e-02 9.43901939e-02
#  9.47759810e-02 9.51599592e-02 9.55421241e-02 9.59224715e-02
#  9.63009971e-02 9.66776970e-02 9.70525670e-02 9.74256034e-02
#  9.77968024e-02 9.81661603e-02 9.85336735e-02 9.88993385e-02
#  9.92631520e-02 9.96251106e-02 9.99852112e-02 1.00343451e-01
#  1.00699826e-01 1.01054334e-01 1.01406972e-01 1.01757737e-01
#  1.02106627e-01 1.02453639e-01 1.02798771e-01 1.03142019e-01
#  1.03483382e-01 1.03822857e-01 1.04160443e-01 1.04496136e-01
#  1.04829936e-01 1.05161839e-01 1.05491845e-01 1.05819951e-01
#  1.06146155e-01 1.06470456e-01 1.06792853e-01 1.07113343e-01
#  1.07431925e-01 1.07748598e-01 1.08063360e-01 1.08376210e-01
#  1.08687146e-01 1.08996168e-01 1.09303275e-01 1.09608465e-01
#  1.09911738e-01 1.10213092e-01 1.10512527e-01 1.10810041e-01
#  1.11105635e-01 1.11399306e-01 1.11691055e-01 1.11980881e-01
#  1.12268783e-01 1.12554761e-01 1.12838814e-01 1.13120942e-01
#  1.13401144e-01 1.13679420e-01 1.13955770e-01 1.14230193e-01
#  1.14502689e-01 1.14773259e-01 1.15041900e-01 1.15308615e-01
#  1.15573401e-01 1.15836261e-01 1.16097192e-01 1.16356196e-01
#  1.16613272e-01 1.16868420e-01 1.17121641e-01 1.17372934e-01
#  1.17622300e-01 1.17869738e-01 1.18115249e-01 1.18358834e-01
#  1.18600491e-01 1.18840221e-01 1.19078026e-01 1.19313903e-01
#  1.19547855e-01 1.19779881e-01 1.20009981e-01 1.20238156e-01
#  1.20464405e-01 1.20688730e-01 1.20911130e-01 1.21131605e-01
#  1.21350156e-01 1.21566782e-01 1.21781485e-01 1.21994264e-01
#  1.22205118e-01 1.22414050e-01 1.22621058e-01 1.22826142e-01
#  1.23029303e-01 1.23230540e-01 1.23429854e-01 1.23627244e-01
#  1.23822710e-01 1.24016253e-01 1.24207871e-01 1.24397565e-01
#  1.24585335e-01 1.24771179e-01 1.24955097e-01 1.25137089e-01
#  1.25317154e-01 1.25495292e-01 1.25671501e-01 1.25845781e-01
#  1.26018131e-01 1.26188549e-01 1.26357035e-01 1.26523587e-01
#  1.26688203e-01 1.26850883e-01 1.27011623e-01 1.27170424e-01
#  1.27327281e-01 1.27482194e-01 1.27635160e-01 1.27786175e-01
#  1.27935239e-01 1.28082347e-01 1.28227496e-01 1.28370683e-01
#  1.28511905e-01 1.28651157e-01 1.28788435e-01 1.28923735e-01
#  1.29057052e-01 1.29188381e-01 1.29317717e-01 1.29445053e-01
#  1.29570384e-01 1.29693703e-01 1.29815004e-01 1.29934278e-01
#  1.30051517e-01 1.30166714e-01 1.30279859e-01 1.30390943e-01
#  1.30499956e-01 1.30606886e-01 1.30711723e-01 1.30814453e-01
#  1.30915064e-01 1.31013541e-01 1.31109870e-01 1.31204035e-01
#  1.31296018e-01 1.31385801e-01 1.31473364e-01 1.31558687e-01
#  1.31641747e-01 1.31722519e-01 1.31800978e-01 1.31877095e-01
#  1.31950840e-01 1.32022181e-01 1.32091082e-01 1.32157505e-01
#  1.32221409e-01 1.32282748e-01 1.32341475e-01 1.32397537e-01
#  1.32450874e-01 1.32501425e-01 1.32549120e-01 1.32593883e-01
#  1.32635633e-01 1.32674278e-01 1.32709718e-01 1.32741844e-01
#  1.32770533e-01 1.32795653e-01 1.32817055e-01 1.32834578e-01
#  1.32848040e-01 1.32857242e-01 1.32861965e-01 1.32861965e-01]
# xi= [2.998389504199737e-05, 0.002161628713619543, 0.006703788137967972, 0.01222393636218595, 0.018539634103203036, 0.025362292082140244, 0.03299954991174071, 0.04026714161397598, 0.04754882463775488, 0.05526246335141683, 0.06230383148746777, 0.06913529706677503, 0.07571288742154549, 0.08243938078094604, 0.08838964451676165, 0.0940026024165755, 0.09962511061970619, 0.10449613626386713, 0.10899616836040714, 0.11312094207993047, 0.11712164088612241, 0.12046440541044628, 0.12342985377253514, 0.12618854908122026, 0.1283706831740456, 0.130166714190721, 0.13155868715115787, 0.13254911970222596]
# moose input for damage is:  if(y>=7.222222222222222e-05, 2.998389504199737e-05, if(y>=6.944444444444443e-05, 0.002161628713619543, if(y>=6.666666666666666e-05, 0.006703788137967972, if(y>=6.388888888888888e-05, 0.01222393636218595, if(y>=6.111111111111111e-05, 0.018539634103203036, if(y>=5.8333333333333326e-05, 0.025362292082140244, if(y>=5.555555555555555e-05, 0.03299954991174071, if(y>=5.277777777777777e-05, 0.04026714161397598, if(y>=4.9999999999999996e-05, 0.04754882463775488, if(y>=4.7222222222222214e-05, 0.05526246335141683, if(y>=4.444444444444444e-05, 0.06230383148746777, if(y>=4.1666666666666665e-05, 0.06913529706677503, if(y>=3.8888888888888884e-05, 0.07571288742154549, if(y>=3.611111111111111e-05, 0.08243938078094604, if(y>=3.333333333333333e-05, 0.08838964451676165, if(y>=3.0555555555555554e-05, 0.0940026024165755, if(y>=2.7777777777777776e-05, 0.09962511061970619, if(y>=2.4999999999999998e-05, 0.10449613626386713, if(y>=2.222222222222222e-05, 0.10899616836040714, if(y>=1.9444444444444442e-05, 0.11312094207993047, if(y>=1.6666666666666664e-05, 0.11712164088612241, if(y>=1.3888888888888888e-05, 0.12046440541044628, if(y>=1.111111111111111e-05, 0.12342985377253514, if(y>=8.333333333333332e-06, 0.12618854908122026, if(y>=5.555555555555555e-06, 0.1283706831740456, if(y>=2.7777777777777775e-06, 0.130166714190721, if(y>=0.0, 0.13155868715115787,  0)))))))))))))))))))))))))))
# khet_fedou= 0.0027786172881957174
# ----------------------------------T= 1273 P= 20000 CMTS0= 0.1717903983288505 CH20= 1.717903983288505 CHCl0= 0
# counter= 10 : at t = 0.0 hours, pore is 1.12 % closed
# counter= 20 : at t = 0.01 hours, pore is 1.24 % closed
# counter= 30 : at t = 0.01 hours, pore is 1.36 % closed
# counter= 40 : at t = 0.01 hours, pore is 1.48 % closed
# counter= 50 : at t = 0.01 hours, pore is 1.6 % closed
# counter= 60 : at t = 0.02 hours, pore is 1.72 % closed
# counter= 70 : at t = 0.02 hours, pore is 1.84 % closed
# counter= 80 : at t = 0.02 hours, pore is 1.95 % closed
# counter= 90 : at t = 0.03 hours, pore is 2.07 % closed
# counter= 100 : at t = 0.03 hours, pore is 2.19 % closed
# counter= 110 : at t = 0.03 hours, pore is 2.31 % closed
# counter= 120 : at t = 0.03 hours, pore is 2.43 % closed
# counter= 130 : at t = 0.04 hours, pore is 2.55 % closed
# counter= 140 : at t = 0.04 hours, pore is 2.67 % closed
# counter= 150 : at t = 0.04 hours, pore is 2.79 % closed
# counter= 160 : at t = 0.04 hours, pore is 2.91 % closed

# %%
#alpha 10

fig, ax = plt.subplots(figsize = (5,2.7), layout='constrained')

ax.plot(asol[1]*1e3,asol[10],label='nz 28',color='red',linewidth=3)
ax.plot(bsol[1]*1e3,bsol[10],label='nz 100',color='orange',linewidth=3)
ax.plot(csol[1]*1e3,csol[10],label='nz 200',color='green',linewidth=3)
ax.plot(dsol[1]*1e3,dsol[10],label='nz 400',color='blue',linewidth=3)
ax.plot(fsol[1]*1e3,fsol[10],label='nz 800',color='magenta',linewidth=3)
# ax.plot(gsol[1]*1e3,gsol[10],label='nz 1000',color='black',linewidth=3)
plt.ylim([0,1])
# plt.xlim([0,5])
# plt.yticks(np.arange(0, 60, step=10))
plt.xticks(np.arange(0, 6, step=1))
ax.set_xlabel('z mm')
ax.set_ylabel(r'$d \ \mu m$')
ax.set_title(r'$\xi_0 = 0.30, \ \alpha=1$') 
ax.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.savefig('sample.svg', dpi=220,bbox_inches='tight')

# %%
gsol = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',1,'',1000)
fig, ax = plt.subplots(figsize = (5,2.7), layout='constrained')

ax.plot(asol[1]*1e3,asol[10],label='nz 28',color='red',linewidth=3)
ax.plot(bsol[1]*1e3,bsol[10],label='nz 100',color='orange',linewidth=3)
ax.plot(csol[1]*1e3,csol[10],label='nz 200',color='green',linewidth=3)
ax.plot(dsol[1]*1e3,dsol[10],label='nz 400',color='blue',linewidth=3)
ax.plot(fsol[1]*1e3,fsol[10],label='nz 800',color='magenta',linewidth=3)
ax.plot(gsol[1]*1e3,gsol[10],label='nz 1000',color='black',linewidth=3)
plt.ylim([0,1])
# plt.xlim([0,5])
# plt.yticks(np.arange(0, 60, step=10))
plt.xticks(np.arange(0, 6, step=1))
ax.set_xlabel('z mm')
ax.set_ylabel(r'$d \ \mu m$')
ax.set_title(r'$\xi_0 = 0.30, \ \alpha=1$') 
ax.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.savefig('sample.svg', dpi=220,bbox_inches='tight')

# lp = cvi_nonlinear(1173,10000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# n = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",500,"phi")

# %%
# hp = cvi_nonlinear(1173,35000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# %%
# hhp = cvi_nonlinear(1173,50000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",200,"phi")

# %%
# b = cvi_nonlinear(1123,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# c = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",500,"phi")

# %%
# d = cvi_nonlinear(1223,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# %%
# e = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",50,"phi")

# %%
# f = cvi_nonlinear(1283,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",40,"phi")

# %%
# g= cvi_nonlinear(1293,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",30,"phi")

# %%
# h= cvi_nonlinear(1303,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",25,"phi")

# %%
# fig, ax = plt.subplots(figsize = (7,3), layout='constrained')

# tp_t = np.array([1073, 1173, 1173, 1173, 1173, 1173, 1273])
# tp_p = np.array([20, 5, 10, 20, 35, 50, 20])
# tp_tf = np.array([358.33, 92.22, 46.11, str(23.06)+' hrs', 13.67, 9.22, 2.31])

# ax.scatter(tp_t, tp_p,color='red')
# for i, txt in enumerate(tp_tf):
#     ax.annotate(txt, (tp_t[i],tp_p[i]),fontsize=13)

# ax.set_xlabel('$T$ K')
# ax.set_ylabel('$P$ kPa')
# plt.xlim([1073-27,1300])
# plt.xticks(np.arange(1073, 1373, step=100))
# plt.ylim([0,60])
# plt.yticks(np.arange(0, 60, step=10))
# plt.title(r'$t_f$ vs. {$T,P$}')
# # plt.legend(bbox_to_anchor=(1.05, 1.1), loc="upper left")
# ax.grid(True)

# plt.savefig('pt.svg', dpi=220,bbox_inches='tight')

# %%
# i= cvi_nonlinear(1313,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",5,"phi")

# %%
# #T comparison

# c = cvi_nonlinear(1073,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",10000,"phi")
# b = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")
# a = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1,"phi")

# %%
# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# arr_10kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_10kpa_y = np.array([2.62, 3.38, 3.88, 4.05, 4.22, 4.31])

# arr_11kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_11kpa_y = np.array([2.62, 7.43, 11.06, 13.26, 14.19, 14.70])

# arr_12kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_12kpa_y = np.array([2.62, 18.66, 28.88, 33.78, 36.57, 37.33])

# arr_10kpa_x = arr_10kpa_x - arr_10kpa_x[0]
# arr_11kpa_x = arr_11kpa_x - arr_11kpa_x[0]
# arr_12kpa_x = arr_12kpa_x - arr_12kpa_x[0]

# arr_10kpa_y = 50 - (arr_10kpa_y - arr_10kpa_y[0])
# arr_11kpa_y = 50 - (arr_11kpa_y - arr_11kpa_y[0])
# arr_12kpa_y = 50 - (arr_12kpa_y - arr_12kpa_y[0])
# ax.plot(b[0]*1000,c[5]*1e6,label=r'1073K',color='blue')
# ax.scatter(arr_10kpa_x, arr_10kpa_y,color='blue',label='1073K, exp',marker=matplotlib.markers.CARETDOWNBASE)
# ax.plot(b[0]*1000,b[5]*1e6,label=r'1173K',color='green')
# ax.scatter(arr_11kpa_x, arr_11kpa_y,color='green',label='1173K, exp',marker='X')
# ax.plot(b[0]*1000,a[5]*1e6,label=r'1273K',color='red')
# ax.scatter(arr_12kpa_x, arr_12kpa_y,color='red',label='1273K, exp',marker=matplotlib.markers.CARETUPBASE)




# ax.set_xlabel('z mm')
# ax.set_ylabel('$d$ $\mu$m')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([0,50])
# plt.yticks(np.arange(0, 60, step=10))
# plt.legend(bbox_to_anchor=(1.05, 1.1), loc="upper left")
# ax.grid(True)

# plt.savefig('dT.svg', dpi=220,bbox_inches='tight')

# %%
#alpha comparison

# c = cvi_nonlinear(1273,20000,100e-6, 100, 100, "blue",r"$1273$K, $dt = 1$s",1000,"phi")
# b = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")
# a = cvi_nonlinear(1273,20000,100e-6, 100, 1, "blue",r"$1273$K, $dt = 1$s",10,"phi")

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(a[0]*1000,a[1],label=r'MTS',color='red')
# ax.plot(a[0]*1000,a[2],label=r'H2',color='blue')
# ax.plot(a[0]*1000,a[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.title(r'$\alpha=1$')
# plt.ylim([0,1.5])
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha1.svg', dpi=220,bbox_inches='tight')


# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(b[0]*1000,b[1],label=r'MTS',color='red')
# ax.plot(b[0]*1000,b[2],label=r'H2',color='blue')
# ax.plot(b[0]*1000,b[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.title(r'$\alpha=10$')
# plt.ylim([-0.2,2])
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha10.svg', dpi=220,bbox_inches='tight')

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(c[0]*1000,c[1],label=r'MTS',color='red')
# ax.plot(c[0]*1000,c[2],label=r'H2',color='blue')
# ax.plot(c[0]*1000,c[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([-0.2,2])
# plt.title(r'$\alpha=100$')
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha100.svg', dpi=220,bbox_inches='tight')
