# %%
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats, optimize, interpolate
from scipy.optimize import fsolve
from scipy.integrate import odeint
from scipy.integrate import solve_bvp
from scipy.linalg import solve_banded
plt.rcParams.update({'font.size': 18})

t1073 = np.loadtxt(r'/Users/jjmarzia/Desktop/cvisim/fpbt_FS/por09/1073.txt')
sigf_t1073 = np.max(t1073)
tsigf_t1073 = np.where(t1073 == sigf_t1073)[0][0]

# t1123 = np.loadtxt(r'/Users/jjmarzia/Desktop/cvisim/fpbt_FS/por09/1123.txt')
# sigf_t1123 = np.max(t1123)
# tsigf_t1123 = np.where(t1123 == sigf_t1123)[0][0]

# t1173 = np.loadtxt(r'/Users/jjmarzia/Desktop/cvisim/fpbt_FS/por09/1173.txt')
# sigf_t1173 = np.max(t1173)
# tsigf_t1173 = np.where(t1173 == sigf_t1173)[0][0]

# t1223 = np.loadtxt(r'/Users/jjmarzia/Desktop/cvisim/fpbt_FS/por09/1223.txt')
# sigf_t1223 = np.max(t1223)
# tsigf_t1223 = np.where(t1223 == sigf_t1223)[0][0]

t1273 = np.loadtxt(r'/Users/jjmarzia/Desktop/cvisim/fpbt_FS/por09/1073.txt')
sigf_t1273 = np.max(t1273)
tsigf_t1273 = np.where(t1273 == sigf_t1273)[0][0]

# t1283 = np.loadtxt(r'/Users/jjmarzia/Desktop/cvisim/fpbt_FS/por09/1283.txt')
# sigf_t1283 = np.max(t1283)
# tsigf_t1283 = np.where(t1283 == sigf_t1283)[0][0]

# t1293 = np.loadtxt(r'/Users/jjmarzia/Desktop/cvisim/fpbt_FS/por09/1293.txt')
# sigf_t1293 = np.max(t1293)
# tsigf_t1293 = np.where(t1293 == sigf_t1293)[0][0]

t1303 = np.loadtxt(r'/Users/jjmarzia/Desktop/cvisim/fpbt_FS/por09/1303.txt')
sigf_t1303 = np.max(t1303)
tsigf_t1303 = np.where(t1303 == sigf_t1303)[0][0]

time = np.linspace(0,6.92,len(t1303))

fig = plt.subplots(figsize = (6,3.5), layout='constrained')
plt.plot(time[:len(t1073)], t1073,color='red',linestyle='-',linewidth=3)
plt.plot(time[tsigf_t1073],sigf_t1073,'^',markersize=15,color='red',label='1073K')
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel('t s')
plt.ylabel('$\sigma_{xx}$ Pa')
plt.title(r'$\xi_0 = 9\%$')
plt.grid(True)
plt.xlim([-0.5,8])
plt.xticks(np.arange(0, 10, step=2))
plt.ylim([-0.5e8,4.5e8])

plt.savefig('Fig5-a.svg', dpi=220,bbox_inches='tight')
plt.figure()

# plt.plot(time[:len(t1123)], t1123)
# plt.plot(time[:len(t1173)], t1173)
# plt.plot(time[:len(t1223)], t1223)
fig = plt.subplots(figsize = (6,3.5), layout='constrained')
plt.plot(time[:len(t1273)], t1273,color='black',linestyle='-',linewidth=3)
plt.plot(time[tsigf_t1273],sigf_t1273,'v',markersize=15,color='black',label='1273K')
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel('t s')
plt.ylabel('$\sigma_{xx}$ Pa')
plt.title(r'$\xi_0 = 9\%$')
plt.grid(True)
plt.xlim([-0.5,8])
plt.xticks(np.arange(0, 10, step=2))
plt.ylim([-0.5e8,4.5e8])
plt.savefig('Fig5-b.svg', dpi=220,bbox_inches='tight')
plt.figure()

# plt.plot(time[:len(t1283)], t1283,color='orange',linestyle='-',linewidth=3)
# plt.plot(time[:len(t1293)], t1293,color='magenta',linestyle='-',linewidth=3)
fig = plt.subplots(figsize = (6,3.5), layout='constrained')
plt.plot(time[tsigf_t1303],sigf_t1303,'P',markersize=15,color='blue',label='1303K')
plt.plot(time[:len(t1303)], t1303,color='blue',linestyle='-',linewidth=3)



# plt.plot(time[tsigf_t1283],sigf_t1283,'*',markersize=20,color='orange',label='1283K')
# plt.plot(time[tsigf_t1293],sigf_t1293,'*',markersize=20,color='magenta',label='1293K')

print(sigf_t1073,sigf_t1303)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel('t s')
plt.ylabel('$\sigma_{xx}$ Pa')
plt.title(r'$\xi_0 = 9\%$')
plt.grid(True)
plt.xlim([-0.5,8])
plt.xticks(np.arange(0, 10, step=2))
plt.ylim([-0.5e8,4.5e8])
plt.savefig('Fig5-c.svg', dpi=220,bbox_inches='tight')
# plt.savefig('95percent.svg', dpi=220,bbox_inches='tight')
# Out:
# 382330000.0 382310000.0
