# %%
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats, optimize, interpolate
from scipy.optimize import fsolve
from scipy.integrate import odeint
from scipy.integrate import solve_bvp
from scipy.linalg import solve_banded
plt.rcParams.update({'font.size': 18})

# %%
#
# Define function cvi_sim which computes resulting pore radius/gas concentration profiles as a function of CVI process parameters
#

def cvi_nonlinear(Tin,Pin, phi0in, rin, ain,plot_line_color,plot_line_label,dt,variable_plotted): # Temperature, pressure, initial pore diameter, aspect ratio, phase ratio, line color, line label, time stepper, variable to plot (between rp and C). 
    
    
    ###
    # CVI CONDITIONS
    ###
    
    phi0 = phi0in     # Pore diameter, m  
    L = rin*phi0      # Length, m
    nz = 28         # Number of grid points, dimensionless
    h = L/(nz+1)      # Distance between grid points, m
    hh = h**2
    dt = dt           # Time stepper, s

    phii = phi0*np.ones(nz)
    phi = phii
    
    Zrange = np.linspace(0,L/2,nz)           # Grid that represents length of specimen
    alpha = ain                            # Ratio between H2 and MTS concentrations at reactor entrance, dimensionless
    P = Pin                                # Pressure, Pa
    T = Tin                                # Temperature, K
    
    
    R = 8.314                              # Ideal gas constant, J/mol K
    
    CMTS0 = (1/(1+alpha))*(P / (R*T))      # MTS concentration at z=0 (BC), mol/m^3
    CH20 = (alpha/(1+alpha))*(P / (R*T))   # H2 concentration at z=0 (1-CMTS0), mol/m^3,  Fedou1993-2 Eqs. 9-10
    CHCl0 = 0                              # HCl concentration at z=0 (1-CMTS0), mol/m^3
    
    k0 = 3.89e9                            # Reaction rate coefficient, m/s
    Ea = 296e3                             # Activation energy, J/mol
    
    CMTS = CMTS0*np.ones(nz)
    CMTS[0] = CMTS0
    CH2 = CH20*np.ones(nz)                     # Gas phase composition at pore entrance, Fedou1993-2 Eqs. 9-10
    CH2[0] = CH20
    CHCl = CHCl0*np.ones(nz)
    CHCl[0] = CHCl0
    
    Ct0_before_penetration = [CMTS, CH2, CHCl]
    
    khet = k0*np.exp(-Ea/(R*T))
    print('khet_fedou=',khet)
    
    
    #### Walker DFT paper
    # R = 8.617333262e-5
    # T = 1273
    # Ea = 0.918 #mean
    # # Ea = 0.493 #lower bound
    # # Ea = 1.342 #upper bound
    # khet = np.exp(-Ea/(R*T))
    # print("khet_walker=",khet)
    ####
    
    nu = khet*CMTS         # Kinetic law, Fedou1993-2 Eq. 3
    
    dKMTS = 3.97 #m/sK^(1/2)               # Reduced Knudsen coefficient of MTS, m/s K^1/2
    dKH2 = 34.30 #m/sK^(1/2)               # Reduced Knudsen coefficient of H2, m/s K^1/2,  Fedou1993-2 Table I
    dKHCl = 8.03 #m/sK^(1/2)               # Reduced Knudsen coefficient of HCl, m/s K^1/2
    
    DKMTS=dKMTS*phi*(T**0.5)              # Knudsen diffusion coefficient of MTS, m^2/s 
    DKH2=dKH2*phi*(T**0.5)                # Knudsen diffusion coefficient of H2, m^2/s,  Fedou1993-2 Eq. 2
    DKHCl=dKHCl*phi*(T**0.5)              # Knudsen diffusion coefficient of HCl, m^2/s 
    
    # MSiC = 0.04011                       # Molar mass of SiC, kg/mol
    MMTS = 0.149                             # Molar mass of MTS, kg/mol
    MH2 = 2e-3                             # Molar mass of H2, kg/mol,  Fedou1993-2 Table I
    MHCl = 3.65e-2                         # Molar mass of HCl, kg/mol
    
    # rhoSiC = 3217                        # Density of SiC, kg/m^3
    # rhoMTS = 1270
    # rhoH2 = 0.08375
    # rhoHCl = 1048
    
    VSiC = 12.5e-6                         # Specific volume of SiC, m^3/mol,  Fedou1993-2 Section 2.2
    VMTS = 122.7e-6                          # Specific volume of MTS, m^3/mol
    VH2  = 14.3e-6                            # Specific volume of H2, m^3/mol,  Fedou1993-2 Table III
    VHCl = 25.3e-6                          # Specific volume of HCl, m^3/mol
    
    # VMTS = 122.7                          # Specific volume of MTS, cm^3/mol
    # VH2  = 14.3                            # Specific volume of H2, cm^3/mol,  Fedou1993-2 Table III
    # VHCl = 25.3                          # Specific volume of HCl, cm^3/mol
    
    sMTS = -1
    sH2 = 0                               # Stoichiometric coefficients of the chemical elements, Fedou1993-1 Eq. 1 and Fedou1993-2 Eq. 1
    sHCl = 3
    sSiC = 1
    deltas = sMTS + sH2 + sHCl + sSiC             # Sum of coefficients, Fedou1993-1 Eq. 11
    s = [sMTS, sH2, sHCl, sSiC]

    Dij_MTSH2 = 1.360e-3*((T**(3/2))/(P*(VH2**(1/3)+VMTS**(1/3))**2))*(1/MH2 + 1/MMTS)**0.5
    Dij_MTSHCl = 1.360e-3*((T**(3/2))/(P*(VHCl**(1/3)+VMTS**(1/3))**2))*(1/MHCl + 1/MMTS)**0.5   # Gilliland formula, Fedou1993-1 Appendix 1 Eq A4
    
    epsik = 59.7
    sigi = 0.2827e-9
    epsjk = 344.7
    sigj = 0.3339e-9
    sigij = (sigi+sigj)/2
    kepsij = (epsik * epsjk)**(-0.5)
    Tstar = kepsij*T
    Tstar = np.rint(Tstar)
    if Tstar ==7:
        omegaD = 0.79643333
    if Tstar == 8: 
        omegaD = 0.78003333                # Hirschfelder formula, Fedou1993-1 Appendix 1 Eqs. A1-A3; calculation of 
    if Tstar == 9:
        omegaD = 0.76611111
    if Tstar == 10:
        omegaD = 0.75401111
    V = 2.78125e4

    Dij_H2HCl = 5.876e-24  *((T**1.5)/(P*(sigij**2)*V*omegaD))*((1/MH2 + 1/MHCl)**0.5)
    Dij_H2HCl = 1.360e-3*((T**(3/2))/(P*(VHCl**(1/3)+VH2**(1/3))**2))*(1/MHCl + 1/MH2)**0.5 
    # print("dfomega=",Dij_H2HCl, "dfvhcl=",Dij_H2HCl_v2)
    
    N = deltas*nu
    
    xMTS  = CMTS/(CMTS+CH2+CHCl)
    xH2 = CH2/(CMTS+CH2+CHCl)                                     # Molar fractions, Fedou1993-1 Eq. 13                                    
    xHCl = CHCl/(CMTS+CH2+CHCl)
    
    dxMTSdz = dxH2dz = dxHCldz = np.zeros(nz)
    
    # DFMTS = ((1/(1-xMTS[0]))*(xHCl[0]/Dij_MTSHCl + xH2[0]/Dij_MTSH2))**(-1)
    # DFH2 = ((1/(1-xH2[0]))*(xHCl[0]/Dij_H2HCl + xMTS[0]/Dij_MTSH2))**(-1)      # Fick diffusion coefficients, Fedou1993-1 Eq. 16
    # DFHCl = ((1/(1-xHCl[0]))*(xH2[0]/Dij_H2HCl + xMTS[0]/Dij_MTSHCl))**(-1)
    
    DFMTS = ((1/(1-xMTS))*(xHCl/Dij_MTSHCl + xH2/Dij_MTSH2))**(-1)
    DFH2 = ((1/(1-xH2))*(xHCl/Dij_H2HCl + xMTS/Dij_MTSH2))**(-1)      # Fick diffusion coefficients, Fedou1993-1 Eq. 16
    DFHCl = ((1/(1-xHCl))*(xH2/Dij_H2HCl + xMTS/Dij_MTSHCl))**(-1)

    DMTS = (1/DFMTS + 1/DKMTS)**(-1)          
    DH2 = (1/DFH2 + 1/DKH2)**(-1)          # Overall diffusion coefficient, Fedou1993-1 Eq. 15
    DHCl = (1/DFHCl + 1/DKHCl)**(-1) 
    
    ###
    # INITIALIZE SOLUTION VECTORS
    ###
    
    Csol = []
    Dsol = []
    for k in range(nz):
        Dsol = np.append(Dsol,DMTS[k])
        Dsol = np.append(Dsol,DH2[k])  # D matrix
        Dsol = np.append(Dsol,DHCl[k])
        Csol = np.append(Csol,CMTS[k])
        Csol = np.append(Csol,CH2[k])  # C matrix
        Csol = np.append(Csol,CHCl[k])
    C0sol = Csol

    print('----------------------------------T=',T,'P=',P, 'CMTS0=',CMTS0,'CH20=',CH20,'CHCl0=',CHCl0)

    
    CMTSt = []                             
    CH2t = []                              # Array containing gas concentration profiles of MTS, H2, HCl
    CHClt = []
    
    phit = []
    rpt = []
    
    percent_closed = 0                     # Dimensionless rating of pore size relative to initial pore size
    counter =0                             # Time counter
    
    
    ###
    # NONLINEAR ITERATIVE SOLVER
    ###
    
    while any(phi<phi0/100) is not True:
        
        # Assemble D, C matrices so that (gas,gridpt)=(i,j) = Cm[3j+i]. Gases\in [0,2] = [MTS, H2, HCl]. Gridpts\in [0,n+1]
        # So C_{1,j} = C_{2,5} = C[3*5 + 2 = C[17].
        Csol = []
        Dsol = []
        
        for k in range(nz):
            Dsol = np.append(Dsol,DMTS[k])
            Dsol = np.append(Dsol,DH2[k])  # D matrix
            Dsol = np.append(Dsol,DHCl[k])
            Csol = np.append(Csol,CMTS[k])
            Csol = np.append(Csol,CH2[k])  # C matrix
            Csol = np.append(Csol,CHCl[k])
        # if counter==0:
        #     print('C=',Csol.size,'D=',Dsol.size)
        #     print(Csol,Dsol)
        
        def F(C, *data_args):
            D, h, hh, N, s, nu, phi = data_args
            exps = []
            n = nz-2
            for j in range(1,n+1): #1\leq j\leq n. #nz=7--> j=1,2,3,4,5     
                # print(C.size)
                # print(j)
                if j==1:
                    xi_jp1 = C[3]/(C[3]+C[4]+C[5])
                    xi_jm1 = CMTS0/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CMTS0 - 2*C[0] + C[3])/hh - (xi_jp1*N[2]-xi_jm1*N[0])/(2*D[0]*h) + (4*s[0]*nu[0])/(D[0]*phi[0]))
                    # print("exps1=",exps.size)
                    
                    xi_jp1 = C[4]/(C[4]+C[5]+C[3])
                    xi_jm1 = CH20/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CH20 - 2*C[1] + C[4])/hh - ((xi_jp1*N[2]-xi_jm1*N[0])/(2*D[1]*h)) + (4*s[1]*nu[0])/(D[1]*phi[0]))
                    # print("exps2=",exps.size)
                    
                    xi_jp1 = C[5]/(C[5]+C[4]+C[3])
                    xi_jm1 = CHCl0/(CMTS0 +CH20 + CHCl0)
                    exps = np.append(exps, (CHCl0 - 2*C[2] + C[5])/hh - ((xi_jp1*N[2]-xi_jm1*N[0])/(2*D[2]*h)) + (4*s[2]*nu[0])/(D[2]*phi[0]))
                    # print("exps3=",exps.size)
                    
                if not j==1 and not j==n: #j=2,3,4
                    for i in range(3): #i=0,1,2
                        if i==0: #defining molar fractions for each gas i. MTS
                            xi_jp1 = C[3*j]/(C[3*j]+C[3*j+1]+C[3*j+2])
                            xi_jm1 = C[3*(j-2)]/(C[3*(j-2)]+C[3*(j-2)+1]+C[3*(j-2)+2])
                        if i==1: #H2
                            xi_jp1 = C[3*j+1]/(C[3*j+1]+C[3*j+2]+C[3*j])
                            xi_jm1 = C[3*(j-2)+1]/(C[3*(j-2)+1]+C[3*(j-2)+2]+C[3*(j-2)])
                        if i==2: #HCl
                            xi_jp1 = C[3*j+2]/(C[3*j+2]+C[3*j+1]+C[3*j])
                            xi_jm1 = C[3*(j-2)+2]/(C[3*(j-2)+2]+C[3*(j-2)+1]+C[3*(j-2)])

                        expij = (C[3*(j-2)+i] - 2*C[3*(j-1)+i] + C[3*j+i])/hh - (xi_jp1*N[j+1]-xi_jm1*N[j-1])/(2*D[3*(j-1)+i]*h) + (4*s[i]*nu[j-1])/(D[3*(j-1)+i]*phi[j-1])
                        exps = np.append(exps, expij)
                        # print("exps4=",exps.size)
                        
                if j==n: #j=5,
                    for i in range(3):
                        if i==0: #defining molar fractions for each gas i. MTS
                            xi_jp1 = C[3*(n-1)]/(C[3*(n-1)]+C[3*(n-1)+1]+C[3*(n-1)+2])
                            xi_jm1 = C[3*(n-2)]/(C[3*(n-2)]+C[3*(n-2)+1]+C[3*(n-2)+2])
                        if i==1: #H2
                            xi_jp1 = C[3*(n-1)+1]/(C[3*(n-1)+1]+C[3*(n-1)+2]+C[3*(n-1)])
                            xi_jm1 = C[3*(n-2)+1]/(C[3*(n-2)+1]+C[3*(n-2)+2]+C[3*(n-2)])
                        if i==2: #HCl
                            xi_jp1 = C[3*(n-1)+2]/(C[3*(n-1)+2]+C[3*(n-1)+1]+C[3*(n-1)])
                            xi_jm1 = C[3*(n-2)+2]/(C[3*(n-2)+2]+C[3*(n-2)+1]+C[3*(n-2)])

                        expij = (C[3*(n-2)+i] - C[3*(n-1)+i])/hh - (xi_jp1*N[n+1]-xi_jm1*N[n-1])/(2*D[3*(n-1)+i]*h) + (4*s[i]*nu[n-1])/(D[3*(n-1)+i]*phi[n-1])
                        exps = np.append(exps, expij)
            return exps
        
        data_args = (Dsol[3:-3], h, hh, N, s, nu[1:-1], phi[1:-1])
        Csol = fsolve(F, C0sol[3:-3], args=data_args)
        Csol = np.insert(Csol, 0, CHCl0)
        Csol = np.insert(Csol, 0, CH20)           # left boundary condition
        Csol = np.insert(Csol, 0, CMTS0)
        for _ in range(3):
            Csol = np.append(Csol, Csol[-3])      # right boundary condition
            
        CMTS = Csol[0::3]
        CH2 = Csol[1::3]
        CHCl = Csol[2::3]
    
        # khet = k0*np.exp(-Ea/(R*T))
        # khet =
    
        nu = khet*CMTS                            # Kinetic law, Fedou1993-2 Eq. 3
        N = deltas*nu 
        phi = phi - (2*dt*nu*VSiC)                # Update pore diameter

        DFMTS = ((1/(1-xMTS))*(xHCl/Dij_MTSHCl + xH2/Dij_MTSH2))**(-1)
        DFH2 = ((1/(1-xH2))*(xHCl/Dij_H2HCl + xMTS/Dij_MTSH2))**(-1)     # Update Fick diffusion coefficients, Fedou1993-1 Eq. 16
        DFHCl = ((1/(1-xHCl))*(xH2/Dij_H2HCl + xMTS/Dij_MTSHCl))**(-1)
        
        DKMTS = dKMTS*phi*(T**0.5)
        DKH2 = dKH2*phi*(T**0.5)                                      # Update Knudsen diffusion coefficients, Fedou1993-2 Eq. 2
        DKHCl = dKHCl*phi*(T**0.5)

        DMTS = (1/DFMTS + 1/DKMTS)**(-1)          
        DH2 = (1/DFH2 + 1/DKH2)**(-1)                                    # Update overall diffusion coefficient, Fedou1993-1 Eq. 15
        DHCl = (1/DFHCl + 1/DKHCl)**(-1)              

        
        counter+=1
        rpt.append(phi[0]/2)
        if counter % 10 == 0:
            # print(rpt)
            CMTSt.append(CMTS)
            CH2t.append(CH2) # Collect pore diameter/gas concentration profiles at current time step
            CHClt.append(CHCl)
            # print("nu=",nu[0:3],"CMTS=",CMTS[0:3])
            phit.append(phi)
            percent_closed = 100*(1 -(phi[0]-phi0/100)/phi0)
            print('counter=',counter,': at t =',round(counter*dt*0.000277778,2),'hours, pore is', round(percent_closed,2),'% closed')
    print(counter) 
    t_f_hrs = counter*dt*0.000277778
    t_f_secs = counter*dt
    d = (phii-phi)/2
    # print('phi=',phi,'CMTS=', CMTS)
    
    counter_t = np.arange(0,counter,dt)
    # print('counter_t=',counter_t)
    # print(np.shape(counter_t), np.shape(rpt))
    
    
    ###
    # MOOSE DAMAGE INPUT
    ###
    
    rp = phi/2
    porosity = 0.3
    RpRVE = np.sqrt(1/porosity)*(phi0/2)

    # print('rp=',rp)
    xi = (rp**2)/(RpRVE**2)
    
    mesh_height = 7.5e-5
    num_elements = 28 #ideally =nz
    element_positions = np.linspace(0, mesh_height, num_elements)  
    
    moose_input_i = ''
    par_input = ''
    for q in range(num_elements-1):
        moose_input = str(moose_input_i)+'if(y>='+str(element_positions[num_elements-2-q])+', '+str(xi[q])+', '
        moose_input_i = moose_input
        par_input = str(par_input)+')'
    moose_input = str(moose_input_i)+' 0'+str(par_input)
    
    print('xi=',xi)
    print('moose input for damage is: ',moose_input)
    
    
    return [Zrange, CMTS,CH2,CHCl, phi, d, L, str(plot_line_label), rp, xi, khet, t_f_hrs, t_f_secs, rpt, counter_t]

# %%
#
# Call the function cvi_sim
#

# Inputs: Temperature (K), pressure (Pa), pore diameter (m), aspect ratio, gas ratio,      ...
#         plot line color, plot line label, dt, variable to be plotted between "phi" or "C".

# %%
a = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',2,'')
b = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',1,'')
c = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',0.5,'')

# c = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',0.5,'')
# d = cvi_nonlinear(1273,20000,100e-6, 100, 10, '','',0.25,'')
# b = cvi_nonlinear(1073,20000,100e-6, 100, 10, '','',1,'')
# c = cvi_nonlinear(1303,20000,100e-6, 100, 10, '','',1,'')
# Out:
# khet_fedou= 0.0027786172881957174
# ----------------------------------T= 1273 P= 20000 CMTS0= 0.1717903983288505 CH20= 1.717903983288505 CHCl0= 0
# counter= 10 : at t = 0.01 hours, pore is 1.24 % closed
# counter= 20 : at t = 0.01 hours, pore is 1.48 % closed
# counter= 30 : at t = 0.02 hours, pore is 1.72 % closed
# counter= 40 : at t = 0.02 hours, pore is 1.95 % closed
# counter= 50 : at t = 0.03 hours, pore is 2.19 % closed
# counter= 60 : at t = 0.03 hours, pore is 2.43 % closed
# counter= 70 : at t = 0.04 hours, pore is 2.67 % closed
# counter= 80 : at t = 0.04 hours, pore is 2.91 % closed
# counter= 90 : at t = 0.05 hours, pore is 3.15 % closed
# counter= 100 : at t = 0.06 hours, pore is 3.39 % closed
# counter= 110 : at t = 0.06 hours, pore is 3.63 % closed
# counter= 120 : at t = 0.07 hours, pore is 3.86 % closed
# counter= 130 : at t = 0.07 hours, pore is 4.1 % closed
# counter= 140 : at t = 0.08 hours, pore is 4.34 % closed
# counter= 150 : at t = 0.08 hours, pore is 4.58 % closed
# counter= 160 : at t = 0.09 hours, pore is 4.82 % closed
# counter= 170 : at t = 0.09 hours, pore is 5.06 % closed
# counter= 180 : at t = 0.1 hours, pore is 5.3 % closed
# counter= 190 : at t = 0.11 hours, pore is 5.53 % closed
# counter= 200 : at t = 0.11 hours, pore is 5.77 % closed
# counter= 210 : at t = 0.12 hours, pore is 6.01 % closed
# counter= 220 : at t = 0.12 hours, pore is 6.25 % closed
# counter= 230 : at t = 0.13 hours, pore is 6.49 % closed
# counter= 240 : at t = 0.13 hours, pore is 6.73 % closed
# counter= 250 : at t = 0.14 hours, pore is 6.97 % closed
# counter= 260 : at t = 0.14 hours, pore is 7.21 % closed
# counter= 270 : at t = 0.15 hours, pore is 7.44 % closed
# counter= 280 : at t = 0.16 hours, pore is 7.68 % closed
# counter= 290 : at t = 0.16 hours, pore is 7.92 % closed
# counter= 300 : at t = 0.17 hours, pore is 8.16 % closed
# counter= 310 : at t = 0.17 hours, pore is 8.4 % closed
# counter= 320 : at t = 0.18 hours, pore is 8.64 % closed
# counter= 330 : at t = 0.18 hours, pore is 8.88 % closed
# counter= 340 : at t = 0.19 hours, pore is 9.11 % closed
# counter= 350 : at t = 0.19 hours, pore is 9.35 % closed
# counter= 360 : at t = 0.2 hours, pore is 9.59 % closed
# counter= 370 : at t = 0.21 hours, pore is 9.83 % closed
# counter= 380 : at t = 0.21 hours, pore is 10.07 % closed
# counter= 390 : at t = 0.22 hours, pore is 10.31 % closed
# counter= 400 : at t = 0.22 hours, pore is 10.55 % closed
# counter= 410 : at t = 0.23 hours, pore is 10.79 % closed
# counter= 420 : at t = 0.23 hours, pore is 11.02 % closed
# counter= 430 : at t = 0.24 hours, pore is 11.26 % closed
# counter= 440 : at t = 0.24 hours, pore is 11.5 % closed
# counter= 450 : at t = 0.25 hours, pore is 11.74 % closed
# counter= 460 : at t = 0.26 hours, pore is 11.98 % closed
# counter= 470 : at t = 0.26 hours, pore is 12.22 % closed
# counter= 480 : at t = 0.27 hours, pore is 12.46 % closed
# counter= 490 : at t = 0.27 hours, pore is 12.69 % closed
# counter= 500 : at t = 0.28 hours, pore is 12.93 % closed
# counter= 510 : at t = 0.28 hours, pore is 13.17 % closed
# counter= 520 : at t = 0.29 hours, pore is 13.41 % closed
# counter= 530 : at t = 0.29 hours, pore is 13.65 % closed
# counter= 540 : at t = 0.3 hours, pore is 13.89 % closed
# counter= 550 : at t = 0.31 hours, pore is 14.13 % closed
# counter= 560 : at t = 0.31 hours, pore is 14.37 % closed
# counter= 570 : at t = 0.32 hours, pore is 14.6 % closed
# counter= 580 : at t = 0.32 hours, pore is 14.84 % closed
# counter= 590 : at t = 0.33 hours, pore is 15.08 % closed
# counter= 600 : at t = 0.33 hours, pore is 15.32 % closed
# counter= 610 : at t = 0.34 hours, pore is 15.56 % closed
# counter= 620 : at t = 0.34 hours, pore is 15.8 % closed
# counter= 630 : at t = 0.35 hours, pore is 16.04 % closed
# counter= 640 : at t = 0.36 hours, pore is 16.27 % closed
# counter= 650 : at t = 0.36 hours, pore is 16.51 % closed
# counter= 660 : at t = 0.37 hours, pore is 16.75 % closed
# counter= 670 : at t = 0.37 hours, pore is 16.99 % closed
# counter= 680 : at t = 0.38 hours, pore is 17.23 % closed
# counter= 690 : at t = 0.38 hours, pore is 17.47 % closed
# counter= 700 : at t = 0.39 hours, pore is 17.71 % closed
# counter= 710 : at t = 0.39 hours, pore is 17.95 % closed
# counter= 720 : at t = 0.4 hours, pore is 18.18 % closed
# counter= 730 : at t = 0.41 hours, pore is 18.42 % closed
# counter= 740 : at t = 0.41 hours, pore is 18.66 % closed
# counter= 750 : at t = 0.42 hours, pore is 18.9 % closed
# counter= 760 : at t = 0.42 hours, pore is 19.14 % closed
# counter= 770 : at t = 0.43 hours, pore is 19.38 % closed
# counter= 780 : at t = 0.43 hours, pore is 19.62 % closed
# counter= 790 : at t = 0.44 hours, pore is 19.85 % closed
# counter= 800 : at t = 0.44 hours, pore is 20.09 % closed
# counter= 810 : at t = 0.45 hours, pore is 20.33 % closed
# counter= 820 : at t = 0.46 hours, pore is 20.57 % closed
# counter= 830 : at t = 0.46 hours, pore is 20.81 % closed
# counter= 840 : at t = 0.47 hours, pore is 21.05 % closed
# counter= 850 : at t = 0.47 hours, pore is 21.29 % closed
# counter= 860 : at t = 0.48 hours, pore is 21.53 % closed
# counter= 870 : at t = 0.48 hours, pore is 21.76 % closed
# counter= 880 : at t = 0.49 hours, pore is 22.0 % closed
# counter= 890 : at t = 0.49 hours, pore is 22.24 % closed
# counter= 900 : at t = 0.5 hours, pore is 22.48 % closed
# counter= 910 : at t = 0.51 hours, pore is 22.72 % closed
# counter= 920 : at t = 0.51 hours, pore is 22.96 % closed
# counter= 930 : at t = 0.52 hours, pore is 23.2 % closed
# counter= 940 : at t = 0.52 hours, pore is 23.43 % closed
# counter= 950 : at t = 0.53 hours, pore is 23.67 % closed
# counter= 960 : at t = 0.53 hours, pore is 23.91 % closed
# counter= 970 : at t = 0.54 hours, pore is 24.15 % closed
# counter= 980 : at t = 0.54 hours, pore is 24.39 % closed
# counter= 990 : at t = 0.55 hours, pore is 24.63 % closed
# counter= 1000 : at t = 0.56 hours, pore is 24.87 % closed
# counter= 1010 : at t = 0.56 hours, pore is 25.11 % closed
# counter= 1020 : at t = 0.57 hours, pore is 25.34 % closed
# counter= 1030 : at t = 0.57 hours, pore is 25.58 % closed
# counter= 1040 : at t = 0.58 hours, pore is 25.82 % closed
# counter= 1050 : at t = 0.58 hours, pore is 26.06 % closed
# counter= 1060 : at t = 0.59 hours, pore is 26.3 % closed
# counter= 1070 : at t = 0.59 hours, pore is 26.54 % closed
# counter= 1080 : at t = 0.6 hours, pore is 26.78 % closed
# counter= 1090 : at t = 0.61 hours, pore is 27.02 % closed
# counter= 1100 : at t = 0.61 hours, pore is 27.25 % closed
# counter= 1110 : at t = 0.62 hours, pore is 27.49 % closed
# counter= 1120 : at t = 0.62 hours, pore is 27.73 % closed
# counter= 1130 : at t = 0.63 hours, pore is 27.97 % closed
# counter= 1140 : at t = 0.63 hours, pore is 28.21 % closed
# counter= 1150 : at t = 0.64 hours, pore is 28.45 % closed
# counter= 1160 : at t = 0.64 hours, pore is 28.69 % closed
# counter= 1170 : at t = 0.65 hours, pore is 28.92 % closed
# counter= 1180 : at t = 0.66 hours, pore is 29.16 % closed
# counter= 1190 : at t = 0.66 hours, pore is 29.4 % closed
# counter= 1200 : at t = 0.67 hours, pore is 29.64 % closed
# counter= 1210 : at t = 0.67 hours, pore is 29.88 % closed
# counter= 1220 : at t = 0.68 hours, pore is 30.12 % closed
# counter= 1230 : at t = 0.68 hours, pore is 30.36 % closed
# counter= 1240 : at t = 0.69 hours, pore is 30.6 % closed
# counter= 1250 : at t = 0.69 hours, pore is 30.83 % closed
# counter= 1260 : at t = 0.7 hours, pore is 31.07 % closed
# counter= 1270 : at t = 0.71 hours, pore is 31.31 % closed
# counter= 1280 : at t = 0.71 hours, pore is 31.55 % closed
# counter= 1290 : at t = 0.72 hours, pore is 31.79 % closed
# counter= 1300 : at t = 0.72 hours, pore is 32.03 % closed
# counter= 1310 : at t = 0.73 hours, pore is 32.27 % closed
# counter= 1320 : at t = 0.73 hours, pore is 32.5 % closed
# counter= 1330 : at t = 0.74 hours, pore is 32.74 % closed
# counter= 1340 : at t = 0.74 hours, pore is 32.98 % closed
# counter= 1350 : at t = 0.75 hours, pore is 33.22 % closed
# counter= 1360 : at t = 0.76 hours, pore is 33.46 % closed
# counter= 1370 : at t = 0.76 hours, pore is 33.7 % closed
# counter= 1380 : at t = 0.77 hours, pore is 33.94 % closed
# counter= 1390 : at t = 0.77 hours, pore is 34.18 % closed
# counter= 1400 : at t = 0.78 hours, pore is 34.41 % closed
# counter= 1410 : at t = 0.78 hours, pore is 34.65 % closed
# counter= 1420 : at t = 0.79 hours, pore is 34.89 % closed
# counter= 1430 : at t = 0.79 hours, pore is 35.13 % closed
# counter= 1440 : at t = 0.8 hours, pore is 35.37 % closed
# counter= 1450 : at t = 0.81 hours, pore is 35.61 % closed
# counter= 1460 : at t = 0.81 hours, pore is 35.85 % closed
# counter= 1470 : at t = 0.82 hours, pore is 36.08 % closed
# counter= 1480 : at t = 0.82 hours, pore is 36.32 % closed
# counter= 1490 : at t = 0.83 hours, pore is 36.56 % closed
# counter= 1500 : at t = 0.83 hours, pore is 36.8 % closed
# counter= 1510 : at t = 0.84 hours, pore is 37.04 % closed
# counter= 1520 : at t = 0.84 hours, pore is 37.28 % closed
# counter= 1530 : at t = 0.85 hours, pore is 37.52 % closed
# counter= 1540 : at t = 0.86 hours, pore is 37.76 % closed
# counter= 1550 : at t = 0.86 hours, pore is 37.99 % closed
# counter= 1560 : at t = 0.87 hours, pore is 38.23 % closed
# counter= 1570 : at t = 0.87 hours, pore is 38.47 % closed
# counter= 1580 : at t = 0.88 hours, pore is 38.71 % closed
# counter= 1590 : at t = 0.88 hours, pore is 38.95 % closed
# counter= 1600 : at t = 0.89 hours, pore is 39.19 % closed
# counter= 1610 : at t = 0.89 hours, pore is 39.43 % closed
# counter= 1620 : at t = 0.9 hours, pore is 39.66 % closed
# counter= 1630 : at t = 0.91 hours, pore is 39.9 % closed
# counter= 1640 : at t = 0.91 hours, pore is 40.14 % closed
# counter= 1650 : at t = 0.92 hours, pore is 40.38 % closed
# counter= 1660 : at t = 0.92 hours, pore is 40.62 % closed
# counter= 1670 : at t = 0.93 hours, pore is 40.86 % closed
# counter= 1680 : at t = 0.93 hours, pore is 41.1 % closed
# counter= 1690 : at t = 0.94 hours, pore is 41.34 % closed
# counter= 1700 : at t = 0.94 hours, pore is 41.57 % closed
# counter= 1710 : at t = 0.95 hours, pore is 41.81 % closed
# counter= 1720 : at t = 0.96 hours, pore is 42.05 % closed
# counter= 1730 : at t = 0.96 hours, pore is 42.29 % closed
# counter= 1740 : at t = 0.97 hours, pore is 42.53 % closed
# counter= 1750 : at t = 0.97 hours, pore is 42.77 % closed
# counter= 1760 : at t = 0.98 hours, pore is 43.01 % closed
# counter= 1770 : at t = 0.98 hours, pore is 43.24 % closed
# counter= 1780 : at t = 0.99 hours, pore is 43.48 % closed
# counter= 1790 : at t = 0.99 hours, pore is 43.72 % closed
# counter= 1800 : at t = 1.0 hours, pore is 43.96 % closed
# counter= 1810 : at t = 1.01 hours, pore is 44.2 % closed
# counter= 1820 : at t = 1.01 hours, pore is 44.44 % closed
# counter= 1830 : at t = 1.02 hours, pore is 44.68 % closed
# counter= 1840 : at t = 1.02 hours, pore is 44.92 % closed
# counter= 1850 : at t = 1.03 hours, pore is 45.15 % closed
# counter= 1860 : at t = 1.03 hours, pore is 45.39 % closed
# counter= 1870 : at t = 1.04 hours, pore is 45.63 % closed
# counter= 1880 : at t = 1.04 hours, pore is 45.87 % closed
# counter= 1890 : at t = 1.05 hours, pore is 46.11 % closed
# counter= 1900 : at t = 1.06 hours, pore is 46.35 % closed
# counter= 1910 : at t = 1.06 hours, pore is 46.59 % closed
# counter= 1920 : at t = 1.07 hours, pore is 46.82 % closed
# counter= 1930 : at t = 1.07 hours, pore is 47.06 % closed
# counter= 1940 : at t = 1.08 hours, pore is 47.3 % closed
# counter= 1950 : at t = 1.08 hours, pore is 47.54 % closed
# counter= 1960 : at t = 1.09 hours, pore is 47.78 % closed
# counter= 1970 : at t = 1.09 hours, pore is 48.02 % closed
# counter= 1980 : at t = 1.1 hours, pore is 48.26 % closed
# counter= 1990 : at t = 1.11 hours, pore is 48.5 % closed
# counter= 2000 : at t = 1.11 hours, pore is 48.73 % closed
# counter= 2010 : at t = 1.12 hours, pore is 48.97 % closed
# counter= 2020 : at t = 1.12 hours, pore is 49.21 % closed
# counter= 2030 : at t = 1.13 hours, pore is 49.45 % closed
# counter= 2040 : at t = 1.13 hours, pore is 49.69 % closed
# counter= 2050 : at t = 1.14 hours, pore is 49.93 % closed
# counter= 2060 : at t = 1.14 hours, pore is 50.17 % closed
# counter= 2070 : at t = 1.15 hours, pore is 50.4 % closed
# counter= 2080 : at t = 1.16 hours, pore is 50.64 % closed
# counter= 2090 : at t = 1.16 hours, pore is 50.88 % closed
# counter= 2100 : at t = 1.17 hours, pore is 51.12 % closed
# counter= 2110 : at t = 1.17 hours, pore is 51.36 % closed
# counter= 2120 : at t = 1.18 hours, pore is 51.6 % closed
# counter= 2130 : at t = 1.18 hours, pore is 51.84 % closed
# counter= 2140 : at t = 1.19 hours, pore is 52.08 % closed
# counter= 2150 : at t = 1.19 hours, pore is 52.31 % closed
# counter= 2160 : at t = 1.2 hours, pore is 52.55 % closed
# counter= 2170 : at t = 1.21 hours, pore is 52.79 % closed
# counter= 2180 : at t = 1.21 hours, pore is 53.03 % closed
# counter= 2190 : at t = 1.22 hours, pore is 53.27 % closed
# counter= 2200 : at t = 1.22 hours, pore is 53.51 % closed
# counter= 2210 : at t = 1.23 hours, pore is 53.75 % closed
# counter= 2220 : at t = 1.23 hours, pore is 53.98 % closed
# counter= 2230 : at t = 1.24 hours, pore is 54.22 % closed
# counter= 2240 : at t = 1.24 hours, pore is 54.46 % closed
# counter= 2250 : at t = 1.25 hours, pore is 54.7 % closed
# counter= 2260 : at t = 1.26 hours, pore is 54.94 % closed
# counter= 2270 : at t = 1.26 hours, pore is 55.18 % closed
# counter= 2280 : at t = 1.27 hours, pore is 55.42 % closed
# counter= 2290 : at t = 1.27 hours, pore is 55.66 % closed
# counter= 2300 : at t = 1.28 hours, pore is 55.89 % closed
# counter= 2310 : at t = 1.28 hours, pore is 56.13 % closed
# counter= 2320 : at t = 1.29 hours, pore is 56.37 % closed
# counter= 2330 : at t = 1.29 hours, pore is 56.61 % closed
# counter= 2340 : at t = 1.3 hours, pore is 56.85 % closed
# counter= 2350 : at t = 1.31 hours, pore is 57.09 % closed
# counter= 2360 : at t = 1.31 hours, pore is 57.33 % closed
# counter= 2370 : at t = 1.32 hours, pore is 57.56 % closed
# counter= 2380 : at t = 1.32 hours, pore is 57.8 % closed
# counter= 2390 : at t = 1.33 hours, pore is 58.04 % closed
# counter= 2400 : at t = 1.33 hours, pore is 58.28 % closed
# counter= 2410 : at t = 1.34 hours, pore is 58.52 % closed
# counter= 2420 : at t = 1.34 hours, pore is 58.76 % closed
# counter= 2430 : at t = 1.35 hours, pore is 59.0 % closed
# counter= 2440 : at t = 1.36 hours, pore is 59.24 % closed
# counter= 2450 : at t = 1.36 hours, pore is 59.47 % closed
# counter= 2460 : at t = 1.37 hours, pore is 59.71 % closed
# counter= 2470 : at t = 1.37 hours, pore is 59.95 % closed
# counter= 2480 : at t = 1.38 hours, pore is 60.19 % closed
# counter= 2490 : at t = 1.38 hours, pore is 60.43 % closed
# counter= 2500 : at t = 1.39 hours, pore is 60.67 % closed
# counter= 2510 : at t = 1.39 hours, pore is 60.91 % closed
# counter= 2520 : at t = 1.4 hours, pore is 61.14 % closed
# counter= 2530 : at t = 1.41 hours, pore is 61.38 % closed
# counter= 2540 : at t = 1.41 hours, pore is 61.62 % closed
# counter= 2550 : at t = 1.42 hours, pore is 61.86 % closed
# counter= 2560 : at t = 1.42 hours, pore is 62.1 % closed
# counter= 2570 : at t = 1.43 hours, pore is 62.34 % closed
# counter= 2580 : at t = 1.43 hours, pore is 62.58 % closed
# counter= 2590 : at t = 1.44 hours, pore is 62.82 % closed
# counter= 2600 : at t = 1.44 hours, pore is 63.05 % closed
# counter= 2610 : at t = 1.45 hours, pore is 63.29 % closed
# counter= 2620 : at t = 1.46 hours, pore is 63.53 % closed
# counter= 2630 : at t = 1.46 hours, pore is 63.77 % closed
# counter= 2640 : at t = 1.47 hours, pore is 64.01 % closed
# counter= 2650 : at t = 1.47 hours, pore is 64.25 % closed
# counter= 2660 : at t = 1.48 hours, pore is 64.49 % closed
# counter= 2670 : at t = 1.48 hours, pore is 64.72 % closed
# counter= 2680 : at t = 1.49 hours, pore is 64.96 % closed
# counter= 2690 : at t = 1.49 hours, pore is 65.2 % closed
# counter= 2700 : at t = 1.5 hours, pore is 65.44 % closed
# counter= 2710 : at t = 1.51 hours, pore is 65.68 % closed
# counter= 2720 : at t = 1.51 hours, pore is 65.92 % closed
# counter= 2730 : at t = 1.52 hours, pore is 66.16 % closed
# counter= 2740 : at t = 1.52 hours, pore is 66.4 % closed
# counter= 2750 : at t = 1.53 hours, pore is 66.63 % closed
# counter= 2760 : at t = 1.53 hours, pore is 66.87 % closed
# counter= 2770 : at t = 1.54 hours, pore is 67.11 % closed
# counter= 2780 : at t = 1.54 hours, pore is 67.35 % closed
# counter= 2790 : at t = 1.55 hours, pore is 67.59 % closed
# counter= 2800 : at t = 1.56 hours, pore is 67.83 % closed
# counter= 2810 : at t = 1.56 hours, pore is 68.07 % closed
# counter= 2820 : at t = 1.57 hours, pore is 68.3 % closed
# counter= 2830 : at t = 1.57 hours, pore is 68.54 % closed
# counter= 2840 : at t = 1.58 hours, pore is 68.78 % closed
# counter= 2850 : at t = 1.58 hours, pore is 69.02 % closed
# counter= 2860 : at t = 1.59 hours, pore is 69.26 % closed
# counter= 2870 : at t = 1.59 hours, pore is 69.5 % closed
# counter= 2880 : at t = 1.6 hours, pore is 69.74 % closed
# counter= 2890 : at t = 1.61 hours, pore is 69.98 % closed
# counter= 2900 : at t = 1.61 hours, pore is 70.21 % closed
# counter= 2910 : at t = 1.62 hours, pore is 70.45 % closed
# counter= 2920 : at t = 1.62 hours, pore is 70.69 % closed
# counter= 2930 : at t = 1.63 hours, pore is 70.93 % closed
# counter= 2940 : at t = 1.63 hours, pore is 71.17 % closed
# counter= 2950 : at t = 1.64 hours, pore is 71.41 % closed
# counter= 2960 : at t = 1.64 hours, pore is 71.65 % closed
# counter= 2970 : at t = 1.65 hours, pore is 71.88 % closed
# counter= 2980 : at t = 1.66 hours, pore is 72.12 % closed
# counter= 2990 : at t = 1.66 hours, pore is 72.36 % closed
# counter= 3000 : at t = 1.67 hours, pore is 72.6 % closed
# counter= 3010 : at t = 1.67 hours, pore is 72.84 % closed
# counter= 3020 : at t = 1.68 hours, pore is 73.08 % closed
# counter= 3030 : at t = 1.68 hours, pore is 73.32 % closed
# counter= 3040 : at t = 1.69 hours, pore is 73.56 % closed
# counter= 3050 : at t = 1.69 hours, pore is 73.79 % closed
# counter= 3060 : at t = 1.7 hours, pore is 74.03 % closed
# counter= 3070 : at t = 1.71 hours, pore is 74.27 % closed
# counter= 3080 : at t = 1.71 hours, pore is 74.51 % closed
# counter= 3090 : at t = 1.72 hours, pore is 74.75 % closed
# counter= 3100 : at t = 1.72 hours, pore is 74.99 % closed
# counter= 3110 : at t = 1.73 hours, pore is 75.23 % closed
# counter= 3120 : at t = 1.73 hours, pore is 75.47 % closed
# counter= 3130 : at t = 1.74 hours, pore is 75.7 % closed
# counter= 3140 : at t = 1.74 hours, pore is 75.94 % closed
# counter= 3150 : at t = 1.75 hours, pore is 76.18 % closed
# counter= 3160 : at t = 1.76 hours, pore is 76.42 % closed
# counter= 3170 : at t = 1.76 hours, pore is 76.66 % closed
# counter= 3180 : at t = 1.77 hours, pore is 76.9 % closed
# counter= 3190 : at t = 1.77 hours, pore is 77.14 % closed
# counter= 3200 : at t = 1.78 hours, pore is 77.37 % closed
# counter= 3210 : at t = 1.78 hours, pore is 77.61 % closed
# counter= 3220 : at t = 1.79 hours, pore is 77.85 % closed
# counter= 3230 : at t = 1.79 hours, pore is 78.09 % closed
# counter= 3240 : at t = 1.8 hours, pore is 78.33 % closed
# counter= 3250 : at t = 1.81 hours, pore is 78.57 % closed
# counter= 3260 : at t = 1.81 hours, pore is 78.81 % closed
# counter= 3270 : at t = 1.82 hours, pore is 79.05 % closed
# counter= 3280 : at t = 1.82 hours, pore is 79.28 % closed
# counter= 3290 : at t = 1.83 hours, pore is 79.52 % closed
# counter= 3300 : at t = 1.83 hours, pore is 79.76 % closed
# counter= 3310 : at t = 1.84 hours, pore is 80.0 % closed
# counter= 3320 : at t = 1.84 hours, pore is 80.24 % closed
# counter= 3330 : at t = 1.85 hours, pore is 80.48 % closed
# counter= 3340 : at t = 1.86 hours, pore is 80.72 % closed
# counter= 3350 : at t = 1.86 hours, pore is 80.95 % closed
# counter= 3360 : at t = 1.87 hours, pore is 81.19 % closed
# counter= 3370 : at t = 1.87 hours, pore is 81.43 % closed
# counter= 3380 : at t = 1.88 hours, pore is 81.67 % closed
# counter= 3390 : at t = 1.88 hours, pore is 81.91 % closed
# counter= 3400 : at t = 1.89 hours, pore is 82.15 % closed
# counter= 3410 : at t = 1.89 hours, pore is 82.39 % closed
# counter= 3420 : at t = 1.9 hours, pore is 82.63 % closed
# counter= 3430 : at t = 1.91 hours, pore is 82.86 % closed
# counter= 3440 : at t = 1.91 hours, pore is 83.1 % closed
# counter= 3450 : at t = 1.92 hours, pore is 83.34 % closed
# counter= 3460 : at t = 1.92 hours, pore is 83.58 % closed
# counter= 3470 : at t = 1.93 hours, pore is 83.82 % closed
# counter= 3480 : at t = 1.93 hours, pore is 84.06 % closed
# counter= 3490 : at t = 1.94 hours, pore is 84.3 % closed
# counter= 3500 : at t = 1.94 hours, pore is 84.53 % closed
# counter= 3510 : at t = 1.95 hours, pore is 84.77 % closed
# counter= 3520 : at t = 1.96 hours, pore is 85.01 % closed
# counter= 3530 : at t = 1.96 hours, pore is 85.25 % closed
# counter= 3540 : at t = 1.97 hours, pore is 85.49 % closed
# counter= 3550 : at t = 1.97 hours, pore is 85.73 % closed
# counter= 3560 : at t = 1.98 hours, pore is 85.97 % closed
# counter= 3570 : at t = 1.98 hours, pore is 86.21 % closed
# counter= 3580 : at t = 1.99 hours, pore is 86.44 % closed
# counter= 3590 : at t = 1.99 hours, pore is 86.68 % closed
# counter= 3600 : at t = 2.0 hours, pore is 86.92 % closed
# counter= 3610 : at t = 2.01 hours, pore is 87.16 % closed
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# counter= 3620 : at t = 2.01 hours, pore is 87.4 % closed
# counter= 3630 : at t = 2.02 hours, pore is 87.64 % closed
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# counter= 3640 : at t = 2.02 hours, pore is 87.88 % closed
# counter= 3650 : at t = 2.03 hours, pore is 88.11 % closed
# counter= 3660 : at t = 2.03 hours, pore is 88.35 % closed
# counter= 3670 : at t = 2.04 hours, pore is 88.59 % closed
# counter= 3680 : at t = 2.04 hours, pore is 88.83 % closed
# counter= 3690 : at t = 2.05 hours, pore is 89.07 % closed
# counter= 3700 : at t = 2.06 hours, pore is 89.31 % closed
# counter= 3710 : at t = 2.06 hours, pore is 89.55 % closed
# counter= 3720 : at t = 2.07 hours, pore is 89.79 % closed
# counter= 3730 : at t = 2.07 hours, pore is 90.02 % closed
# counter= 3740 : at t = 2.08 hours, pore is 90.26 % closed
# counter= 3750 : at t = 2.08 hours, pore is 90.5 % closed
# counter= 3760 : at t = 2.09 hours, pore is 90.74 % closed
# counter= 3770 : at t = 2.09 hours, pore is 90.98 % closed
# counter= 3780 : at t = 2.1 hours, pore is 91.22 % closed
# counter= 3790 : at t = 2.11 hours, pore is 91.46 % closed
# counter= 3800 : at t = 2.11 hours, pore is 91.69 % closed
# counter= 3810 : at t = 2.12 hours, pore is 91.93 % closed
# counter= 3820 : at t = 2.12 hours, pore is 92.17 % closed
# counter= 3830 : at t = 2.13 hours, pore is 92.41 % closed
# counter= 3840 : at t = 2.13 hours, pore is 92.65 % closed
# counter= 3850 : at t = 2.14 hours, pore is 92.89 % closed
# counter= 3860 : at t = 2.14 hours, pore is 93.13 % closed
# counter= 3870 : at t = 2.15 hours, pore is 93.37 % closed
# counter= 3880 : at t = 2.16 hours, pore is 93.6 % closed
# counter= 3890 : at t = 2.16 hours, pore is 93.84 % closed
# counter= 3900 : at t = 2.17 hours, pore is 94.08 % closed
# counter= 3910 : at t = 2.17 hours, pore is 94.32 % closed
# counter= 3920 : at t = 2.18 hours, pore is 94.56 % closed
# counter= 3930 : at t = 2.18 hours, pore is 94.8 % closed
# counter= 3940 : at t = 2.19 hours, pore is 95.04 % closed
# counter= 3950 : at t = 2.19 hours, pore is 95.27 % closed
# counter= 3960 : at t = 2.2 hours, pore is 95.51 % closed
# counter= 3970 : at t = 2.21 hours, pore is 95.75 % closed
# counter= 3980 : at t = 2.21 hours, pore is 95.99 % closed
# counter= 3990 : at t = 2.22 hours, pore is 96.23 % closed
# counter= 4000 : at t = 2.22 hours, pore is 96.47 % closed
# counter= 4010 : at t = 2.23 hours, pore is 96.71 % closed
# counter= 4020 : at t = 2.23 hours, pore is 96.95 % closed
# counter= 4030 : at t = 2.24 hours, pore is 97.18 % closed
# counter= 4040 : at t = 2.24 hours, pore is 97.42 % closed
# counter= 4050 : at t = 2.25 hours, pore is 97.66 % closed
# counter= 4060 : at t = 2.26 hours, pore is 97.9 % closed
# counter= 4070 : at t = 2.26 hours, pore is 98.14 % closed
# counter= 4080 : at t = 2.27 hours, pore is 98.38 % closed
# counter= 4090 : at t = 2.27 hours, pore is 98.62 % closed
# counter= 4100 : at t = 2.28 hours, pore is 98.85 % closed
# counter= 4110 : at t = 2.28 hours, pore is 99.09 % closed
# counter= 4120 : at t = 2.29 hours, pore is 99.33 % closed
# counter= 4130 : at t = 2.29 hours, pore is 99.57 % closed
# counter= 4140 : at t = 2.3 hours, pore is 99.81 % closed
# 4148
# xi= [2.99838950e-05 1.86875825e-03 6.14476818e-03 1.21332058e-02
#  1.87732827e-02 2.56794307e-02 3.26065719e-02 3.96042965e-02
#  4.67138266e-02 5.35832191e-02 5.99900015e-02 6.61593455e-02
#  7.20461166e-02 7.77812060e-02 8.31798040e-02 8.80644424e-02
#  9.25895563e-02 9.67502003e-02 1.00546968e-01 1.03983723e-01
#  1.07067516e-01 1.09804433e-01 1.12198230e-01 1.14247225e-01
#  1.15943626e-01 1.17247666e-01 1.18055804e-01 1.18055804e-01]
# moose input for damage is:  if(y>=7.222222222222222e-05, 2.998389504160136e-05, if(y>=6.944444444444443e-05, 0.0018687582540659756, if(y>=6.666666666666666e-05, 0.006144768182079328, if(y>=6.388888888888888e-05, 0.012133205784968326, if(y>=6.111111111111111e-05, 0.01877328270630179, if(y>=5.8333333333333326e-05, 0.025679430655782997, if(y>=5.555555555555555e-05, 0.03260657192273106, if(y>=5.277777777777777e-05, 0.039604296539419534, if(y>=4.9999999999999996e-05, 0.046713826612860096, if(y>=4.7222222222222214e-05, 0.05358321913089301, if(y>=4.444444444444444e-05, 0.059990001464004676, if(y>=4.1666666666666665e-05, 0.06615934550228603, if(y>=3.8888888888888884e-05, 0.07204611656990742, if(y>=3.611111111111111e-05, 0.0777812059668802, if(y>=3.333333333333333e-05, 0.08317980401600918, if(y>=3.0555555555555554e-05, 0.08806444239391217, if(y>=2.7777777777777776e-05, 0.09258955630908994, if(y>=2.4999999999999998e-05, 0.09675020029924725, if(y>=2.222222222222222e-05, 0.10054696789664294, if(y>=1.9444444444444442e-05, 0.10398372260023526, if(y>=1.6666666666666664e-05, 0.10706751558687388, if(y>=1.3888888888888888e-05, 0.10980443329920396, if(y>=1.111111111111111e-05, 0.11219823028208661, if(y>=8.333333333333332e-06, 0.11424722524516694, if(y>=5.555555555555555e-06, 0.11594362609427611, if(y>=2.7777777777777775e-06, 0.11724766584636802, if(y>=0.0, 0.11805580409764423,  0)))))))))))))))))))))))))))
# khet_fedou= 0.0027786172881957174
# ----------------------------------T= 1273 P= 20000 CMTS0= 0.1717903983288505 CH20= 1.717903983288505 CHCl0= 0
# counter= 10 : at t = 0.0 hours, pore is 1.12 % closed
# counter= 20 : at t = 0.01 hours, pore is 1.24 % closed
# counter= 30 : at t = 0.01 hours, pore is 1.36 % closed
# counter= 40 : at t = 0.01 hours, pore is 1.48 % closed
# counter= 50 : at t = 0.01 hours, pore is 1.6 % closed
# counter= 60 : at t = 0.02 hours, pore is 1.72 % closed
# counter= 70 : at t = 0.02 hours, pore is 1.84 % closed
# counter= 80 : at t = 0.02 hours, pore is 1.95 % closed
# counter= 90 : at t = 0.03 hours, pore is 2.07 % closed
# counter= 100 : at t = 0.03 hours, pore is 2.19 % closed
# counter= 110 : at t = 0.03 hours, pore is 2.31 % closed
# counter= 120 : at t = 0.03 hours, pore is 2.43 % closed
# counter= 130 : at t = 0.04 hours, pore is 2.55 % closed
# counter= 140 : at t = 0.04 hours, pore is 2.67 % closed
# counter= 150 : at t = 0.04 hours, pore is 2.79 % closed
# counter= 160 : at t = 0.04 hours, pore is 2.91 % closed
# counter= 170 : at t = 0.05 hours, pore is 3.03 % closed
# counter= 180 : at t = 0.05 hours, pore is 3.15 % closed
# counter= 190 : at t = 0.05 hours, pore is 3.27 % closed
# counter= 200 : at t = 0.06 hours, pore is 3.39 % closed
# counter= 210 : at t = 0.06 hours, pore is 3.51 % closed
# counter= 220 : at t = 0.06 hours, pore is 3.63 % closed
# counter= 230 : at t = 0.06 hours, pore is 3.74 % closed
# counter= 240 : at t = 0.07 hours, pore is 3.86 % closed
# counter= 250 : at t = 0.07 hours, pore is 3.98 % closed
# counter= 260 : at t = 0.07 hours, pore is 4.1 % closed
# counter= 270 : at t = 0.08 hours, pore is 4.22 % closed
# counter= 280 : at t = 0.08 hours, pore is 4.34 % closed
# counter= 290 : at t = 0.08 hours, pore is 4.46 % closed
# counter= 300 : at t = 0.08 hours, pore is 4.58 % closed
# counter= 310 : at t = 0.09 hours, pore is 4.7 % closed
# counter= 320 : at t = 0.09 hours, pore is 4.82 % closed
# counter= 330 : at t = 0.09 hours, pore is 4.94 % closed
# counter= 340 : at t = 0.09 hours, pore is 5.06 % closed
# counter= 350 : at t = 0.1 hours, pore is 5.18 % closed
# counter= 360 : at t = 0.1 hours, pore is 5.3 % closed
# counter= 370 : at t = 0.1 hours, pore is 5.42 % closed
# counter= 380 : at t = 0.11 hours, pore is 5.53 % closed
# counter= 390 : at t = 0.11 hours, pore is 5.65 % closed
# counter= 400 : at t = 0.11 hours, pore is 5.77 % closed
# counter= 410 : at t = 0.11 hours, pore is 5.89 % closed
# counter= 420 : at t = 0.12 hours, pore is 6.01 % closed
# counter= 430 : at t = 0.12 hours, pore is 6.13 % closed
# counter= 440 : at t = 0.12 hours, pore is 6.25 % closed
# counter= 450 : at t = 0.13 hours, pore is 6.37 % closed
# counter= 460 : at t = 0.13 hours, pore is 6.49 % closed
# counter= 470 : at t = 0.13 hours, pore is 6.61 % closed
# counter= 480 : at t = 0.13 hours, pore is 6.73 % closed
# counter= 490 : at t = 0.14 hours, pore is 6.85 % closed
# counter= 500 : at t = 0.14 hours, pore is 6.97 % closed
# counter= 510 : at t = 0.14 hours, pore is 7.09 % closed
# counter= 520 : at t = 0.14 hours, pore is 7.21 % closed
# counter= 530 : at t = 0.15 hours, pore is 7.32 % closed
# counter= 540 : at t = 0.15 hours, pore is 7.44 % closed
# counter= 550 : at t = 0.15 hours, pore is 7.56 % closed
# counter= 560 : at t = 0.16 hours, pore is 7.68 % closed
# counter= 570 : at t = 0.16 hours, pore is 7.8 % closed
# counter= 580 : at t = 0.16 hours, pore is 7.92 % closed
# counter= 590 : at t = 0.16 hours, pore is 8.04 % closed
# counter= 600 : at t = 0.17 hours, pore is 8.16 % closed
# counter= 610 : at t = 0.17 hours, pore is 8.28 % closed
# counter= 620 : at t = 0.17 hours, pore is 8.4 % closed
# counter= 630 : at t = 0.18 hours, pore is 8.52 % closed
# counter= 640 : at t = 0.18 hours, pore is 8.64 % closed
# counter= 650 : at t = 0.18 hours, pore is 8.76 % closed
# counter= 660 : at t = 0.18 hours, pore is 8.88 % closed
# counter= 670 : at t = 0.19 hours, pore is 9.0 % closed
# counter= 680 : at t = 0.19 hours, pore is 9.11 % closed
# counter= 690 : at t = 0.19 hours, pore is 9.23 % closed
# counter= 700 : at t = 0.19 hours, pore is 9.35 % closed
# counter= 710 : at t = 0.2 hours, pore is 9.47 % closed
# counter= 720 : at t = 0.2 hours, pore is 9.59 % closed
# counter= 730 : at t = 0.2 hours, pore is 9.71 % closed
# counter= 740 : at t = 0.21 hours, pore is 9.83 % closed
# counter= 750 : at t = 0.21 hours, pore is 9.95 % closed
# counter= 760 : at t = 0.21 hours, pore is 10.07 % closed
# counter= 770 : at t = 0.21 hours, pore is 10.19 % closed
# counter= 780 : at t = 0.22 hours, pore is 10.31 % closed
# counter= 790 : at t = 0.22 hours, pore is 10.43 % closed
# counter= 800 : at t = 0.22 hours, pore is 10.55 % closed
# counter= 810 : at t = 0.23 hours, pore is 10.67 % closed
# counter= 820 : at t = 0.23 hours, pore is 10.79 % closed
# counter= 830 : at t = 0.23 hours, pore is 10.9 % closed
# counter= 840 : at t = 0.23 hours, pore is 11.02 % closed
# counter= 850 : at t = 0.24 hours, pore is 11.14 % closed
# counter= 860 : at t = 0.24 hours, pore is 11.26 % closed
# counter= 870 : at t = 0.24 hours, pore is 11.38 % closed
# counter= 880 : at t = 0.24 hours, pore is 11.5 % closed
# counter= 890 : at t = 0.25 hours, pore is 11.62 % closed
# counter= 900 : at t = 0.25 hours, pore is 11.74 % closed
# counter= 910 : at t = 0.25 hours, pore is 11.86 % closed
# counter= 920 : at t = 0.26 hours, pore is 11.98 % closed
# counter= 930 : at t = 0.26 hours, pore is 12.1 % closed
# counter= 940 : at t = 0.26 hours, pore is 12.22 % closed
# counter= 950 : at t = 0.26 hours, pore is 12.34 % closed
# counter= 960 : at t = 0.27 hours, pore is 12.46 % closed
# counter= 970 : at t = 0.27 hours, pore is 12.58 % closed
# counter= 980 : at t = 0.27 hours, pore is 12.69 % closed
# counter= 990 : at t = 0.28 hours, pore is 12.81 % closed
# counter= 1000 : at t = 0.28 hours, pore is 12.93 % closed
# counter= 1010 : at t = 0.28 hours, pore is 13.05 % closed
# counter= 1020 : at t = 0.28 hours, pore is 13.17 % closed
# counter= 1030 : at t = 0.29 hours, pore is 13.29 % closed
# counter= 1040 : at t = 0.29 hours, pore is 13.41 % closed
# counter= 1050 : at t = 0.29 hours, pore is 13.53 % closed
# counter= 1060 : at t = 0.29 hours, pore is 13.65 % closed
# counter= 1070 : at t = 0.3 hours, pore is 13.77 % closed
# counter= 1080 : at t = 0.3 hours, pore is 13.89 % closed
# counter= 1090 : at t = 0.3 hours, pore is 14.01 % closed
# counter= 1100 : at t = 0.31 hours, pore is 14.13 % closed
# counter= 1110 : at t = 0.31 hours, pore is 14.25 % closed
# counter= 1120 : at t = 0.31 hours, pore is 14.37 % closed
# counter= 1130 : at t = 0.31 hours, pore is 14.48 % closed
# counter= 1140 : at t = 0.32 hours, pore is 14.6 % closed
# counter= 1150 : at t = 0.32 hours, pore is 14.72 % closed
# counter= 1160 : at t = 0.32 hours, pore is 14.84 % closed
# counter= 1170 : at t = 0.33 hours, pore is 14.96 % closed
# counter= 1180 : at t = 0.33 hours, pore is 15.08 % closed
# counter= 1190 : at t = 0.33 hours, pore is 15.2 % closed
# counter= 1200 : at t = 0.33 hours, pore is 15.32 % closed
# counter= 1210 : at t = 0.34 hours, pore is 15.44 % closed
# counter= 1220 : at t = 0.34 hours, pore is 15.56 % closed
# counter= 1230 : at t = 0.34 hours, pore is 15.68 % closed
# counter= 1240 : at t = 0.34 hours, pore is 15.8 % closed
# counter= 1250 : at t = 0.35 hours, pore is 15.92 % closed
# counter= 1260 : at t = 0.35 hours, pore is 16.04 % closed
# counter= 1270 : at t = 0.35 hours, pore is 16.16 % closed
# counter= 1280 : at t = 0.36 hours, pore is 16.27 % closed
# counter= 1290 : at t = 0.36 hours, pore is 16.39 % closed
# counter= 1300 : at t = 0.36 hours, pore is 16.51 % closed
# counter= 1310 : at t = 0.36 hours, pore is 16.63 % closed
# counter= 1320 : at t = 0.37 hours, pore is 16.75 % closed
# counter= 1330 : at t = 0.37 hours, pore is 16.87 % closed
# counter= 1340 : at t = 0.37 hours, pore is 16.99 % closed
# counter= 1350 : at t = 0.38 hours, pore is 17.11 % closed
# counter= 1360 : at t = 0.38 hours, pore is 17.23 % closed
# counter= 1370 : at t = 0.38 hours, pore is 17.35 % closed
# counter= 1380 : at t = 0.38 hours, pore is 17.47 % closed
# counter= 1390 : at t = 0.39 hours, pore is 17.59 % closed
# counter= 1400 : at t = 0.39 hours, pore is 17.71 % closed
# counter= 1410 : at t = 0.39 hours, pore is 17.83 % closed
# counter= 1420 : at t = 0.39 hours, pore is 17.95 % closed
# counter= 1430 : at t = 0.4 hours, pore is 18.06 % closed
# counter= 1440 : at t = 0.4 hours, pore is 18.18 % closed
# counter= 1450 : at t = 0.4 hours, pore is 18.3 % closed
# counter= 1460 : at t = 0.41 hours, pore is 18.42 % closed
# counter= 1470 : at t = 0.41 hours, pore is 18.54 % closed
# counter= 1480 : at t = 0.41 hours, pore is 18.66 % closed
# counter= 1490 : at t = 0.41 hours, pore is 18.78 % closed
# counter= 1500 : at t = 0.42 hours, pore is 18.9 % closed
# counter= 1510 : at t = 0.42 hours, pore is 19.02 % closed
# counter= 1520 : at t = 0.42 hours, pore is 19.14 % closed
# counter= 1530 : at t = 0.43 hours, pore is 19.26 % closed
# counter= 1540 : at t = 0.43 hours, pore is 19.38 % closed
# counter= 1550 : at t = 0.43 hours, pore is 19.5 % closed
# counter= 1560 : at t = 0.43 hours, pore is 19.62 % closed
# counter= 1570 : at t = 0.44 hours, pore is 19.74 % closed
# counter= 1580 : at t = 0.44 hours, pore is 19.85 % closed
# counter= 1590 : at t = 0.44 hours, pore is 19.97 % closed
# counter= 1600 : at t = 0.44 hours, pore is 20.09 % closed
# counter= 1610 : at t = 0.45 hours, pore is 20.21 % closed
# counter= 1620 : at t = 0.45 hours, pore is 20.33 % closed
# counter= 1630 : at t = 0.45 hours, pore is 20.45 % closed
# counter= 1640 : at t = 0.46 hours, pore is 20.57 % closed
# counter= 1650 : at t = 0.46 hours, pore is 20.69 % closed
# counter= 1660 : at t = 0.46 hours, pore is 20.81 % closed
# counter= 1670 : at t = 0.46 hours, pore is 20.93 % closed
# counter= 1680 : at t = 0.47 hours, pore is 21.05 % closed
# counter= 1690 : at t = 0.47 hours, pore is 21.17 % closed
# counter= 1700 : at t = 0.47 hours, pore is 21.29 % closed
# counter= 1710 : at t = 0.48 hours, pore is 21.41 % closed
# counter= 1720 : at t = 0.48 hours, pore is 21.53 % closed
# counter= 1730 : at t = 0.48 hours, pore is 21.64 % closed
# counter= 1740 : at t = 0.48 hours, pore is 21.76 % closed
# counter= 1750 : at t = 0.49 hours, pore is 21.88 % closed
# counter= 1760 : at t = 0.49 hours, pore is 22.0 % closed
# counter= 1770 : at t = 0.49 hours, pore is 22.12 % closed
# counter= 1780 : at t = 0.49 hours, pore is 22.24 % closed
# counter= 1790 : at t = 0.5 hours, pore is 22.36 % closed
# counter= 1800 : at t = 0.5 hours, pore is 22.48 % closed
# counter= 1810 : at t = 0.5 hours, pore is 22.6 % closed
# counter= 1820 : at t = 0.51 hours, pore is 22.72 % closed
# counter= 1830 : at t = 0.51 hours, pore is 22.84 % closed
# counter= 1840 : at t = 0.51 hours, pore is 22.96 % closed
# counter= 1850 : at t = 0.51 hours, pore is 23.08 % closed
# counter= 1860 : at t = 0.52 hours, pore is 23.2 % closed
# counter= 1870 : at t = 0.52 hours, pore is 23.32 % closed
# counter= 1880 : at t = 0.52 hours, pore is 23.43 % closed
# counter= 1890 : at t = 0.53 hours, pore is 23.55 % closed
# counter= 1900 : at t = 0.53 hours, pore is 23.67 % closed
# counter= 1910 : at t = 0.53 hours, pore is 23.79 % closed
# counter= 1920 : at t = 0.53 hours, pore is 23.91 % closed
# counter= 1930 : at t = 0.54 hours, pore is 24.03 % closed
# counter= 1940 : at t = 0.54 hours, pore is 24.15 % closed
# counter= 1950 : at t = 0.54 hours, pore is 24.27 % closed
# counter= 1960 : at t = 0.54 hours, pore is 24.39 % closed
# counter= 1970 : at t = 0.55 hours, pore is 24.51 % closed
# counter= 1980 : at t = 0.55 hours, pore is 24.63 % closed
# counter= 1990 : at t = 0.55 hours, pore is 24.75 % closed
# counter= 2000 : at t = 0.56 hours, pore is 24.87 % closed
# counter= 2010 : at t = 0.56 hours, pore is 24.99 % closed
# counter= 2020 : at t = 0.56 hours, pore is 25.11 % closed
# counter= 2030 : at t = 0.56 hours, pore is 25.22 % closed
# counter= 2040 : at t = 0.57 hours, pore is 25.34 % closed
# counter= 2050 : at t = 0.57 hours, pore is 25.46 % closed
# counter= 2060 : at t = 0.57 hours, pore is 25.58 % closed
# counter= 2070 : at t = 0.58 hours, pore is 25.7 % closed
# counter= 2080 : at t = 0.58 hours, pore is 25.82 % closed
# counter= 2090 : at t = 0.58 hours, pore is 25.94 % closed
# counter= 2100 : at t = 0.58 hours, pore is 26.06 % closed
# counter= 2110 : at t = 0.59 hours, pore is 26.18 % closed
# counter= 2120 : at t = 0.59 hours, pore is 26.3 % closed
# counter= 2130 : at t = 0.59 hours, pore is 26.42 % closed
# counter= 2140 : at t = 0.59 hours, pore is 26.54 % closed
# counter= 2150 : at t = 0.6 hours, pore is 26.66 % closed
# counter= 2160 : at t = 0.6 hours, pore is 26.78 % closed
# counter= 2170 : at t = 0.6 hours, pore is 26.9 % closed
# counter= 2180 : at t = 0.61 hours, pore is 27.02 % closed
# counter= 2190 : at t = 0.61 hours, pore is 27.13 % closed
# counter= 2200 : at t = 0.61 hours, pore is 27.25 % closed
# counter= 2210 : at t = 0.61 hours, pore is 27.37 % closed
# counter= 2220 : at t = 0.62 hours, pore is 27.49 % closed
# counter= 2230 : at t = 0.62 hours, pore is 27.61 % closed
# counter= 2240 : at t = 0.62 hours, pore is 27.73 % closed
# counter= 2250 : at t = 0.63 hours, pore is 27.85 % closed
# counter= 2260 : at t = 0.63 hours, pore is 27.97 % closed
# counter= 2270 : at t = 0.63 hours, pore is 28.09 % closed
# counter= 2280 : at t = 0.63 hours, pore is 28.21 % closed
# counter= 2290 : at t = 0.64 hours, pore is 28.33 % closed
# counter= 2300 : at t = 0.64 hours, pore is 28.45 % closed
# counter= 2310 : at t = 0.64 hours, pore is 28.57 % closed
# counter= 2320 : at t = 0.64 hours, pore is 28.69 % closed
# counter= 2330 : at t = 0.65 hours, pore is 28.81 % closed
# counter= 2340 : at t = 0.65 hours, pore is 28.92 % closed
# counter= 2350 : at t = 0.65 hours, pore is 29.04 % closed
# counter= 2360 : at t = 0.66 hours, pore is 29.16 % closed
# counter= 2370 : at t = 0.66 hours, pore is 29.28 % closed
# counter= 2380 : at t = 0.66 hours, pore is 29.4 % closed
# counter= 2390 : at t = 0.66 hours, pore is 29.52 % closed
# counter= 2400 : at t = 0.67 hours, pore is 29.64 % closed
# counter= 2410 : at t = 0.67 hours, pore is 29.76 % closed
# counter= 2420 : at t = 0.67 hours, pore is 29.88 % closed
# counter= 2430 : at t = 0.68 hours, pore is 30.0 % closed
# counter= 2440 : at t = 0.68 hours, pore is 30.12 % closed
# counter= 2450 : at t = 0.68 hours, pore is 30.24 % closed
# counter= 2460 : at t = 0.68 hours, pore is 30.36 % closed
# counter= 2470 : at t = 0.69 hours, pore is 30.48 % closed
# counter= 2480 : at t = 0.69 hours, pore is 30.6 % closed
# counter= 2490 : at t = 0.69 hours, pore is 30.71 % closed
# counter= 2500 : at t = 0.69 hours, pore is 30.83 % closed
# counter= 2510 : at t = 0.7 hours, pore is 30.95 % closed
# counter= 2520 : at t = 0.7 hours, pore is 31.07 % closed
# counter= 2530 : at t = 0.7 hours, pore is 31.19 % closed
# counter= 2540 : at t = 0.71 hours, pore is 31.31 % closed
# counter= 2550 : at t = 0.71 hours, pore is 31.43 % closed
# counter= 2560 : at t = 0.71 hours, pore is 31.55 % closed
# counter= 2570 : at t = 0.71 hours, pore is 31.67 % closed
# counter= 2580 : at t = 0.72 hours, pore is 31.79 % closed
# counter= 2590 : at t = 0.72 hours, pore is 31.91 % closed
# counter= 2600 : at t = 0.72 hours, pore is 32.03 % closed
# counter= 2610 : at t = 0.73 hours, pore is 32.15 % closed
# counter= 2620 : at t = 0.73 hours, pore is 32.27 % closed
# counter= 2630 : at t = 0.73 hours, pore is 32.39 % closed
# counter= 2640 : at t = 0.73 hours, pore is 32.5 % closed
# counter= 2650 : at t = 0.74 hours, pore is 32.62 % closed
# counter= 2660 : at t = 0.74 hours, pore is 32.74 % closed
# counter= 2670 : at t = 0.74 hours, pore is 32.86 % closed
# counter= 2680 : at t = 0.74 hours, pore is 32.98 % closed
# counter= 2690 : at t = 0.75 hours, pore is 33.1 % closed
# counter= 2700 : at t = 0.75 hours, pore is 33.22 % closed
# counter= 2710 : at t = 0.75 hours, pore is 33.34 % closed
# counter= 2720 : at t = 0.76 hours, pore is 33.46 % closed
# counter= 2730 : at t = 0.76 hours, pore is 33.58 % closed
# counter= 2740 : at t = 0.76 hours, pore is 33.7 % closed
# counter= 2750 : at t = 0.76 hours, pore is 33.82 % closed
# counter= 2760 : at t = 0.77 hours, pore is 33.94 % closed
# counter= 2770 : at t = 0.77 hours, pore is 34.06 % closed
# counter= 2780 : at t = 0.77 hours, pore is 34.18 % closed
# counter= 2790 : at t = 0.78 hours, pore is 34.29 % closed
# counter= 2800 : at t = 0.78 hours, pore is 34.41 % closed
# counter= 2810 : at t = 0.78 hours, pore is 34.53 % closed
# counter= 2820 : at t = 0.78 hours, pore is 34.65 % closed
# counter= 2830 : at t = 0.79 hours, pore is 34.77 % closed
# counter= 2840 : at t = 0.79 hours, pore is 34.89 % closed
# counter= 2850 : at t = 0.79 hours, pore is 35.01 % closed
# counter= 2860 : at t = 0.79 hours, pore is 35.13 % closed
# counter= 2870 : at t = 0.8 hours, pore is 35.25 % closed
# counter= 2880 : at t = 0.8 hours, pore is 35.37 % closed
# counter= 2890 : at t = 0.8 hours, pore is 35.49 % closed
# counter= 2900 : at t = 0.81 hours, pore is 35.61 % closed
# counter= 2910 : at t = 0.81 hours, pore is 35.73 % closed
# counter= 2920 : at t = 0.81 hours, pore is 35.85 % closed
# counter= 2930 : at t = 0.81 hours, pore is 35.97 % closed
# counter= 2940 : at t = 0.82 hours, pore is 36.08 % closed
# counter= 2950 : at t = 0.82 hours, pore is 36.2 % closed
# counter= 2960 : at t = 0.82 hours, pore is 36.32 % closed
# counter= 2970 : at t = 0.83 hours, pore is 36.44 % closed
# counter= 2980 : at t = 0.83 hours, pore is 36.56 % closed
# counter= 2990 : at t = 0.83 hours, pore is 36.68 % closed
# counter= 3000 : at t = 0.83 hours, pore is 36.8 % closed
# counter= 3010 : at t = 0.84 hours, pore is 36.92 % closed
# counter= 3020 : at t = 0.84 hours, pore is 37.04 % closed
# counter= 3030 : at t = 0.84 hours, pore is 37.16 % closed
# counter= 3040 : at t = 0.84 hours, pore is 37.28 % closed
# counter= 3050 : at t = 0.85 hours, pore is 37.4 % closed
# counter= 3060 : at t = 0.85 hours, pore is 37.52 % closed
# counter= 3070 : at t = 0.85 hours, pore is 37.64 % closed
# counter= 3080 : at t = 0.86 hours, pore is 37.76 % closed
# counter= 3090 : at t = 0.86 hours, pore is 37.87 % closed
# counter= 3100 : at t = 0.86 hours, pore is 37.99 % closed
# counter= 3110 : at t = 0.86 hours, pore is 38.11 % closed
# counter= 3120 : at t = 0.87 hours, pore is 38.23 % closed
# counter= 3130 : at t = 0.87 hours, pore is 38.35 % closed
# counter= 3140 : at t = 0.87 hours, pore is 38.47 % closed
# counter= 3150 : at t = 0.88 hours, pore is 38.59 % closed
# counter= 3160 : at t = 0.88 hours, pore is 38.71 % closed
# counter= 3170 : at t = 0.88 hours, pore is 38.83 % closed
# counter= 3180 : at t = 0.88 hours, pore is 38.95 % closed
# counter= 3190 : at t = 0.89 hours, pore is 39.07 % closed
# counter= 3200 : at t = 0.89 hours, pore is 39.19 % closed
# counter= 3210 : at t = 0.89 hours, pore is 39.31 % closed
# counter= 3220 : at t = 0.89 hours, pore is 39.43 % closed
# counter= 3230 : at t = 0.9 hours, pore is 39.55 % closed
# counter= 3240 : at t = 0.9 hours, pore is 39.66 % closed
# counter= 3250 : at t = 0.9 hours, pore is 39.78 % closed
# counter= 3260 : at t = 0.91 hours, pore is 39.9 % closed
# counter= 3270 : at t = 0.91 hours, pore is 40.02 % closed
# counter= 3280 : at t = 0.91 hours, pore is 40.14 % closed
# counter= 3290 : at t = 0.91 hours, pore is 40.26 % closed
# counter= 3300 : at t = 0.92 hours, pore is 40.38 % closed
# counter= 3310 : at t = 0.92 hours, pore is 40.5 % closed
# counter= 3320 : at t = 0.92 hours, pore is 40.62 % closed
# counter= 3330 : at t = 0.93 hours, pore is 40.74 % closed
# counter= 3340 : at t = 0.93 hours, pore is 40.86 % closed
# counter= 3350 : at t = 0.93 hours, pore is 40.98 % closed
# counter= 3360 : at t = 0.93 hours, pore is 41.1 % closed
# counter= 3370 : at t = 0.94 hours, pore is 41.22 % closed
# counter= 3380 : at t = 0.94 hours, pore is 41.34 % closed
# counter= 3390 : at t = 0.94 hours, pore is 41.45 % closed
# counter= 3400 : at t = 0.94 hours, pore is 41.57 % closed
# counter= 3410 : at t = 0.95 hours, pore is 41.69 % closed
# counter= 3420 : at t = 0.95 hours, pore is 41.81 % closed
# counter= 3430 : at t = 0.95 hours, pore is 41.93 % closed
# counter= 3440 : at t = 0.96 hours, pore is 42.05 % closed
# counter= 3450 : at t = 0.96 hours, pore is 42.17 % closed
# counter= 3460 : at t = 0.96 hours, pore is 42.29 % closed
# counter= 3470 : at t = 0.96 hours, pore is 42.41 % closed
# counter= 3480 : at t = 0.97 hours, pore is 42.53 % closed
# counter= 3490 : at t = 0.97 hours, pore is 42.65 % closed
# counter= 3500 : at t = 0.97 hours, pore is 42.77 % closed
# counter= 3510 : at t = 0.98 hours, pore is 42.89 % closed
# counter= 3520 : at t = 0.98 hours, pore is 43.01 % closed
# counter= 3530 : at t = 0.98 hours, pore is 43.13 % closed
# counter= 3540 : at t = 0.98 hours, pore is 43.24 % closed
# counter= 3550 : at t = 0.99 hours, pore is 43.36 % closed
# counter= 3560 : at t = 0.99 hours, pore is 43.48 % closed
# counter= 3570 : at t = 0.99 hours, pore is 43.6 % closed
# counter= 3580 : at t = 0.99 hours, pore is 43.72 % closed
# counter= 3590 : at t = 1.0 hours, pore is 43.84 % closed
# counter= 3600 : at t = 1.0 hours, pore is 43.96 % closed
# counter= 3610 : at t = 1.0 hours, pore is 44.08 % closed
# counter= 3620 : at t = 1.01 hours, pore is 44.2 % closed
# counter= 3630 : at t = 1.01 hours, pore is 44.32 % closed
# counter= 3640 : at t = 1.01 hours, pore is 44.44 % closed
# counter= 3650 : at t = 1.01 hours, pore is 44.56 % closed
# counter= 3660 : at t = 1.02 hours, pore is 44.68 % closed
# counter= 3670 : at t = 1.02 hours, pore is 44.8 % closed
# counter= 3680 : at t = 1.02 hours, pore is 44.92 % closed
# counter= 3690 : at t = 1.03 hours, pore is 45.03 % closed
# counter= 3700 : at t = 1.03 hours, pore is 45.15 % closed
# counter= 3710 : at t = 1.03 hours, pore is 45.27 % closed
# counter= 3720 : at t = 1.03 hours, pore is 45.39 % closed
# counter= 3730 : at t = 1.04 hours, pore is 45.51 % closed
# counter= 3740 : at t = 1.04 hours, pore is 45.63 % closed
# counter= 3750 : at t = 1.04 hours, pore is 45.75 % closed
# ...
# counter= 14200 : at t = 1.97 hours, pore is 85.73 % closed
# counter= 14210 : at t = 1.97 hours, pore is 85.79 % closed
# counter= 14220 : at t = 1.98 hours, pore is 85.85 % closed
# counter= 14230 : at t = 1.98 hours, pore is 85.91 % closed
# counter= 14240 : at t = 1.98 hours, pore is 85.97 % closed
# counter= 14250 : at t = 1.98 hours, pore is 86.03 % closed
# counter= 14260 : at t = 1.98 hours, pore is 86.09 % closed
# counter= 14270 : at t = 1.98 hours, pore is 86.15 % closed
# counter= 14280 : at t = 1.98 hours, pore is 86.21 % closed
# counter= 14290 : at t = 1.98 hours, pore is 86.26 % closed
# counter= 14300 : at t = 1.99 hours, pore is 86.32 % closed
# counter= 14310 : at t = 1.99 hours, pore is 86.38 % closed
# counter= 14320 : at t = 1.99 hours, pore is 86.44 % closed
# counter= 14330 : at t = 1.99 hours, pore is 86.5 % closed
# counter= 14340 : at t = 1.99 hours, pore is 86.56 % closed
# counter= 14350 : at t = 1.99 hours, pore is 86.62 % closed
# counter= 14360 : at t = 1.99 hours, pore is 86.68 % closed
# counter= 14370 : at t = 2.0 hours, pore is 86.74 % closed
# counter= 14380 : at t = 2.0 hours, pore is 86.8 % closed
# counter= 14390 : at t = 2.0 hours, pore is 86.86 % closed
# counter= 14400 : at t = 2.0 hours, pore is 86.92 % closed
# counter= 14410 : at t = 2.0 hours, pore is 86.98 % closed
# counter= 14420 : at t = 2.0 hours, pore is 87.04 % closed
# counter= 14430 : at t = 2.0 hours, pore is 87.1 % closed
# counter= 14440 : at t = 2.01 hours, pore is 87.16 % closed
# counter= 14450 : at t = 2.01 hours, pore is 87.22 % closed
# counter= 14460 : at t = 2.01 hours, pore is 87.28 % closed
# counter= 14470 : at t = 2.01 hours, pore is 87.34 % closed
# counter= 14480 : at t = 2.01 hours, pore is 87.4 % closed
# counter= 14490 : at t = 2.01 hours, pore is 87.46 % closed
# counter= 14500 : at t = 2.01 hours, pore is 87.52 % closed
# counter= 14510 : at t = 2.02 hours, pore is 87.58 % closed
# counter= 14520 : at t = 2.02 hours, pore is 87.64 % closed
# counter= 14530 : at t = 2.02 hours, pore is 87.7 % closed
# counter= 14540 : at t = 2.02 hours, pore is 87.76 % closed
# counter= 14550 : at t = 2.02 hours, pore is 87.82 % closed
# counter= 14560 : at t = 2.02 hours, pore is 87.88 % closed
# counter= 14570 : at t = 2.02 hours, pore is 87.94 % closed
# counter= 14580 : at t = 2.03 hours, pore is 88.0 % closed
# counter= 14590 : at t = 2.03 hours, pore is 88.05 % closed
# counter= 14600 : at t = 2.03 hours, pore is 88.11 % closed
# counter= 14610 : at t = 2.03 hours, pore is 88.17 % closed
# counter= 14620 : at t = 2.03 hours, pore is 88.23 % closed
# counter= 14630 : at t = 2.03 hours, pore is 88.29 % closed
# counter= 14640 : at t = 2.03 hours, pore is 88.35 % closed
# counter= 14650 : at t = 2.03 hours, pore is 88.41 % closed
# counter= 14660 : at t = 2.04 hours, pore is 88.47 % closed
# counter= 14670 : at t = 2.04 hours, pore is 88.53 % closed
# counter= 14680 : at t = 2.04 hours, pore is 88.59 % closed
# counter= 14690 : at t = 2.04 hours, pore is 88.65 % closed
# counter= 14700 : at t = 2.04 hours, pore is 88.71 % closed
# counter= 14710 : at t = 2.04 hours, pore is 88.77 % closed
# counter= 14720 : at t = 2.04 hours, pore is 88.83 % closed
# counter= 14730 : at t = 2.05 hours, pore is 88.89 % closed
# counter= 14740 : at t = 2.05 hours, pore is 88.95 % closed
# counter= 14750 : at t = 2.05 hours, pore is 89.01 % closed
# counter= 14760 : at t = 2.05 hours, pore is 89.07 % closed
# counter= 14770 : at t = 2.05 hours, pore is 89.13 % closed
# counter= 14780 : at t = 2.05 hours, pore is 89.19 % closed
# counter= 14790 : at t = 2.05 hours, pore is 89.25 % closed
# counter= 14800 : at t = 2.06 hours, pore is 89.31 % closed
# counter= 14810 : at t = 2.06 hours, pore is 89.37 % closed
# counter= 14820 : at t = 2.06 hours, pore is 89.43 % closed
# counter= 14830 : at t = 2.06 hours, pore is 89.49 % closed
# counter= 14840 : at t = 2.06 hours, pore is 89.55 % closed
# counter= 14850 : at t = 2.06 hours, pore is 89.61 % closed
# counter= 14860 : at t = 2.06 hours, pore is 89.67 % closed
# counter= 14870 : at t = 2.07 hours, pore is 89.73 % closed
# counter= 14880 : at t = 2.07 hours, pore is 89.79 % closed
# counter= 14890 : at t = 2.07 hours, pore is 89.84 % closed
# counter= 14900 : at t = 2.07 hours, pore is 89.9 % closed
# counter= 14910 : at t = 2.07 hours, pore is 89.96 % closed
# counter= 14920 : at t = 2.07 hours, pore is 90.02 % closed
# counter= 14930 : at t = 2.07 hours, pore is 90.08 % closed
# counter= 14940 : at t = 2.08 hours, pore is 90.14 % closed
# counter= 14950 : at t = 2.08 hours, pore is 90.2 % closed
# counter= 14960 : at t = 2.08 hours, pore is 90.26 % closed
# counter= 14970 : at t = 2.08 hours, pore is 90.32 % closed
# counter= 14980 : at t = 2.08 hours, pore is 90.38 % closed
# counter= 14990 : at t = 2.08 hours, pore is 90.44 % closed
# counter= 15000 : at t = 2.08 hours, pore is 90.5 % closed
# counter= 15010 : at t = 2.08 hours, pore is 90.56 % closed
# counter= 15020 : at t = 2.09 hours, pore is 90.62 % closed
# counter= 15030 : at t = 2.09 hours, pore is 90.68 % closed
# counter= 15040 : at t = 2.09 hours, pore is 90.74 % closed
# counter= 15050 : at t = 2.09 hours, pore is 90.8 % closed
# counter= 15060 : at t = 2.09 hours, pore is 90.86 % closed
# counter= 15070 : at t = 2.09 hours, pore is 90.92 % closed
# counter= 15080 : at t = 2.09 hours, pore is 90.98 % closed
# counter= 15090 : at t = 2.1 hours, pore is 91.04 % closed
# counter= 15100 : at t = 2.1 hours, pore is 91.1 % closed
# counter= 15110 : at t = 2.1 hours, pore is 91.16 % closed
# counter= 15120 : at t = 2.1 hours, pore is 91.22 % closed
# counter= 15130 : at t = 2.1 hours, pore is 91.28 % closed
# counter= 15140 : at t = 2.1 hours, pore is 91.34 % closed
# counter= 15150 : at t = 2.1 hours, pore is 91.4 % closed
# counter= 15160 : at t = 2.11 hours, pore is 91.46 % closed
# counter= 15170 : at t = 2.11 hours, pore is 91.52 % closed
# counter= 15180 : at t = 2.11 hours, pore is 91.58 % closed
# counter= 15190 : at t = 2.11 hours, pore is 91.63 % closed
# counter= 15200 : at t = 2.11 hours, pore is 91.69 % closed
# counter= 15210 : at t = 2.11 hours, pore is 91.75 % closed
# counter= 15220 : at t = 2.11 hours, pore is 91.81 % closed
# counter= 15230 : at t = 2.12 hours, pore is 91.87 % closed
# counter= 15240 : at t = 2.12 hours, pore is 91.93 % closed
# counter= 15250 : at t = 2.12 hours, pore is 91.99 % closed
# counter= 15260 : at t = 2.12 hours, pore is 92.05 % closed
# counter= 15270 : at t = 2.12 hours, pore is 92.11 % closed
# counter= 15280 : at t = 2.12 hours, pore is 92.17 % closed
# counter= 15290 : at t = 2.12 hours, pore is 92.23 % closed
# counter= 15300 : at t = 2.13 hours, pore is 92.29 % closed
# counter= 15310 : at t = 2.13 hours, pore is 92.35 % closed
# counter= 15320 : at t = 2.13 hours, pore is 92.41 % closed
# counter= 15330 : at t = 2.13 hours, pore is 92.47 % closed
# counter= 15340 : at t = 2.13 hours, pore is 92.53 % closed
# counter= 15350 : at t = 2.13 hours, pore is 92.59 % closed
# counter= 15360 : at t = 2.13 hours, pore is 92.65 % closed
# counter= 15370 : at t = 2.13 hours, pore is 92.71 % closed
# counter= 15380 : at t = 2.14 hours, pore is 92.77 % closed
# counter= 15390 : at t = 2.14 hours, pore is 92.83 % closed
# counter= 15400 : at t = 2.14 hours, pore is 92.89 % closed
# counter= 15410 : at t = 2.14 hours, pore is 92.95 % closed
# counter= 15420 : at t = 2.14 hours, pore is 93.01 % closed
# counter= 15430 : at t = 2.14 hours, pore is 93.07 % closed
# counter= 15440 : at t = 2.14 hours, pore is 93.13 % closed
# counter= 15450 : at t = 2.15 hours, pore is 93.19 % closed
# counter= 15460 : at t = 2.15 hours, pore is 93.25 % closed
# counter= 15470 : at t = 2.15 hours, pore is 93.31 % closed
# counter= 15480 : at t = 2.15 hours, pore is 93.37 % closed
# counter= 15490 : at t = 2.15 hours, pore is 93.42 % closed
# counter= 15500 : at t = 2.15 hours, pore is 93.48 % closed
# counter= 15510 : at t = 2.15 hours, pore is 93.54 % closed
# counter= 15520 : at t = 2.16 hours, pore is 93.6 % closed
# counter= 15530 : at t = 2.16 hours, pore is 93.66 % closed
# counter= 15540 : at t = 2.16 hours, pore is 93.72 % closed
# counter= 15550 : at t = 2.16 hours, pore is 93.78 % closed
# counter= 15560 : at t = 2.16 hours, pore is 93.84 % closed
# counter= 15570 : at t = 2.16 hours, pore is 93.9 % closed
# counter= 15580 : at t = 2.16 hours, pore is 93.96 % closed
# counter= 15590 : at t = 2.17 hours, pore is 94.02 % closed
# counter= 15600 : at t = 2.17 hours, pore is 94.08 % closed
# counter= 15610 : at t = 2.17 hours, pore is 94.14 % closed
# counter= 15620 : at t = 2.17 hours, pore is 94.2 % closed
# counter= 15630 : at t = 2.17 hours, pore is 94.26 % closed
# counter= 15640 : at t = 2.17 hours, pore is 94.32 % closed
# counter= 15650 : at t = 2.17 hours, pore is 94.38 % closed
# counter= 15660 : at t = 2.18 hours, pore is 94.44 % closed
# counter= 15670 : at t = 2.18 hours, pore is 94.5 % closed
# counter= 15680 : at t = 2.18 hours, pore is 94.56 % closed
# counter= 15690 : at t = 2.18 hours, pore is 94.62 % closed
# counter= 15700 : at t = 2.18 hours, pore is 94.68 % closed
# counter= 15710 : at t = 2.18 hours, pore is 94.74 % closed
# counter= 15720 : at t = 2.18 hours, pore is 94.8 % closed
# counter= 15730 : at t = 2.18 hours, pore is 94.86 % closed
# counter= 15740 : at t = 2.19 hours, pore is 94.92 % closed
# counter= 15750 : at t = 2.19 hours, pore is 94.98 % closed
# counter= 15760 : at t = 2.19 hours, pore is 95.04 % closed
# counter= 15770 : at t = 2.19 hours, pore is 95.1 % closed
# counter= 15780 : at t = 2.19 hours, pore is 95.16 % closed
# counter= 15790 : at t = 2.19 hours, pore is 95.21 % closed
# counter= 15800 : at t = 2.19 hours, pore is 95.27 % closed
# counter= 15810 : at t = 2.2 hours, pore is 95.33 % closed
# counter= 15820 : at t = 2.2 hours, pore is 95.39 % closed
# counter= 15830 : at t = 2.2 hours, pore is 95.45 % closed
# counter= 15840 : at t = 2.2 hours, pore is 95.51 % closed
# counter= 15850 : at t = 2.2 hours, pore is 95.57 % closed
# counter= 15860 : at t = 2.2 hours, pore is 95.63 % closed
# counter= 15870 : at t = 2.2 hours, pore is 95.69 % closed
# counter= 15880 : at t = 2.21 hours, pore is 95.75 % closed
# counter= 15890 : at t = 2.21 hours, pore is 95.81 % closed
# counter= 15900 : at t = 2.21 hours, pore is 95.87 % closed
# counter= 15910 : at t = 2.21 hours, pore is 95.93 % closed
# counter= 15920 : at t = 2.21 hours, pore is 95.99 % closed
# counter= 15930 : at t = 2.21 hours, pore is 96.05 % closed
# counter= 15940 : at t = 2.21 hours, pore is 96.11 % closed
# counter= 15950 : at t = 2.22 hours, pore is 96.17 % closed
# counter= 15960 : at t = 2.22 hours, pore is 96.23 % closed
# counter= 15970 : at t = 2.22 hours, pore is 96.29 % closed
# counter= 15980 : at t = 2.22 hours, pore is 96.35 % closed
# counter= 15990 : at t = 2.22 hours, pore is 96.41 % closed
# counter= 16000 : at t = 2.22 hours, pore is 96.47 % closed
# counter= 16010 : at t = 2.22 hours, pore is 96.53 % closed
# counter= 16020 : at t = 2.23 hours, pore is 96.59 % closed
# counter= 16030 : at t = 2.23 hours, pore is 96.65 % closed
# counter= 16040 : at t = 2.23 hours, pore is 96.71 % closed
# counter= 16050 : at t = 2.23 hours, pore is 96.77 % closed
# counter= 16060 : at t = 2.23 hours, pore is 96.83 % closed
# counter= 16070 : at t = 2.23 hours, pore is 96.89 % closed
# counter= 16080 : at t = 2.23 hours, pore is 96.95 % closed
# counter= 16090 : at t = 2.23 hours, pore is 97.0 % closed
# counter= 16100 : at t = 2.24 hours, pore is 97.06 % closed
# counter= 16110 : at t = 2.24 hours, pore is 97.12 % closed
# counter= 16120 : at t = 2.24 hours, pore is 97.18 % closed
# counter= 16130 : at t = 2.24 hours, pore is 97.24 % closed
# counter= 16140 : at t = 2.24 hours, pore is 97.3 % closed
# counter= 16150 : at t = 2.24 hours, pore is 97.36 % closed
# counter= 16160 : at t = 2.24 hours, pore is 97.42 % closed
# counter= 16170 : at t = 2.25 hours, pore is 97.48 % closed
# counter= 16180 : at t = 2.25 hours, pore is 97.54 % closed
# counter= 16190 : at t = 2.25 hours, pore is 97.6 % closed
# counter= 16200 : at t = 2.25 hours, pore is 97.66 % closed
# counter= 16210 : at t = 2.25 hours, pore is 97.72 % closed
# counter= 16220 : at t = 2.25 hours, pore is 97.78 % closed
# counter= 16230 : at t = 2.25 hours, pore is 97.84 % closed
# counter= 16240 : at t = 2.26 hours, pore is 97.9 % closed
# counter= 16250 : at t = 2.26 hours, pore is 97.96 % closed
# counter= 16260 : at t = 2.26 hours, pore is 98.02 % closed
# counter= 16270 : at t = 2.26 hours, pore is 98.08 % closed
# counter= 16280 : at t = 2.26 hours, pore is 98.14 % closed
# counter= 16290 : at t = 2.26 hours, pore is 98.2 % closed
# counter= 16300 : at t = 2.26 hours, pore is 98.26 % closed
# counter= 16310 : at t = 2.27 hours, pore is 98.32 % closed
# counter= 16320 : at t = 2.27 hours, pore is 98.38 % closed
# counter= 16330 : at t = 2.27 hours, pore is 98.44 % closed
# counter= 16340 : at t = 2.27 hours, pore is 98.5 % closed
# counter= 16350 : at t = 2.27 hours, pore is 98.56 % closed
# counter= 16360 : at t = 2.27 hours, pore is 98.62 % closed
# counter= 16370 : at t = 2.27 hours, pore is 98.68 % closed
# counter= 16380 : at t = 2.28 hours, pore is 98.74 % closed
# counter= 16390 : at t = 2.28 hours, pore is 98.79 % closed
# counter= 16400 : at t = 2.28 hours, pore is 98.85 % closed
# counter= 16410 : at t = 2.28 hours, pore is 98.91 % closed
# counter= 16420 : at t = 2.28 hours, pore is 98.97 % closed
# counter= 16430 : at t = 2.28 hours, pore is 99.03 % closed
# counter= 16440 : at t = 2.28 hours, pore is 99.09 % closed
# counter= 16450 : at t = 2.28 hours, pore is 99.15 % closed
# counter= 16460 : at t = 2.29 hours, pore is 99.21 % closed
# counter= 16470 : at t = 2.29 hours, pore is 99.27 % closed
# counter= 16480 : at t = 2.29 hours, pore is 99.33 % closed
# counter= 16490 : at t = 2.29 hours, pore is 99.39 % closed
# counter= 16500 : at t = 2.29 hours, pore is 99.45 % closed
# counter= 16510 : at t = 2.29 hours, pore is 99.51 % closed
# counter= 16520 : at t = 2.29 hours, pore is 99.57 % closed
# counter= 16530 : at t = 2.3 hours, pore is 99.63 % closed
# counter= 16540 : at t = 2.3 hours, pore is 99.69 % closed
# counter= 16550 : at t = 2.3 hours, pore is 99.75 % closed
# counter= 16560 : at t = 2.3 hours, pore is 99.81 % closed
# counter= 16570 : at t = 2.3 hours, pore is 99.87 % closed
# counter= 16580 : at t = 2.3 hours, pore is 99.93 % closed
# counter= 16590 : at t = 2.3 hours, pore is 99.99 % closed
# 16592
# xi= [2.99838950e-05 1.88454767e-03 5.60101240e-03 1.05036661e-02
#  1.61531968e-02 2.24257031e-02 2.90493477e-02 3.58029472e-02
#  4.27180664e-02 4.94944785e-02 5.61810760e-02 6.28580341e-02
#  6.92479766e-02 7.52701673e-02 8.10000386e-02 8.64047243e-02
#  9.14574133e-02 9.61363925e-02 1.00425327e-01 1.04316178e-01
#  1.07802906e-01 1.10815558e-01 1.13324732e-01 1.15361195e-01
#  1.16912456e-01 1.17974812e-01 1.18527729e-01 1.18527729e-01]
# moose input for damage is:  if(y>=7.222222222222222e-05, 2.998389503954122e-05, if(y>=6.944444444444443e-05, 0.0018845476707300794, if(y>=6.666666666666666e-05, 0.005601012401510866, if(y>=6.388888888888888e-05, 0.010503666133410515, if(y>=6.111111111111111e-05, 0.016153196777004983, if(y>=5.8333333333333326e-05, 0.022425703051299282, if(y>=5.555555555555555e-05, 0.029049347700755238, if(y>=5.277777777777777e-05, 0.03580294722390833, if(y>=4.9999999999999996e-05, 0.042718066405972276, if(y>=4.7222222222222214e-05, 0.04949447848193805, if(y>=4.444444444444444e-05, 0.05618107602680116, if(y>=4.1666666666666665e-05, 0.06285803409416635, if(y>=3.8888888888888884e-05, 0.06924797658584966, if(y>=3.611111111111111e-05, 0.07527016727189455, if(y>=3.333333333333333e-05, 0.08100003858859478, if(y>=3.0555555555555554e-05, 0.08640472434264083, if(y>=2.7777777777777776e-05, 0.09145741329182218, if(y>=2.4999999999999998e-05, 0.09613639247866529, if(y>=2.222222222222222e-05, 0.10042532708599615, if(y>=1.9444444444444442e-05, 0.10431617838635325, if(y>=1.6666666666666664e-05, 0.10780290622695625, if(y>=1.3888888888888888e-05, 0.11081555754070742, if(y>=1.111111111111111e-05, 0.11332473177871853, if(y>=8.333333333333332e-06, 0.11536119500801935, if(y>=5.555555555555555e-06, 0.1169124557934884, if(y>=2.7777777777777775e-06, 0.11797481242951481, if(y>=0.0, 0.11852772868597783,  0)))))))))))))))))))))))))))

# %%
fig, ax = plt.subplots(figsize = (5,2.7), layout='constrained')
# a[-1]=a[-1]*3600
# ax.plot(np.linspace(0,5,5),np.ones(5)*0.3,color='black',linestyle='--',label='Initial')
ax.plot(a[0]*1e3,a[5]*1e6,label='dt 2',color='black',linewidth=3)
ax.plot(b[0]*1e3,b[5]*1e6,label='dt 1',color='red',linewidth=3)
ax.plot(c[0]*1e3,c[5]*1e6,label='dt 0.5',color='green',linewidth=3)
plt.xlim([0,5])
plt.ylim([0,50])
ax.set_xlabel('z mm')
ax.set_ylabel(r'$d \mu$ m')
ax.set_title(r'$\xi_0 = 0.30, \ \alpha=10$') 
plt.yticks(np.arange(0, 60, step=10))
plt.xticks(np.arange(0, 6, step=1))
ax.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.savefig('FigConvergencePhi-Alpha10.svg', dpi=220,bbox_inches='tight')
plt.savefig('FigConvergencePhi-Alpha10.pdf', dpi=220,bbox_inches='tight')


# Fig Time Convergence C

# ax.plot(a[0]*1e3,a[1],label='MTS dt 2',color='black',linewidth=3)
# ax.plot(a[0]*1e3,a[2],label='H2 dt 2',color='black',linewidth=3,linestyle='dotted')
# ax.plot(a[0]*1e3,a[3],label='HCl dt 2',color='black',linewidth=3,linestyle='dashed')

# ax.plot(b[0]*1e3,b[1],label='MTS dt 1',color='red',linewidth=3)
# ax.plot(b[0]*1e3,b[2],label='H2 dt 1',color='red',linewidth=3,linestyle='dotted')
# ax.plot(b[0]*1e3,b[3],label='HCl dt 1',color='red',linewidth=3,linestyle='dashed')

# ax.plot(c[0]*1e3,c[1],label='MTS dt 0.5',color='green',linewidth=3)
# ax.plot(c[0]*1e3,c[2],label='H2 dt 0.5',color='green',linewidth=3,linestyle='dotted')
# ax.plot(c[0]*1e3,c[3],label='HCl dt 0.5',color='green',linewidth=3,linestyle='dashed')

# ax.plot(a[0]*1e3,a[5],label='dt 2',color='black',linewidth=3)
# ax.plot(b[0]*1e3,b[5],label='dt 1',color='red',linewidth=3)
# ax.plot(c[0]*1e3,c[5],label='dt 0.5',color='green',linewidth=3)
# ax.plot(d[0]*1e3,d[5],label='dt 0.25',color='blue',linewidth=3)

# ax.plot(np.linspace(0,a[-1][-1],len(a[-2])),a[-2],label='0.918 eV mean',color='black',linewidth=3)
# ax.plot(b[0]*1e3,b[5],label='1073K',color='red',linewidth=3)
# plt.ylim([0,2])
# plt.xlim([0,5])
# plt.yticks(np.arange(0, 60, step=10))
# ax.set_xlabel('z mm')
# ax.set_ylabel(r'$C_i$')
# ax.set_title(r'$\xi_0 = 0.30, \ \alpha=10$') 
# ax.grid(True)
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# plt.savefig('FigConvergenceC-Alpha10.svg', dpi=220,bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 fig, ax = plt.subplots(figsize = (5,2.7), layout='constrained')
#       2 # a[-1]=a[-1]*3600
#       3 # ax.plot(np.linspace(0,5,5),np.ones(5)*0.3,color='black',linestyle='--',label='Initial')
#       4 ax.plot(a[0]*1e3,a[5]*1e6,label='dt 2',color='black',linewidth=3)
#
# NameError: name 'plt' is not defined

# %%
# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(a[-1],a[-2],label='K='+str(round(a[-5],6)))
# # ax.plot(b[-1],b[-2],label='9.85')

# ax.set_xlabel('t s')
# ax.set_ylabel('$r_p$ $\mu$m')
# # plt.xlim([0,1000])
# # plt.xticks(np.arange(0, 6, step=1))
# # plt.ylim([0,50])
# # plt.yticks(np.arange(0, (50 + 50/5), step=50/5))
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('dP.svg', dpi=220,bbox_inches='tight')

# %%
# c = cvi_nonlinear(1223,2000,34e-6, 10e-3/34e-6, 5, "blue",r"$1273$K, $dt = 1$s",100,"phi")
# b = cvi_nonlinear(1223,10000,34e-6, 10e-3/34e-6, 5, "blue",r"$1273$K, $dt = 1$s",10,"phi")
# a = cvi_nonlinear(1223,20000,34e-6, 10e-3/34e-6, 5, "blue",r"$1273$K, $dt = 1$s",10,"phi")

# %%
#P comparison

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# arr_10kpa_x = np.array([0.89,1.48,1.89,2.89,3.08,5.68])
# arr_10kpa_y = np.array([0.92,6.98,9.98,13.01,13.49,15.76])

# arr_2kpa_x = np.array([0.41, 2.38, 3.28, 4.39, 4.99])
# arr_2kpa_y = np.array([0.76, 14.68, 16, 16.7,16.92])

# arr_10kpa_x = arr_10kpa_x - arr_10kpa_x[0]
# arr_2kpa_x = arr_2kpa_x - arr_2kpa_x[0]
# arr_10kpa_y = 17 - (arr_10kpa_y - arr_10kpa_y[0])
# arr_2kpa_y = 17 - (arr_2kpa_y - arr_2kpa_y[0])

# # ax.plot(b[0]*1000,a[5]*1e6,label=r'20kPa',color='blue')
# ax.plot(b[0]*1000,b[5]*1e6,label=r'10kPa, calc',color='green')
# ax.scatter(arr_10kpa_x, arr_10kpa_y,color='green',label='10kPa, exp',marker=matplotlib.markers.CARETUPBASE)
# ax.plot(c[0]*1000,c[5]*1e6,label=r'2kPa, calc',color='red')
# ax.scatter(arr_2kpa_x, arr_2kpa_y,color='red',label='2kPa, exp',marker=matplotlib.markers.CARETDOWNBASE)

# ax.set_xlabel('z mm')
# ax.set_ylabel('$d$ $\mu$m')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([0,17])
# plt.yticks(np.arange(0, (17 + 17/5), step=17/5))
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('dP.svg', dpi=220,bbox_inches='tight')

# %%
# llp = cvi_nonlinear(1173,5000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# lp = cvi_nonlinear(1173,10000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# n = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",500,"phi")

# %%
# hp = cvi_nonlinear(1173,35000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# %%
# hhp = cvi_nonlinear(1173,50000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",200,"phi")

# %%
# b = cvi_nonlinear(1123,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")

# %%
# c = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",500,"phi")

# %%
# d = cvi_nonlinear(1223,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# %%
# e = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",50,"phi")

# %%
# f = cvi_nonlinear(1283,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",40,"phi")

# %%
# g= cvi_nonlinear(1293,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",30,"phi")

# %%
# h= cvi_nonlinear(1303,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",25,"phi")

# %%
# fig, ax = plt.subplots(figsize = (7,3), layout='constrained')

# tp_t = np.array([1073, 1173, 1173, 1173, 1173, 1173, 1273])
# tp_p = np.array([20, 5, 10, 20, 35, 50, 20])
# tp_tf = np.array([358.33, 92.22, 46.11, str(23.06)+' hrs', 13.67, 9.22, 2.31])

# ax.scatter(tp_t, tp_p,color='red')
# for i, txt in enumerate(tp_tf):
#     ax.annotate(txt, (tp_t[i],tp_p[i]),fontsize=13)

# ax.set_xlabel('$T$ K')
# ax.set_ylabel('$P$ kPa')
# plt.xlim([1073-27,1300])
# plt.xticks(np.arange(1073, 1373, step=100))
# plt.ylim([0,60])
# plt.yticks(np.arange(0, 60, step=10))
# plt.title(r'$t_f$ vs. {$T,P$}')
# # plt.legend(bbox_to_anchor=(1.05, 1.1), loc="upper left")
# ax.grid(True)

# plt.savefig('pt.svg', dpi=220,bbox_inches='tight')

# %%
# i= cvi_nonlinear(1313,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",5,"phi")

# %%
#T comparison

# c = cvi_nonlinear(1073,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",10000,"phi")
# b = cvi_nonlinear(1173,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1000,"phi")
# a = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",1,"phi")

# %%
# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# arr_10kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_10kpa_y = np.array([2.62, 3.38, 3.88, 4.05, 4.22, 4.31])

# arr_11kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_11kpa_y = np.array([2.62, 7.43, 11.06, 13.26, 14.19, 14.70])

# arr_12kpa_x = np.array([1.01, 2.02, 3.02, 4.01, 5.02, 6.01])
# arr_12kpa_y = np.array([2.62, 18.66, 28.88, 33.78, 36.57, 37.33])

# arr_10kpa_x = arr_10kpa_x - arr_10kpa_x[0]
# arr_11kpa_x = arr_11kpa_x - arr_11kpa_x[0]
# arr_12kpa_x = arr_12kpa_x - arr_12kpa_x[0]

# arr_10kpa_y = 50 - (arr_10kpa_y - arr_10kpa_y[0])
# arr_11kpa_y = 50 - (arr_11kpa_y - arr_11kpa_y[0])
# arr_12kpa_y = 50 - (arr_12kpa_y - arr_12kpa_y[0])
# # ax.plot(b[0]*1000,c[5]*1e6,label=r'1073K',color='blue')
# # ax.scatter(arr_10kpa_x, arr_10kpa_y,color='blue',label='1073K, exp',marker=matplotlib.markers.CARETDOWNBASE)
# # ax.plot(b[0]*1000,b[5]*1e6,label=r'1173K',color='green')
# # ax.scatter(arr_11kpa_x, arr_11kpa_y,color='green',label='1173K, exp',marker='X')
# ax.plot(a[0]*1000,a[5]*1e6,label=r'1273K',color='red')
# ax.scatter(arr_12kpa_x, arr_12kpa_y,color='red',label='1273K, exp',marker=matplotlib.markers.CARETUPBASE)




# ax.set_xlabel('z mm')
# ax.set_ylabel('$d$ $\mu$m')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([0,50])
# plt.yticks(np.arange(0, 60, step=10))
# plt.legend(bbox_to_anchor=(1.05, 1.1), loc="upper left")
# ax.grid(True)

# plt.savefig('dT.svg', dpi=220,bbox_inches='tight')

# %%
#alpha comparison

# c = cvi_nonlinear(1273,20000,100e-6, 100, 100, "blue",r"$1273$K, $dt = 1$s",1000,"phi")
# b = cvi_nonlinear(1273,20000,100e-6, 100, 10, "blue",r"$1273$K, $dt = 1$s",100,"phi")

# a = cvi_nonlinear(1273,20000,100e-6, 100, 1, "blue",r"$1273$K, $dt = 1$s",10,"phi")

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(a[0]*1000,a[1],label=r'MTS',color='red')
# ax.plot(a[0]*1000,a[2],label=r'H2',color='blue')
# ax.plot(a[0]*1000,a[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.title(r'$\alpha=1$')
# plt.ylim([0,1.5])
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha1.svg', dpi=220,bbox_inches='tight')


# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(b[0]*1000,b[1],label=r'MTS',color='red')
# ax.plot(b[0]*1000,b[2],label=r'H2',color='blue')
# ax.plot(b[0]*1000,b[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.title(r'$\alpha=10$')
# plt.ylim([-0.2,2])
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha10.svg', dpi=220,bbox_inches='tight')

# fig, ax = plt.subplots(figsize = (7,2.7), layout='constrained')

# ax.plot(c[0]*1000,c[1],label=r'MTS',color='red')
# ax.plot(c[0]*1000,c[2],label=r'H2',color='blue')
# ax.plot(c[0]*1000,c[3],label=r'HCl',color='green')
# ax.set_xlabel('z mm')
# ax.set_ylabel('$C_i$ mol/m$^3$')
# plt.xlim([0,5])
# plt.xticks(np.arange(0, 6, step=1))
# plt.ylim([-0.2,2])
# plt.title(r'$\alpha=100$')
# plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# ax.grid(True)

# plt.savefig('alpha100.svg', dpi=220,bbox_inches='tight')
